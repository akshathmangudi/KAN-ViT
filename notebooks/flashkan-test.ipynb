# %%
# !pip install monai
# !pip install einops
# Out:
# Collecting monai
#   Downloading monai-1.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai) (2.1.2)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Downloading monai-1.3.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.2 MB/s eta 0:00:00 0:00:01
# Installing collected packages: monai
# Successfully installed monai-1.3.2
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.8.0

# %%
from einops import rearrange
from pathlib import Path
import math
import numpy
import torch
from torch import nn, einsum
from functools import partial
from torch.autograd.function import Function
import numpy as np
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
# Uncomment this line for MNIST training.
from torchvision.datasets.mnist import MNIST
from torchvision import transforms
from tqdm import tqdm, trange
from torch.optim import Adam
from torch.jit import fork, wait
from torch.cuda.amp import autocast, GradScaler
from torch.nn import DataParallel
import torch.nn.functional as F

np.random.seed(42)
torch.manual_seed(42)
EPSILON = 1e-10

# %%
class FlashAttentionFunction(Function):
    @staticmethod
    @torch.no_grad()
    def forward(ctx, q, k, v, mask, causal, q_bucket_size, k_bucket_size):
        """ Algorithm 1 in the v2 paper """

        device = q.device
        max_neg_value = -torch.finfo(q.dtype).max
        qk_len_diff = max(k.shape[-2] - q.shape[-2], 0)

        o = torch.zeros_like(q)
        all_row_sums = torch.zeros((*q.shape[:-1], 1), device = device)
        all_row_maxes = torch.full((*q.shape[:-1], 1), max_neg_value, device = device)

        scale = (q.shape[-1] ** -0.5)

        num_row_tiles = math.ceil(q.shape[-2] / q_bucket_size)
        num_col_tiles = math.ceil(k.shape[-2] / k_bucket_size)

        if exists(mask) and mask.ndim == 2:
            mask = rearrange(mask, 'b n -> b 1 1 n')

        if not exists(mask):
            col_masks = (None,) * num_col_tiles
            mask = (col_masks,) * num_row_tiles 
        else:
            mask = ((mask,) * num_row_tiles) if mask.shape[-2] == 1 else mask.split(q_bucket_size, dim = -2)
            mask = tuple(((row_mask,) * num_col_tiles) if row_mask.shape[-1] == 1 else row_mask.split(k_bucket_size, dim = -1) for row_mask in mask)

        row_splits = zip(
            q.split(q_bucket_size, dim = -2),
            o.split(q_bucket_size, dim = -2),
            mask,
            all_row_sums.split(q_bucket_size, dim = -2),
            all_row_maxes.split(q_bucket_size, dim = -2),
        )

        for ind, (qc, oc, row_mask, row_sums, row_maxes) in enumerate(row_splits):
            q_start_index = ind * q_bucket_size - qk_len_diff

            col_splits = zip(
                k.split(k_bucket_size, dim = -2),
                v.split(k_bucket_size, dim = -2),
                row_mask
            )

            for k_ind, (kc, vc, col_mask) in enumerate(col_splits):
                k_start_index = k_ind * k_bucket_size

                attn_weights = einsum('... i d, ... j d -> ... i j', qc, kc) * scale

                if exists(col_mask):
                    attn_weights.masked_fill_(~col_mask, max_neg_value)

                if causal and q_start_index < (k_start_index + k_bucket_size - 1):
                    causal_mask = torch.ones((qc.shape[-2], kc.shape[-2]), dtype = torch.bool, device = device).triu(q_start_index - k_start_index + 1)
                    attn_weights.masked_fill_(causal_mask, max_neg_value)

                block_row_maxes = attn_weights.amax(dim = -1, keepdims = True)
                new_row_maxes = torch.maximum(block_row_maxes, row_maxes)

                exp_weights = torch.exp(attn_weights - new_row_maxes)

                if exists(col_mask):
                    exp_weights.masked_fill_(~col_mask, 0.)

                block_row_sums = exp_weights.sum(dim = -1, keepdims = True).clamp(min = EPSILON)

                exp_values = einsum('... i j, ... j d -> ... i d', exp_weights, vc)

                exp_row_max_diff = torch.exp(row_maxes - new_row_maxes)

                new_row_sums = exp_row_max_diff * row_sums + block_row_sums

                oc.mul_(exp_row_max_diff).add_(exp_values)

                row_maxes.copy_(new_row_maxes)
                row_sums.copy_(new_row_sums)

            oc.div_(row_sums)

        lse = all_row_sums.log() + all_row_maxes

        ctx.args = (causal, scale, mask, q_bucket_size, k_bucket_size)
        ctx.save_for_backward(q, k, v, o, lse)

        return o

    @staticmethod
    @torch.no_grad()
    def backward(ctx, do):
        """ Algorithm 2 in the v2 paper """

        causal, scale, mask, q_bucket_size, k_bucket_size = ctx.args
        q, k, v, o, lse = ctx.saved_tensors

        device = q.device

        max_neg_value = -torch.finfo(q.dtype).max
        qk_len_diff = max(k.shape[-2] - q.shape[-2], 0)

        dq = torch.zeros_like(q)
        dk = torch.zeros_like(k)
        dv = torch.zeros_like(v)

        row_splits = zip(
            q.split(q_bucket_size, dim = -2),
            o.split(q_bucket_size, dim = -2),
            do.split(q_bucket_size, dim = -2),
            mask,
            lse.split(q_bucket_size, dim = -2),
            dq.split(q_bucket_size, dim = -2)
        )

        for ind, (qc, oc, doc, row_mask, lsec, dqc) in enumerate(row_splits):
            q_start_index = ind * q_bucket_size - qk_len_diff

            col_splits = zip(
                k.split(k_bucket_size, dim = -2),
                v.split(k_bucket_size, dim = -2),
                dk.split(k_bucket_size, dim = -2),
                dv.split(k_bucket_size, dim = -2),
                row_mask
            )

            for k_ind, (kc, vc, dkc, dvc, col_mask) in enumerate(col_splits):
                k_start_index = k_ind * k_bucket_size

                attn_weights = einsum('... i d, ... j d -> ... i j', qc, kc) * scale

                if causal and q_start_index < (k_start_index + k_bucket_size - 1):
                    causal_mask = torch.ones((qc.shape[-2], kc.shape[-2]), dtype = torch.bool, device = device).triu(q_start_index - k_start_index + 1)
                    attn_weights.masked_fill_(causal_mask, max_neg_value)

                p = torch.exp(attn_weights - lsec)

                if exists(col_mask):
                    p.masked_fill_(~col_mask, 0.)

                dv_chunk = einsum('... i j, ... i d -> ... j d', p, doc)
                dp = einsum('... i d, ... j d -> ... i j', doc, vc)

                D = (doc * oc).sum(dim = -1, keepdims = True)
                ds = p * scale * (dp - D)

                dq_chunk = einsum('... i j, ... j d -> ... i d', ds, kc)
                dk_chunk = einsum('... i j, ... i d -> ... j d', ds, qc)

                dqc.add_(dq_chunk)
                dkc.add_(dk_chunk)
                dvc.add_(dv_chunk)

        return dq, dk, dv, None, None, None, None

# %%
class KANLinear(torch.nn.Module):
    def __init__(
        self,
        in_features,
        out_features,
        grid_size=5,
        spline_order=3,
        scale_noise=0.1,
        scale_base=1.0,
        scale_spline=1.0,
        enable_standalone_scale_spline=True,
        base_activation=torch.nn.SiLU,
        grid_eps=0.02,
        grid_range=[-1, 1],
    ):
        super(KANLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.grid_size = grid_size
        self.spline_order = spline_order

        h = (grid_range[1] - grid_range[0]) / grid_size
        grid = (
            (
                torch.arange(-spline_order, grid_size + spline_order + 1) * h
                + grid_range[0]
            )
            .expand(in_features, -1)
            .contiguous()
        )
        self.register_buffer("grid", grid)

        self.base_weight = torch.nn.Parameter(torch.Tensor(out_features, in_features))
        self.spline_weight = torch.nn.Parameter(
            torch.Tensor(out_features, in_features, grid_size + spline_order)
        )
        if enable_standalone_scale_spline:
            self.spline_scaler = torch.nn.Parameter(
                torch.Tensor(out_features, in_features)
            )

        self.scale_noise = scale_noise
        self.scale_base = scale_base
        self.scale_spline = scale_spline
        self.enable_standalone_scale_spline = enable_standalone_scale_spline
        self.base_activation = base_activation()
        self.grid_eps = grid_eps

        self.reset_parameters()

    def reset_parameters(self):
        torch.nn.init.kaiming_uniform_(self.base_weight, a=math.sqrt(5) * self.scale_base)
        with torch.no_grad():
            noise = (
                (
                    torch.rand(self.grid_size + 1, self.in_features, self.out_features)
                    - 1 / 2
                )
                * self.scale_noise
                / self.grid_size
            )
            self.spline_weight.data.copy_(
                (self.scale_spline if not self.enable_standalone_scale_spline else 1.0)
                * self.curve2coeff(
                    self.grid.T[self.spline_order : -self.spline_order],
                    noise,
                )
            )
            if self.enable_standalone_scale_spline:
                # torch.nn.init.constant_(self.spline_scaler, self.scale_spline)
                torch.nn.init.kaiming_uniform_(self.spline_scaler, a=math.sqrt(5) * self.scale_spline)

    def b_splines(self, x: torch.Tensor):
        """
        Compute the B-spline bases for the given input tensor.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_features).

        Returns:
            torch.Tensor: B-spline bases tensor of shape (batch_size, in_features, grid_size + spline_order).
        """
        assert x.dim() == 2 and x.size(1) == self.in_features

        grid: torch.Tensor = (
            self.grid
        )  # (in_features, grid_size + 2 * spline_order + 1)
        x = x.unsqueeze(-1)
        bases = ((x >= grid[:, :-1]) & (x < grid[:, 1:])).to(x.dtype)
        for k in range(1, self.spline_order + 1):
            bases = (
                (x - grid[:, : -(k + 1)])
                / (grid[:, k:-1] - grid[:, : -(k + 1)])
                * bases[:, :, :-1]
            ) + (
                (grid[:, k + 1 :] - x)
                / (grid[:, k + 1 :] - grid[:, 1:(-k)])
                * bases[:, :, 1:]
            )

        assert bases.size() == (
            x.size(0),
            self.in_features,
            self.grid_size + self.spline_order,
        )
        return bases.contiguous()

    def curve2coeff(self, x: torch.Tensor, y: torch.Tensor):
        """
        Compute the coefficients of the curve that interpolates the given points.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_features).
            y (torch.Tensor): Output tensor of shape (batch_size, in_features, out_features).

        Returns:
            torch.Tensor: Coefficients tensor of shape (out_features, in_features, grid_size + spline_order).
        """
        assert x.dim() == 2 and x.size(1) == self.in_features
        assert y.size() == (x.size(0), self.in_features, self.out_features)

        A = self.b_splines(x).transpose(
            0, 1
        )  # (in_features, batch_size, grid_size + spline_order)
        B = y.transpose(0, 1)  # (in_features, batch_size, out_features)
        solution = torch.linalg.lstsq(
            A, B
        ).solution  # (in_features, grid_size + spline_order, out_features)
        result = solution.permute(
            2, 0, 1
        )  # (out_features, in_features, grid_size + spline_order)

        assert result.size() == (
            self.out_features,
            self.in_features,
            self.grid_size + self.spline_order,
        )
        return result.contiguous()

    @property
    def scaled_spline_weight(self):
        return self.spline_weight * (
            self.spline_scaler.unsqueeze(-1)
            if self.enable_standalone_scale_spline
            else 1.0
        )

    def forward(self, x: torch.Tensor):
        assert x.size(-1) == self.in_features
        original_shape = x.shape
        x = x.reshape(-1, self.in_features)

        base_output = F.linear(self.base_activation(x), self.base_weight)
        spline_output = F.linear(
            self.b_splines(x).view(x.size(0), -1),
            self.scaled_spline_weight.view(self.out_features, -1),
        )
        output = base_output + spline_output
        
        output = output.reshape(*original_shape[:-1], self.out_features)
        return output

    @torch.no_grad()
    def update_grid(self, x: torch.Tensor, margin=0.01):
        assert x.dim() == 2 and x.size(1) == self.in_features
        batch = x.size(0)

        splines = self.b_splines(x)  # (batch, in, coeff)
        splines = splines.permute(1, 0, 2)  # (in, batch, coeff)
        orig_coeff = self.scaled_spline_weight  # (out, in, coeff)
        orig_coeff = orig_coeff.permute(1, 2, 0)  # (in, coeff, out)
        unreduced_spline_output = torch.bmm(splines, orig_coeff)  # (in, batch, out)
        unreduced_spline_output = unreduced_spline_output.permute(
            1, 0, 2
        )  # (batch, in, out)

        # sort each channel individually to collect data distribution
        x_sorted = torch.sort(x, dim=0)[0]
        grid_adaptive = x_sorted[
            torch.linspace(
                0, batch - 1, self.grid_size + 1, dtype=torch.int64, device=x.device
            )
        ]

        uniform_step = (x_sorted[-1] - x_sorted[0] + 2 * margin) / self.grid_size
        grid_uniform = (
            torch.arange(
                self.grid_size + 1, dtype=torch.float32, device=x.device
            ).unsqueeze(1)
            * uniform_step
            + x_sorted[0]
            - margin
        )

        grid = self.grid_eps * grid_uniform + (1 - self.grid_eps) * grid_adaptive
        grid = torch.concatenate(
            [
                grid[:1]
                - uniform_step
                * torch.arange(self.spline_order, 0, -1, device=x.device).unsqueeze(1),
                grid,
                grid[-1:]
                + uniform_step
                * torch.arange(1, self.spline_order + 1, device=x.device).unsqueeze(1),
            ],
            dim=0,
        )

        self.grid.copy_(grid.T)
        self.spline_weight.data.copy_(self.curve2coeff(x, unreduced_spline_output))

    def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
        """
        Compute the regularization loss.

        This is a dumb simulation of the original L1 regularization as stated in the
        paper, since the original one requires computing absolutes and entropy from the
        expanded (batch, in_features, out_features) intermediate tensor, which is hidden
        behind the F.linear function if we want an memory efficient implementation.

        The L1 regularization is now computed as mean absolute value of the spline
        weights. The authors implementation also includes this term in addition to the
        sample-based regularization.
        """
        l1_fake = self.spline_weight.abs().mean(-1)
        regularization_loss_activation = l1_fake.sum()
        p = l1_fake / regularization_loss_activation
        regularization_loss_entropy = -torch.sum(p * p.log())
        return (
            regularize_activation * regularization_loss_activation
            + regularize_entropy * regularization_loss_entropy
        )

# %%
# helper functions

def exists(val):
    return val is not None

def default(val, d):
    return val if exists(val) else d

# flash attention forwards and backwards

# flash attention v1 - https://arxiv.org/abs/2205.14135
# flash attention v2 - https://tridao.me/publications/flash2/flash2.pdf


# main class

# just flash attention in plain pytorch
# it will be way slower than implementing it in CUDA
# for tinkering and educational purposes


class KANFlashAttention(nn.Module):
    def __init__(
        self,
        *,
        dim,
        heads = 8,
        dim_head = 64,
        causal = False,
        q_bucket_size = 512,
        k_bucket_size = 1024,
        parallel = False,
        mixed_precision = False
    ):
        super().__init__()
        self.heads = heads
        self.causal = causal
        self.parallel = parallel
        self.mixed_precision = mixed_precision

        inner_dim = heads * dim_head

        self.to_q = KANLinear(dim, inner_dim)
        self.to_kv = KANLinear(dim, inner_dim * 2)
        self.to_out = KANLinear(inner_dim, dim)

        # memory efficient attention related parameters
        # can be overriden on forward
        self.q_bucket_size = q_bucket_size
        self.k_bucket_size = k_bucket_size

        if self.parallel:
            self.model = DataParallel(self)
        if self.mixed_precision:
            self.scaler = GradScaler()

    def forward(
        self,
        x,
        context = None,
        mask = None,
        q_bucket_size = None,
        k_bucket_size = None,
    ):
        q_bucket_size = default(q_bucket_size, self.q_bucket_size)
        k_bucket_size = default(k_bucket_size, self.k_bucket_size)

        h = self.heads
        context = default(context, x)

        q = self.to_q(x)
        k, v = self.to_kv(context).chunk(2, dim=-1)

        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h=h), (q, k, v))

        if self.parallel:
            # Split the input data into chunks and move each chunk to the correct GPU
            num_gpus = torch.cuda.device_count()
            x_chunks = x.split(x.size(0) // num_gpus)
            x_chunks = [chunk.to(f'cuda:{i}') for i, chunk in enumerate(x_chunks)]
            q = x_chunks

        if self.mixed_precision:
            # Use autocast to allow operations to run in lower precision
            with autocast():
                out = FlashAttentionFunction.apply(q, k, v, mask, self.causal, q_bucket_size, k_bucket_size)
        else:
            out = FlashAttentionFunction.apply(q, k, v, mask, self.causal, q_bucket_size, k_bucket_size)

        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

# %%
def patchify(images, n_patches): 
    """
    The purpose of this function is to break down the main image into multiple sub-images and map them. 

    Args:
        images (_type_): The image passeed into this function. 
        n_patches (_type_): The number of sub-images that will be created.
    """
    
    n, c, h, w = images.shape
    assert h == w, "Only for square images"
    
    patches = torch.zeros(n, n_patches**2, h * w * c // n_patches ** 2) # The equation to calculate the patches
    patch_size = h // n_patches
    
    for idx, image in enumerate(images):
        for i in range(n_patches): 
            for j in range(n_patches): 
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches

def positional_embeddings(seq_length, d): 
    """
    the purpose of this function is to find high and low interaction of a word with surrounding words. 
    We can do so by the following equation below: 
    
    Args: 
        seq_length (int): The length of the sequence/sentence
        d (int): The dimension of the embedding
    """
    
    result = torch.ones(seq_length, d)
    for i in range(seq_length): 
        for j in range(d): 
            result[i][j] = numpy.sin(i / 10000 ** (j / d)) if j % 2 == 0 else numpy.cos(i / 10000 ** (j/ d))
    return result


class FlashKAN_ViT(torch.nn.Module): 
    """
        Initializes a Vision Transformer (ViT) module.

        Args:
            chw (list/tuple of 3 ints): The input image shape.
            n_patches (int, optional): The number of patches to split the image into. Defaults to 10.
            n_blocks (int, optional): The number of blocks in the transformer encoder. Defaults to 2.
            d_hidden (int, optional): The number of hidden dimensions in the transformer encoder. Defaults to 8.
            n_heads (int, optional): The number of attention heads in each block. Defaults to 2.
            out_d (int, optional): The number of output dimensions. Defaults to 10.

        Returns:
            None
    """    
    def __init__(self, chw, n_patches=10, n_blocks=2, d_hidden=8, n_heads=2, out_d=10): 
        super(FlashKAN_ViT, self).__init__()
        
        self.chw = chw
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.d_hidden = d_hidden
        
        assert chw[1] % n_patches == 0 
        assert chw[2] % n_patches == 0
        
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # Linear mapping
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = KANLinear(self.input_d, self.d_hidden)

        # Classification token
        self.v_class = torch.nn.Parameter(torch.rand(1, self.d_hidden))

        # Positional embedding
        self.register_buffer('positional_embeddings', positional_embeddings(n_patches ** 2 + 1, d_hidden),
                             persistent=False)

        # Encoder blocks
        self.blocks = torch.nn.ModuleList([KANFlashAttention(dim = d_hidden, heads = n_heads) for _ in range(n_blocks)])

        self.mlp = torch.nn.Sequential(
            KANLinear(self.d_hidden, out_d),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, images):
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)

        # running tokenization
        tokens = self.linear_mapper(patches)
        tokens = torch.cat((self.v_class.expand(n, 1, -1), tokens), dim=1)
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        for block in self.blocks:
            out = block(out)

        out = out[:, 0]
        return self.mlp(out)

# %%
from torch.optim import Adam
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mnist_model = FlashKAN_ViT((1, 28, 28), n_patches=7, n_blocks=2, d_hidden=8, n_heads=2, out_d=10).to(device)
optimizer = Adam(mnist_model.parameters(), lr=0.005)

# %%
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST
from tqdm import tqdm, trange

def main(train_loader, test_loader):
    """
    This code contains the training and testing loop for training the vision transformers model. It requires two
    parameters

    :param train_loader: The dataloader for the training set for training the model.
    :param test_loader: The dataloader for the testing set during evaluation phase.
    """
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    epochs = 8
    criterion = torch.nn.CrossEntropyLoss()
    for epoch in trange(epochs, desc="train"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch + 1}/{epochs} loss: {train_loss:.2f}")

    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
transform = transforms.ToTensor()
train_mnist = MNIST(root='./mnist', train=True, download=True, transform=transform)
test_mnist = MNIST(root='./mnist', train=False, download=True, transform=transform)
train_loader = DataLoader(train_mnist, shuffle=True, batch_size=128)
test_loader = DataLoader(test_mnist, shuffle=False, batch_size=128)
main(train_loader=train_loader, test_loader=test_loader)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 6027097.96it/s]
# Extracting ./mnist/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 158719.53it/s]
# Extracting ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1294026.58it/s]
# Extracting ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2346413.20it/s]
# Extracting ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Using device:  cuda (Tesla P100-PCIE-16GB)
# train:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:00<07:20,  1.06it/s]
# Epoch 1 in training:   0%|          | 2/469 [00:01<04:32,  1.71it/s]
# Epoch 1 in training:   1%|          | 3/469 [00:01<03:39,  2.13it/s]
# Epoch 1 in training:   1%|          | 4/469 [00:01<03:13,  2.40it/s]
# Epoch 1 in training:   1%|          | 5/469 [00:02<03:02,  2.54it/s]
# Epoch 1 in training:   1%|▏         | 6/469 [00:02<02:54,  2.65it/s]
# Epoch 1 in training:   1%|▏         | 7/469 [00:02<02:48,  2.74it/s]
# Epoch 1 in training:   2%|▏         | 8/469 [00:03<02:43,  2.82it/s]
# Epoch 1 in training:   2%|▏         | 9/469 [00:03<02:41,  2.86it/s]
# Epoch 1 in training:   2%|▏         | 10/469 [00:04<02:40,  2.86it/s]
# Epoch 1 in training:   2%|▏         | 11/469 [00:04<02:38,  2.90it/s]
# Epoch 1 in training:   3%|▎         | 12/469 [00:04<02:36,  2.92it/s]
# Epoch 1 in training:   3%|▎         | 13/469 [00:05<02:34,  2.94it/s]
# Epoch 1 in training:   3%|▎         | 14/469 [00:05<02:33,  2.96it/s]
# Epoch 1 in training:   3%|▎         | 15/469 [00:05<02:32,  2.97it/s]
# Epoch 1 in training:   3%|▎         | 16/469 [00:06<02:31,  2.98it/s]
# Epoch 1 in training:   4%|▎         | 17/469 [00:06<02:31,  2.98it/s]
# Epoch 1 in training:   4%|▍         | 18/469 [00:06<02:31,  2.97it/s]
# Epoch 1 in training:   4%|▍         | 19/469 [00:07<02:32,  2.96it/s]
# Epoch 1 in training:   4%|▍         | 20/469 [00:07<02:32,  2.95it/s]
# Epoch 1 in training:   4%|▍         | 21/469 [00:07<02:31,  2.96it/s]
# Epoch 1 in training:   5%|▍         | 22/469 [00:08<02:30,  2.97it/s]
# Epoch 1 in training:   5%|▍         | 23/469 [00:08<02:30,  2.97it/s]
# Epoch 1 in training:   5%|▌         | 24/469 [00:08<02:29,  2.97it/s]
# Epoch 1 in training:   5%|▌         | 25/469 [00:09<02:29,  2.96it/s]
# Epoch 1 in training:   6%|▌         | 26/469 [00:09<02:29,  2.97it/s]
# Epoch 1 in training:   6%|▌         | 27/469 [00:09<02:28,  2.97it/s]
# Epoch 1 in training:   6%|▌         | 28/469 [00:10<02:28,  2.97it/s]
# Epoch 1 in training:   6%|▌         | 29/469 [00:10<02:27,  2.97it/s]
# Epoch 1 in training:   6%|▋         | 30/469 [00:10<02:27,  2.97it/s]
# Epoch 1 in training:   7%|▋         | 31/469 [00:11<02:28,  2.95it/s]
# Epoch 1 in training:   7%|▋         | 32/469 [00:11<02:27,  2.96it/s]
# Epoch 1 in training:   7%|▋         | 33/469 [00:11<02:27,  2.96it/s]
# Epoch 1 in training:   7%|▋         | 34/469 [00:12<02:27,  2.96it/s]
# Epoch 1 in training:   7%|▋         | 35/469 [00:12<02:29,  2.89it/s]
# Epoch 1 in training:   8%|▊         | 36/469 [00:12<02:27,  2.93it/s]
# Epoch 1 in training:   8%|▊         | 37/469 [00:13<02:26,  2.94it/s]
# Epoch 1 in training:   8%|▊         | 38/469 [00:13<02:25,  2.95it/s]
# Epoch 1 in training:   8%|▊         | 39/469 [00:13<02:24,  2.97it/s]
# Epoch 1 in training:   9%|▊         | 40/469 [00:14<02:24,  2.97it/s]
# Epoch 1 in training:   9%|▊         | 41/469 [00:14<02:25,  2.95it/s]
# Epoch 1 in training:   9%|▉         | 42/469 [00:14<02:24,  2.96it/s]
# Epoch 1 in training:   9%|▉         | 43/469 [00:15<02:23,  2.97it/s]
# Epoch 1 in training:   9%|▉         | 44/469 [00:15<02:22,  2.97it/s]
# Epoch 1 in training:  10%|▉         | 45/469 [00:15<02:22,  2.98it/s]
# Epoch 1 in training:  10%|▉         | 46/469 [00:16<02:22,  2.98it/s]
# Epoch 1 in training:  10%|█         | 47/469 [00:16<02:21,  2.98it/s]
# Epoch 1 in training:  10%|█         | 48/469 [00:16<02:21,  2.98it/s]
# Epoch 1 in training:  10%|█         | 49/469 [00:17<02:21,  2.97it/s]
# Epoch 1 in training:  11%|█         | 50/469 [00:17<02:21,  2.97it/s]
# Epoch 1 in training:  11%|█         | 51/469 [00:17<02:20,  2.98it/s]
# Epoch 1 in training:  11%|█         | 52/469 [00:18<02:20,  2.97it/s]
# Epoch 1 in training:  11%|█▏        | 53/469 [00:18<02:20,  2.96it/s]
# Epoch 1 in training:  12%|█▏        | 54/469 [00:18<02:20,  2.96it/s]
# Epoch 1 in training:  12%|█▏        | 55/469 [00:19<02:21,  2.92it/s]
# Epoch 1 in training:  12%|█▏        | 56/469 [00:19<02:25,  2.84it/s]
# Epoch 1 in training:  12%|█▏        | 57/469 [00:19<02:23,  2.87it/s]
# Epoch 1 in training:  12%|█▏        | 58/469 [00:20<02:22,  2.88it/s]
# Epoch 1 in training:  13%|█▎        | 59/469 [00:20<02:21,  2.90it/s]
# Epoch 1 in training:  13%|█▎        | 60/469 [00:20<02:20,  2.92it/s]
# Epoch 1 in training:  13%|█▎        | 61/469 [00:21<02:19,  2.93it/s]
# Epoch 1 in training:  13%|█▎        | 62/469 [00:21<02:18,  2.94it/s]
# Epoch 1 in training:  13%|█▎        | 63/469 [00:21<02:18,  2.94it/s]
# Epoch 1 in training:  14%|█▎        | 64/469 [00:22<02:18,  2.92it/s]
# Epoch 1 in training:  14%|█▍        | 65/469 [00:22<02:19,  2.90it/s]
# Epoch 1 in training:  14%|█▍        | 66/469 [00:22<02:18,  2.92it/s]
# Epoch 1 in training:  14%|█▍        | 67/469 [00:23<02:16,  2.94it/s]
# Epoch 1 in training:  14%|█▍        | 68/469 [00:23<02:16,  2.94it/s]
# Epoch 1 in training:  15%|█▍        | 69/469 [00:24<02:17,  2.91it/s]
# Epoch 1 in training:  15%|█▍        | 70/469 [00:24<02:16,  2.93it/s]
# Epoch 1 in training:  15%|█▌        | 71/469 [00:24<02:15,  2.95it/s]
# Epoch 1 in training:  15%|█▌        | 72/469 [00:25<02:14,  2.96it/s]
# Epoch 1 in training:  16%|█▌        | 73/469 [00:25<02:14,  2.95it/s]
# Epoch 1 in training:  16%|█▌        | 74/469 [00:25<02:13,  2.95it/s]
# Epoch 1 in training:  16%|█▌        | 75/469 [00:26<02:13,  2.96it/s]
# Epoch 1 in training:  16%|█▌        | 76/469 [00:26<02:12,  2.96it/s]
# Epoch 1 in training:  16%|█▋        | 77/469 [00:26<02:12,  2.96it/s]
# Epoch 1 in training:  17%|█▋        | 78/469 [00:27<02:12,  2.96it/s]
# Epoch 1 in training:  17%|█▋        | 79/469 [00:27<02:11,  2.97it/s]
# Epoch 1 in training:  17%|█▋        | 80/469 [00:27<02:11,  2.97it/s]
# Epoch 1 in training:  17%|█▋        | 81/469 [00:28<02:13,  2.91it/s]
# Epoch 1 in training:  17%|█▋        | 82/469 [00:28<02:12,  2.92it/s]
# Epoch 1 in training:  18%|█▊        | 83/469 [00:28<02:11,  2.94it/s]
# Epoch 1 in training:  18%|█▊        | 84/469 [00:29<02:10,  2.94it/s]
# Epoch 1 in training:  18%|█▊        | 85/469 [00:29<02:10,  2.95it/s]
# Epoch 1 in training:  18%|█▊        | 86/469 [00:29<02:09,  2.95it/s]
# Epoch 1 in training:  19%|█▊        | 87/469 [00:30<02:09,  2.95it/s]
# Epoch 1 in training:  19%|█▉        | 88/469 [00:30<02:08,  2.96it/s]
# Epoch 1 in training:  19%|█▉        | 89/469 [00:30<02:08,  2.95it/s]
# Epoch 1 in training:  19%|█▉        | 90/469 [00:31<02:09,  2.93it/s]
# Epoch 1 in training:  19%|█▉        | 91/469 [00:31<02:08,  2.94it/s]
# Epoch 1 in training:  20%|█▉        | 92/469 [00:31<02:07,  2.95it/s]
# Epoch 1 in training:  20%|█▉        | 93/469 [00:32<02:07,  2.96it/s]
# Epoch 1 in training:  20%|██        | 94/469 [00:32<02:09,  2.89it/s]
# Epoch 1 in training:  20%|██        | 95/469 [00:32<02:08,  2.91it/s]
# Epoch 1 in training:  20%|██        | 96/469 [00:33<02:07,  2.93it/s]
# Epoch 1 in training:  21%|██        | 97/469 [00:33<02:06,  2.93it/s]
# Epoch 1 in training:  21%|██        | 98/469 [00:33<02:07,  2.92it/s]
# Epoch 1 in training:  21%|██        | 99/469 [00:34<02:07,  2.91it/s]
# Epoch 1 in training:  21%|██▏       | 100/469 [00:34<02:05,  2.93it/s]
# Epoch 1 in training:  22%|██▏       | 101/469 [00:34<02:04,  2.95it/s]
# Epoch 1 in training:  22%|██▏       | 102/469 [00:35<02:03,  2.96it/s]
# Epoch 1 in training:  22%|██▏       | 103/469 [00:35<02:03,  2.97it/s]
# Epoch 1 in training:  22%|██▏       | 104/469 [00:35<02:02,  2.97it/s]
# Epoch 1 in training:  22%|██▏       | 105/469 [00:36<02:02,  2.98it/s]
# Epoch 1 in training:  23%|██▎       | 106/469 [00:36<02:01,  2.98it/s]
# Epoch 1 in training:  23%|██▎       | 107/469 [00:36<02:01,  2.99it/s]
# Epoch 1 in training:  23%|██▎       | 108/469 [00:37<02:00,  2.99it/s]
# Epoch 1 in training:  23%|██▎       | 109/469 [00:37<02:00,  2.98it/s]
# Epoch 1 in training:  23%|██▎       | 110/469 [00:37<02:00,  2.98it/s]
# Epoch 1 in training:  24%|██▎       | 111/469 [00:38<02:00,  2.97it/s]
# Epoch 1 in training:  24%|██▍       | 112/469 [00:38<02:00,  2.96it/s]
# Epoch 1 in training:  24%|██▍       | 113/469 [00:38<01:59,  2.97it/s]
# Epoch 1 in training:  24%|██▍       | 114/469 [00:39<02:00,  2.95it/s]
# Epoch 1 in training:  25%|██▍       | 115/469 [00:39<02:00,  2.95it/s]
# Epoch 1 in training:  25%|██▍       | 116/469 [00:39<01:59,  2.95it/s]
# Epoch 1 in training:  25%|██▍       | 117/469 [00:40<01:58,  2.96it/s]
# Epoch 1 in training:  25%|██▌       | 118/469 [00:40<01:58,  2.96it/s]
# Epoch 1 in training:  25%|██▌       | 119/469 [00:40<01:58,  2.95it/s]
# Epoch 1 in training:  26%|██▌       | 120/469 [00:41<01:57,  2.96it/s]
# Epoch 1 in training:  26%|██▌       | 121/469 [00:41<01:58,  2.94it/s]
# Epoch 1 in training:  26%|██▌       | 122/469 [00:41<01:57,  2.95it/s]
# Epoch 1 in training:  26%|██▌       | 123/469 [00:42<01:59,  2.90it/s]
# Epoch 1 in training:  26%|██▋       | 124/469 [00:42<01:58,  2.90it/s]
# Epoch 1 in training:  27%|██▋       | 125/469 [00:42<01:57,  2.92it/s]
# Epoch 1 in training:  27%|██▋       | 126/469 [00:43<01:56,  2.93it/s]
# Epoch 1 in training:  27%|██▋       | 127/469 [00:43<01:56,  2.94it/s]
# Epoch 1 in training:  27%|██▋       | 128/469 [00:44<01:55,  2.94it/s]
# Epoch 1 in training:  28%|██▊       | 129/469 [00:44<01:55,  2.95it/s]
# Epoch 1 in training:  28%|██▊       | 130/469 [00:44<01:54,  2.96it/s]
# Epoch 1 in training:  28%|██▊       | 131/469 [00:45<01:54,  2.96it/s]
# Epoch 1 in training:  28%|██▊       | 132/469 [00:45<01:53,  2.97it/s]
# Epoch 1 in training:  28%|██▊       | 133/469 [00:45<01:53,  2.96it/s]
# Epoch 1 in training:  29%|██▊       | 134/469 [00:46<01:52,  2.97it/s]
# Epoch 1 in training:  29%|██▉       | 135/469 [00:46<01:52,  2.97it/s]
# Epoch 1 in training:  29%|██▉       | 136/469 [00:46<01:52,  2.96it/s]
# Epoch 1 in training:  29%|██▉       | 137/469 [00:47<01:52,  2.96it/s]
# Epoch 1 in training:  29%|██▉       | 138/469 [00:47<01:51,  2.96it/s]
# Epoch 1 in training:  30%|██▉       | 139/469 [00:47<01:51,  2.97it/s]
# Epoch 1 in training:  30%|██▉       | 140/469 [00:48<01:50,  2.98it/s]
# Epoch 1 in training:  30%|███       | 141/469 [00:48<01:49,  2.98it/s]
# Epoch 1 in training:  30%|███       | 142/469 [00:48<01:49,  2.98it/s]
# Epoch 1 in training:  30%|███       | 143/469 [00:49<01:49,  2.98it/s]
# Epoch 1 in training:  31%|███       | 144/469 [00:49<01:49,  2.97it/s]
# Epoch 1 in training:  31%|███       | 145/469 [00:49<01:49,  2.96it/s]
# Epoch 1 in training:  31%|███       | 146/469 [00:50<01:48,  2.97it/s]
# Epoch 1 in training:  31%|███▏      | 147/469 [00:50<01:48,  2.97it/s]
# Epoch 1 in training:  32%|███▏      | 148/469 [00:50<01:51,  2.87it/s]
# Epoch 1 in training:  32%|███▏      | 149/469 [00:51<01:55,  2.77it/s]
# Epoch 1 in training:  32%|███▏      | 150/469 [00:51<01:53,  2.80it/s]
# Epoch 1 in training:  32%|███▏      | 151/469 [00:51<01:52,  2.83it/s]
# Epoch 1 in training:  32%|███▏      | 152/469 [00:52<01:52,  2.81it/s]
# Epoch 1 in training:  33%|███▎      | 153/469 [00:52<01:52,  2.80it/s]
# Epoch 1 in training:  33%|███▎      | 154/469 [00:52<01:50,  2.84it/s]
# Epoch 1 in training:  33%|███▎      | 155/469 [00:53<01:49,  2.88it/s]
# Epoch 1 in training:  33%|███▎      | 156/469 [00:53<01:47,  2.90it/s]
# Epoch 1 in training:  33%|███▎      | 157/469 [00:53<01:46,  2.92it/s]
# Epoch 1 in training:  34%|███▎      | 158/469 [00:54<01:45,  2.93it/s]
# Epoch 1 in training:  34%|███▍      | 159/469 [00:54<01:45,  2.94it/s]
# Epoch 1 in training:  34%|███▍      | 160/469 [00:54<01:44,  2.94it/s]
# Epoch 1 in training:  34%|███▍      | 161/469 [00:55<01:44,  2.95it/s]
# Epoch 1 in training:  35%|███▍      | 162/469 [00:55<01:44,  2.95it/s]
# Epoch 1 in training:  35%|███▍      | 163/469 [00:55<01:43,  2.96it/s]
# Epoch 1 in training:  35%|███▍      | 164/469 [00:56<01:42,  2.96it/s]
# Epoch 1 in training:  35%|███▌      | 165/469 [00:56<01:43,  2.95it/s]
# Epoch 1 in training:  35%|███▌      | 166/469 [00:56<01:43,  2.93it/s]
# Epoch 1 in training:  36%|███▌      | 167/469 [00:57<01:42,  2.94it/s]
# Epoch 1 in training:  36%|███▌      | 168/469 [00:57<01:42,  2.94it/s]
# Epoch 1 in training:  36%|███▌      | 169/469 [00:58<01:41,  2.95it/s]
# Epoch 1 in training:  36%|███▌      | 170/469 [00:58<01:41,  2.95it/s]
# Epoch 1 in training:  36%|███▋      | 171/469 [00:58<01:41,  2.94it/s]
# Epoch 1 in training:  37%|███▋      | 172/469 [00:59<01:40,  2.94it/s]
# Epoch 1 in training:  37%|███▋      | 173/469 [00:59<01:40,  2.94it/s]
# Epoch 1 in training:  37%|███▋      | 174/469 [00:59<01:39,  2.95it/s]
# Epoch 1 in training:  37%|███▋      | 175/469 [01:00<01:39,  2.96it/s]
# Epoch 1 in training:  38%|███▊      | 176/469 [01:00<01:39,  2.96it/s]
# Epoch 1 in training:  38%|███▊      | 177/469 [01:00<01:38,  2.96it/s]
# Epoch 1 in training:  38%|███▊      | 178/469 [01:01<01:39,  2.93it/s]
# Epoch 1 in training:  38%|███▊      | 179/469 [01:01<01:38,  2.94it/s]
# Epoch 1 in training:  38%|███▊      | 180/469 [01:01<01:37,  2.95it/s]
# Epoch 1 in training:  39%|███▊      | 181/469 [01:02<01:36,  2.97it/s]
# Epoch 1 in training:  39%|███▉      | 182/469 [01:02<01:38,  2.90it/s]
# Epoch 1 in training:  39%|███▉      | 183/469 [01:02<01:38,  2.92it/s]
# Epoch 1 in training:  39%|███▉      | 184/469 [01:03<01:37,  2.94it/s]
# Epoch 1 in training:  39%|███▉      | 185/469 [01:03<01:36,  2.95it/s]
# Epoch 1 in training:  40%|███▉      | 186/469 [01:03<01:37,  2.90it/s]
# Epoch 1 in training:  40%|███▉      | 187/469 [01:04<01:36,  2.91it/s]
# Epoch 1 in training:  40%|████      | 188/469 [01:04<01:35,  2.93it/s]
# Epoch 1 in training:  40%|████      | 189/469 [01:04<01:35,  2.94it/s]
# Epoch 1 in training:  41%|████      | 190/469 [01:05<01:34,  2.95it/s]
# Epoch 1 in training:  41%|████      | 191/469 [01:05<01:33,  2.96it/s]
# Epoch 1 in training:  41%|████      | 192/469 [01:05<01:33,  2.97it/s]
# Epoch 1 in training:  41%|████      | 193/469 [01:06<01:32,  2.97it/s]
# Epoch 1 in training:  41%|████▏     | 194/469 [01:06<01:32,  2.98it/s]
# Epoch 1 in training:  42%|████▏     | 195/469 [01:06<01:32,  2.98it/s]
# Epoch 1 in training:  42%|████▏     | 196/469 [01:07<01:32,  2.95it/s]
# Epoch 1 in training:  42%|████▏     | 197/469 [01:07<01:32,  2.95it/s]
# Epoch 1 in training:  42%|████▏     | 198/469 [01:07<01:31,  2.95it/s]
# Epoch 1 in training:  42%|████▏     | 199/469 [01:08<01:31,  2.96it/s]
# Epoch 1 in training:  43%|████▎     | 200/469 [01:08<01:30,  2.97it/s]
# Epoch 1 in training:  43%|████▎     | 201/469 [01:08<01:30,  2.97it/s]
# Epoch 1 in training:  43%|████▎     | 202/469 [01:09<01:29,  2.97it/s]
# Epoch 1 in training:  43%|████▎     | 203/469 [01:09<01:29,  2.97it/s]
# Epoch 1 in training:  43%|████▎     | 204/469 [01:09<01:29,  2.97it/s]
# Epoch 1 in training:  44%|████▎     | 205/469 [01:10<01:28,  2.97it/s]
# Epoch 1 in training:  44%|████▍     | 206/469 [01:10<01:28,  2.98it/s]
# Epoch 1 in training:  44%|████▍     | 207/469 [01:10<01:27,  2.98it/s]
# Epoch 1 in training:  44%|████▍     | 208/469 [01:11<01:27,  2.99it/s]
# Epoch 1 in training:  45%|████▍     | 209/469 [01:11<01:27,  2.97it/s]
# Epoch 1 in training:  45%|████▍     | 210/469 [01:11<01:27,  2.96it/s]
# Epoch 1 in training:  45%|████▍     | 211/469 [01:12<01:27,  2.95it/s]
# Epoch 1 in training:  45%|████▌     | 212/469 [01:12<01:28,  2.89it/s]
# Epoch 1 in training:  45%|████▌     | 213/469 [01:12<01:27,  2.92it/s]
# Epoch 1 in training:  46%|████▌     | 214/469 [01:13<01:26,  2.94it/s]
# Epoch 1 in training:  46%|████▌     | 215/469 [01:13<01:26,  2.95it/s]
# Epoch 1 in training:  46%|████▌     | 216/469 [01:13<01:25,  2.95it/s]
# Epoch 1 in training:  46%|████▋     | 217/469 [01:14<01:24,  2.97it/s]
# Epoch 1 in training:  46%|████▋     | 218/469 [01:14<01:24,  2.97it/s]
# Epoch 1 in training:  47%|████▋     | 219/469 [01:14<01:24,  2.97it/s]
# Epoch 1 in training:  47%|████▋     | 220/469 [01:15<01:23,  2.98it/s]
# Epoch 1 in training:  47%|████▋     | 221/469 [01:15<01:23,  2.98it/s]
# Epoch 1 in training:  47%|████▋     | 222/469 [01:15<01:23,  2.97it/s]
# Epoch 1 in training:  48%|████▊     | 223/469 [01:16<01:22,  2.97it/s]
# Epoch 1 in training:  48%|████▊     | 224/469 [01:16<01:22,  2.97it/s]
# Epoch 1 in training:  48%|████▊     | 225/469 [01:16<01:22,  2.95it/s]
# Epoch 1 in training:  48%|████▊     | 226/469 [01:17<01:23,  2.92it/s]
# Epoch 1 in training:  48%|████▊     | 227/469 [01:17<01:22,  2.92it/s]
# Epoch 1 in training:  49%|████▊     | 228/469 [01:17<01:22,  2.94it/s]
# Epoch 1 in training:  49%|████▉     | 229/469 [01:18<01:21,  2.93it/s]
# Epoch 1 in training:  49%|████▉     | 230/469 [01:18<01:20,  2.95it/s]
# Epoch 1 in training:  49%|████▉     | 231/469 [01:19<01:20,  2.95it/s]
# Epoch 1 in training:  49%|████▉     | 232/469 [01:19<01:20,  2.96it/s]
# Epoch 1 in training:  50%|████▉     | 233/469 [01:19<01:19,  2.97it/s]
# Epoch 1 in training:  50%|████▉     | 234/469 [01:20<01:19,  2.96it/s]
# Epoch 1 in training:  50%|█████     | 235/469 [01:20<01:19,  2.96it/s]
# Epoch 1 in training:  50%|█████     | 236/469 [01:20<01:19,  2.92it/s]
# Epoch 1 in training:  51%|█████     | 237/469 [01:21<01:19,  2.93it/s]
# Epoch 1 in training:  51%|█████     | 238/469 [01:21<01:18,  2.94it/s]
# Epoch 1 in training:  51%|█████     | 239/469 [01:21<01:17,  2.95it/s]
# Epoch 1 in training:  51%|█████     | 240/469 [01:22<01:18,  2.93it/s]
# Epoch 1 in training:  51%|█████▏    | 241/469 [01:22<01:21,  2.80it/s]
# Epoch 1 in training:  52%|█████▏    | 242/469 [01:22<01:22,  2.74it/s]
# Epoch 1 in training:  52%|█████▏    | 243/469 [01:23<01:20,  2.81it/s]
# Epoch 1 in training:  52%|█████▏    | 244/469 [01:23<01:19,  2.84it/s]
# Epoch 1 in training:  52%|█████▏    | 245/469 [01:23<01:17,  2.88it/s]
# Epoch 1 in training:  52%|█████▏    | 246/469 [01:24<01:16,  2.91it/s]
# Epoch 1 in training:  53%|█████▎    | 247/469 [01:24<01:15,  2.94it/s]
# Epoch 1 in training:  53%|█████▎    | 248/469 [01:24<01:14,  2.95it/s]
# Epoch 1 in training:  53%|█████▎    | 249/469 [01:25<01:14,  2.96it/s]
# Epoch 1 in training:  53%|█████▎    | 250/469 [01:25<01:14,  2.96it/s]
# Epoch 1 in training:  54%|█████▎    | 251/469 [01:25<01:13,  2.96it/s]
# Epoch 1 in training:  54%|█████▎    | 252/469 [01:26<01:13,  2.96it/s]
# Epoch 1 in training:  54%|█████▍    | 253/469 [01:26<01:12,  2.96it/s]
# Epoch 1 in training:  54%|█████▍    | 254/469 [01:26<01:12,  2.96it/s]
# Epoch 1 in training:  54%|█████▍    | 255/469 [01:27<01:12,  2.96it/s]
# Epoch 1 in training:  55%|█████▍    | 256/469 [01:27<01:12,  2.95it/s]
# Epoch 1 in training:  55%|█████▍    | 257/469 [01:27<01:11,  2.95it/s]
# Epoch 1 in training:  55%|█████▌    | 258/469 [01:28<01:12,  2.90it/s]
# Epoch 1 in training:  55%|█████▌    | 259/469 [01:28<01:11,  2.93it/s]
# Epoch 1 in training:  55%|█████▌    | 260/469 [01:28<01:10,  2.95it/s]
# Epoch 1 in training:  56%|█████▌    | 261/469 [01:29<01:10,  2.97it/s]
# Epoch 1 in training:  56%|█████▌    | 262/469 [01:29<01:09,  2.97it/s]
# Epoch 1 in training:  56%|█████▌    | 263/469 [01:29<01:09,  2.96it/s]
# Epoch 1 in training:  56%|█████▋    | 264/469 [01:30<01:08,  2.98it/s]
# Epoch 1 in training:  57%|█████▋    | 265/469 [01:30<01:08,  2.99it/s]
# Epoch 1 in training:  57%|█████▋    | 266/469 [01:30<01:08,  2.97it/s]
# Epoch 1 in training:  57%|█████▋    | 267/469 [01:31<01:07,  2.98it/s]
# Epoch 1 in training:  57%|█████▋    | 268/469 [01:31<01:07,  2.99it/s]
# Epoch 1 in training:  57%|█████▋    | 269/469 [01:31<01:06,  2.99it/s]
# Epoch 1 in training:  58%|█████▊    | 270/469 [01:32<01:07,  2.93it/s]
# Epoch 1 in training:  58%|█████▊    | 271/469 [01:32<01:07,  2.92it/s]
# Epoch 1 in training:  58%|█████▊    | 272/469 [01:32<01:07,  2.93it/s]
# Epoch 1 in training:  58%|█████▊    | 273/469 [01:33<01:06,  2.93it/s]
# Epoch 1 in training:  58%|█████▊    | 274/469 [01:33<01:06,  2.94it/s]
# Epoch 1 in training:  59%|█████▊    | 275/469 [01:33<01:05,  2.95it/s]
# Epoch 1 in training:  59%|█████▉    | 276/469 [01:34<01:05,  2.96it/s]
# Epoch 1 in training:  59%|█████▉    | 277/469 [01:34<01:04,  2.97it/s]
# Epoch 1 in training:  59%|█████▉    | 278/469 [01:35<01:04,  2.97it/s]
# Epoch 1 in training:  59%|█████▉    | 279/469 [01:35<01:03,  2.98it/s]
# Epoch 1 in training:  60%|█████▉    | 280/469 [01:35<01:03,  2.99it/s]
# Epoch 1 in training:  60%|█████▉    | 281/469 [01:36<01:02,  2.99it/s]
# Epoch 1 in training:  60%|██████    | 282/469 [01:36<01:02,  2.99it/s]
# Epoch 1 in training:  60%|██████    | 283/469 [01:36<01:02,  2.99it/s]
# Epoch 1 in training:  61%|██████    | 284/469 [01:37<01:01,  2.99it/s]
# Epoch 1 in training:  61%|██████    | 285/469 [01:37<01:01,  2.98it/s]
# Epoch 1 in training:  61%|██████    | 286/469 [01:37<01:01,  2.99it/s]
# Epoch 1 in training:  61%|██████    | 287/469 [01:38<01:00,  2.99it/s]
# Epoch 1 in training:  61%|██████▏   | 288/469 [01:38<01:00,  2.99it/s]
# Epoch 1 in training:  62%|██████▏   | 289/469 [01:38<01:00,  2.99it/s]
# Epoch 1 in training:  62%|██████▏   | 290/469 [01:39<00:59,  2.99it/s]
# Epoch 1 in training:  62%|██████▏   | 291/469 [01:39<00:59,  2.99it/s]
# Epoch 1 in training:  62%|██████▏   | 292/469 [01:39<00:59,  2.99it/s]
# Epoch 1 in training:  62%|██████▏   | 293/469 [01:40<00:58,  2.99it/s]
# Epoch 1 in training:  63%|██████▎   | 294/469 [01:40<00:58,  2.99it/s]
# Epoch 1 in training:  63%|██████▎   | 295/469 [01:40<00:58,  2.99it/s]
# Epoch 1 in training:  63%|██████▎   | 296/469 [01:41<00:57,  2.98it/s]
# Epoch 1 in training:  63%|██████▎   | 297/469 [01:41<00:57,  2.99it/s]
# Epoch 1 in training:  64%|██████▎   | 298/469 [01:41<00:57,  2.99it/s]
# Epoch 1 in training:  64%|██████▍   | 299/469 [01:42<00:56,  2.99it/s]
# Epoch 1 in training:  64%|██████▍   | 300/469 [01:42<00:58,  2.91it/s]
# Epoch 1 in training:  64%|██████▍   | 301/469 [01:42<00:57,  2.94it/s]
# Epoch 1 in training:  64%|██████▍   | 302/469 [01:43<00:56,  2.95it/s]
# Epoch 1 in training:  65%|██████▍   | 303/469 [01:43<00:56,  2.96it/s]
# Epoch 1 in training:  65%|██████▍   | 304/469 [01:43<00:55,  2.98it/s]
# Epoch 1 in training:  65%|██████▌   | 305/469 [01:44<00:54,  2.99it/s]
# Epoch 1 in training:  65%|██████▌   | 306/469 [01:44<00:54,  2.99it/s]
# Epoch 1 in training:  65%|██████▌   | 307/469 [01:44<00:54,  2.99it/s]
# Epoch 1 in training:  66%|██████▌   | 308/469 [01:45<00:53,  2.98it/s]
# Epoch 1 in training:  66%|██████▌   | 309/469 [01:45<00:53,  2.99it/s]
# Epoch 1 in training:  66%|██████▌   | 310/469 [01:45<00:53,  2.99it/s]
# Epoch 1 in training:  66%|██████▋   | 311/469 [01:46<00:52,  2.99it/s]
# Epoch 1 in training:  67%|██████▋   | 312/469 [01:46<00:52,  2.98it/s]
# Epoch 1 in training:  67%|██████▋   | 313/469 [01:46<00:52,  2.98it/s]
# Epoch 1 in training:  67%|██████▋   | 314/469 [01:47<00:51,  2.98it/s]
# Epoch 1 in training:  67%|██████▋   | 315/469 [01:47<00:51,  2.99it/s]
# Epoch 1 in training:  67%|██████▋   | 316/469 [01:47<00:51,  3.00it/s]
# Epoch 1 in training:  68%|██████▊   | 317/469 [01:48<00:50,  2.98it/s]
# Epoch 1 in training:  68%|██████▊   | 318/469 [01:48<00:51,  2.96it/s]
# Epoch 1 in training:  68%|██████▊   | 319/469 [01:48<00:50,  2.97it/s]
# Epoch 1 in training:  68%|██████▊   | 320/469 [01:49<00:49,  2.98it/s]
# Epoch 1 in training:  68%|██████▊   | 321/469 [01:49<00:49,  2.98it/s]
# Epoch 1 in training:  69%|██████▊   | 322/469 [01:49<00:49,  2.98it/s]
# Epoch 1 in training:  69%|██████▉   | 323/469 [01:50<00:49,  2.97it/s]
# Epoch 1 in training:  69%|██████▉   | 324/469 [01:50<00:48,  2.98it/s]
# Epoch 1 in training:  69%|██████▉   | 325/469 [01:50<00:48,  2.99it/s]
# Epoch 1 in training:  70%|██████▉   | 326/469 [01:51<00:47,  2.99it/s]
# Epoch 1 in training:  70%|██████▉   | 327/469 [01:51<00:47,  3.00it/s]
# Epoch 1 in training:  70%|██████▉   | 328/469 [01:51<00:46,  3.01it/s]
# Epoch 1 in training:  70%|███████   | 329/469 [01:52<00:46,  3.00it/s]
# Epoch 1 in training:  70%|███████   | 330/469 [01:52<00:47,  2.90it/s]
# Epoch 1 in training:  71%|███████   | 331/469 [01:52<00:47,  2.93it/s]
# Epoch 1 in training:  71%|███████   | 332/469 [01:53<00:46,  2.95it/s]
# Epoch 1 in training:  71%|███████   | 333/469 [01:53<00:45,  2.96it/s]
# Epoch 1 in training:  71%|███████   | 334/469 [01:53<00:45,  2.96it/s]
# Epoch 1 in training:  71%|███████▏  | 335/469 [01:54<00:46,  2.86it/s]
# Epoch 1 in training:  72%|███████▏  | 336/469 [01:54<00:46,  2.87it/s]
# Epoch 1 in training:  72%|███████▏  | 337/469 [01:54<00:45,  2.89it/s]
# Epoch 1 in training:  72%|███████▏  | 338/469 [01:55<00:44,  2.91it/s]
# Epoch 1 in training:  72%|███████▏  | 339/469 [01:55<00:44,  2.94it/s]
# Epoch 1 in training:  72%|███████▏  | 340/469 [01:55<00:43,  2.96it/s]
# Epoch 1 in training:  73%|███████▎  | 341/469 [01:56<00:43,  2.97it/s]
# Epoch 1 in training:  73%|███████▎  | 342/469 [01:56<00:42,  2.98it/s]
# Epoch 1 in training:  73%|███████▎  | 343/469 [01:56<00:42,  2.98it/s]
# Epoch 1 in training:  73%|███████▎  | 344/469 [01:57<00:41,  2.99it/s]
# Epoch 1 in training:  74%|███████▎  | 345/469 [01:57<00:41,  2.99it/s]
# Epoch 1 in training:  74%|███████▍  | 346/469 [01:57<00:40,  3.01it/s]
# Epoch 1 in training:  74%|███████▍  | 347/469 [01:58<00:40,  3.01it/s]
# Epoch 1 in training:  74%|███████▍  | 348/469 [01:58<00:40,  3.02it/s]
# Epoch 1 in training:  74%|███████▍  | 349/469 [01:58<00:39,  3.01it/s]
# Epoch 1 in training:  75%|███████▍  | 350/469 [01:59<00:39,  3.01it/s]
# Epoch 1 in training:  75%|███████▍  | 351/469 [01:59<00:39,  3.01it/s]
# Epoch 1 in training:  75%|███████▌  | 352/469 [01:59<00:38,  3.00it/s]
# Epoch 1 in training:  75%|███████▌  | 353/469 [02:00<00:38,  2.99it/s]
# Epoch 1 in training:  75%|███████▌  | 354/469 [02:00<00:38,  2.99it/s]
# Epoch 1 in training:  76%|███████▌  | 355/469 [02:00<00:38,  2.96it/s]
# Epoch 1 in training:  76%|███████▌  | 356/469 [02:01<00:38,  2.96it/s]
# Epoch 1 in training:  76%|███████▌  | 357/469 [02:01<00:37,  2.98it/s]
# Epoch 1 in training:  76%|███████▋  | 358/469 [02:01<00:37,  2.98it/s]
# Epoch 1 in training:  77%|███████▋  | 359/469 [02:02<00:36,  2.98it/s]
# Epoch 1 in training:  77%|███████▋  | 360/469 [02:02<00:37,  2.93it/s]
# Epoch 1 in training:  77%|███████▋  | 361/469 [02:02<00:36,  2.92it/s]
# Epoch 1 in training:  77%|███████▋  | 362/469 [02:03<00:36,  2.94it/s]
# Epoch 1 in training:  77%|███████▋  | 363/469 [02:03<00:35,  2.96it/s]
# Epoch 1 in training:  78%|███████▊  | 364/469 [02:03<00:35,  2.95it/s]
# Epoch 1 in training:  78%|███████▊  | 365/469 [02:04<00:35,  2.96it/s]
# Epoch 1 in training:  78%|███████▊  | 366/469 [02:04<00:34,  2.98it/s]
# Epoch 1 in training:  78%|███████▊  | 367/469 [02:04<00:34,  2.97it/s]
# Epoch 1 in training:  78%|███████▊  | 368/469 [02:05<00:33,  2.98it/s]
# Epoch 1 in training:  79%|███████▊  | 369/469 [02:05<00:33,  2.98it/s]
# Epoch 1 in training:  79%|███████▉  | 370/469 [02:05<00:33,  2.99it/s]
# Epoch 1 in training:  79%|███████▉  | 371/469 [02:06<00:32,  2.99it/s]
# Epoch 1 in training:  79%|███████▉  | 372/469 [02:06<00:32,  3.00it/s]
# Epoch 1 in training:  80%|███████▉  | 373/469 [02:06<00:31,  3.00it/s]
# Epoch 1 in training:  80%|███████▉  | 374/469 [02:07<00:31,  3.01it/s]
# Epoch 1 in training:  80%|███████▉  | 375/469 [02:07<00:31,  3.00it/s]
# Epoch 1 in training:  80%|████████  | 376/469 [02:07<00:31,  3.00it/s]
# Epoch 1 in training:  80%|████████  | 377/469 [02:08<00:30,  3.01it/s]
# Epoch 1 in training:  81%|████████  | 378/469 [02:08<00:30,  3.00it/s]
# Epoch 1 in training:  81%|████████  | 379/469 [02:08<00:30,  3.00it/s]
# Epoch 1 in training:  81%|████████  | 380/469 [02:09<00:29,  3.00it/s]
# Epoch 1 in training:  81%|████████  | 381/469 [02:09<00:29,  3.01it/s]
# Epoch 1 in training:  81%|████████▏ | 382/469 [02:09<00:28,  3.00it/s]
# Epoch 1 in training:  82%|████████▏ | 383/469 [02:10<00:28,  3.00it/s]
# Epoch 1 in training:  82%|████████▏ | 384/469 [02:10<00:28,  3.00it/s]
# Epoch 1 in training:  82%|████████▏ | 385/469 [02:10<00:28,  3.00it/s]
# Epoch 1 in training:  82%|████████▏ | 386/469 [02:11<00:27,  3.00it/s]
# Epoch 1 in training:  83%|████████▎ | 387/469 [02:11<00:27,  3.00it/s]
# Epoch 1 in training:  83%|████████▎ | 388/469 [02:11<00:27,  3.00it/s]
# Epoch 1 in training:  83%|████████▎ | 389/469 [02:12<00:26,  2.96it/s]
# Epoch 1 in training:  83%|████████▎ | 390/469 [02:12<00:27,  2.92it/s]
# Epoch 1 in training:  83%|████████▎ | 391/469 [02:12<00:26,  2.94it/s]
# Epoch 1 in training:  84%|████████▎ | 392/469 [02:13<00:26,  2.95it/s]
# Epoch 1 in training:  84%|████████▍ | 393/469 [02:13<00:25,  2.96it/s]
# Epoch 1 in training:  84%|████████▍ | 394/469 [02:13<00:25,  2.97it/s]
# Epoch 1 in training:  84%|████████▍ | 395/469 [02:14<00:24,  2.98it/s]
# Epoch 1 in training:  84%|████████▍ | 396/469 [02:14<00:24,  3.00it/s]
# Epoch 1 in training:  85%|████████▍ | 397/469 [02:14<00:24,  2.99it/s]
# Epoch 1 in training:  85%|████████▍ | 398/469 [02:15<00:23,  3.00it/s]
# Epoch 1 in training:  85%|████████▌ | 399/469 [02:15<00:23,  2.99it/s]
# Epoch 1 in training:  85%|████████▌ | 400/469 [02:15<00:23,  2.99it/s]
# Epoch 1 in training:  86%|████████▌ | 401/469 [02:16<00:22,  2.99it/s]
# Epoch 1 in training:  86%|████████▌ | 402/469 [02:16<00:22,  3.00it/s]
# Epoch 1 in training:  86%|████████▌ | 403/469 [02:16<00:22,  2.99it/s]
# Epoch 1 in training:  86%|████████▌ | 404/469 [02:17<00:21,  2.99it/s]
# Epoch 1 in training:  86%|████████▋ | 405/469 [02:17<00:21,  3.00it/s]
# Epoch 1 in training:  87%|████████▋ | 406/469 [02:17<00:21,  2.99it/s]
# Epoch 1 in training:  87%|████████▋ | 407/469 [02:18<00:20,  3.00it/s]
# Epoch 1 in training:  87%|████████▋ | 408/469 [02:18<00:20,  3.00it/s]
# Epoch 1 in training:  87%|████████▋ | 409/469 [02:18<00:20,  3.00it/s]
# Epoch 1 in training:  87%|████████▋ | 410/469 [02:19<00:19,  3.00it/s]
# Epoch 1 in training:  88%|████████▊ | 411/469 [02:19<00:19,  3.00it/s]
# Epoch 1 in training:  88%|████████▊ | 412/469 [02:19<00:19,  3.00it/s]
# Epoch 1 in training:  88%|████████▊ | 413/469 [02:20<00:18,  3.00it/s]
# Epoch 1 in training:  88%|████████▊ | 414/469 [02:20<00:18,  3.00it/s]
# Epoch 1 in training:  88%|████████▊ | 415/469 [02:20<00:18,  2.98it/s]
# Epoch 1 in training:  89%|████████▊ | 416/469 [02:21<00:17,  2.95it/s]
# Epoch 1 in training:  89%|████████▉ | 417/469 [02:21<00:17,  2.96it/s]
# Epoch 1 in training:  89%|████████▉ | 418/469 [02:21<00:17,  2.96it/s]
# Epoch 1 in training:  89%|████████▉ | 419/469 [02:22<00:17,  2.90it/s]
# Epoch 1 in training:  90%|████████▉ | 420/469 [02:22<00:16,  2.94it/s]
# Epoch 1 in training:  90%|████████▉ | 421/469 [02:23<00:16,  2.96it/s]
# Epoch 1 in training:  90%|████████▉ | 422/469 [02:23<00:15,  2.97it/s]
# Epoch 1 in training:  90%|█████████ | 423/469 [02:23<00:15,  2.98it/s]
# Epoch 1 in training:  90%|█████████ | 424/469 [02:24<00:15,  2.96it/s]
# Epoch 1 in training:  91%|█████████ | 425/469 [02:24<00:14,  2.98it/s]
# Epoch 1 in training:  91%|█████████ | 426/469 [02:24<00:14,  2.98it/s]
# Epoch 1 in training:  91%|█████████ | 427/469 [02:25<00:14,  2.98it/s]
# Epoch 1 in training:  91%|█████████▏| 428/469 [02:25<00:13,  2.93it/s]
# Epoch 1 in training:  91%|█████████▏| 429/469 [02:25<00:14,  2.75it/s]
# Epoch 1 in training:  92%|█████████▏| 430/469 [02:26<00:13,  2.79it/s]
# Epoch 1 in training:  92%|█████████▏| 431/469 [02:26<00:13,  2.83it/s]
# Epoch 1 in training:  92%|█████████▏| 432/469 [02:26<00:12,  2.87it/s]
# Epoch 1 in training:  92%|█████████▏| 433/469 [02:27<00:12,  2.89it/s]
# Epoch 1 in training:  93%|█████████▎| 434/469 [02:27<00:12,  2.90it/s]
# Epoch 1 in training:  93%|█████████▎| 435/469 [02:27<00:11,  2.91it/s]
# Epoch 1 in training:  93%|█████████▎| 436/469 [02:28<00:11,  2.89it/s]
# Epoch 1 in training:  93%|█████████▎| 437/469 [02:28<00:10,  2.92it/s]
# Epoch 1 in training:  93%|█████████▎| 438/469 [02:28<00:10,  2.94it/s]
# Epoch 1 in training:  94%|█████████▎| 439/469 [02:29<00:10,  2.95it/s]
# Epoch 1 in training:  94%|█████████▍| 440/469 [02:29<00:09,  2.96it/s]
# Epoch 1 in training:  94%|█████████▍| 441/469 [02:29<00:09,  2.98it/s]
# Epoch 1 in training:  94%|█████████▍| 442/469 [02:30<00:09,  2.97it/s]
# Epoch 1 in training:  94%|█████████▍| 443/469 [02:30<00:08,  2.99it/s]
# Epoch 1 in training:  95%|█████████▍| 444/469 [02:30<00:08,  2.95it/s]
# Epoch 1 in training:  95%|█████████▍| 445/469 [02:31<00:08,  2.94it/s]
# Epoch 1 in training:  95%|█████████▌| 446/469 [02:31<00:07,  2.95it/s]
# Epoch 1 in training:  95%|█████████▌| 447/469 [02:31<00:07,  2.97it/s]
# Epoch 1 in training:  96%|█████████▌| 448/469 [02:32<00:07,  2.96it/s]
# Epoch 1 in training:  96%|█████████▌| 449/469 [02:32<00:06,  2.91it/s]
# Epoch 1 in training:  96%|█████████▌| 450/469 [02:32<00:06,  2.93it/s]
# Epoch 1 in training:  96%|█████████▌| 451/469 [02:33<00:06,  2.95it/s]
# Epoch 1 in training:  96%|█████████▋| 452/469 [02:33<00:05,  2.96it/s]
# Epoch 1 in training:  97%|█████████▋| 453/469 [02:33<00:05,  2.94it/s]
# Epoch 1 in training:  97%|█████████▋| 454/469 [02:34<00:05,  2.94it/s]
# Epoch 1 in training:  97%|█████████▋| 455/469 [02:34<00:04,  2.95it/s]
# Epoch 1 in training:  97%|█████████▋| 456/469 [02:34<00:04,  2.96it/s]
# Epoch 1 in training:  97%|█████████▋| 457/469 [02:35<00:04,  2.95it/s]
# Epoch 1 in training:  98%|█████████▊| 458/469 [02:35<00:03,  2.96it/s]
# Epoch 1 in training:  98%|█████████▊| 459/469 [02:35<00:03,  2.97it/s]
# Epoch 1 in training:  98%|█████████▊| 460/469 [02:36<00:03,  2.96it/s]
# Epoch 1 in training:  98%|█████████▊| 461/469 [02:36<00:02,  2.97it/s]
# Epoch 1 in training:  99%|█████████▊| 462/469 [02:36<00:02,  2.97it/s]
# Epoch 1 in training:  99%|█████████▊| 463/469 [02:37<00:02,  2.98it/s]
# Epoch 1 in training:  99%|█████████▉| 464/469 [02:37<00:01,  2.97it/s]
# Epoch 1 in training:  99%|█████████▉| 465/469 [02:37<00:01,  2.98it/s]
# Epoch 1 in training:  99%|█████████▉| 466/469 [02:38<00:01,  2.98it/s]
# Epoch 1 in training: 100%|█████████▉| 467/469 [02:38<00:00,  2.99it/s]
# Epoch 1 in training: 100%|█████████▉| 468/469 [02:38<00:00,  2.99it/s]
# Epoch 1 in training: 100%|██████████| 469/469 [02:39<00:00,  3.21it/s]
# train:  12%|█▎        | 1/8 [02:39<18:34, 159.25s/it]
# Epoch 1/8 loss: 2.07
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:00<02:38,  2.95it/s]
# Epoch 2 in training:   0%|          | 2/469 [00:00<02:37,  2.97it/s]
# Epoch 2 in training:   1%|          | 3/469 [00:01<02:37,  2.97it/s]
# Epoch 2 in training:   1%|          | 4/469 [00:01<02:36,  2.98it/s]
# Epoch 2 in training:   1%|          | 5/469 [00:01<02:36,  2.97it/s]
# Epoch 2 in training:   1%|▏         | 6/469 [00:02<02:35,  2.98it/s]
# Epoch 2 in training:   1%|▏         | 7/469 [00:02<02:36,  2.95it/s]
# Epoch 2 in training:   2%|▏         | 8/469 [00:02<02:35,  2.97it/s]
# Epoch 2 in training:   2%|▏         | 9/469 [00:03<02:37,  2.92it/s]
# Epoch 2 in training:   2%|▏         | 10/469 [00:03<02:36,  2.93it/s]
# Epoch 2 in training:   2%|▏         | 11/469 [00:03<02:34,  2.96it/s]
# Epoch 2 in training:   3%|▎         | 12/469 [00:04<02:34,  2.97it/s]
# Epoch 2 in training:   3%|▎         | 13/469 [00:04<02:33,  2.98it/s]
# Epoch 2 in training:   3%|▎         | 14/469 [00:04<02:31,  2.99it/s]
# Epoch 2 in training:   3%|▎         | 15/469 [00:05<02:31,  3.00it/s]
# Epoch 2 in training:   3%|▎         | 16/469 [00:05<02:31,  3.00it/s]
# Epoch 2 in training:   4%|▎         | 17/469 [00:05<02:30,  3.00it/s]
# Epoch 2 in training:   4%|▍         | 18/469 [00:06<02:30,  2.99it/s]
# Epoch 2 in training:   4%|▍         | 19/469 [00:06<02:30,  2.99it/s]
# Epoch 2 in training:   4%|▍         | 20/469 [00:06<02:30,  2.99it/s]
# Epoch 2 in training:   4%|▍         | 21/469 [00:07<02:29,  2.99it/s]
# Epoch 2 in training:   5%|▍         | 22/469 [00:07<02:29,  2.99it/s]
# Epoch 2 in training:   5%|▍         | 23/469 [00:07<02:28,  2.99it/s]
# Epoch 2 in training:   5%|▌         | 24/469 [00:08<02:28,  2.99it/s]
# Epoch 2 in training:   5%|▌         | 25/469 [00:08<02:28,  2.99it/s]
# Epoch 2 in training:   6%|▌         | 26/469 [00:08<02:27,  3.00it/s]
# Epoch 2 in training:   6%|▌         | 27/469 [00:09<02:27,  3.00it/s]
# Epoch 2 in training:   6%|▌         | 28/469 [00:09<02:27,  3.00it/s]
# Epoch 2 in training:   6%|▌         | 29/469 [00:09<02:27,  2.99it/s]
# Epoch 2 in training:   6%|▋         | 30/469 [00:10<02:26,  2.99it/s]
# Epoch 2 in training:   7%|▋         | 31/469 [00:10<02:26,  2.99it/s]
# Epoch 2 in training:   7%|▋         | 32/469 [00:10<02:25,  3.00it/s]
# Epoch 2 in training:   7%|▋         | 33/469 [00:11<02:25,  3.00it/s]
# Epoch 2 in training:   7%|▋         | 34/469 [00:11<02:24,  3.00it/s]
# Epoch 2 in training:   7%|▋         | 35/469 [00:11<02:24,  3.01it/s]
# Epoch 2 in training:   8%|▊         | 36/469 [00:12<02:24,  3.00it/s]
# Epoch 2 in training:   8%|▊         | 37/469 [00:12<02:23,  3.01it/s]
# Epoch 2 in training:   8%|▊         | 38/469 [00:12<02:22,  3.01it/s]
# Epoch 2 in training:   8%|▊         | 39/469 [00:13<02:28,  2.89it/s]
# Epoch 2 in training:   9%|▊         | 40/469 [00:13<02:27,  2.91it/s]
# Epoch 2 in training:   9%|▊         | 41/469 [00:13<02:25,  2.94it/s]
# Epoch 2 in training:   9%|▉         | 42/469 [00:14<02:24,  2.96it/s]
# Epoch 2 in training:   9%|▉         | 43/469 [00:14<02:22,  2.98it/s]
# Epoch 2 in training:   9%|▉         | 44/469 [00:14<02:21,  2.99it/s]
# Epoch 2 in training:  10%|▉         | 45/469 [00:15<02:21,  3.00it/s]
# Epoch 2 in training:  10%|▉         | 46/469 [00:15<02:21,  3.00it/s]
# Epoch 2 in training:  10%|█         | 47/469 [00:15<02:20,  3.00it/s]
# Epoch 2 in training:  10%|█         | 48/469 [00:16<02:20,  2.99it/s]
# Epoch 2 in training:  10%|█         | 49/469 [00:16<02:19,  3.00it/s]
# Epoch 2 in training:  11%|█         | 50/469 [00:16<02:19,  3.01it/s]
# Epoch 2 in training:  11%|█         | 51/469 [00:17<02:19,  3.00it/s]
# Epoch 2 in training:  11%|█         | 52/469 [00:17<02:18,  3.00it/s]
# Epoch 2 in training:  11%|█▏        | 53/469 [00:17<02:22,  2.91it/s]
# Epoch 2 in training:  12%|█▏        | 54/469 [00:18<02:25,  2.86it/s]
# Epoch 2 in training:  12%|█▏        | 55/469 [00:18<02:23,  2.89it/s]
# Epoch 2 in training:  12%|█▏        | 56/469 [00:18<02:22,  2.91it/s]
# Epoch 2 in training:  12%|█▏        | 57/469 [00:19<02:20,  2.93it/s]
# Epoch 2 in training:  12%|█▏        | 58/469 [00:19<02:18,  2.96it/s]
# Epoch 2 in training:  13%|█▎        | 59/469 [00:19<02:18,  2.97it/s]
# Epoch 2 in training:  13%|█▎        | 60/469 [00:20<02:18,  2.96it/s]
# Epoch 2 in training:  13%|█▎        | 61/469 [00:20<02:17,  2.97it/s]
# Epoch 2 in training:  13%|█▎        | 62/469 [00:20<02:17,  2.97it/s]
# Epoch 2 in training:  13%|█▎        | 63/469 [00:21<02:16,  2.98it/s]
# Epoch 2 in training:  14%|█▎        | 64/469 [00:21<02:15,  2.99it/s]
# Epoch 2 in training:  14%|█▍        | 65/469 [00:21<02:16,  2.95it/s]
# Epoch 2 in training:  14%|█▍        | 66/469 [00:22<02:15,  2.97it/s]
# Epoch 2 in training:  14%|█▍        | 67/469 [00:22<02:14,  2.98it/s]
# Epoch 2 in training:  14%|█▍        | 68/469 [00:22<02:14,  2.97it/s]
# Epoch 2 in training:  15%|█▍        | 69/469 [00:23<02:17,  2.91it/s]
# Epoch 2 in training:  15%|█▍        | 70/469 [00:23<02:16,  2.93it/s]
# Epoch 2 in training:  15%|█▌        | 71/469 [00:23<02:15,  2.94it/s]
# Epoch 2 in training:  15%|█▌        | 72/469 [00:24<02:14,  2.96it/s]
# Epoch 2 in training:  16%|█▌        | 73/469 [00:24<02:14,  2.95it/s]
# Epoch 2 in training:  16%|█▌        | 74/469 [00:24<02:13,  2.97it/s]
# Epoch 2 in training:  16%|█▌        | 75/469 [00:25<02:12,  2.97it/s]
# Epoch 2 in training:  16%|█▌        | 76/469 [00:25<02:11,  2.98it/s]
# Epoch 2 in training:  16%|█▋        | 77/469 [00:25<02:11,  2.98it/s]
# Epoch 2 in training:  17%|█▋        | 78/469 [00:26<02:10,  2.99it/s]
# Epoch 2 in training:  17%|█▋        | 79/469 [00:26<02:09,  3.00it/s]
# Epoch 2 in training:  17%|█▋        | 80/469 [00:26<02:09,  3.00it/s]
# Epoch 2 in training:  17%|█▋        | 81/469 [00:27<02:09,  3.00it/s]
# Epoch 2 in training:  17%|█▋        | 82/469 [00:27<02:08,  3.00it/s]
# Epoch 2 in training:  18%|█▊        | 83/469 [00:27<02:08,  3.00it/s]
# Epoch 2 in training:  18%|█▊        | 84/469 [00:28<02:08,  3.00it/s]
# Epoch 2 in training:  18%|█▊        | 85/469 [00:28<02:07,  3.01it/s]
# Epoch 2 in training:  18%|█▊        | 86/469 [00:28<02:07,  3.01it/s]
# Epoch 2 in training:  19%|█▊        | 87/469 [00:29<02:07,  3.00it/s]
# Epoch 2 in training:  19%|█▉        | 88/469 [00:29<02:07,  2.99it/s]
# Epoch 2 in training:  19%|█▉        | 89/469 [00:29<02:07,  2.98it/s]
# Epoch 2 in training:  19%|█▉        | 90/469 [00:30<02:07,  2.98it/s]
# Epoch 2 in training:  19%|█▉        | 91/469 [00:30<02:06,  2.99it/s]
# Epoch 2 in training:  20%|█▉        | 92/469 [00:30<02:06,  2.99it/s]
# Epoch 2 in training:  20%|█▉        | 93/469 [00:31<02:05,  2.99it/s]
# Epoch 2 in training:  20%|██        | 94/469 [00:31<02:05,  3.00it/s]
# Epoch 2 in training:  20%|██        | 95/469 [00:31<02:05,  2.99it/s]
# Epoch 2 in training:  20%|██        | 96/469 [00:32<02:05,  2.98it/s]
# Epoch 2 in training:  21%|██        | 97/469 [00:32<02:04,  2.98it/s]
# Epoch 2 in training:  21%|██        | 98/469 [00:32<02:04,  2.97it/s]
# Epoch 2 in training:  21%|██        | 99/469 [00:33<02:07,  2.91it/s]
# Epoch 2 in training:  21%|██▏       | 100/469 [00:33<02:05,  2.94it/s]
# Epoch 2 in training:  22%|██▏       | 101/469 [00:33<02:04,  2.95it/s]
# Epoch 2 in training:  22%|██▏       | 102/469 [00:34<02:04,  2.96it/s]
# Epoch 2 in training:  22%|██▏       | 103/469 [00:34<02:02,  2.98it/s]
# Epoch 2 in training:  22%|██▏       | 104/469 [00:34<02:02,  2.98it/s]
# Epoch 2 in training:  22%|██▏       | 105/469 [00:35<02:01,  2.99it/s]
# Epoch 2 in training:  23%|██▎       | 106/469 [00:35<02:01,  2.99it/s]
# Epoch 2 in training:  23%|██▎       | 107/469 [00:35<02:01,  2.98it/s]
# Epoch 2 in training:  23%|██▎       | 108/469 [00:36<02:00,  2.99it/s]
# Epoch 2 in training:  23%|██▎       | 109/469 [00:36<01:59,  3.00it/s]
# Epoch 2 in training:  23%|██▎       | 110/469 [00:36<01:59,  2.99it/s]
# Epoch 2 in training:  24%|██▎       | 111/469 [00:37<01:59,  2.99it/s]
# Epoch 2 in training:  24%|██▍       | 112/469 [00:37<01:58,  3.00it/s]
# Epoch 2 in training:  24%|██▍       | 113/469 [00:37<01:58,  2.99it/s]
# Epoch 2 in training:  24%|██▍       | 114/469 [00:38<01:58,  3.00it/s]
# Epoch 2 in training:  25%|██▍       | 115/469 [00:38<01:57,  3.01it/s]
# Epoch 2 in training:  25%|██▍       | 116/469 [00:38<01:57,  3.00it/s]
# Epoch 2 in training:  25%|██▍       | 117/469 [00:39<01:57,  3.01it/s]
# Epoch 2 in training:  25%|██▌       | 118/469 [00:39<01:56,  3.01it/s]
# Epoch 2 in training:  25%|██▌       | 119/469 [00:39<01:56,  2.99it/s]
# Epoch 2 in training:  26%|██▌       | 120/469 [00:40<01:56,  3.00it/s]
# Epoch 2 in training:  26%|██▌       | 121/469 [00:40<01:56,  3.00it/s]
# Epoch 2 in training:  26%|██▌       | 122/469 [00:40<01:55,  3.00it/s]
# Epoch 2 in training:  26%|██▌       | 123/469 [00:41<01:55,  3.00it/s]
# Epoch 2 in training:  26%|██▋       | 124/469 [00:41<01:55,  3.00it/s]
# Epoch 2 in training:  27%|██▋       | 125/469 [00:41<01:54,  3.00it/s]
# Epoch 2 in training:  27%|██▋       | 126/469 [00:42<01:54,  3.00it/s]
# Epoch 2 in training:  27%|██▋       | 127/469 [00:42<01:53,  3.01it/s]
# Epoch 2 in training:  27%|██▋       | 128/469 [00:42<01:53,  3.00it/s]
# Epoch 2 in training:  28%|██▊       | 129/469 [00:43<01:55,  2.94it/s]
# Epoch 2 in training:  28%|██▊       | 130/469 [00:43<01:54,  2.95it/s]
# Epoch 2 in training:  28%|██▊       | 131/469 [00:43<01:53,  2.97it/s]
# Epoch 2 in training:  28%|██▊       | 132/469 [00:44<01:53,  2.98it/s]
# Epoch 2 in training:  28%|██▊       | 133/469 [00:44<01:52,  2.98it/s]
# Epoch 2 in training:  29%|██▊       | 134/469 [00:44<01:52,  2.98it/s]
# Epoch 2 in training:  29%|██▉       | 135/469 [00:45<01:52,  2.98it/s]
# Epoch 2 in training:  29%|██▉       | 136/469 [00:45<01:51,  2.99it/s]
# Epoch 2 in training:  29%|██▉       | 137/469 [00:45<01:51,  2.99it/s]
# Epoch 2 in training:  29%|██▉       | 138/469 [00:46<01:50,  3.00it/s]
# Epoch 2 in training:  30%|██▉       | 139/469 [00:46<01:49,  3.00it/s]
# Epoch 2 in training:  30%|██▉       | 140/469 [00:46<01:49,  2.99it/s]
# Epoch 2 in training:  30%|███       | 141/469 [00:47<01:49,  3.00it/s]
# Epoch 2 in training:  30%|███       | 142/469 [00:47<01:48,  3.00it/s]
# Epoch 2 in training:  30%|███       | 143/469 [00:47<01:48,  3.00it/s]
# Epoch 2 in training:  31%|███       | 144/469 [00:48<01:48,  3.00it/s]
# Epoch 2 in training:  31%|███       | 145/469 [00:48<01:47,  3.01it/s]
# Epoch 2 in training:  31%|███       | 146/469 [00:49<01:49,  2.95it/s]
# Epoch 2 in training:  31%|███▏      | 147/469 [00:49<01:53,  2.83it/s]
# Epoch 2 in training:  32%|███▏      | 148/469 [00:49<01:53,  2.82it/s]
# Epoch 2 in training:  32%|███▏      | 149/469 [00:50<01:52,  2.84it/s]
# Epoch 2 in training:  32%|███▏      | 150/469 [00:50<01:51,  2.87it/s]
# Epoch 2 in training:  32%|███▏      | 151/469 [00:50<01:49,  2.91it/s]
# Epoch 2 in training:  32%|███▏      | 152/469 [00:51<01:47,  2.94it/s]
# Epoch 2 in training:  33%|███▎      | 153/469 [00:51<01:46,  2.97it/s]
# Epoch 2 in training:  33%|███▎      | 154/469 [00:51<01:46,  2.96it/s]
# Epoch 2 in training:  33%|███▎      | 155/469 [00:52<01:46,  2.96it/s]
# Epoch 2 in training:  33%|███▎      | 156/469 [00:52<01:45,  2.97it/s]
# Epoch 2 in training:  33%|███▎      | 157/469 [00:52<01:44,  2.99it/s]
# Epoch 2 in training:  34%|███▎      | 158/469 [00:53<01:46,  2.91it/s]
# Epoch 2 in training:  34%|███▍      | 159/469 [00:53<01:45,  2.94it/s]
# Epoch 2 in training:  34%|███▍      | 160/469 [00:53<01:44,  2.96it/s]
# Epoch 2 in training:  34%|███▍      | 161/469 [00:54<01:43,  2.97it/s]
# Epoch 2 in training:  35%|███▍      | 162/469 [00:54<01:43,  2.96it/s]
# Epoch 2 in training:  35%|███▍      | 163/469 [00:54<01:43,  2.95it/s]
# Epoch 2 in training:  35%|███▍      | 164/469 [00:55<01:43,  2.96it/s]
# Epoch 2 in training:  35%|███▌      | 165/469 [00:55<01:42,  2.97it/s]
# Epoch 2 in training:  35%|███▌      | 166/469 [00:55<01:41,  2.97it/s]
# Epoch 2 in training:  36%|███▌      | 167/469 [00:56<01:41,  2.98it/s]
# Epoch 2 in training:  36%|███▌      | 168/469 [00:56<01:40,  2.99it/s]
# Epoch 2 in training:  36%|███▌      | 169/469 [00:56<01:39,  3.00it/s]
# Epoch 2 in training:  36%|███▌      | 170/469 [00:57<01:39,  3.00it/s]
# Epoch 2 in training:  36%|███▋      | 171/469 [00:57<01:39,  3.00it/s]
# Epoch 2 in training:  37%|███▋      | 172/469 [00:57<01:39,  2.99it/s]
# Epoch 2 in training:  37%|███▋      | 173/469 [00:58<01:39,  2.98it/s]
# Epoch 2 in training:  37%|███▋      | 174/469 [00:58<01:38,  2.99it/s]
# Epoch 2 in training:  37%|███▋      | 175/469 [00:58<01:38,  2.98it/s]
# Epoch 2 in training:  38%|███▊      | 176/469 [00:59<01:38,  2.98it/s]
# Epoch 2 in training:  38%|███▊      | 177/469 [00:59<01:38,  2.97it/s]
# Epoch 2 in training:  38%|███▊      | 178/469 [00:59<01:37,  2.98it/s]
# ...
# Epoch 6 in training:  75%|███████▍  | 350/469 [01:58<00:39,  3.00it/s]
# Epoch 6 in training:  75%|███████▍  | 351/469 [01:58<00:39,  2.98it/s]
# Epoch 6 in training:  75%|███████▌  | 352/469 [01:58<00:39,  2.99it/s]
# Epoch 6 in training:  75%|███████▌  | 353/469 [01:59<00:38,  2.98it/s]
# Epoch 6 in training:  75%|███████▌  | 354/469 [01:59<00:38,  2.97it/s]
# Epoch 6 in training:  76%|███████▌  | 355/469 [01:59<00:39,  2.89it/s]
# Epoch 6 in training:  76%|███████▌  | 356/469 [02:00<00:38,  2.92it/s]
# Epoch 6 in training:  76%|███████▌  | 357/469 [02:00<00:38,  2.94it/s]
# Epoch 6 in training:  76%|███████▋  | 358/469 [02:00<00:37,  2.96it/s]
# Epoch 6 in training:  77%|███████▋  | 359/469 [02:01<00:37,  2.96it/s]
# Epoch 6 in training:  77%|███████▋  | 360/469 [02:01<00:36,  2.98it/s]
# Epoch 6 in training:  77%|███████▋  | 361/469 [02:01<00:36,  2.99it/s]
# Epoch 6 in training:  77%|███████▋  | 362/469 [02:02<00:35,  3.00it/s]
# Epoch 6 in training:  77%|███████▋  | 363/469 [02:02<00:35,  2.99it/s]
# Epoch 6 in training:  78%|███████▊  | 364/469 [02:02<00:34,  3.00it/s]
# Epoch 6 in training:  78%|███████▊  | 365/469 [02:03<00:34,  3.00it/s]
# Epoch 6 in training:  78%|███████▊  | 366/469 [02:03<00:34,  3.00it/s]
# Epoch 6 in training:  78%|███████▊  | 367/469 [02:03<00:33,  3.01it/s]
# Epoch 6 in training:  78%|███████▊  | 368/469 [02:04<00:33,  3.01it/s]
# Epoch 6 in training:  79%|███████▊  | 369/469 [02:04<00:33,  2.99it/s]
# Epoch 6 in training:  79%|███████▉  | 370/469 [02:04<00:33,  2.99it/s]
# Epoch 6 in training:  79%|███████▉  | 371/469 [02:05<00:32,  2.99it/s]
# Epoch 6 in training:  79%|███████▉  | 372/469 [02:05<00:32,  2.99it/s]
# Epoch 6 in training:  80%|███████▉  | 373/469 [02:05<00:32,  2.98it/s]
# Epoch 6 in training:  80%|███████▉  | 374/469 [02:06<00:31,  2.99it/s]
# Epoch 6 in training:  80%|███████▉  | 375/469 [02:06<00:31,  2.98it/s]
# Epoch 6 in training:  80%|████████  | 376/469 [02:06<00:31,  2.99it/s]
# Epoch 6 in training:  80%|████████  | 377/469 [02:07<00:30,  3.00it/s]
# Epoch 6 in training:  81%|████████  | 378/469 [02:07<00:30,  3.00it/s]
# Epoch 6 in training:  81%|████████  | 379/469 [02:07<00:30,  3.00it/s]
# Epoch 6 in training:  81%|████████  | 380/469 [02:08<00:29,  3.01it/s]
# Epoch 6 in training:  81%|████████  | 381/469 [02:08<00:29,  3.00it/s]
# Epoch 6 in training:  81%|████████▏ | 382/469 [02:08<00:28,  3.00it/s]
# Epoch 6 in training:  82%|████████▏ | 383/469 [02:09<00:28,  3.00it/s]
# Epoch 6 in training:  82%|████████▏ | 384/469 [02:09<00:28,  3.00it/s]
# Epoch 6 in training:  82%|████████▏ | 385/469 [02:09<00:28,  2.92it/s]
# Epoch 6 in training:  82%|████████▏ | 386/469 [02:10<00:28,  2.95it/s]
# Epoch 6 in training:  83%|████████▎ | 387/469 [02:10<00:27,  2.97it/s]
# Epoch 6 in training:  83%|████████▎ | 388/469 [02:10<00:27,  2.98it/s]
# Epoch 6 in training:  83%|████████▎ | 389/469 [02:11<00:26,  2.98it/s]
# Epoch 6 in training:  83%|████████▎ | 390/469 [02:11<00:26,  2.98it/s]
# Epoch 6 in training:  83%|████████▎ | 391/469 [02:11<00:26,  2.98it/s]
# Epoch 6 in training:  84%|████████▎ | 392/469 [02:12<00:25,  2.99it/s]
# Epoch 6 in training:  84%|████████▍ | 393/469 [02:12<00:25,  2.98it/s]
# Epoch 6 in training:  84%|████████▍ | 394/469 [02:12<00:25,  2.99it/s]
# Epoch 6 in training:  84%|████████▍ | 395/469 [02:13<00:24,  2.99it/s]
# Epoch 6 in training:  84%|████████▍ | 396/469 [02:13<00:24,  2.99it/s]
# Epoch 6 in training:  85%|████████▍ | 397/469 [02:13<00:24,  2.98it/s]
# Epoch 6 in training:  85%|████████▍ | 398/469 [02:14<00:23,  2.98it/s]
# Epoch 6 in training:  85%|████████▌ | 399/469 [02:14<00:23,  2.99it/s]
# Epoch 6 in training:  85%|████████▌ | 400/469 [02:14<00:23,  3.00it/s]
# Epoch 6 in training:  86%|████████▌ | 401/469 [02:15<00:22,  3.00it/s]
# Epoch 6 in training:  86%|████████▌ | 402/469 [02:15<00:22,  3.00it/s]
# Epoch 6 in training:  86%|████████▌ | 403/469 [02:15<00:21,  3.01it/s]
# Epoch 6 in training:  86%|████████▌ | 404/469 [02:16<00:21,  3.00it/s]
# Epoch 6 in training:  86%|████████▋ | 405/469 [02:16<00:21,  3.00it/s]
# Epoch 6 in training:  87%|████████▋ | 406/469 [02:16<00:20,  3.01it/s]
# Epoch 6 in training:  87%|████████▋ | 407/469 [02:17<00:20,  2.97it/s]
# Epoch 6 in training:  87%|████████▋ | 408/469 [02:17<00:20,  2.98it/s]
# Epoch 6 in training:  87%|████████▋ | 409/469 [02:17<00:19,  3.00it/s]
# Epoch 6 in training:  87%|████████▋ | 410/469 [02:18<00:19,  3.00it/s]
# Epoch 6 in training:  88%|████████▊ | 411/469 [02:18<00:19,  2.99it/s]
# Epoch 6 in training:  88%|████████▊ | 412/469 [02:18<00:19,  2.99it/s]
# Epoch 6 in training:  88%|████████▊ | 413/469 [02:19<00:18,  2.99it/s]
# Epoch 6 in training:  88%|████████▊ | 414/469 [02:19<00:18,  2.98it/s]
# Epoch 6 in training:  88%|████████▊ | 415/469 [02:19<00:18,  2.93it/s]
# Epoch 6 in training:  89%|████████▊ | 416/469 [02:20<00:18,  2.94it/s]
# Epoch 6 in training:  89%|████████▉ | 417/469 [02:20<00:17,  2.95it/s]
# Epoch 6 in training:  89%|████████▉ | 418/469 [02:20<00:17,  2.97it/s]
# Epoch 6 in training:  89%|████████▉ | 419/469 [02:21<00:16,  2.95it/s]
# Epoch 6 in training:  90%|████████▉ | 420/469 [02:21<00:17,  2.88it/s]
# Epoch 6 in training:  90%|████████▉ | 421/469 [02:22<00:16,  2.85it/s]
# Epoch 6 in training:  90%|████████▉ | 422/469 [02:22<00:16,  2.88it/s]
# Epoch 6 in training:  90%|█████████ | 423/469 [02:22<00:15,  2.90it/s]
# Epoch 6 in training:  90%|█████████ | 424/469 [02:23<00:15,  2.93it/s]
# Epoch 6 in training:  91%|█████████ | 425/469 [02:23<00:14,  2.95it/s]
# Epoch 6 in training:  91%|█████████ | 426/469 [02:23<00:14,  2.97it/s]
# Epoch 6 in training:  91%|█████████ | 427/469 [02:24<00:14,  2.98it/s]
# Epoch 6 in training:  91%|█████████▏| 428/469 [02:24<00:13,  2.97it/s]
# Epoch 6 in training:  91%|█████████▏| 429/469 [02:24<00:13,  2.97it/s]
# Epoch 6 in training:  92%|█████████▏| 430/469 [02:25<00:13,  2.98it/s]
# Epoch 6 in training:  92%|█████████▏| 431/469 [02:25<00:12,  2.97it/s]
# Epoch 6 in training:  92%|█████████▏| 432/469 [02:25<00:12,  2.98it/s]
# Epoch 6 in training:  92%|█████████▏| 433/469 [02:26<00:12,  2.99it/s]
# Epoch 6 in training:  93%|█████████▎| 434/469 [02:26<00:11,  2.98it/s]
# Epoch 6 in training:  93%|█████████▎| 435/469 [02:26<00:11,  2.98it/s]
# Epoch 6 in training:  93%|█████████▎| 436/469 [02:27<00:11,  2.99it/s]
# Epoch 6 in training:  93%|█████████▎| 437/469 [02:27<00:10,  2.99it/s]
# Epoch 6 in training:  93%|█████████▎| 438/469 [02:27<00:10,  3.00it/s]
# Epoch 6 in training:  94%|█████████▎| 439/469 [02:28<00:09,  3.01it/s]
# Epoch 6 in training:  94%|█████████▍| 440/469 [02:28<00:09,  3.00it/s]
# Epoch 6 in training:  94%|█████████▍| 441/469 [02:28<00:09,  3.00it/s]
# Epoch 6 in training:  94%|█████████▍| 442/469 [02:29<00:09,  2.99it/s]
# Epoch 6 in training:  94%|█████████▍| 443/469 [02:29<00:08,  2.98it/s]
# Epoch 6 in training:  95%|█████████▍| 444/469 [02:29<00:08,  2.97it/s]
# Epoch 6 in training:  95%|█████████▍| 445/469 [02:30<00:08,  2.91it/s]
# Epoch 6 in training:  95%|█████████▌| 446/469 [02:30<00:07,  2.93it/s]
# Epoch 6 in training:  95%|█████████▌| 447/469 [02:30<00:07,  2.95it/s]
# Epoch 6 in training:  96%|█████████▌| 448/469 [02:31<00:07,  2.97it/s]
# Epoch 6 in training:  96%|█████████▌| 449/469 [02:31<00:06,  2.97it/s]
# Epoch 6 in training:  96%|█████████▌| 450/469 [02:31<00:06,  2.98it/s]
# Epoch 6 in training:  96%|█████████▌| 451/469 [02:32<00:06,  2.99it/s]
# Epoch 6 in training:  96%|█████████▋| 452/469 [02:32<00:05,  2.99it/s]
# Epoch 6 in training:  97%|█████████▋| 453/469 [02:32<00:05,  2.97it/s]
# Epoch 6 in training:  97%|█████████▋| 454/469 [02:33<00:05,  2.97it/s]
# Epoch 6 in training:  97%|█████████▋| 455/469 [02:33<00:04,  2.98it/s]
# Epoch 6 in training:  97%|█████████▋| 456/469 [02:33<00:04,  3.00it/s]
# Epoch 6 in training:  97%|█████████▋| 457/469 [02:34<00:03,  3.01it/s]
# Epoch 6 in training:  98%|█████████▊| 458/469 [02:34<00:03,  3.01it/s]
# Epoch 6 in training:  98%|█████████▊| 459/469 [02:34<00:03,  3.01it/s]
# Epoch 6 in training:  98%|█████████▊| 460/469 [02:35<00:02,  3.00it/s]
# Epoch 6 in training:  98%|█████████▊| 461/469 [02:35<00:02,  2.98it/s]
# Epoch 6 in training:  99%|█████████▊| 462/469 [02:35<00:02,  2.99it/s]
# Epoch 6 in training:  99%|█████████▊| 463/469 [02:36<00:02,  3.00it/s]
# Epoch 6 in training:  99%|█████████▉| 464/469 [02:36<00:01,  2.99it/s]
# Epoch 6 in training:  99%|█████████▉| 465/469 [02:36<00:01,  2.99it/s]
# Epoch 6 in training:  99%|█████████▉| 466/469 [02:37<00:01,  2.99it/s]
# Epoch 6 in training: 100%|█████████▉| 467/469 [02:37<00:00,  2.99it/s]
# Epoch 6 in training: 100%|█████████▉| 468/469 [02:37<00:00,  2.99it/s]
# Epoch 6 in training: 100%|██████████| 469/469 [02:38<00:00,  3.10it/s]
# train:  75%|███████▌  | 6/8 [15:50<05:16, 158.38s/it]
# Epoch 6/8 loss: 1.65
# Epoch 7 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 7 in training:   0%|          | 1/469 [00:00<02:41,  2.89it/s]
# Epoch 7 in training:   0%|          | 2/469 [00:00<02:41,  2.89it/s]
# Epoch 7 in training:   1%|          | 3/469 [00:01<02:38,  2.95it/s]
# Epoch 7 in training:   1%|          | 4/469 [00:01<02:36,  2.97it/s]
# Epoch 7 in training:   1%|          | 5/469 [00:01<02:41,  2.88it/s]
# Epoch 7 in training:   1%|▏         | 6/469 [00:02<02:38,  2.92it/s]
# Epoch 7 in training:   1%|▏         | 7/469 [00:02<02:37,  2.94it/s]
# Epoch 7 in training:   2%|▏         | 8/469 [00:02<02:35,  2.96it/s]
# Epoch 7 in training:   2%|▏         | 9/469 [00:03<02:34,  2.97it/s]
# Epoch 7 in training:   2%|▏         | 10/469 [00:03<02:33,  2.98it/s]
# Epoch 7 in training:   2%|▏         | 11/469 [00:03<02:33,  2.99it/s]
# Epoch 7 in training:   3%|▎         | 12/469 [00:04<02:32,  3.00it/s]
# Epoch 7 in training:   3%|▎         | 13/469 [00:04<02:32,  2.99it/s]
# Epoch 7 in training:   3%|▎         | 14/469 [00:04<02:32,  2.99it/s]
# Epoch 7 in training:   3%|▎         | 15/469 [00:05<02:31,  3.00it/s]
# Epoch 7 in training:   3%|▎         | 16/469 [00:05<02:30,  3.00it/s]
# Epoch 7 in training:   4%|▎         | 17/469 [00:05<02:30,  3.00it/s]
# Epoch 7 in training:   4%|▍         | 18/469 [00:06<02:30,  3.00it/s]
# Epoch 7 in training:   4%|▍         | 19/469 [00:06<02:30,  2.99it/s]
# Epoch 7 in training:   4%|▍         | 20/469 [00:06<02:30,  2.99it/s]
# Epoch 7 in training:   4%|▍         | 21/469 [00:07<02:29,  3.00it/s]
# Epoch 7 in training:   5%|▍         | 22/469 [00:07<02:29,  3.00it/s]
# Epoch 7 in training:   5%|▍         | 23/469 [00:07<02:28,  3.00it/s]
# Epoch 7 in training:   5%|▌         | 24/469 [00:08<02:28,  3.00it/s]
# Epoch 7 in training:   5%|▌         | 25/469 [00:08<02:27,  3.00it/s]
# Epoch 7 in training:   6%|▌         | 26/469 [00:08<02:27,  3.00it/s]
# Epoch 7 in training:   6%|▌         | 27/469 [00:09<02:26,  3.01it/s]
# Epoch 7 in training:   6%|▌         | 28/469 [00:09<02:26,  3.01it/s]
# Epoch 7 in training:   6%|▌         | 29/469 [00:09<02:26,  3.00it/s]
# Epoch 7 in training:   6%|▋         | 30/469 [00:10<02:26,  3.01it/s]
# Epoch 7 in training:   7%|▋         | 31/469 [00:10<02:26,  2.99it/s]
# Epoch 7 in training:   7%|▋         | 32/469 [00:10<02:26,  2.98it/s]
# Epoch 7 in training:   7%|▋         | 33/469 [00:11<02:25,  2.99it/s]
# Epoch 7 in training:   7%|▋         | 34/469 [00:11<02:25,  2.99it/s]
# Epoch 7 in training:   7%|▋         | 35/469 [00:11<02:28,  2.92it/s]
# Epoch 7 in training:   8%|▊         | 36/469 [00:12<02:27,  2.94it/s]
# Epoch 7 in training:   8%|▊         | 37/469 [00:12<02:26,  2.95it/s]
# Epoch 7 in training:   8%|▊         | 38/469 [00:12<02:25,  2.96it/s]
# Epoch 7 in training:   8%|▊         | 39/469 [00:13<02:25,  2.96it/s]
# Epoch 7 in training:   9%|▊         | 40/469 [00:13<02:24,  2.97it/s]
# Epoch 7 in training:   9%|▊         | 41/469 [00:13<02:23,  2.98it/s]
# Epoch 7 in training:   9%|▉         | 42/469 [00:14<02:22,  3.00it/s]
# Epoch 7 in training:   9%|▉         | 43/469 [00:14<02:22,  3.00it/s]
# Epoch 7 in training:   9%|▉         | 44/469 [00:14<02:21,  2.99it/s]
# Epoch 7 in training:  10%|▉         | 45/469 [00:15<02:27,  2.87it/s]
# Epoch 7 in training:  10%|▉         | 46/469 [00:15<02:28,  2.84it/s]
# Epoch 7 in training:  10%|█         | 47/469 [00:15<02:26,  2.87it/s]
# Epoch 7 in training:  10%|█         | 48/469 [00:16<02:25,  2.90it/s]
# Epoch 7 in training:  10%|█         | 49/469 [00:16<02:24,  2.91it/s]
# Epoch 7 in training:  11%|█         | 50/469 [00:16<02:22,  2.94it/s]
# Epoch 7 in training:  11%|█         | 51/469 [00:17<02:21,  2.96it/s]
# Epoch 7 in training:  11%|█         | 52/469 [00:17<02:20,  2.97it/s]
# Epoch 7 in training:  11%|█▏        | 53/469 [00:17<02:19,  2.97it/s]
# Epoch 7 in training:  12%|█▏        | 54/469 [00:18<02:19,  2.98it/s]
# Epoch 7 in training:  12%|█▏        | 55/469 [00:18<02:19,  2.97it/s]
# Epoch 7 in training:  12%|█▏        | 56/469 [00:18<02:18,  2.98it/s]
# Epoch 7 in training:  12%|█▏        | 57/469 [00:19<02:18,  2.98it/s]
# Epoch 7 in training:  12%|█▏        | 58/469 [00:19<02:17,  2.98it/s]
# Epoch 7 in training:  13%|█▎        | 59/469 [00:19<02:17,  2.98it/s]
# Epoch 7 in training:  13%|█▎        | 60/469 [00:20<02:16,  3.00it/s]
# Epoch 7 in training:  13%|█▎        | 61/469 [00:20<02:16,  2.98it/s]
# Epoch 7 in training:  13%|█▎        | 62/469 [00:20<02:16,  2.99it/s]
# Epoch 7 in training:  13%|█▎        | 63/469 [00:21<02:16,  2.98it/s]
# Epoch 7 in training:  14%|█▎        | 64/469 [00:21<02:15,  2.98it/s]
# Epoch 7 in training:  14%|█▍        | 65/469 [00:21<02:18,  2.92it/s]
# Epoch 7 in training:  14%|█▍        | 66/469 [00:22<02:16,  2.95it/s]
# Epoch 7 in training:  14%|█▍        | 67/469 [00:22<02:15,  2.96it/s]
# Epoch 7 in training:  14%|█▍        | 68/469 [00:22<02:15,  2.97it/s]
# Epoch 7 in training:  15%|█▍        | 69/469 [00:23<02:14,  2.97it/s]
# Epoch 7 in training:  15%|█▍        | 70/469 [00:23<02:13,  2.98it/s]
# Epoch 7 in training:  15%|█▌        | 71/469 [00:23<02:12,  2.99it/s]
# Epoch 7 in training:  15%|█▌        | 72/469 [00:24<02:12,  3.00it/s]
# Epoch 7 in training:  16%|█▌        | 73/469 [00:24<02:12,  2.99it/s]
# Epoch 7 in training:  16%|█▌        | 74/469 [00:24<02:11,  2.99it/s]
# Epoch 7 in training:  16%|█▌        | 75/469 [00:25<02:11,  2.99it/s]
# Epoch 7 in training:  16%|█▌        | 76/469 [00:25<02:11,  2.99it/s]
# Epoch 7 in training:  16%|█▋        | 77/469 [00:25<02:11,  2.99it/s]
# Epoch 7 in training:  17%|█▋        | 78/469 [00:26<02:10,  2.99it/s]
# Epoch 7 in training:  17%|█▋        | 79/469 [00:26<02:10,  2.99it/s]
# Epoch 7 in training:  17%|█▋        | 80/469 [00:26<02:09,  3.00it/s]
# Epoch 7 in training:  17%|█▋        | 81/469 [00:27<02:09,  3.00it/s]
# Epoch 7 in training:  17%|█▋        | 82/469 [00:27<02:09,  2.99it/s]
# Epoch 7 in training:  18%|█▊        | 83/469 [00:27<02:10,  2.97it/s]
# Epoch 7 in training:  18%|█▊        | 84/469 [00:28<02:09,  2.98it/s]
# Epoch 7 in training:  18%|█▊        | 85/469 [00:28<02:08,  2.98it/s]
# Epoch 7 in training:  18%|█▊        | 86/469 [00:28<02:08,  2.99it/s]
# Epoch 7 in training:  19%|█▊        | 87/469 [00:29<02:07,  2.99it/s]
# Epoch 7 in training:  19%|█▉        | 88/469 [00:29<02:07,  2.99it/s]
# Epoch 7 in training:  19%|█▉        | 89/469 [00:29<02:06,  2.99it/s]
# Epoch 7 in training:  19%|█▉        | 90/469 [00:30<02:06,  2.99it/s]
# Epoch 7 in training:  19%|█▉        | 91/469 [00:30<02:06,  2.99it/s]
# Epoch 7 in training:  20%|█▉        | 92/469 [00:30<02:05,  2.99it/s]
# Epoch 7 in training:  20%|█▉        | 93/469 [00:31<02:05,  2.99it/s]
# Epoch 7 in training:  20%|██        | 94/469 [00:31<02:05,  2.99it/s]
# Epoch 7 in training:  20%|██        | 95/469 [00:31<02:07,  2.93it/s]
# Epoch 7 in training:  20%|██        | 96/469 [00:32<02:06,  2.94it/s]
# Epoch 7 in training:  21%|██        | 97/469 [00:32<02:05,  2.96it/s]
# Epoch 7 in training:  21%|██        | 98/469 [00:32<02:04,  2.98it/s]
# Epoch 7 in training:  21%|██        | 99/469 [00:33<02:03,  2.98it/s]
# Epoch 7 in training:  21%|██▏       | 100/469 [00:33<02:03,  3.00it/s]
# Epoch 7 in training:  22%|██▏       | 101/469 [00:33<02:02,  3.01it/s]
# Epoch 7 in training:  22%|██▏       | 102/469 [00:34<02:02,  2.99it/s]
# Epoch 7 in training:  22%|██▏       | 103/469 [00:34<02:01,  3.00it/s]
# Epoch 7 in training:  22%|██▏       | 104/469 [00:34<02:01,  3.00it/s]

# %%
path: str = "flashkan_vit_5epochs.pth"

torch.save(mnist_model.state_dict(), path)
