# %%
from pathlib import Path
import torch
import numpy as np
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
# Uncomment this line for MNIST training.
from torchvision.datasets.mnist import MNIST
from torchvision import transforms
from tqdm import tqdm, trange
from torch.optim import Adam

np.random.seed(42)
torch.manual_seed(42)

# %%
class MSA(torch.nn.Module):
    """
    This is the template implementation of the "Multi-Scale Attention" Layer.

    The query, key and value mapping are matrix-multipled against each other in order to
    find the attention, or, the relation of a word and its interaction with surrounding words.
    """
    def __init__(self, d, n_heads=4):
        super(MSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0  # Shouldn't divide dimension (d) into n_heads

        d_head = int(d / n_heads)
        self.q_mappings = torch.nn.ModuleList([torch.nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = torch.nn.ModuleList([torch.nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = torch.nn.ModuleList([torch.nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = torch.nn.Softmax(dim=-1)

    def forward(self, sequences):
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
# !pip install monai
# !pip install einops
# Out:
# Collecting monai
#   Downloading monai-1.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai) (2.1.2)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (2024.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Downloading monai-1.3.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: monai
# Successfully installed monai-1.3.2
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.8.0

# %%
import math
import torch
from functools import partial
from torch import nn, einsum
from torch.autograd.function import Function

from einops import rearrange

from torch.jit import fork, wait

from torch.cuda.amp import autocast, GradScaler
from torch.nn import DataParallel
# constants

EPSILON = 1e-10

# helper functions

def exists(val):
    return val is not None

def default(val, d):
    return val if exists(val) else d

class FlashAttentionFunction(Function):
    @staticmethod
    @torch.no_grad()
    def forward(ctx, q, k, v, mask, causal, q_bucket_size, k_bucket_size):
        """ Algorithm 1 in the v2 paper """

        device = q.device
        max_neg_value = -torch.finfo(q.dtype).max
        qk_len_diff = max(k.shape[-2] - q.shape[-2], 0)

        o = torch.zeros_like(q)
        all_row_sums = torch.zeros((*q.shape[:-1], 1), device = device)
        all_row_maxes = torch.full((*q.shape[:-1], 1), max_neg_value, device = device)

        scale = (q.shape[-1] ** -0.5)

        num_row_tiles = math.ceil(q.shape[-2] / q_bucket_size)
        num_col_tiles = math.ceil(k.shape[-2] / k_bucket_size)

        if exists(mask) and mask.ndim == 2:
            mask = rearrange(mask, 'b n -> b 1 1 n')

        if not exists(mask):
            col_masks = (None,) * num_col_tiles
            mask = (col_masks,) * num_row_tiles 
        else:
            mask = ((mask,) * num_row_tiles) if mask.shape[-2] == 1 else mask.split(q_bucket_size, dim = -2)
            mask = tuple(((row_mask,) * num_col_tiles) if row_mask.shape[-1] == 1 else row_mask.split(k_bucket_size, dim = -1) for row_mask in mask)

        row_splits = zip(
            q.split(q_bucket_size, dim = -2),
            o.split(q_bucket_size, dim = -2),
            mask,
            all_row_sums.split(q_bucket_size, dim = -2),
            all_row_maxes.split(q_bucket_size, dim = -2),
        )

        for ind, (qc, oc, row_mask, row_sums, row_maxes) in enumerate(row_splits):
            q_start_index = ind * q_bucket_size - qk_len_diff

            col_splits = zip(
                k.split(k_bucket_size, dim = -2),
                v.split(k_bucket_size, dim = -2),
                row_mask
            )

            for k_ind, (kc, vc, col_mask) in enumerate(col_splits):
                k_start_index = k_ind * k_bucket_size

                attn_weights = einsum('... i d, ... j d -> ... i j', qc, kc) * scale

                if exists(col_mask):
                    attn_weights.masked_fill_(~col_mask, max_neg_value)

                if causal and q_start_index < (k_start_index + k_bucket_size - 1):
                    causal_mask = torch.ones((qc.shape[-2], kc.shape[-2]), dtype = torch.bool, device = device).triu(q_start_index - k_start_index + 1)
                    attn_weights.masked_fill_(causal_mask, max_neg_value)

                block_row_maxes = attn_weights.amax(dim = -1, keepdims = True)
                new_row_maxes = torch.maximum(block_row_maxes, row_maxes)

                exp_weights = torch.exp(attn_weights - new_row_maxes)

                if exists(col_mask):
                    exp_weights.masked_fill_(~col_mask, 0.)

                block_row_sums = exp_weights.sum(dim = -1, keepdims = True).clamp(min = EPSILON)

                exp_values = einsum('... i j, ... j d -> ... i d', exp_weights, vc)

                exp_row_max_diff = torch.exp(row_maxes - new_row_maxes)

                new_row_sums = exp_row_max_diff * row_sums + block_row_sums

                oc.mul_(exp_row_max_diff).add_(exp_values)

                row_maxes.copy_(new_row_maxes)
                row_sums.copy_(new_row_sums)

            oc.div_(row_sums)

        lse = all_row_sums.log() + all_row_maxes

        ctx.args = (causal, scale, mask, q_bucket_size, k_bucket_size)
        ctx.save_for_backward(q, k, v, o, lse)

        return o

    @staticmethod
    @torch.no_grad()
    def backward(ctx, do):
        """ Algorithm 2 in the v2 paper """

        causal, scale, mask, q_bucket_size, k_bucket_size = ctx.args
        q, k, v, o, lse = ctx.saved_tensors

        device = q.device

        max_neg_value = -torch.finfo(q.dtype).max
        qk_len_diff = max(k.shape[-2] - q.shape[-2], 0)

        dq = torch.zeros_like(q)
        dk = torch.zeros_like(k)
        dv = torch.zeros_like(v)

        row_splits = zip(
            q.split(q_bucket_size, dim = -2),
            o.split(q_bucket_size, dim = -2),
            do.split(q_bucket_size, dim = -2),
            mask,
            lse.split(q_bucket_size, dim = -2),
            dq.split(q_bucket_size, dim = -2)
        )

        for ind, (qc, oc, doc, row_mask, lsec, dqc) in enumerate(row_splits):
            q_start_index = ind * q_bucket_size - qk_len_diff

            col_splits = zip(
                k.split(k_bucket_size, dim = -2),
                v.split(k_bucket_size, dim = -2),
                dk.split(k_bucket_size, dim = -2),
                dv.split(k_bucket_size, dim = -2),
                row_mask
            )

            for k_ind, (kc, vc, dkc, dvc, col_mask) in enumerate(col_splits):
                k_start_index = k_ind * k_bucket_size

                attn_weights = einsum('... i d, ... j d -> ... i j', qc, kc) * scale

                if causal and q_start_index < (k_start_index + k_bucket_size - 1):
                    causal_mask = torch.ones((qc.shape[-2], kc.shape[-2]), dtype = torch.bool, device = device).triu(q_start_index - k_start_index + 1)
                    attn_weights.masked_fill_(causal_mask, max_neg_value)

                p = torch.exp(attn_weights - lsec)

                if exists(col_mask):
                    p.masked_fill_(~col_mask, 0.)

                dv_chunk = einsum('... i j, ... i d -> ... j d', p, doc)
                dp = einsum('... i d, ... j d -> ... i j', doc, vc)

                D = (doc * oc).sum(dim = -1, keepdims = True)
                ds = p * scale * (dp - D)

                dq_chunk = einsum('... i j, ... j d -> ... i d', ds, kc)
                dk_chunk = einsum('... i j, ... i d -> ... j d', ds, qc)

                dqc.add_(dq_chunk)
                dkc.add_(dk_chunk)
                dvc.add_(dv_chunk)

        return dq, dk, dv, None, None, None, None

# %%
class FlashAttention(nn.Module):
    def __init__(
        self,
        *,
        dim,
        heads = 8,
        dim_head = 64,
        causal = False,
        q_bucket_size = 512,
        k_bucket_size = 1024,
        parallel = False,
        mixed_precision = False
    ):
        super().__init__()
        self.heads = heads
        self.causal = causal
        self.parallel = parallel
        self.mixed_precision = mixed_precision

        inner_dim = heads * dim_head

        self.to_q = nn.Linear(dim, inner_dim, bias = False)
        self.to_kv = nn.Linear(dim, inner_dim * 2, bias = False)
        self.to_out = nn.Linear(inner_dim, dim, bias = False)

        # memory efficient attention related parameters
        # can be overriden on forward
        self.q_bucket_size = q_bucket_size
        self.k_bucket_size = k_bucket_size

        if self.parallel:
            self.model = DataParallel(self)
        if self.mixed_precision:
            self.scaler = GradScaler()

    def forward(
        self,
        x,
        context = None,
        mask = None,
        q_bucket_size = None,
        k_bucket_size = None,
    ):
        q_bucket_size = default(q_bucket_size, self.q_bucket_size)
        k_bucket_size = default(k_bucket_size, self.k_bucket_size)

        h = self.heads
        context = default(context, x)

        q = self.to_q(x)
        k, v = self.to_kv(context).chunk(2, dim=-1)

        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h=h), (q, k, v))

        if self.parallel:
            # Split the input data into chunks and move each chunk to the correct GPU
            num_gpus = torch.cuda.device_count()
            x_chunks = x.split(x.size(0) // num_gpus)
            x_chunks = [chunk.to(f'cuda:{i}') for i, chunk in enumerate(x_chunks)]
            q = x_chunks

        if self.mixed_precision:
            # Use autocast to allow operations to run in lower precision
            with autocast():
                out = FlashAttentionFunction.apply(q, k, v, mask, self.causal, q_bucket_size, k_bucket_size)
        else:
            out = FlashAttentionFunction.apply(q, k, v, mask, self.causal, q_bucket_size, k_bucket_size)

        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

# %%
class FlashViT(torch.nn.Module):
    """
    The workflow will be as follows.
        1. Find the linear mapping of the input
        2. Embed them using the function that we have written
        3. Use 'n' MSA blocks and add a linear and a softmax layer at the end
    """

    def __init__(self, chw, n_patches=16, n_blocks=2, hidden_d=8, n_heads=4, out_d=10):
        super(FlashViT, self).__init__()

        self.chw = chw
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d

        # Input and patch sizes
        assert chw[1] % n_patches == 0
        assert chw[2] % n_patches == 0
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # Linear mapping
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = torch.nn.Linear(self.input_d, self.hidden_d)

        # Classification token
        self.v_class = torch.nn.Parameter(torch.rand(1, self.hidden_d))

        # Positional embedding
        self.register_buffer('pos_embeddings', self.positional_embeddings(n_patches ** 2 + 1, hidden_d),
                             persistent=False)

        # Encoder blocks
        self.blocks = torch.nn.ModuleList([FlashAttention(dim = hidden_d, heads = n_heads) for _ in range(n_blocks)])

        self.mlp = torch.nn.Sequential(
            torch.nn.Linear(self.hidden_d, out_d),
            torch.nn.Softmax(dim=-1)
        )
        
    def patchify(self, images, n_patches):
        """
        In order to "sequentially" pass in the images, we can break down the main image into multiple sub-images
        and map them to a vector. This is exactly what this function does.

        Arguments:
        images: The image passed into this function
        n_patches: The number of patches to split the image into.

        Returns our patches aka the sub-images.
        """
        n, c, h, w = images.shape

        assert h == w, "Only for square images"

        patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
        patch_size = h // n_patches

        for idx, image in enumerate(images):
            for i in range(n_patches):
                for j in range(n_patches):
                    patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                    patches[idx, i * n_patches + j] = patch.flatten()
        return patches
    
    def positional_embeddings(self, sequence_length, d):
        """
        In order for the model to know where to place each image, one can use positional embeddings where high freq values
        are classified into the first few dimensions while low frequency values are added on to the latter dimensions. This
        function performs exactly that. It has two parameters.

        Arguments:
        sequence_length: The number of tokens for the dataset.
        d: The dimensionality for each token.

        Returns a matrix where each (i,j) is added as token i in dimension j.
        """
        result = torch.ones(sequence_length, d)
        for i in range(sequence_length):
            for j in range(d):
                result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** (j / d)))
        return result

    def forward(self, images):
        n, c, h, w = images.shape
        patches = self.patchify(images, self.n_patches).to(self.pos_embeddings.device)

        # rutorch.nning tokenization
        tokens = self.linear_mapper(patches)
        tokens = torch.cat((self.v_class.expand(n, 1, -1), tokens), dim=1)
        out = tokens + self.pos_embeddings.repeat(n, 1, 1)

        for block in self.blocks:
            out = block(out)

        out = out[:, 0]
        return self.mlp(out)

# %%
lr = 2e-3
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mnist_model = FlashViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)
optimizer = Adam(mnist_model.parameters(), lr=lr)

# %%
def main(train_loader, test_loader):
    """
    This code contains the training and testing loop for training the vision transformers model. It requires two
    parameters

    :param train_loader: The dataloader for the training set for training the model.
    :param test_loader: The dataloader for the testing set during evaluation phase.
    """
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    epochs = 5
    criterion = CrossEntropyLoss()
    for epoch in trange(epochs, desc="train"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch + 1}/{epochs} loss: {train_loss:.2f}")

    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
# For MNIST: comment out the lines above and uncomment the lines below.

transform = transforms.ToTensor()
train_mnist = MNIST(root='./mnist', train=True, download=True, transform=transform)
test_mnist = MNIST(root='./mnist', train=False, download=True, transform=transform)
train_loader = DataLoader(train_mnist, shuffle=True, batch_size=128)
test_loader = DataLoader(test_mnist, shuffle=False, batch_size=128)
main(train_loader=train_loader, test_loader=test_loader)
# Out:
# Using device:  cuda (Tesla P100-PCIE-16GB)
# train:   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:00<06:40,  1.17it/s]
# Epoch 1 in training:   0%|          | 2/469 [00:01<04:09,  1.87it/s]
# Epoch 1 in training:   1%|          | 3/469 [00:01<03:18,  2.34it/s]
# Epoch 1 in training:   1%|          | 4/469 [00:01<02:55,  2.66it/s]
# Epoch 1 in training:   1%|          | 5/469 [00:02<02:42,  2.86it/s]
# Epoch 1 in training:   1%|▏         | 6/469 [00:02<02:33,  3.01it/s]
# Epoch 1 in training:   1%|▏         | 7/469 [00:02<02:28,  3.11it/s]
# Epoch 1 in training:   2%|▏         | 8/469 [00:02<02:25,  3.18it/s]
# Epoch 1 in training:   2%|▏         | 9/469 [00:03<02:22,  3.23it/s]
# Epoch 1 in training:   2%|▏         | 10/469 [00:03<02:20,  3.26it/s]
# Epoch 1 in training:   2%|▏         | 11/469 [00:03<02:19,  3.27it/s]
# Epoch 1 in training:   3%|▎         | 12/469 [00:04<02:23,  3.19it/s]
# Epoch 1 in training:   3%|▎         | 13/469 [00:04<02:24,  3.17it/s]
# Epoch 1 in training:   3%|▎         | 14/469 [00:04<02:28,  3.06it/s]
# Epoch 1 in training:   3%|▎         | 15/469 [00:05<02:26,  3.09it/s]
# Epoch 1 in training:   3%|▎         | 16/469 [00:05<02:23,  3.15it/s]
# Epoch 1 in training:   4%|▎         | 17/469 [00:05<02:21,  3.20it/s]
# Epoch 1 in training:   4%|▍         | 18/469 [00:06<02:19,  3.24it/s]
# Epoch 1 in training:   4%|▍         | 19/469 [00:06<02:17,  3.27it/s]
# Epoch 1 in training:   4%|▍         | 20/469 [00:06<02:16,  3.29it/s]
# Epoch 1 in training:   4%|▍         | 21/469 [00:06<02:15,  3.31it/s]
# Epoch 1 in training:   5%|▍         | 22/469 [00:07<02:14,  3.33it/s]
# Epoch 1 in training:   5%|▍         | 23/469 [00:07<02:12,  3.35it/s]
# Epoch 1 in training:   5%|▌         | 24/469 [00:07<02:12,  3.36it/s]
# Epoch 1 in training:   5%|▌         | 25/469 [00:08<02:12,  3.35it/s]
# Epoch 1 in training:   6%|▌         | 26/469 [00:08<02:12,  3.34it/s]
# Epoch 1 in training:   6%|▌         | 27/469 [00:08<02:11,  3.35it/s]
# Epoch 1 in training:   6%|▌         | 28/469 [00:09<02:11,  3.35it/s]
# Epoch 1 in training:   6%|▌         | 29/469 [00:09<02:10,  3.36it/s]
# Epoch 1 in training:   6%|▋         | 30/469 [00:09<02:10,  3.36it/s]
# Epoch 1 in training:   7%|▋         | 31/469 [00:09<02:10,  3.36it/s]
# Epoch 1 in training:   7%|▋         | 32/469 [00:10<02:10,  3.36it/s]
# Epoch 1 in training:   7%|▋         | 33/469 [00:10<02:10,  3.35it/s]
# Epoch 1 in training:   7%|▋         | 34/469 [00:10<02:09,  3.35it/s]
# Epoch 1 in training:   7%|▋         | 35/469 [00:11<02:09,  3.35it/s]
# Epoch 1 in training:   8%|▊         | 36/469 [00:11<02:09,  3.35it/s]
# Epoch 1 in training:   8%|▊         | 37/469 [00:11<02:09,  3.35it/s]
# Epoch 1 in training:   8%|▊         | 38/469 [00:12<02:08,  3.35it/s]
# Epoch 1 in training:   8%|▊         | 39/469 [00:12<02:08,  3.35it/s]
# Epoch 1 in training:   9%|▊         | 40/469 [00:12<02:07,  3.36it/s]
# Epoch 1 in training:   9%|▊         | 41/469 [00:12<02:07,  3.35it/s]
# Epoch 1 in training:   9%|▉         | 42/469 [00:13<02:07,  3.35it/s]
# Epoch 1 in training:   9%|▉         | 43/469 [00:13<02:06,  3.36it/s]
# Epoch 1 in training:   9%|▉         | 44/469 [00:13<02:06,  3.35it/s]
# Epoch 1 in training:  10%|▉         | 45/469 [00:14<02:06,  3.36it/s]
# Epoch 1 in training:  10%|▉         | 46/469 [00:14<02:06,  3.36it/s]
# Epoch 1 in training:  10%|█         | 47/469 [00:14<02:11,  3.21it/s]
# Epoch 1 in training:  10%|█         | 48/469 [00:15<02:09,  3.26it/s]
# Epoch 1 in training:  10%|█         | 49/469 [00:15<02:07,  3.29it/s]
# Epoch 1 in training:  11%|█         | 50/469 [00:15<02:06,  3.30it/s]
# Epoch 1 in training:  11%|█         | 51/469 [00:15<02:06,  3.32it/s]
# Epoch 1 in training:  11%|█         | 52/469 [00:16<02:05,  3.33it/s]
# Epoch 1 in training:  11%|█▏        | 53/469 [00:16<02:04,  3.35it/s]
# Epoch 1 in training:  12%|█▏        | 54/469 [00:16<02:03,  3.35it/s]
# Epoch 1 in training:  12%|█▏        | 55/469 [00:17<02:03,  3.36it/s]
# Epoch 1 in training:  12%|█▏        | 56/469 [00:17<02:03,  3.35it/s]
# Epoch 1 in training:  12%|█▏        | 57/469 [00:17<02:02,  3.35it/s]
# Epoch 1 in training:  12%|█▏        | 58/469 [00:18<02:02,  3.36it/s]
# Epoch 1 in training:  13%|█▎        | 59/469 [00:18<02:01,  3.37it/s]
# Epoch 1 in training:  13%|█▎        | 60/469 [00:18<02:01,  3.36it/s]
# Epoch 1 in training:  13%|█▎        | 61/469 [00:18<02:03,  3.31it/s]
# Epoch 1 in training:  13%|█▎        | 62/469 [00:19<02:02,  3.32it/s]
# Epoch 1 in training:  13%|█▎        | 63/469 [00:19<02:01,  3.34it/s]
# Epoch 1 in training:  14%|█▎        | 64/469 [00:19<02:01,  3.34it/s]
# Epoch 1 in training:  14%|█▍        | 65/469 [00:20<02:01,  3.33it/s]
# Epoch 1 in training:  14%|█▍        | 66/469 [00:20<02:00,  3.34it/s]
# Epoch 1 in training:  14%|█▍        | 67/469 [00:20<02:00,  3.33it/s]
# Epoch 1 in training:  14%|█▍        | 68/469 [00:21<02:00,  3.33it/s]
# Epoch 1 in training:  15%|█▍        | 69/469 [00:21<01:59,  3.34it/s]
# Epoch 1 in training:  15%|█▍        | 70/469 [00:21<01:59,  3.35it/s]
# Epoch 1 in training:  15%|█▌        | 71/469 [00:21<01:59,  3.34it/s]
# Epoch 1 in training:  15%|█▌        | 72/469 [00:22<01:58,  3.35it/s]
# Epoch 1 in training:  16%|█▌        | 73/469 [00:22<01:58,  3.35it/s]
# Epoch 1 in training:  16%|█▌        | 74/469 [00:22<01:57,  3.35it/s]
# Epoch 1 in training:  16%|█▌        | 75/469 [00:23<01:57,  3.34it/s]
# Epoch 1 in training:  16%|█▌        | 76/469 [00:23<01:57,  3.35it/s]
# Epoch 1 in training:  16%|█▋        | 77/469 [00:23<01:57,  3.35it/s]
# Epoch 1 in training:  17%|█▋        | 78/469 [00:24<01:56,  3.34it/s]
# Epoch 1 in training:  17%|█▋        | 79/469 [00:24<01:56,  3.35it/s]
# Epoch 1 in training:  17%|█▋        | 80/469 [00:24<01:58,  3.27it/s]
# Epoch 1 in training:  17%|█▋        | 81/469 [00:24<01:59,  3.24it/s]
# Epoch 1 in training:  17%|█▋        | 82/469 [00:25<01:58,  3.28it/s]
# Epoch 1 in training:  18%|█▊        | 83/469 [00:25<01:57,  3.30it/s]
# Epoch 1 in training:  18%|█▊        | 84/469 [00:25<01:56,  3.31it/s]
# Epoch 1 in training:  18%|█▊        | 85/469 [00:26<01:55,  3.33it/s]
# Epoch 1 in training:  18%|█▊        | 86/469 [00:26<01:54,  3.34it/s]
# Epoch 1 in training:  19%|█▊        | 87/469 [00:26<01:54,  3.35it/s]
# Epoch 1 in training:  19%|█▉        | 88/469 [00:27<01:53,  3.34it/s]
# Epoch 1 in training:  19%|█▉        | 89/469 [00:27<01:53,  3.36it/s]
# Epoch 1 in training:  19%|█▉        | 90/469 [00:27<01:52,  3.36it/s]
# Epoch 1 in training:  19%|█▉        | 91/469 [00:27<01:53,  3.34it/s]
# Epoch 1 in training:  20%|█▉        | 92/469 [00:28<01:52,  3.35it/s]
# Epoch 1 in training:  20%|█▉        | 93/469 [00:28<01:52,  3.35it/s]
# Epoch 1 in training:  20%|██        | 94/469 [00:28<01:51,  3.35it/s]
# Epoch 1 in training:  20%|██        | 95/469 [00:29<01:51,  3.36it/s]
# Epoch 1 in training:  20%|██        | 96/469 [00:29<01:50,  3.36it/s]
# Epoch 1 in training:  21%|██        | 97/469 [00:29<01:50,  3.36it/s]
# Epoch 1 in training:  21%|██        | 98/469 [00:30<01:50,  3.37it/s]
# Epoch 1 in training:  21%|██        | 99/469 [00:30<01:50,  3.36it/s]
# Epoch 1 in training:  21%|██▏       | 100/469 [00:30<01:49,  3.37it/s]
# Epoch 1 in training:  22%|██▏       | 101/469 [00:30<01:49,  3.37it/s]
# Epoch 1 in training:  22%|██▏       | 102/469 [00:31<01:49,  3.35it/s]
# Epoch 1 in training:  22%|██▏       | 103/469 [00:31<01:48,  3.36it/s]
# Epoch 1 in training:  22%|██▏       | 104/469 [00:31<01:48,  3.36it/s]
# Epoch 1 in training:  22%|██▏       | 105/469 [00:32<01:48,  3.37it/s]
# Epoch 1 in training:  23%|██▎       | 106/469 [00:32<01:47,  3.37it/s]
# Epoch 1 in training:  23%|██▎       | 107/469 [00:32<01:47,  3.37it/s]
# Epoch 1 in training:  23%|██▎       | 108/469 [00:33<01:47,  3.36it/s]
# Epoch 1 in training:  23%|██▎       | 109/469 [00:33<01:46,  3.37it/s]
# Epoch 1 in training:  23%|██▎       | 110/469 [00:33<01:46,  3.37it/s]
# Epoch 1 in training:  24%|██▎       | 111/469 [00:33<01:46,  3.37it/s]
# Epoch 1 in training:  24%|██▍       | 112/469 [00:34<01:46,  3.35it/s]
# Epoch 1 in training:  24%|██▍       | 113/469 [00:34<01:46,  3.34it/s]
# Epoch 1 in training:  24%|██▍       | 114/469 [00:34<01:48,  3.26it/s]
# Epoch 1 in training:  25%|██▍       | 115/469 [00:35<01:48,  3.28it/s]
# Epoch 1 in training:  25%|██▍       | 116/469 [00:35<01:50,  3.21it/s]
# Epoch 1 in training:  25%|██▍       | 117/469 [00:35<01:52,  3.12it/s]
# Epoch 1 in training:  25%|██▌       | 118/469 [00:36<01:50,  3.17it/s]
# Epoch 1 in training:  25%|██▌       | 119/469 [00:36<01:49,  3.20it/s]
# Epoch 1 in training:  26%|██▌       | 120/469 [00:36<01:47,  3.24it/s]
# Epoch 1 in training:  26%|██▌       | 121/469 [00:37<01:46,  3.27it/s]
# Epoch 1 in training:  26%|██▌       | 122/469 [00:37<01:45,  3.29it/s]
# Epoch 1 in training:  26%|██▌       | 123/469 [00:37<01:44,  3.31it/s]
# Epoch 1 in training:  26%|██▋       | 124/469 [00:37<01:44,  3.32it/s]
# Epoch 1 in training:  27%|██▋       | 125/469 [00:38<01:44,  3.31it/s]
# Epoch 1 in training:  27%|██▋       | 126/469 [00:38<01:43,  3.32it/s]
# Epoch 1 in training:  27%|██▋       | 127/469 [00:38<01:42,  3.33it/s]
# Epoch 1 in training:  27%|██▋       | 128/469 [00:39<01:42,  3.32it/s]
# Epoch 1 in training:  28%|██▊       | 129/469 [00:39<01:41,  3.34it/s]
# Epoch 1 in training:  28%|██▊       | 130/469 [00:39<01:41,  3.35it/s]
# Epoch 1 in training:  28%|██▊       | 131/469 [00:40<01:41,  3.33it/s]
# Epoch 1 in training:  28%|██▊       | 132/469 [00:40<01:41,  3.34it/s]
# Epoch 1 in training:  28%|██▊       | 133/469 [00:40<01:40,  3.33it/s]
# Epoch 1 in training:  29%|██▊       | 134/469 [00:40<01:40,  3.34it/s]
# Epoch 1 in training:  29%|██▉       | 135/469 [00:41<01:40,  3.34it/s]
# Epoch 1 in training:  29%|██▉       | 136/469 [00:41<01:39,  3.34it/s]
# Epoch 1 in training:  29%|██▉       | 137/469 [00:41<01:39,  3.35it/s]
# Epoch 1 in training:  29%|██▉       | 138/469 [00:42<01:38,  3.36it/s]
# Epoch 1 in training:  30%|██▉       | 139/469 [00:42<01:38,  3.36it/s]
# Epoch 1 in training:  30%|██▉       | 140/469 [00:42<01:37,  3.36it/s]
# Epoch 1 in training:  30%|███       | 141/469 [00:42<01:37,  3.36it/s]
# Epoch 1 in training:  30%|███       | 142/469 [00:43<01:37,  3.36it/s]
# Epoch 1 in training:  30%|███       | 143/469 [00:43<01:37,  3.35it/s]
# Epoch 1 in training:  31%|███       | 144/469 [00:43<01:37,  3.35it/s]
# Epoch 1 in training:  31%|███       | 145/469 [00:44<01:36,  3.35it/s]
# Epoch 1 in training:  31%|███       | 146/469 [00:44<01:36,  3.34it/s]
# Epoch 1 in training:  31%|███▏      | 147/469 [00:44<01:39,  3.25it/s]
# Epoch 1 in training:  32%|███▏      | 148/469 [00:45<01:38,  3.27it/s]
# Epoch 1 in training:  32%|███▏      | 149/469 [00:45<01:37,  3.30it/s]
# Epoch 1 in training:  32%|███▏      | 150/469 [00:45<01:36,  3.31it/s]
# Epoch 1 in training:  32%|███▏      | 151/469 [00:46<01:35,  3.33it/s]
# Epoch 1 in training:  32%|███▏      | 152/469 [00:46<01:35,  3.33it/s]
# Epoch 1 in training:  33%|███▎      | 153/469 [00:46<01:34,  3.35it/s]
# Epoch 1 in training:  33%|███▎      | 154/469 [00:46<01:34,  3.35it/s]
# Epoch 1 in training:  33%|███▎      | 155/469 [00:47<01:34,  3.34it/s]
# Epoch 1 in training:  33%|███▎      | 156/469 [00:47<01:33,  3.34it/s]
# Epoch 1 in training:  33%|███▎      | 157/469 [00:47<01:33,  3.34it/s]
# Epoch 1 in training:  34%|███▎      | 158/469 [00:48<01:33,  3.33it/s]
# Epoch 1 in training:  34%|███▍      | 159/469 [00:48<01:32,  3.35it/s]
# Epoch 1 in training:  34%|███▍      | 160/469 [00:48<01:31,  3.36it/s]
# Epoch 1 in training:  34%|███▍      | 161/469 [00:48<01:31,  3.36it/s]
# Epoch 1 in training:  35%|███▍      | 162/469 [00:49<01:31,  3.36it/s]
# Epoch 1 in training:  35%|███▍      | 163/469 [00:49<01:31,  3.35it/s]
# Epoch 1 in training:  35%|███▍      | 164/469 [00:49<01:31,  3.32it/s]
# Epoch 1 in training:  35%|███▌      | 165/469 [00:50<01:31,  3.33it/s]
# Epoch 1 in training:  35%|███▌      | 166/469 [00:50<01:30,  3.34it/s]
# Epoch 1 in training:  36%|███▌      | 167/469 [00:50<01:30,  3.34it/s]
# Epoch 1 in training:  36%|███▌      | 168/469 [00:51<01:30,  3.34it/s]
# Epoch 1 in training:  36%|███▌      | 169/469 [00:51<01:29,  3.35it/s]
# Epoch 1 in training:  36%|███▌      | 170/469 [00:51<01:29,  3.36it/s]
# Epoch 1 in training:  36%|███▋      | 171/469 [00:51<01:29,  3.34it/s]
# Epoch 1 in training:  37%|███▋      | 172/469 [00:52<01:28,  3.35it/s]
# Epoch 1 in training:  37%|███▋      | 173/469 [00:52<01:28,  3.36it/s]
# Epoch 1 in training:  37%|███▋      | 174/469 [00:52<01:27,  3.36it/s]
# Epoch 1 in training:  37%|███▋      | 175/469 [00:53<01:29,  3.27it/s]
# Epoch 1 in training:  38%|███▊      | 176/469 [00:53<01:29,  3.28it/s]
# Epoch 1 in training:  38%|███▊      | 177/469 [00:53<01:28,  3.30it/s]
# Epoch 1 in training:  38%|███▊      | 178/469 [00:54<01:28,  3.30it/s]
# Epoch 1 in training:  38%|███▊      | 179/469 [00:54<01:27,  3.31it/s]
# Epoch 1 in training:  38%|███▊      | 180/469 [00:54<01:29,  3.23it/s]
# Epoch 1 in training:  39%|███▊      | 181/469 [00:55<01:28,  3.26it/s]
# Epoch 1 in training:  39%|███▉      | 182/469 [00:55<01:27,  3.29it/s]
# Epoch 1 in training:  39%|███▉      | 183/469 [00:55<01:26,  3.29it/s]
# Epoch 1 in training:  39%|███▉      | 184/469 [00:55<01:26,  3.29it/s]
# Epoch 1 in training:  39%|███▉      | 185/469 [00:56<01:26,  3.30it/s]
# Epoch 1 in training:  40%|███▉      | 186/469 [00:56<01:25,  3.30it/s]
# Epoch 1 in training:  40%|███▉      | 187/469 [00:56<01:25,  3.28it/s]
# Epoch 1 in training:  40%|████      | 188/469 [00:57<01:25,  3.30it/s]
# Epoch 1 in training:  40%|████      | 189/469 [00:57<01:24,  3.31it/s]
# Epoch 1 in training:  41%|████      | 190/469 [00:57<01:24,  3.31it/s]
# Epoch 1 in training:  41%|████      | 191/469 [00:58<01:23,  3.31it/s]
# Epoch 1 in training:  41%|████      | 192/469 [00:58<01:23,  3.30it/s]
# Epoch 1 in training:  41%|████      | 193/469 [00:58<01:23,  3.30it/s]
# Epoch 1 in training:  41%|████▏     | 194/469 [00:58<01:23,  3.30it/s]
# Epoch 1 in training:  42%|████▏     | 195/469 [00:59<01:23,  3.28it/s]
# Epoch 1 in training:  42%|████▏     | 196/469 [00:59<01:23,  3.28it/s]
# Epoch 1 in training:  42%|████▏     | 197/469 [00:59<01:23,  3.25it/s]
# Epoch 1 in training:  42%|████▏     | 198/469 [01:00<01:24,  3.22it/s]
# Epoch 1 in training:  42%|████▏     | 199/469 [01:00<01:23,  3.25it/s]
# Epoch 1 in training:  43%|████▎     | 200/469 [01:00<01:21,  3.28it/s]
# Epoch 1 in training:  43%|████▎     | 201/469 [01:01<01:21,  3.30it/s]
# Epoch 1 in training:  43%|████▎     | 202/469 [01:01<01:20,  3.32it/s]
# Epoch 1 in training:  43%|████▎     | 203/469 [01:01<01:20,  3.31it/s]
# Epoch 1 in training:  43%|████▎     | 204/469 [01:02<01:20,  3.31it/s]
# Epoch 1 in training:  44%|████▎     | 205/469 [01:02<01:19,  3.32it/s]
# Epoch 1 in training:  44%|████▍     | 206/469 [01:02<01:19,  3.32it/s]
# Epoch 1 in training:  44%|████▍     | 207/469 [01:02<01:18,  3.32it/s]
# Epoch 1 in training:  44%|████▍     | 208/469 [01:03<01:18,  3.34it/s]
# Epoch 1 in training:  45%|████▍     | 209/469 [01:03<01:17,  3.35it/s]
# Epoch 1 in training:  45%|████▍     | 210/469 [01:03<01:17,  3.34it/s]
# Epoch 1 in training:  45%|████▍     | 211/469 [01:04<01:18,  3.31it/s]
# Epoch 1 in training:  45%|████▌     | 212/469 [01:04<01:17,  3.32it/s]
# Epoch 1 in training:  45%|████▌     | 213/469 [01:04<01:18,  3.24it/s]
# Epoch 1 in training:  46%|████▌     | 214/469 [01:05<01:18,  3.26it/s]
# Epoch 1 in training:  46%|████▌     | 215/469 [01:05<01:18,  3.23it/s]
# Epoch 1 in training:  46%|████▌     | 216/469 [01:05<01:18,  3.23it/s]
# Epoch 1 in training:  46%|████▋     | 217/469 [01:05<01:17,  3.26it/s]
# Epoch 1 in training:  46%|████▋     | 218/469 [01:06<01:16,  3.30it/s]
# Epoch 1 in training:  47%|████▋     | 219/469 [01:06<01:17,  3.22it/s]
# Epoch 1 in training:  47%|████▋     | 220/469 [01:06<01:18,  3.15it/s]
# Epoch 1 in training:  47%|████▋     | 221/469 [01:07<01:18,  3.17it/s]
# Epoch 1 in training:  47%|████▋     | 222/469 [01:07<01:18,  3.13it/s]
# Epoch 1 in training:  48%|████▊     | 223/469 [01:07<01:17,  3.19it/s]
# Epoch 1 in training:  48%|████▊     | 224/469 [01:08<01:15,  3.24it/s]
# Epoch 1 in training:  48%|████▊     | 225/469 [01:08<01:14,  3.27it/s]
# Epoch 1 in training:  48%|████▊     | 226/469 [01:08<01:13,  3.30it/s]
# Epoch 1 in training:  48%|████▊     | 227/469 [01:09<01:13,  3.30it/s]
# Epoch 1 in training:  49%|████▊     | 228/469 [01:09<01:12,  3.31it/s]
# Epoch 1 in training:  49%|████▉     | 229/469 [01:09<01:12,  3.31it/s]
# Epoch 1 in training:  49%|████▉     | 230/469 [01:09<01:12,  3.32it/s]
# Epoch 1 in training:  49%|████▉     | 231/469 [01:10<01:11,  3.32it/s]
# Epoch 1 in training:  49%|████▉     | 232/469 [01:10<01:11,  3.33it/s]
# Epoch 1 in training:  50%|████▉     | 233/469 [01:10<01:10,  3.33it/s]
# Epoch 1 in training:  50%|████▉     | 234/469 [01:11<01:11,  3.30it/s]
# Epoch 1 in training:  50%|█████     | 235/469 [01:11<01:10,  3.31it/s]
# Epoch 1 in training:  50%|█████     | 236/469 [01:11<01:10,  3.33it/s]
# Epoch 1 in training:  51%|█████     | 237/469 [01:12<01:09,  3.33it/s]
# Epoch 1 in training:  51%|█████     | 238/469 [01:12<01:09,  3.34it/s]
# Epoch 1 in training:  51%|█████     | 239/469 [01:12<01:08,  3.34it/s]
# Epoch 1 in training:  51%|█████     | 240/469 [01:12<01:08,  3.33it/s]
# Epoch 1 in training:  51%|█████▏    | 241/469 [01:13<01:08,  3.35it/s]
# Epoch 1 in training:  52%|█████▏    | 242/469 [01:13<01:07,  3.36it/s]
# Epoch 1 in training:  52%|█████▏    | 243/469 [01:13<01:07,  3.35it/s]
# Epoch 1 in training:  52%|█████▏    | 244/469 [01:14<01:07,  3.33it/s]
# Epoch 1 in training:  52%|█████▏    | 245/469 [01:14<01:07,  3.34it/s]
# Epoch 1 in training:  52%|█████▏    | 246/469 [01:14<01:09,  3.21it/s]
# Epoch 1 in training:  53%|█████▎    | 247/469 [01:15<01:08,  3.26it/s]
# Epoch 1 in training:  53%|█████▎    | 248/469 [01:15<01:07,  3.29it/s]
# Epoch 1 in training:  53%|█████▎    | 249/469 [01:15<01:06,  3.32it/s]
# Epoch 1 in training:  53%|█████▎    | 250/469 [01:15<01:06,  3.32it/s]
# Epoch 1 in training:  54%|█████▎    | 251/469 [01:16<01:05,  3.31it/s]
# Epoch 1 in training:  54%|█████▎    | 252/469 [01:16<01:05,  3.33it/s]
# Epoch 1 in training:  54%|█████▍    | 253/469 [01:16<01:04,  3.34it/s]
# Epoch 1 in training:  54%|█████▍    | 254/469 [01:17<01:04,  3.33it/s]
# Epoch 1 in training:  54%|█████▍    | 255/469 [01:17<01:03,  3.35it/s]
# Epoch 1 in training:  55%|█████▍    | 256/469 [01:17<01:03,  3.36it/s]
# Epoch 1 in training:  55%|█████▍    | 257/469 [01:18<01:03,  3.34it/s]
# Epoch 1 in training:  55%|█████▌    | 258/469 [01:18<01:03,  3.34it/s]
# Epoch 1 in training:  55%|█████▌    | 259/469 [01:18<01:02,  3.34it/s]
# Epoch 1 in training:  55%|█████▌    | 260/469 [01:18<01:02,  3.35it/s]
# Epoch 1 in training:  56%|█████▌    | 261/469 [01:19<01:02,  3.34it/s]
# Epoch 1 in training:  56%|█████▌    | 262/469 [01:19<01:01,  3.35it/s]
# Epoch 1 in training:  56%|█████▌    | 263/469 [01:19<01:01,  3.36it/s]
# Epoch 1 in training:  56%|█████▋    | 264/469 [01:20<01:01,  3.34it/s]
# Epoch 1 in training:  57%|█████▋    | 265/469 [01:20<01:01,  3.34it/s]
# Epoch 1 in training:  57%|█████▋    | 266/469 [01:20<01:00,  3.34it/s]
# Epoch 1 in training:  57%|█████▋    | 267/469 [01:21<01:00,  3.33it/s]
# Epoch 1 in training:  57%|█████▋    | 268/469 [01:21<01:00,  3.34it/s]
# Epoch 1 in training:  57%|█████▋    | 269/469 [01:21<00:59,  3.35it/s]
# Epoch 1 in training:  58%|█████▊    | 270/469 [01:21<00:59,  3.33it/s]
# Epoch 1 in training:  58%|█████▊    | 271/469 [01:22<00:59,  3.32it/s]
# Epoch 1 in training:  58%|█████▊    | 272/469 [01:22<00:59,  3.30it/s]
# Epoch 1 in training:  58%|█████▊    | 273/469 [01:22<00:59,  3.31it/s]
# Epoch 1 in training:  58%|█████▊    | 274/469 [01:23<00:58,  3.31it/s]
# Epoch 1 in training:  59%|█████▊    | 275/469 [01:23<00:58,  3.31it/s]
# Epoch 1 in training:  59%|█████▉    | 276/469 [01:23<00:58,  3.32it/s]
# Epoch 1 in training:  59%|█████▉    | 277/469 [01:24<00:57,  3.33it/s]
# Epoch 1 in training:  59%|█████▉    | 278/469 [01:24<00:57,  3.33it/s]
# Epoch 1 in training:  59%|█████▉    | 279/469 [01:24<00:58,  3.24it/s]
# Epoch 1 in training:  60%|█████▉    | 280/469 [01:25<00:57,  3.26it/s]
# Epoch 1 in training:  60%|█████▉    | 281/469 [01:25<00:57,  3.29it/s]
# Epoch 1 in training:  60%|██████    | 282/469 [01:25<00:56,  3.31it/s]
# Epoch 1 in training:  60%|██████    | 283/469 [01:25<00:56,  3.31it/s]
# Epoch 1 in training:  61%|██████    | 284/469 [01:26<00:55,  3.31it/s]
# Epoch 1 in training:  61%|██████    | 285/469 [01:26<00:55,  3.31it/s]
# Epoch 1 in training:  61%|██████    | 286/469 [01:26<00:55,  3.32it/s]
# Epoch 1 in training:  61%|██████    | 287/469 [01:27<00:54,  3.33it/s]
# Epoch 1 in training:  61%|██████▏   | 288/469 [01:27<00:54,  3.34it/s]
# Epoch 1 in training:  62%|██████▏   | 289/469 [01:27<00:53,  3.35it/s]
# Epoch 1 in training:  62%|██████▏   | 290/469 [01:28<00:53,  3.35it/s]
# Epoch 1 in training:  62%|██████▏   | 291/469 [01:28<00:53,  3.34it/s]
# Epoch 1 in training:  62%|██████▏   | 292/469 [01:28<00:52,  3.34it/s]
# Epoch 1 in training:  62%|██████▏   | 293/469 [01:28<00:52,  3.36it/s]
# Epoch 1 in training:  63%|██████▎   | 294/469 [01:29<00:52,  3.35it/s]
# Epoch 1 in training:  63%|██████▎   | 295/469 [01:29<00:51,  3.35it/s]
# Epoch 1 in training:  63%|██████▎   | 296/469 [01:29<00:51,  3.34it/s]
# Epoch 1 in training:  63%|██████▎   | 297/469 [01:30<00:51,  3.34it/s]
# Epoch 1 in training:  64%|██████▎   | 298/469 [01:30<00:51,  3.35it/s]
# Epoch 1 in training:  64%|██████▍   | 299/469 [01:30<00:50,  3.35it/s]
# Epoch 1 in training:  64%|██████▍   | 300/469 [01:30<00:50,  3.35it/s]
# Epoch 1 in training:  64%|██████▍   | 301/469 [01:31<00:50,  3.35it/s]
# Epoch 1 in training:  64%|██████▍   | 302/469 [01:31<00:49,  3.35it/s]
# Epoch 1 in training:  65%|██████▍   | 303/469 [01:31<00:49,  3.36it/s]
# Epoch 1 in training:  65%|██████▍   | 304/469 [01:32<00:49,  3.36it/s]
# Epoch 1 in training:  65%|██████▌   | 305/469 [01:32<00:48,  3.36it/s]
# Epoch 1 in training:  65%|██████▌   | 306/469 [01:32<00:48,  3.36it/s]
# Epoch 1 in training:  65%|██████▌   | 307/469 [01:33<00:48,  3.35it/s]
# Epoch 1 in training:  66%|██████▌   | 308/469 [01:33<00:48,  3.34it/s]
# Epoch 1 in training:  66%|██████▌   | 309/469 [01:33<00:47,  3.35it/s]
# Epoch 1 in training:  66%|██████▌   | 310/469 [01:33<00:47,  3.36it/s]
# Epoch 1 in training:  66%|██████▋   | 311/469 [01:34<00:47,  3.36it/s]
# Epoch 1 in training:  67%|██████▋   | 312/469 [01:34<00:47,  3.33it/s]
# Epoch 1 in training:  67%|██████▋   | 313/469 [01:34<00:47,  3.27it/s]
# Epoch 1 in training:  67%|██████▋   | 314/469 [01:35<00:47,  3.29it/s]
# Epoch 1 in training:  67%|██████▋   | 315/469 [01:35<00:46,  3.30it/s]
# Epoch 1 in training:  67%|██████▋   | 316/469 [01:35<00:46,  3.31it/s]
# Epoch 1 in training:  68%|██████▊   | 317/469 [01:36<00:45,  3.33it/s]
# Epoch 1 in training:  68%|██████▊   | 318/469 [01:36<00:45,  3.35it/s]
# Epoch 1 in training:  68%|██████▊   | 319/469 [01:36<00:44,  3.36it/s]
# Epoch 1 in training:  68%|██████▊   | 320/469 [01:36<00:44,  3.37it/s]
# Epoch 1 in training:  68%|██████▊   | 321/469 [01:37<00:44,  3.36it/s]
# Epoch 1 in training:  69%|██████▊   | 322/469 [01:37<00:43,  3.37it/s]
# Epoch 1 in training:  69%|██████▉   | 323/469 [01:37<00:45,  3.24it/s]
# Epoch 1 in training:  69%|██████▉   | 324/469 [01:38<00:45,  3.18it/s]
# Epoch 1 in training:  69%|██████▉   | 325/469 [01:38<00:44,  3.22it/s]
# Epoch 1 in training:  70%|██████▉   | 326/469 [01:38<00:44,  3.25it/s]
# Epoch 1 in training:  70%|██████▉   | 327/469 [01:39<00:43,  3.27it/s]
# Epoch 1 in training:  70%|██████▉   | 328/469 [01:39<00:42,  3.29it/s]
# Epoch 1 in training:  70%|███████   | 329/469 [01:39<00:42,  3.31it/s]
# Epoch 1 in training:  70%|███████   | 330/469 [01:40<00:41,  3.32it/s]
# Epoch 1 in training:  71%|███████   | 331/469 [01:40<00:41,  3.30it/s]
# Epoch 1 in training:  71%|███████   | 332/469 [01:40<00:41,  3.33it/s]
# Epoch 1 in training:  71%|███████   | 333/469 [01:40<00:40,  3.34it/s]
# Epoch 1 in training:  71%|███████   | 334/469 [01:41<00:40,  3.35it/s]
# Epoch 1 in training:  71%|███████▏  | 335/469 [01:41<00:39,  3.36it/s]
# Epoch 1 in training:  72%|███████▏  | 336/469 [01:41<00:39,  3.37it/s]
# Epoch 1 in training:  72%|███████▏  | 337/469 [01:42<00:39,  3.36it/s]
# Epoch 1 in training:  72%|███████▏  | 338/469 [01:42<00:38,  3.36it/s]
# Epoch 1 in training:  72%|███████▏  | 339/469 [01:42<00:38,  3.35it/s]
# Epoch 1 in training:  72%|███████▏  | 340/469 [01:43<00:38,  3.35it/s]
# Epoch 1 in training:  73%|███████▎  | 341/469 [01:43<00:38,  3.35it/s]
# Epoch 1 in training:  73%|███████▎  | 342/469 [01:43<00:37,  3.36it/s]
# Epoch 1 in training:  73%|███████▎  | 343/469 [01:43<00:37,  3.35it/s]
# Epoch 1 in training:  73%|███████▎  | 344/469 [01:44<00:37,  3.34it/s]
# Epoch 1 in training:  74%|███████▎  | 345/469 [01:44<00:37,  3.33it/s]
# Epoch 1 in training:  74%|███████▍  | 346/469 [01:44<00:37,  3.25it/s]
# Epoch 1 in training:  74%|███████▍  | 347/469 [01:45<00:37,  3.26it/s]
# Epoch 1 in training:  74%|███████▍  | 348/469 [01:45<00:36,  3.29it/s]
# Epoch 1 in training:  74%|███████▍  | 349/469 [01:45<00:36,  3.31it/s]
# Epoch 1 in training:  75%|███████▍  | 350/469 [01:46<00:36,  3.31it/s]
# Epoch 1 in training:  75%|███████▍  | 351/469 [01:46<00:35,  3.32it/s]
# Epoch 1 in training:  75%|███████▌  | 352/469 [01:46<00:35,  3.33it/s]
# Epoch 1 in training:  75%|███████▌  | 353/469 [01:46<00:34,  3.33it/s]
# Epoch 1 in training:  75%|███████▌  | 354/469 [01:47<00:34,  3.33it/s]
# Epoch 1 in training:  76%|███████▌  | 355/469 [01:47<00:34,  3.33it/s]
# Epoch 1 in training:  76%|███████▌  | 356/469 [01:47<00:33,  3.34it/s]
# Epoch 1 in training:  76%|███████▌  | 357/469 [01:48<00:33,  3.34it/s]
# Epoch 1 in training:  76%|███████▋  | 358/469 [01:48<00:33,  3.35it/s]
# Epoch 1 in training:  77%|███████▋  | 359/469 [01:48<00:32,  3.36it/s]
# Epoch 1 in training:  77%|███████▋  | 360/469 [01:49<00:32,  3.37it/s]
# Epoch 1 in training:  77%|███████▋  | 361/469 [01:49<00:32,  3.36it/s]
# Epoch 1 in training:  77%|███████▋  | 362/469 [01:49<00:31,  3.37it/s]
# Epoch 1 in training:  77%|███████▋  | 363/469 [01:49<00:31,  3.37it/s]
# Epoch 1 in training:  78%|███████▊  | 364/469 [01:50<00:31,  3.36it/s]
# Epoch 1 in training:  78%|███████▊  | 365/469 [01:50<00:30,  3.36it/s]
# Epoch 1 in training:  78%|███████▊  | 366/469 [01:50<00:30,  3.37it/s]
# Epoch 1 in training:  78%|███████▊  | 367/469 [01:51<00:30,  3.36it/s]
# Epoch 1 in training:  78%|███████▊  | 368/469 [01:51<00:29,  3.37it/s]
# Epoch 1 in training:  79%|███████▊  | 369/469 [01:51<00:29,  3.38it/s]
# Epoch 1 in training:  79%|███████▉  | 370/469 [01:51<00:29,  3.38it/s]
# Epoch 1 in training:  79%|███████▉  | 371/469 [01:52<00:29,  3.36it/s]
# Epoch 1 in training:  79%|███████▉  | 372/469 [01:52<00:28,  3.37it/s]
# Epoch 1 in training:  80%|███████▉  | 373/469 [01:52<00:28,  3.37it/s]
# Epoch 1 in training:  80%|███████▉  | 374/469 [01:53<00:28,  3.33it/s]
# Epoch 1 in training:  80%|███████▉  | 375/469 [01:53<00:28,  3.32it/s]
# Epoch 1 in training:  80%|████████  | 376/469 [01:53<00:27,  3.33it/s]
# Epoch 1 in training:  80%|████████  | 377/469 [01:54<00:27,  3.33it/s]
# Epoch 1 in training:  81%|████████  | 378/469 [01:54<00:27,  3.34it/s]
# Epoch 1 in training:  81%|████████  | 379/469 [01:54<00:27,  3.25it/s]
# Epoch 1 in training:  81%|████████  | 380/469 [01:55<00:27,  3.28it/s]
# Epoch 1 in training:  81%|████████  | 381/469 [01:55<00:26,  3.29it/s]
# Epoch 1 in training:  81%|████████▏ | 382/469 [01:55<00:26,  3.32it/s]
# Epoch 1 in training:  82%|████████▏ | 383/469 [01:55<00:25,  3.33it/s]
# Epoch 1 in training:  82%|████████▏ | 384/469 [01:56<00:25,  3.33it/s]
# Epoch 1 in training:  82%|████████▏ | 385/469 [01:56<00:25,  3.33it/s]
# Epoch 1 in training:  82%|████████▏ | 386/469 [01:56<00:24,  3.34it/s]
# Epoch 1 in training:  83%|████████▎ | 387/469 [01:57<00:24,  3.34it/s]
# Epoch 1 in training:  83%|████████▎ | 388/469 [01:57<00:24,  3.34it/s]
# Epoch 1 in training:  83%|████████▎ | 389/469 [01:57<00:23,  3.35it/s]
# Epoch 1 in training:  83%|████████▎ | 390/469 [01:57<00:23,  3.36it/s]
# Epoch 1 in training:  83%|████████▎ | 391/469 [01:58<00:23,  3.36it/s]
# Epoch 1 in training:  84%|████████▎ | 392/469 [01:58<00:22,  3.37it/s]
# Epoch 1 in training:  84%|████████▍ | 393/469 [01:58<00:22,  3.38it/s]
# Epoch 1 in training:  84%|████████▍ | 394/469 [01:59<00:22,  3.36it/s]
# Epoch 1 in training:  84%|████████▍ | 395/469 [01:59<00:22,  3.35it/s]
# Epoch 1 in training:  84%|████████▍ | 396/469 [01:59<00:21,  3.36it/s]
# Epoch 1 in training:  85%|████████▍ | 397/469 [02:00<00:21,  3.37it/s]
# Epoch 1 in training:  85%|████████▍ | 398/469 [02:00<00:21,  3.37it/s]
# Epoch 1 in training:  85%|████████▌ | 399/469 [02:00<00:20,  3.37it/s]
# Epoch 1 in training:  85%|████████▌ | 400/469 [02:00<00:20,  3.36it/s]
# Epoch 1 in training:  86%|████████▌ | 401/469 [02:01<00:20,  3.36it/s]
# Epoch 1 in training:  86%|████████▌ | 402/469 [02:01<00:19,  3.37it/s]
# Epoch 1 in training:  86%|████████▌ | 403/469 [02:01<00:19,  3.36it/s]
# Epoch 1 in training:  86%|████████▌ | 404/469 [02:02<00:19,  3.36it/s]
# Epoch 1 in training:  86%|████████▋ | 405/469 [02:02<00:19,  3.37it/s]
# Epoch 1 in training:  87%|████████▋ | 406/469 [02:02<00:18,  3.37it/s]
# Epoch 1 in training:  87%|████████▋ | 407/469 [02:03<00:18,  3.36it/s]
# Epoch 1 in training:  87%|████████▋ | 408/469 [02:03<00:18,  3.34it/s]
# Epoch 1 in training:  87%|████████▋ | 409/469 [02:03<00:17,  3.34it/s]
# Epoch 1 in training:  87%|████████▋ | 410/469 [02:03<00:17,  3.35it/s]
# Epoch 1 in training:  88%|████████▊ | 411/469 [02:04<00:17,  3.34it/s]
# Epoch 1 in training:  88%|████████▊ | 412/469 [02:04<00:17,  3.34it/s]
# Epoch 1 in training:  88%|████████▊ | 413/469 [02:04<00:17,  3.27it/s]
# Epoch 1 in training:  88%|████████▊ | 414/469 [02:05<00:16,  3.27it/s]
# Epoch 1 in training:  88%|████████▊ | 415/469 [02:05<00:16,  3.31it/s]
# Epoch 1 in training:  89%|████████▊ | 416/469 [02:05<00:15,  3.33it/s]
# Epoch 1 in training:  89%|████████▉ | 417/469 [02:06<00:15,  3.33it/s]
# Epoch 1 in training:  89%|████████▉ | 418/469 [02:06<00:15,  3.33it/s]
# Epoch 1 in training:  89%|████████▉ | 419/469 [02:06<00:15,  3.33it/s]
# Epoch 1 in training:  90%|████████▉ | 420/469 [02:06<00:14,  3.35it/s]
# Epoch 1 in training:  90%|████████▉ | 421/469 [02:07<00:14,  3.34it/s]
# Epoch 1 in training:  90%|████████▉ | 422/469 [02:07<00:14,  3.34it/s]
# Epoch 1 in training:  90%|█████████ | 423/469 [02:07<00:13,  3.35it/s]
# Epoch 1 in training:  90%|█████████ | 424/469 [02:08<00:13,  3.35it/s]
# Epoch 1 in training:  91%|█████████ | 425/469 [02:08<00:13,  3.36it/s]
# Epoch 1 in training:  91%|█████████ | 426/469 [02:08<00:12,  3.34it/s]
# Epoch 1 in training:  91%|█████████ | 427/469 [02:09<00:12,  3.23it/s]
# Epoch 1 in training:  91%|█████████▏| 428/469 [02:09<00:12,  3.22it/s]
# Epoch 1 in training:  91%|█████████▏| 429/469 [02:09<00:12,  3.24it/s]
# Epoch 1 in training:  92%|█████████▏| 430/469 [02:10<00:11,  3.26it/s]
# Epoch 1 in training:  92%|█████████▏| 431/469 [02:10<00:11,  3.28it/s]
# Epoch 1 in training:  92%|█████████▏| 432/469 [02:10<00:11,  3.30it/s]
# Epoch 1 in training:  92%|█████████▏| 433/469 [02:10<00:10,  3.32it/s]
# Epoch 1 in training:  93%|█████████▎| 434/469 [02:11<00:10,  3.32it/s]
# Epoch 1 in training:  93%|█████████▎| 435/469 [02:11<00:10,  3.33it/s]
# Epoch 1 in training:  93%|█████████▎| 436/469 [02:11<00:09,  3.35it/s]
# Epoch 1 in training:  93%|█████████▎| 437/469 [02:12<00:09,  3.35it/s]
# Epoch 1 in training:  93%|█████████▎| 438/469 [02:12<00:09,  3.35it/s]
# Epoch 1 in training:  94%|█████████▎| 439/469 [02:12<00:08,  3.35it/s]
# Epoch 1 in training:  94%|█████████▍| 440/469 [02:12<00:08,  3.36it/s]
# Epoch 1 in training:  94%|█████████▍| 441/469 [02:13<00:08,  3.35it/s]
# Epoch 1 in training:  94%|█████████▍| 442/469 [02:13<00:08,  3.34it/s]
# Epoch 1 in training:  94%|█████████▍| 443/469 [02:13<00:07,  3.34it/s]
# Epoch 1 in training:  95%|█████████▍| 444/469 [02:14<00:07,  3.35it/s]
# Epoch 1 in training:  95%|█████████▍| 445/469 [02:14<00:07,  3.32it/s]
# Epoch 1 in training:  95%|█████████▌| 446/469 [02:14<00:07,  3.24it/s]
# Epoch 1 in training:  95%|█████████▌| 447/469 [02:15<00:06,  3.28it/s]
# Epoch 1 in training:  96%|█████████▌| 448/469 [02:15<00:06,  3.29it/s]
# Epoch 1 in training:  96%|█████████▌| 449/469 [02:15<00:06,  3.31it/s]
# Epoch 1 in training:  96%|█████████▌| 450/469 [02:16<00:05,  3.32it/s]
# Epoch 1 in training:  96%|█████████▌| 451/469 [02:16<00:05,  3.29it/s]
# Epoch 1 in training:  96%|█████████▋| 452/469 [02:16<00:05,  3.30it/s]
# Epoch 1 in training:  97%|█████████▋| 453/469 [02:16<00:04,  3.33it/s]
# Epoch 1 in training:  97%|█████████▋| 454/469 [02:17<00:04,  3.33it/s]
# Epoch 1 in training:  97%|█████████▋| 455/469 [02:17<00:04,  3.34it/s]
# Epoch 1 in training:  97%|█████████▋| 456/469 [02:17<00:03,  3.36it/s]
# Epoch 1 in training:  97%|█████████▋| 457/469 [02:18<00:03,  3.36it/s]
# Epoch 1 in training:  98%|█████████▊| 458/469 [02:18<00:03,  3.36it/s]
# Epoch 1 in training:  98%|█████████▊| 459/469 [02:18<00:02,  3.35it/s]
# Epoch 1 in training:  98%|█████████▊| 460/469 [02:19<00:02,  3.36it/s]
# Epoch 1 in training:  98%|█████████▊| 461/469 [02:19<00:02,  3.36it/s]
# Epoch 1 in training:  99%|█████████▊| 462/469 [02:19<00:02,  3.36it/s]
# Epoch 1 in training:  99%|█████████▊| 463/469 [02:19<00:01,  3.35it/s]
# Epoch 1 in training:  99%|█████████▉| 464/469 [02:20<00:01,  3.34it/s]
# Epoch 1 in training:  99%|█████████▉| 465/469 [02:20<00:01,  3.34it/s]
# Epoch 1 in training:  99%|█████████▉| 466/469 [02:20<00:00,  3.35it/s]
# Epoch 1 in training: 100%|█████████▉| 467/469 [02:21<00:00,  3.35it/s]
# Epoch 1 in training: 100%|█████████▉| 468/469 [02:21<00:00,  3.35it/s]
# Epoch 1 in training: 100%|██████████| 469/469 [02:21<00:00,  3.60it/s]
# train:  20%|██        | 1/5 [02:21<09:26, 141.63s/it]
# Epoch 1/5 loss: 2.17
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:00<02:22,  3.29it/s]
# Epoch 2 in training:   0%|          | 2/469 [00:00<02:21,  3.30it/s]
# Epoch 2 in training:   1%|          | 3/469 [00:00<02:20,  3.32it/s]
# Epoch 2 in training:   1%|          | 4/469 [00:01<02:19,  3.33it/s]
# Epoch 2 in training:   1%|          | 5/469 [00:01<02:18,  3.34it/s]
# Epoch 2 in training:   1%|▏         | 6/469 [00:01<02:18,  3.34it/s]
# Epoch 2 in training:   1%|▏         | 7/469 [00:02<02:18,  3.34it/s]
# Epoch 2 in training:   2%|▏         | 8/469 [00:02<02:17,  3.34it/s]
# Epoch 2 in training:   2%|▏         | 9/469 [00:02<02:17,  3.34it/s]
# Epoch 2 in training:   2%|▏         | 10/469 [00:03<02:20,  3.27it/s]
# Epoch 2 in training:   2%|▏         | 11/469 [00:03<02:20,  3.27it/s]
# Epoch 2 in training:   3%|▎         | 12/469 [00:03<02:19,  3.29it/s]
# Epoch 2 in training:   3%|▎         | 13/469 [00:03<02:17,  3.31it/s]
# Epoch 2 in training:   3%|▎         | 14/469 [00:04<02:16,  3.32it/s]
# Epoch 2 in training:   3%|▎         | 15/469 [00:04<02:16,  3.33it/s]
# Epoch 2 in training:   3%|▎         | 16/469 [00:04<02:15,  3.33it/s]
# Epoch 2 in training:   4%|▎         | 17/469 [00:05<02:16,  3.32it/s]
# Epoch 2 in training:   4%|▍         | 18/469 [00:05<02:16,  3.31it/s]
# Epoch 2 in training:   4%|▍         | 19/469 [00:05<02:15,  3.31it/s]
# Epoch 2 in training:   4%|▍         | 20/469 [00:06<02:14,  3.33it/s]
# Epoch 2 in training:   4%|▍         | 21/469 [00:06<02:14,  3.34it/s]
# Epoch 2 in training:   5%|▍         | 22/469 [00:06<02:13,  3.34it/s]
# Epoch 2 in training:   5%|▍         | 23/469 [00:06<02:13,  3.34it/s]
# Epoch 2 in training:   5%|▌         | 24/469 [00:07<02:13,  3.34it/s]
# Epoch 2 in training:   5%|▌         | 25/469 [00:07<02:12,  3.34it/s]
# Epoch 2 in training:   6%|▌         | 26/469 [00:07<02:12,  3.34it/s]
# Epoch 2 in training:   6%|▌         | 27/469 [00:08<02:12,  3.35it/s]
# Epoch 2 in training:   6%|▌         | 28/469 [00:08<02:11,  3.34it/s]
# Epoch 2 in training:   6%|▌         | 29/469 [00:08<02:11,  3.35it/s]
# Epoch 2 in training:   6%|▋         | 30/469 [00:09<02:11,  3.35it/s]
# Epoch 2 in training:   7%|▋         | 31/469 [00:09<02:10,  3.35it/s]
# Epoch 2 in training:   7%|▋         | 32/469 [00:09<02:10,  3.35it/s]
# Epoch 2 in training:   7%|▋         | 33/469 [00:09<02:10,  3.35it/s]
# Epoch 2 in training:   7%|▋         | 34/469 [00:10<02:09,  3.36it/s]
# Epoch 2 in training:   7%|▋         | 35/469 [00:10<02:09,  3.35it/s]
# Epoch 2 in training:   8%|▊         | 36/469 [00:10<02:09,  3.35it/s]
# Epoch 2 in training:   8%|▊         | 37/469 [00:11<02:08,  3.35it/s]
# Epoch 2 in training:   8%|▊         | 38/469 [00:11<02:08,  3.36it/s]
# Epoch 2 in training:   8%|▊         | 39/469 [00:11<02:08,  3.36it/s]
# Epoch 2 in training:   9%|▊         | 40/469 [00:11<02:07,  3.37it/s]
# Epoch 2 in training:   9%|▊         | 41/469 [00:12<02:06,  3.37it/s]
# Epoch 2 in training:   9%|▉         | 42/469 [00:12<02:07,  3.36it/s]
# Epoch 2 in training:   9%|▉         | 43/469 [00:12<02:07,  3.34it/s]
# Epoch 2 in training:   9%|▉         | 44/469 [00:13<02:09,  3.28it/s]
# Epoch 2 in training:  10%|▉         | 45/469 [00:13<02:09,  3.28it/s]
# Epoch 2 in training:  10%|▉         | 46/469 [00:13<02:08,  3.29it/s]
# Epoch 2 in training:  10%|█         | 47/469 [00:14<02:07,  3.31it/s]
# Epoch 2 in training:  10%|█         | 48/469 [00:14<02:06,  3.32it/s]
# Epoch 2 in training:  10%|█         | 49/469 [00:14<02:06,  3.32it/s]
# Epoch 2 in training:  11%|█         | 50/469 [00:15<02:05,  3.33it/s]
# Epoch 2 in training:  11%|█         | 51/469 [00:15<02:05,  3.34it/s]
# Epoch 2 in training:  11%|█         | 52/469 [00:15<02:04,  3.35it/s]
# Epoch 2 in training:  11%|█▏        | 53/469 [00:15<02:03,  3.36it/s]
# Epoch 2 in training:  12%|█▏        | 54/469 [00:16<02:03,  3.36it/s]
# Epoch 2 in training:  12%|█▏        | 55/469 [00:16<02:03,  3.36it/s]
# Epoch 2 in training:  12%|█▏        | 56/469 [00:16<02:03,  3.35it/s]
# Epoch 2 in training:  12%|█▏        | 57/469 [00:17<02:02,  3.35it/s]
# Epoch 2 in training:  12%|█▏        | 58/469 [00:17<02:02,  3.35it/s]
# Epoch 2 in training:  13%|█▎        | 59/469 [00:17<02:02,  3.33it/s]
# Epoch 2 in training:  13%|█▎        | 60/469 [00:17<02:02,  3.34it/s]
# Epoch 2 in training:  13%|█▎        | 61/469 [00:18<02:04,  3.27it/s]
# Epoch 2 in training:  13%|█▎        | 62/469 [00:18<02:07,  3.20it/s]
# Epoch 2 in training:  13%|█▎        | 63/469 [00:18<02:05,  3.23it/s]
# Epoch 2 in training:  14%|█▎        | 64/469 [00:19<02:04,  3.25it/s]
# Epoch 2 in training:  14%|█▍        | 65/469 [00:19<02:03,  3.28it/s]
# Epoch 2 in training:  14%|█▍        | 66/469 [00:19<02:02,  3.28it/s]
# Epoch 2 in training:  14%|█▍        | 67/469 [00:20<02:02,  3.29it/s]
# Epoch 2 in training:  14%|█▍        | 68/469 [00:20<02:00,  3.31it/s]
# Epoch 2 in training:  15%|█▍        | 69/469 [00:20<02:00,  3.32it/s]
# Epoch 2 in training:  15%|█▍        | 70/469 [00:21<01:59,  3.34it/s]
# Epoch 2 in training:  15%|█▌        | 71/469 [00:21<01:58,  3.35it/s]
# Epoch 2 in training:  15%|█▌        | 72/469 [00:21<01:58,  3.34it/s]
# Epoch 2 in training:  16%|█▌        | 73/469 [00:21<01:58,  3.35it/s]
# Epoch 2 in training:  16%|█▌        | 74/469 [00:22<01:57,  3.35it/s]
# Epoch 2 in training:  16%|█▌        | 75/469 [00:22<01:57,  3.34it/s]
# Epoch 2 in training:  16%|█▌        | 76/469 [00:22<01:58,  3.31it/s]
# Epoch 2 in training:  16%|█▋        | 77/469 [00:23<02:01,  3.23it/s]
# Epoch 2 in training:  17%|█▋        | 78/469 [00:23<01:59,  3.26it/s]
# Epoch 2 in training:  17%|█▋        | 79/469 [00:23<01:58,  3.28it/s]
# Epoch 2 in training:  17%|█▋        | 80/469 [00:24<01:58,  3.29it/s]
# Epoch 2 in training:  17%|█▋        | 81/469 [00:24<01:57,  3.31it/s]
# Epoch 2 in training:  17%|█▋        | 82/469 [00:24<01:57,  3.29it/s]
# Epoch 2 in training:  18%|█▊        | 83/469 [00:24<01:57,  3.30it/s]
# Epoch 2 in training:  18%|█▊        | 84/469 [00:25<01:55,  3.32it/s]
# Epoch 2 in training:  18%|█▊        | 85/469 [00:25<01:54,  3.34it/s]
# Epoch 2 in training:  18%|█▊        | 86/469 [00:25<01:54,  3.35it/s]
# Epoch 2 in training:  19%|█▊        | 87/469 [00:26<01:53,  3.36it/s]
# Epoch 2 in training:  19%|█▉        | 88/469 [00:26<01:53,  3.36it/s]
# Epoch 2 in training:  19%|█▉        | 89/469 [00:26<01:53,  3.34it/s]
# Epoch 2 in training:  19%|█▉        | 90/469 [00:27<01:52,  3.35it/s]
# Epoch 2 in training:  19%|█▉        | 91/469 [00:27<01:52,  3.35it/s]
# Epoch 2 in training:  20%|█▉        | 92/469 [00:27<01:52,  3.35it/s]
# Epoch 2 in training:  20%|█▉        | 93/469 [00:27<01:51,  3.36it/s]
# Epoch 2 in training:  20%|██        | 94/469 [00:28<01:51,  3.36it/s]
# Epoch 2 in training:  20%|██        | 95/469 [00:28<01:51,  3.36it/s]
# Epoch 2 in training:  20%|██        | 96/469 [00:28<01:51,  3.36it/s]
# Epoch 2 in training:  21%|██        | 97/469 [00:29<01:50,  3.37it/s]
# Epoch 2 in training:  21%|██        | 98/469 [00:29<01:50,  3.35it/s]
# Epoch 2 in training:  21%|██        | 99/469 [00:29<01:50,  3.34it/s]
# Epoch 2 in training:  21%|██▏       | 100/469 [00:30<01:50,  3.35it/s]
# Epoch 2 in training:  22%|██▏       | 101/469 [00:30<01:49,  3.37it/s]
# Epoch 2 in training:  22%|██▏       | 102/469 [00:30<01:49,  3.36it/s]
# Epoch 2 in training:  22%|██▏       | 103/469 [00:30<01:49,  3.35it/s]
# Epoch 2 in training:  22%|██▏       | 104/469 [00:31<01:48,  3.35it/s]
# Epoch 2 in training:  22%|██▏       | 105/469 [00:31<01:48,  3.36it/s]
# Epoch 2 in training:  23%|██▎       | 106/469 [00:31<01:51,  3.24it/s]
# Epoch 2 in training:  23%|██▎       | 107/469 [00:32<01:50,  3.28it/s]
# Epoch 2 in training:  23%|██▎       | 108/469 [00:32<01:49,  3.31it/s]
# Epoch 2 in training:  23%|██▎       | 109/469 [00:32<01:48,  3.32it/s]
# Epoch 2 in training:  23%|██▎       | 110/469 [00:33<01:50,  3.24it/s]
# Epoch 2 in training:  24%|██▎       | 111/469 [00:33<01:49,  3.26it/s]
# Epoch 2 in training:  24%|██▍       | 112/469 [00:33<01:48,  3.29it/s]
# Epoch 2 in training:  24%|██▍       | 113/469 [00:33<01:47,  3.31it/s]
# Epoch 2 in training:  24%|██▍       | 114/469 [00:34<01:46,  3.32it/s]
# Epoch 2 in training:  25%|██▍       | 115/469 [00:34<01:46,  3.32it/s]
# Epoch 2 in training:  25%|██▍       | 116/469 [00:34<01:46,  3.33it/s]
# Epoch 2 in training:  25%|██▍       | 117/469 [00:35<01:45,  3.35it/s]
# Epoch 2 in training:  25%|██▌       | 118/469 [00:35<01:44,  3.36it/s]
# Epoch 2 in training:  25%|██▌       | 119/469 [00:35<01:44,  3.36it/s]
# Epoch 2 in training:  26%|██▌       | 120/469 [00:36<01:43,  3.37it/s]
# Epoch 2 in training:  26%|██▌       | 121/469 [00:36<01:43,  3.38it/s]
# Epoch 2 in training:  26%|██▌       | 122/469 [00:36<01:42,  3.38it/s]
# Epoch 2 in training:  26%|██▌       | 123/469 [00:36<01:42,  3.37it/s]
# Epoch 2 in training:  26%|██▋       | 124/469 [00:37<01:42,  3.38it/s]
# Epoch 2 in training:  27%|██▋       | 125/469 [00:37<01:41,  3.38it/s]
# Epoch 2 in training:  27%|██▋       | 126/469 [00:37<01:41,  3.37it/s]
# Epoch 2 in training:  27%|██▋       | 127/469 [00:38<01:41,  3.37it/s]
# Epoch 2 in training:  27%|██▋       | 128/469 [00:38<01:41,  3.35it/s]
# Epoch 2 in training:  28%|██▊       | 129/469 [00:38<01:41,  3.34it/s]
# Epoch 2 in training:  28%|██▊       | 130/469 [00:39<01:41,  3.35it/s]
# Epoch 2 in training:  28%|██▊       | 131/469 [00:39<01:41,  3.34it/s]
# Epoch 2 in training:  28%|██▊       | 132/469 [00:39<01:40,  3.34it/s]
# Epoch 2 in training:  28%|██▊       | 133/469 [00:39<01:40,  3.34it/s]
# Epoch 2 in training:  29%|██▊       | 134/469 [00:40<01:40,  3.35it/s]
# Epoch 2 in training:  29%|██▉       | 135/469 [00:40<01:39,  3.35it/s]
# Epoch 2 in training:  29%|██▉       | 136/469 [00:40<01:39,  3.35it/s]
# Epoch 2 in training:  29%|██▉       | 137/469 [00:41<01:38,  3.36it/s]
# Epoch 2 in training:  29%|██▉       | 138/469 [00:41<01:38,  3.37it/s]
# Epoch 2 in training:  30%|██▉       | 139/469 [00:41<01:38,  3.35it/s]
# Epoch 2 in training:  30%|██▉       | 140/469 [00:42<01:38,  3.35it/s]
# Epoch 2 in training:  30%|███       | 141/469 [00:42<01:37,  3.36it/s]
# Epoch 2 in training:  30%|███       | 142/469 [00:42<01:37,  3.37it/s]
# Epoch 2 in training:  30%|███       | 143/469 [00:42<01:37,  3.34it/s]
# Epoch 2 in training:  31%|███       | 144/469 [00:43<01:39,  3.27it/s]
# Epoch 2 in training:  31%|███       | 145/469 [00:43<01:38,  3.30it/s]
# Epoch 2 in training:  31%|███       | 146/469 [00:43<01:37,  3.30it/s]
# Epoch 2 in training:  31%|███▏      | 147/469 [00:44<01:37,  3.32it/s]
# Epoch 2 in training:  32%|███▏      | 148/469 [00:44<01:36,  3.33it/s]
# Epoch 2 in training:  32%|███▏      | 149/469 [00:44<01:35,  3.34it/s]
# Epoch 2 in training:  32%|███▏      | 150/469 [00:45<01:35,  3.36it/s]
# Epoch 2 in training:  32%|███▏      | 151/469 [00:45<01:34,  3.37it/s]
# Epoch 2 in training:  32%|███▏      | 152/469 [00:45<01:33,  3.38it/s]
# Epoch 2 in training:  33%|███▎      | 153/469 [00:45<01:33,  3.37it/s]
# Epoch 2 in training:  33%|███▎      | 154/469 [00:46<01:33,  3.39it/s]
# Epoch 2 in training:  33%|███▎      | 155/469 [00:46<01:32,  3.38it/s]
# Epoch 2 in training:  33%|███▎      | 156/469 [00:46<01:32,  3.37it/s]
# Epoch 2 in training:  33%|███▎      | 157/469 [00:47<01:32,  3.36it/s]
# Epoch 2 in training:  34%|███▎      | 158/469 [00:47<01:32,  3.36it/s]
# Epoch 2 in training:  34%|███▍      | 159/469 [00:47<01:32,  3.36it/s]
# Epoch 2 in training:  34%|███▍      | 160/469 [00:47<01:32,  3.35it/s]
# Epoch 2 in training:  34%|███▍      | 161/469 [00:48<01:31,  3.35it/s]
# Epoch 2 in training:  35%|███▍      | 162/469 [00:48<01:31,  3.35it/s]
# Epoch 2 in training:  35%|███▍      | 163/469 [00:48<01:31,  3.33it/s]
# Epoch 2 in training:  35%|███▍      | 164/469 [00:49<01:30,  3.35it/s]
# Epoch 2 in training:  35%|███▌      | 165/469 [00:49<01:35,  3.18it/s]
# Epoch 2 in training:  35%|███▌      | 166/469 [00:49<01:36,  3.15it/s]
# Epoch 2 in training:  36%|███▌      | 167/469 [00:50<01:34,  3.19it/s]
# Epoch 2 in training:  36%|███▌      | 168/469 [00:50<01:33,  3.23it/s]
# Epoch 2 in training:  36%|███▌      | 169/469 [00:50<01:32,  3.24it/s]
# Epoch 2 in training:  36%|███▌      | 170/469 [00:51<01:31,  3.28it/s]
# Epoch 2 in training:  36%|███▋      | 171/469 [00:51<01:30,  3.29it/s]
# Epoch 2 in training:  37%|███▋      | 172/469 [00:51<01:29,  3.32it/s]
# Epoch 2 in training:  37%|███▋      | 173/469 [00:51<01:28,  3.33it/s]
# Epoch 2 in training:  37%|███▋      | 174/469 [00:52<01:28,  3.32it/s]
# Epoch 2 in training:  37%|███▋      | 175/469 [00:52<01:28,  3.33it/s]
# Epoch 2 in training:  38%|███▊      | 176/469 [00:52<01:29,  3.28it/s]
# Epoch 2 in training:  38%|███▊      | 177/469 [00:53<01:30,  3.22it/s]
# Epoch 2 in training:  38%|███▊      | 178/469 [00:53<01:29,  3.26it/s]
# Epoch 2 in training:  38%|███▊      | 179/469 [00:53<01:28,  3.28it/s]
# Epoch 2 in training:  38%|███▊      | 180/469 [00:54<01:27,  3.30it/s]
# Epoch 2 in training:  39%|███▊      | 181/469 [00:54<01:26,  3.32it/s]
# Epoch 2 in training:  39%|███▉      | 182/469 [00:54<01:25,  3.34it/s]
# Epoch 2 in training:  39%|███▉      | 183/469 [00:55<01:25,  3.34it/s]
# Epoch 2 in training:  39%|███▉      | 184/469 [00:55<01:25,  3.35it/s]
# Epoch 2 in training:  39%|███▉      | 185/469 [00:55<01:24,  3.35it/s]
# Epoch 2 in training:  40%|███▉      | 186/469 [00:55<01:24,  3.34it/s]
# Epoch 2 in training:  40%|███▉      | 187/469 [00:56<01:24,  3.35it/s]
# Epoch 2 in training:  40%|████      | 188/469 [00:56<01:23,  3.35it/s]
# Epoch 2 in training:  40%|████      | 189/469 [00:56<01:23,  3.35it/s]
# Epoch 2 in training:  41%|████      | 190/469 [00:57<01:23,  3.36it/s]
# Epoch 2 in training:  41%|████      | 191/469 [00:57<01:22,  3.36it/s]
# Epoch 2 in training:  41%|████      | 192/469 [00:57<01:22,  3.37it/s]
# Epoch 2 in training:  41%|████      | 193/469 [00:57<01:22,  3.33it/s]
# Epoch 2 in training:  41%|████▏     | 194/469 [00:58<01:22,  3.34it/s]
# Epoch 2 in training:  42%|████▏     | 195/469 [00:58<01:22,  3.34it/s]
# Epoch 2 in training:  42%|████▏     | 196/469 [00:58<01:21,  3.35it/s]
# Epoch 2 in training:  42%|████▏     | 197/469 [00:59<01:21,  3.34it/s]
# Epoch 2 in training:  42%|████▏     | 198/469 [00:59<01:20,  3.35it/s]
# Epoch 2 in training:  42%|████▏     | 199/469 [00:59<01:20,  3.35it/s]
# Epoch 2 in training:  43%|████▎     | 200/469 [01:00<01:20,  3.36it/s]
# Epoch 2 in training:  43%|████▎     | 201/469 [01:00<01:19,  3.35it/s]
# Epoch 2 in training:  43%|████▎     | 202/469 [01:00<01:19,  3.37it/s]
# Epoch 2 in training:  43%|████▎     | 203/469 [01:00<01:19,  3.35it/s]
# Epoch 2 in training:  43%|████▎     | 204/469 [01:01<01:19,  3.35it/s]
# Epoch 2 in training:  44%|████▎     | 205/469 [01:01<01:19,  3.32it/s]
# Epoch 2 in training:  44%|████▍     | 206/469 [01:01<01:19,  3.33it/s]
# ...
# Epoch 5 in training:  53%|█████▎    | 248/469 [01:14<01:05,  3.36it/s]
# Epoch 5 in training:  53%|█████▎    | 249/469 [01:14<01:05,  3.35it/s]
# Epoch 5 in training:  53%|█████▎    | 250/469 [01:15<01:05,  3.35it/s]
# Epoch 5 in training:  54%|█████▎    | 251/469 [01:15<01:05,  3.35it/s]
# Epoch 5 in training:  54%|█████▎    | 252/469 [01:15<01:04,  3.34it/s]
# Epoch 5 in training:  54%|█████▍    | 253/469 [01:15<01:04,  3.36it/s]
# Epoch 5 in training:  54%|█████▍    | 254/469 [01:16<01:03,  3.36it/s]
# Epoch 5 in training:  54%|█████▍    | 255/469 [01:16<01:03,  3.35it/s]
# Epoch 5 in training:  55%|█████▍    | 256/469 [01:16<01:03,  3.36it/s]
# Epoch 5 in training:  55%|█████▍    | 257/469 [01:17<01:02,  3.37it/s]
# Epoch 5 in training:  55%|█████▌    | 258/469 [01:17<01:02,  3.37it/s]
# Epoch 5 in training:  55%|█████▌    | 259/469 [01:17<01:02,  3.35it/s]
# Epoch 5 in training:  55%|█████▌    | 260/469 [01:18<01:02,  3.36it/s]
# Epoch 5 in training:  56%|█████▌    | 261/469 [01:18<01:01,  3.37it/s]
# Epoch 5 in training:  56%|█████▌    | 262/469 [01:18<01:01,  3.37it/s]
# Epoch 5 in training:  56%|█████▌    | 263/469 [01:18<01:01,  3.37it/s]
# Epoch 5 in training:  56%|█████▋    | 264/469 [01:19<01:00,  3.38it/s]
# Epoch 5 in training:  57%|█████▋    | 265/469 [01:19<01:00,  3.38it/s]
# Epoch 5 in training:  57%|█████▋    | 266/469 [01:19<01:00,  3.37it/s]
# Epoch 5 in training:  57%|█████▋    | 267/469 [01:20<01:00,  3.35it/s]
# Epoch 5 in training:  57%|█████▋    | 268/469 [01:20<01:01,  3.28it/s]
# Epoch 5 in training:  57%|█████▋    | 269/469 [01:20<01:00,  3.31it/s]
# Epoch 5 in training:  58%|█████▊    | 270/469 [01:21<00:59,  3.32it/s]
# Epoch 5 in training:  58%|█████▊    | 271/469 [01:21<00:59,  3.33it/s]
# Epoch 5 in training:  58%|█████▊    | 272/469 [01:21<00:59,  3.33it/s]
# Epoch 5 in training:  58%|█████▊    | 273/469 [01:21<00:58,  3.34it/s]
# Epoch 5 in training:  58%|█████▊    | 274/469 [01:22<00:58,  3.35it/s]
# Epoch 5 in training:  59%|█████▊    | 275/469 [01:22<00:58,  3.34it/s]
# Epoch 5 in training:  59%|█████▉    | 276/469 [01:22<00:57,  3.34it/s]
# Epoch 5 in training:  59%|█████▉    | 277/469 [01:23<00:57,  3.31it/s]
# Epoch 5 in training:  59%|█████▉    | 278/469 [01:23<00:57,  3.33it/s]
# Epoch 5 in training:  59%|█████▉    | 279/469 [01:23<00:57,  3.33it/s]
# Epoch 5 in training:  60%|█████▉    | 280/469 [01:24<00:56,  3.33it/s]
# Epoch 5 in training:  60%|█████▉    | 281/469 [01:24<00:56,  3.34it/s]
# Epoch 5 in training:  60%|██████    | 282/469 [01:24<00:56,  3.34it/s]
# Epoch 5 in training:  60%|██████    | 283/469 [01:24<00:55,  3.33it/s]
# Epoch 5 in training:  61%|██████    | 284/469 [01:25<00:55,  3.35it/s]
# Epoch 5 in training:  61%|██████    | 285/469 [01:25<00:54,  3.35it/s]
# Epoch 5 in training:  61%|██████    | 286/469 [01:25<00:54,  3.35it/s]
# Epoch 5 in training:  61%|██████    | 287/469 [01:26<00:54,  3.36it/s]
# Epoch 5 in training:  61%|██████▏   | 288/469 [01:26<00:53,  3.37it/s]
# Epoch 5 in training:  62%|██████▏   | 289/469 [01:26<00:53,  3.36it/s]
# Epoch 5 in training:  62%|██████▏   | 290/469 [01:26<00:53,  3.37it/s]
# Epoch 5 in training:  62%|██████▏   | 291/469 [01:27<00:52,  3.36it/s]
# Epoch 5 in training:  62%|██████▏   | 292/469 [01:27<00:52,  3.35it/s]
# Epoch 5 in training:  62%|██████▏   | 293/469 [01:27<00:52,  3.36it/s]
# Epoch 5 in training:  63%|██████▎   | 294/469 [01:28<00:52,  3.36it/s]
# Epoch 5 in training:  63%|██████▎   | 295/469 [01:28<00:51,  3.36it/s]
# Epoch 5 in training:  63%|██████▎   | 296/469 [01:28<00:51,  3.36it/s]
# Epoch 5 in training:  63%|██████▎   | 297/469 [01:29<00:51,  3.36it/s]
# Epoch 5 in training:  64%|██████▎   | 298/469 [01:29<00:50,  3.37it/s]
# Epoch 5 in training:  64%|██████▍   | 299/469 [01:29<00:50,  3.35it/s]
# Epoch 5 in training:  64%|██████▍   | 300/469 [01:29<00:50,  3.31it/s]
# Epoch 5 in training:  64%|██████▍   | 301/469 [01:30<00:52,  3.23it/s]
# Epoch 5 in training:  64%|██████▍   | 302/469 [01:30<00:51,  3.26it/s]
# Epoch 5 in training:  65%|██████▍   | 303/469 [01:30<00:50,  3.29it/s]
# Epoch 5 in training:  65%|██████▍   | 304/469 [01:31<00:49,  3.31it/s]
# Epoch 5 in training:  65%|██████▌   | 305/469 [01:31<00:49,  3.32it/s]
# Epoch 5 in training:  65%|██████▌   | 306/469 [01:31<00:49,  3.32it/s]
# Epoch 5 in training:  65%|██████▌   | 307/469 [01:32<00:48,  3.33it/s]
# Epoch 5 in training:  66%|██████▌   | 308/469 [01:32<00:48,  3.33it/s]
# Epoch 5 in training:  66%|██████▌   | 309/469 [01:32<00:47,  3.34it/s]
# Epoch 5 in training:  66%|██████▌   | 310/469 [01:32<00:47,  3.35it/s]
# Epoch 5 in training:  66%|██████▋   | 311/469 [01:33<00:47,  3.36it/s]
# Epoch 5 in training:  67%|██████▋   | 312/469 [01:33<00:46,  3.36it/s]
# Epoch 5 in training:  67%|██████▋   | 313/469 [01:33<00:47,  3.25it/s]
# Epoch 5 in training:  67%|██████▋   | 314/469 [01:34<00:49,  3.16it/s]
# Epoch 5 in training:  67%|██████▋   | 315/469 [01:34<00:48,  3.18it/s]
# Epoch 5 in training:  67%|██████▋   | 316/469 [01:34<00:47,  3.21it/s]
# Epoch 5 in training:  68%|██████▊   | 317/469 [01:35<00:46,  3.26it/s]
# Epoch 5 in training:  68%|██████▊   | 318/469 [01:35<00:45,  3.28it/s]
# Epoch 5 in training:  68%|██████▊   | 319/469 [01:35<00:45,  3.30it/s]
# Epoch 5 in training:  68%|██████▊   | 320/469 [01:36<00:44,  3.32it/s]
# Epoch 5 in training:  68%|██████▊   | 321/469 [01:36<00:44,  3.34it/s]
# Epoch 5 in training:  69%|██████▊   | 322/469 [01:36<00:43,  3.35it/s]
# Epoch 5 in training:  69%|██████▉   | 323/469 [01:36<00:44,  3.30it/s]
# Epoch 5 in training:  69%|██████▉   | 324/469 [01:37<00:43,  3.32it/s]
# Epoch 5 in training:  69%|██████▉   | 325/469 [01:37<00:43,  3.34it/s]
# Epoch 5 in training:  70%|██████▉   | 326/469 [01:37<00:42,  3.35it/s]
# Epoch 5 in training:  70%|██████▉   | 327/469 [01:38<00:42,  3.36it/s]
# Epoch 5 in training:  70%|██████▉   | 328/469 [01:38<00:41,  3.37it/s]
# Epoch 5 in training:  70%|███████   | 329/469 [01:38<00:41,  3.37it/s]
# Epoch 5 in training:  70%|███████   | 330/469 [01:39<00:41,  3.37it/s]
# Epoch 5 in training:  71%|███████   | 331/469 [01:39<00:41,  3.36it/s]
# Epoch 5 in training:  71%|███████   | 332/469 [01:39<00:40,  3.36it/s]
# Epoch 5 in training:  71%|███████   | 333/469 [01:39<00:40,  3.36it/s]
# Epoch 5 in training:  71%|███████   | 334/469 [01:40<00:41,  3.28it/s]
# Epoch 5 in training:  71%|███████▏  | 335/469 [01:40<00:40,  3.29it/s]
# Epoch 5 in training:  72%|███████▏  | 336/469 [01:40<00:40,  3.29it/s]
# Epoch 5 in training:  72%|███████▏  | 337/469 [01:41<00:39,  3.32it/s]
# Epoch 5 in training:  72%|███████▏  | 338/469 [01:41<00:39,  3.34it/s]
# Epoch 5 in training:  72%|███████▏  | 339/469 [01:41<00:38,  3.34it/s]
# Epoch 5 in training:  72%|███████▏  | 340/469 [01:42<00:38,  3.34it/s]
# Epoch 5 in training:  73%|███████▎  | 341/469 [01:42<00:38,  3.35it/s]
# Epoch 5 in training:  73%|███████▎  | 342/469 [01:42<00:37,  3.36it/s]
# Epoch 5 in training:  73%|███████▎  | 343/469 [01:42<00:37,  3.37it/s]
# Epoch 5 in training:  73%|███████▎  | 344/469 [01:43<00:37,  3.37it/s]
# Epoch 5 in training:  74%|███████▎  | 345/469 [01:43<00:36,  3.37it/s]
# Epoch 5 in training:  74%|███████▍  | 346/469 [01:43<00:36,  3.36it/s]
# Epoch 5 in training:  74%|███████▍  | 347/469 [01:44<00:36,  3.34it/s]
# Epoch 5 in training:  74%|███████▍  | 348/469 [01:44<00:36,  3.36it/s]
# Epoch 5 in training:  74%|███████▍  | 349/469 [01:44<00:35,  3.36it/s]
# Epoch 5 in training:  75%|███████▍  | 350/469 [01:45<00:35,  3.37it/s]
# Epoch 5 in training:  75%|███████▍  | 351/469 [01:45<00:35,  3.36it/s]
# Epoch 5 in training:  75%|███████▌  | 352/469 [01:45<00:34,  3.36it/s]
# Epoch 5 in training:  75%|███████▌  | 353/469 [01:45<00:34,  3.36it/s]
# Epoch 5 in training:  75%|███████▌  | 354/469 [01:46<00:34,  3.36it/s]
# Epoch 5 in training:  76%|███████▌  | 355/469 [01:46<00:34,  3.35it/s]
# Epoch 5 in training:  76%|███████▌  | 356/469 [01:46<00:33,  3.34it/s]
# Epoch 5 in training:  76%|███████▌  | 357/469 [01:47<00:33,  3.34it/s]
# Epoch 5 in training:  76%|███████▋  | 358/469 [01:47<00:33,  3.35it/s]
# Epoch 5 in training:  77%|███████▋  | 359/469 [01:47<00:32,  3.34it/s]
# Epoch 5 in training:  77%|███████▋  | 360/469 [01:48<00:32,  3.34it/s]
# Epoch 5 in training:  77%|███████▋  | 361/469 [01:48<00:32,  3.35it/s]
# Epoch 5 in training:  77%|███████▋  | 362/469 [01:48<00:31,  3.35it/s]
# Epoch 5 in training:  77%|███████▋  | 363/469 [01:48<00:31,  3.34it/s]
# Epoch 5 in training:  78%|███████▊  | 364/469 [01:49<00:31,  3.34it/s]
# Epoch 5 in training:  78%|███████▊  | 365/469 [01:49<00:31,  3.35it/s]
# Epoch 5 in training:  78%|███████▊  | 366/469 [01:49<00:30,  3.35it/s]
# Epoch 5 in training:  78%|███████▊  | 367/469 [01:50<00:30,  3.30it/s]
# Epoch 5 in training:  78%|███████▊  | 368/469 [01:50<00:31,  3.25it/s]
# Epoch 5 in training:  79%|███████▊  | 369/469 [01:50<00:30,  3.28it/s]
# Epoch 5 in training:  79%|███████▉  | 370/469 [01:51<00:29,  3.31it/s]
# Epoch 5 in training:  79%|███████▉  | 371/469 [01:51<00:29,  3.32it/s]
# Epoch 5 in training:  79%|███████▉  | 372/469 [01:51<00:29,  3.33it/s]
# Epoch 5 in training:  80%|███████▉  | 373/469 [01:51<00:28,  3.32it/s]
# Epoch 5 in training:  80%|███████▉  | 374/469 [01:52<00:28,  3.34it/s]
# Epoch 5 in training:  80%|███████▉  | 375/469 [01:52<00:28,  3.35it/s]
# Epoch 5 in training:  80%|████████  | 376/469 [01:52<00:27,  3.33it/s]
# Epoch 5 in training:  80%|████████  | 377/469 [01:53<00:27,  3.34it/s]
# Epoch 5 in training:  81%|████████  | 378/469 [01:53<00:27,  3.35it/s]
# Epoch 5 in training:  81%|████████  | 379/469 [01:53<00:27,  3.33it/s]
# Epoch 5 in training:  81%|████████  | 380/469 [01:54<00:26,  3.33it/s]
# Epoch 5 in training:  81%|████████  | 381/469 [01:54<00:26,  3.34it/s]
# Epoch 5 in training:  81%|████████▏ | 382/469 [01:54<00:26,  3.34it/s]
# Epoch 5 in training:  82%|████████▏ | 383/469 [01:54<00:25,  3.33it/s]
# Epoch 5 in training:  82%|████████▏ | 384/469 [01:55<00:25,  3.34it/s]
# Epoch 5 in training:  82%|████████▏ | 385/469 [01:55<00:25,  3.35it/s]
# Epoch 5 in training:  82%|████████▏ | 386/469 [01:55<00:24,  3.34it/s]
# Epoch 5 in training:  83%|████████▎ | 387/469 [01:56<00:24,  3.33it/s]
# Epoch 5 in training:  83%|████████▎ | 388/469 [01:56<00:24,  3.26it/s]
# Epoch 5 in training:  83%|████████▎ | 389/469 [01:56<00:24,  3.28it/s]
# Epoch 5 in training:  83%|████████▎ | 390/469 [01:57<00:23,  3.31it/s]
# Epoch 5 in training:  83%|████████▎ | 391/469 [01:57<00:23,  3.33it/s]
# Epoch 5 in training:  84%|████████▎ | 392/469 [01:57<00:23,  3.32it/s]
# Epoch 5 in training:  84%|████████▍ | 393/469 [01:57<00:22,  3.32it/s]
# Epoch 5 in training:  84%|████████▍ | 394/469 [01:58<00:22,  3.32it/s]
# Epoch 5 in training:  84%|████████▍ | 395/469 [01:58<00:22,  3.32it/s]
# Epoch 5 in training:  84%|████████▍ | 396/469 [01:58<00:22,  3.32it/s]
# Epoch 5 in training:  85%|████████▍ | 397/469 [01:59<00:21,  3.32it/s]
# Epoch 5 in training:  85%|████████▍ | 398/469 [01:59<00:21,  3.32it/s]
# Epoch 5 in training:  85%|████████▌ | 399/469 [01:59<00:21,  3.31it/s]
# Epoch 5 in training:  85%|████████▌ | 400/469 [02:00<00:20,  3.31it/s]
# Epoch 5 in training:  86%|████████▌ | 401/469 [02:00<00:21,  3.22it/s]
# Epoch 5 in training:  86%|████████▌ | 402/469 [02:00<00:20,  3.24it/s]
# Epoch 5 in training:  86%|████████▌ | 403/469 [02:00<00:20,  3.26it/s]
# Epoch 5 in training:  86%|████████▌ | 404/469 [02:01<00:19,  3.29it/s]
# Epoch 5 in training:  86%|████████▋ | 405/469 [02:01<00:19,  3.26it/s]
# Epoch 5 in training:  87%|████████▋ | 406/469 [02:01<00:19,  3.28it/s]
# Epoch 5 in training:  87%|████████▋ | 407/469 [02:02<00:18,  3.31it/s]
# Epoch 5 in training:  87%|████████▋ | 408/469 [02:02<00:18,  3.33it/s]
# Epoch 5 in training:  87%|████████▋ | 409/469 [02:02<00:18,  3.33it/s]
# Epoch 5 in training:  87%|████████▋ | 410/469 [02:03<00:17,  3.33it/s]
# Epoch 5 in training:  88%|████████▊ | 411/469 [02:03<00:17,  3.34it/s]
# Epoch 5 in training:  88%|████████▊ | 412/469 [02:03<00:17,  3.34it/s]
# Epoch 5 in training:  88%|████████▊ | 413/469 [02:03<00:16,  3.36it/s]
# Epoch 5 in training:  88%|████████▊ | 414/469 [02:04<00:16,  3.37it/s]
# Epoch 5 in training:  88%|████████▊ | 415/469 [02:04<00:16,  3.37it/s]
# Epoch 5 in training:  89%|████████▊ | 416/469 [02:04<00:15,  3.36it/s]
# Epoch 5 in training:  89%|████████▉ | 417/469 [02:05<00:16,  3.23it/s]
# Epoch 5 in training:  89%|████████▉ | 418/469 [02:05<00:16,  3.18it/s]
# Epoch 5 in training:  89%|████████▉ | 419/469 [02:05<00:15,  3.21it/s]
# Epoch 5 in training:  90%|████████▉ | 420/469 [02:06<00:15,  3.24it/s]
# Epoch 5 in training:  90%|████████▉ | 421/469 [02:06<00:14,  3.27it/s]
# Epoch 5 in training:  90%|████████▉ | 422/469 [02:06<00:14,  3.30it/s]
# Epoch 5 in training:  90%|█████████ | 423/469 [02:07<00:13,  3.32it/s]
# Epoch 5 in training:  90%|█████████ | 424/469 [02:07<00:13,  3.33it/s]
# Epoch 5 in training:  91%|█████████ | 425/469 [02:07<00:13,  3.35it/s]
# Epoch 5 in training:  91%|█████████ | 426/469 [02:07<00:12,  3.34it/s]
# Epoch 5 in training:  91%|█████████ | 427/469 [02:08<00:12,  3.33it/s]
# Epoch 5 in training:  91%|█████████▏| 428/469 [02:08<00:12,  3.35it/s]
# Epoch 5 in training:  91%|█████████▏| 429/469 [02:08<00:12,  3.26it/s]
# Epoch 5 in training:  92%|█████████▏| 430/469 [02:09<00:12,  3.20it/s]
# Epoch 5 in training:  92%|█████████▏| 431/469 [02:09<00:11,  3.21it/s]
# Epoch 5 in training:  92%|█████████▏| 432/469 [02:09<00:11,  3.18it/s]
# Epoch 5 in training:  92%|█████████▏| 433/469 [02:10<00:11,  3.22it/s]
# Epoch 5 in training:  93%|█████████▎| 434/469 [02:10<00:11,  3.18it/s]
# Epoch 5 in training:  93%|█████████▎| 435/469 [02:10<00:10,  3.21it/s]
# Epoch 5 in training:  93%|█████████▎| 436/469 [02:11<00:10,  3.26it/s]
# Epoch 5 in training:  93%|█████████▎| 437/469 [02:11<00:09,  3.29it/s]
# Epoch 5 in training:  93%|█████████▎| 438/469 [02:11<00:09,  3.31it/s]
# Epoch 5 in training:  94%|█████████▎| 439/469 [02:11<00:09,  3.32it/s]
# Epoch 5 in training:  94%|█████████▍| 440/469 [02:12<00:08,  3.34it/s]
# Epoch 5 in training:  94%|█████████▍| 441/469 [02:12<00:08,  3.33it/s]
# Epoch 5 in training:  94%|█████████▍| 442/469 [02:12<00:08,  3.34it/s]
# Epoch 5 in training:  94%|█████████▍| 443/469 [02:13<00:07,  3.34it/s]
# Epoch 5 in training:  95%|█████████▍| 444/469 [02:13<00:07,  3.35it/s]
# Epoch 5 in training:  95%|█████████▍| 445/469 [02:13<00:07,  3.32it/s]
# Epoch 5 in training:  95%|█████████▌| 446/469 [02:14<00:06,  3.34it/s]
# Epoch 5 in training:  95%|█████████▌| 447/469 [02:14<00:06,  3.36it/s]
# Epoch 5 in training:  96%|█████████▌| 448/469 [02:14<00:06,  3.37it/s]
# Epoch 5 in training:  96%|█████████▌| 449/469 [02:14<00:05,  3.36it/s]
# Epoch 5 in training:  96%|█████████▌| 450/469 [02:15<00:05,  3.36it/s]
# Epoch 5 in training:  96%|█████████▌| 451/469 [02:15<00:05,  3.35it/s]
# Epoch 5 in training:  96%|█████████▋| 452/469 [02:15<00:05,  3.34it/s]
# Epoch 5 in training:  97%|█████████▋| 453/469 [02:16<00:04,  3.34it/s]
# Epoch 5 in training:  97%|█████████▋| 454/469 [02:16<00:04,  3.35it/s]
# Epoch 5 in training:  97%|█████████▋| 455/469 [02:16<00:04,  3.36it/s]
# Epoch 5 in training:  97%|█████████▋| 456/469 [02:16<00:03,  3.36it/s]
# Epoch 5 in training:  97%|█████████▋| 457/469 [02:17<00:03,  3.36it/s]
# Epoch 5 in training:  98%|█████████▊| 458/469 [02:17<00:03,  3.37it/s]
# Epoch 5 in training:  98%|█████████▊| 459/469 [02:17<00:02,  3.35it/s]
# Epoch 5 in training:  98%|█████████▊| 460/469 [02:18<00:02,  3.36it/s]
# Epoch 5 in training:  98%|█████████▊| 461/469 [02:18<00:02,  3.37it/s]
# Epoch 5 in training:  99%|█████████▊| 462/469 [02:18<00:02,  3.36it/s]
# Epoch 5 in training:  99%|█████████▊| 463/469 [02:19<00:01,  3.37it/s]
# Epoch 5 in training:  99%|█████████▉| 464/469 [02:19<00:01,  3.37it/s]
# Epoch 5 in training:  99%|█████████▉| 465/469 [02:19<00:01,  3.36it/s]
# Epoch 5 in training:  99%|█████████▉| 466/469 [02:19<00:00,  3.35it/s]
# Epoch 5 in training: 100%|█████████▉| 467/469 [02:20<00:00,  3.26it/s]
# Epoch 5 in training: 100%|█████████▉| 468/469 [02:20<00:00,  3.28it/s]
# Epoch 5 in training: 100%|██████████| 469/469 [02:20<00:00,  3.53it/s]
# train: 100%|██████████| 5/5 [11:45<00:00, 141.05s/it]
# Epoch 5/5 loss: 1.84
# Testing: 100%|██████████| 79/79 [00:23<00:00,  3.41it/s]
# Test loss: 1.82
# Test accuracy: 64.35%

# %%
path: str = "flash_vit_5epochs.pth"
torch.save(mnist_model.state_dict(), path)
