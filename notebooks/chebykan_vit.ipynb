# %%
# !pip install monai
# !pip install einops
# Out:
# Requirement already satisfied: monai in /opt/conda/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai) (2.4.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Requirement already satisfied: einops in /opt/conda/lib/python3.10/site-packages (0.8.0)

# %%
import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import Adam
import torch.nn as nn
import numpy as np
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy

# %%
import torch
import torch.nn as nn


# This is inspired by Kolmogorov-Arnold Networks but using Chebyshev polynomials instead of splines coefficients
class ChebyKANLayer(nn.Module):
    def __init__(self, input_dim, output_dim, degree):
        super(ChebyKANLayer, self).__init__()
        self.inputdim = input_dim
        self.outdim = output_dim
        self.degree = degree

        self.cheby_coeffs = nn.Parameter(torch.empty(input_dim, output_dim, degree + 1))
        nn.init.normal_(self.cheby_coeffs, mean=0.0, std=1 / (input_dim * (degree + 1)))
        self.register_buffer("arange", torch.arange(0, degree + 1, 1))

    def forward(self, x):
        # Since Chebyshev polynomial is defined in [-1, 1]
        # We need to normalize x to [-1, 1] using tanh
        x = torch.tanh(x)
        # View and repeat input degree + 1 times
        x = x.view((-1, self.inputdim, 1)).expand(
            -1, -1, self.degree + 1
        )  # shape = (batch_size, inputdim, self.degree + 1)
        # Apply acos
        x = x.acos()
        # Multiply by arange [0 .. degree]
        x *= self.arange
        # Apply cos
        x = x.cos()
        # Compute the Chebyshev interpolation
        y = torch.einsum(
            "bid,iod->bo", x, self.cheby_coeffs
        )  # shape = (batch_size, outdim)
        y = y.view(-1, self.outdim)
        return y

# %%
torch.manual_seed(42)
numpy.random.seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
class ChebyMSA(torch.nn.Module):
    """
    This is the template implementation of the "Multi-Scale Attention" Layer.

    The query, key and value mapping are matrix-multipled against each other in order to
    find the attention, or, the relation of a word and its interaction with surrounding words.
    """
    def __init__(self, d, n_heads=4):
        super(ChebyMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0  # Shouldn't divide dimension (d) into n_heads

        d_head = int(d / n_heads)
        self.q_mappings = torch.nn.ModuleList([ChebyKANLayer(d_head, d_head, 4) for _ in range(self.n_heads)])
        self.k_mappings = torch.nn.ModuleList([ChebyKANLayer(d_head, d_head, 4) for _ in range(self.n_heads)])
        self.v_mappings = torch.nn.ModuleList([ChebyKANLayer(d_head, d_head, 4) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = torch.nn.Softmax(dim=-1)

    def forward(self, sequences):
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class ChebyViT(torch.nn.Module): 
    """
        Initializes a Vision Transformer (ViT) module.

        Args:
            chw (list/tuple of 3 ints): The input image shape.
            n_patches (int, optional): The number of patches to split the image into. Defaults to 10.
            n_blocks (int, optional): The number of blocks in the transformer encoder. Defaults to 2.
            d_hidden (int, optional): The number of hidden dimensions in the transformer encoder. Defaults to 8.
            n_heads (int, optional): The number of attention heads in each block. Defaults to 2.
            out_d (int, optional): The number of output dimensions. Defaults to 10.

        Returns:
            None
    """    
    def __init__(self, chw, n_patches=10, n_blocks=2, d_hidden=8, n_heads=2, out_d=10): 
        super(ChebyViT, self).__init__()
        
        self.chw = chw
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.d_hidden = d_hidden
        
        assert chw[1] % n_patches == 0 
        assert chw[2] % n_patches == 0
        
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # Linear mapping
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = ChebyKANLayer(self.input_d, self.d_hidden, 4)

        # Classification token
        self.v_class = torch.nn.Parameter(torch.rand(1, self.d_hidden))

        # Positional embedding
        self.register_buffer('pos_embeddings', self.positional_embeddings(n_patches ** 2 + 1, d_hidden),
                             persistent=False)

        # Encoder blocks
        self.blocks = torch.nn.ModuleList([ChebyMSA(d_hidden, n_heads) for _ in range(n_blocks)])

        self.mlp = torch.nn.Sequential(
            ChebyKANLayer(self.d_hidden, out_d, 4),
            torch.nn.Softmax(dim=-1)
        )
        
    def patchify(self, images, n_patches):
        """
        The purpose of this function is to break down the main image into multiple sub-images and map them.

        Args:
            images (_type_): The image passeed into this function.
            n_patches (_type_): The number of sub-images that will be created.
        """

        n, c, h, w = images.shape
        assert h == w, "Only for square images"

        patches = torch.zeros(n, n_patches**2, h * w * c // n_patches ** 2) # The equation to calculate the patches
        patch_size = h // n_patches

        for idx, image in enumerate(images):
            for i in range(n_patches):
                for j in range(n_patches):
                    patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                    patches[idx, i * n_patches + j] = patch.flatten()
        return patches

    def positional_embeddings(self, seq_length, d):
        """
        the purpose of this function is to find high and low interaction of a word with surrounding words.
        We can do so by the following equation below:

        Args:
            seq_length (int): The length of the sequence/sentence
            d (int): The dimension of the embedding
        """

        result = torch.ones(seq_length, d)
        for i in range(seq_length):
            for j in range(d):
                result[i][j] = numpy.sin(i / 10000 ** (j / d)) if j % 2 == 0 else numpy.cos(i / 10000 ** (j/ d))
        return result

    def forward(self, images):
        n, c, h, w = images.shape
        patches = self.patchify(images, self.n_patches).to(self.pos_embeddings.device)
        # running tokenization
        tokens = self.linear_mapper(patches)
        # Reshape tokens to maintain batch dimension
        tokens = tokens.reshape(n, -1, tokens.shape[-1])
        # Expand v_class
        v_class_expanded = self.v_class.expand(n, 1, -1)
        # Concatenate
        tokens = torch.cat((v_class_expanded, tokens), dim=1)
        out = tokens + self.pos_embeddings.repeat(n, 1, 1)
        for block in self.blocks:
            out = block(out)

        out = out[:, 0]
        return self.mlp(out)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mnist_model = ChebyViT((1, 28, 28), n_patches=7, n_blocks=2, d_hidden=8, n_heads=2, out_d=10).to(device)
optimizer = Adam(mnist_model.parameters(), lr=0.005)

# %%
from tqdm import tqdm, trange
def main(train_loader, test_loader):
    """
    This code contains the training and testing loop for training the vision transformers model. It requires two
    parameters

    :param train_loader: The dataloader for the training set for training the model.
    :param test_loader: The dataloader for the testing set during evaluation phase.
    """
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    epochs = 10
    criterion = torch.nn.CrossEntropyLoss()
    for epoch in trange(epochs, desc="train"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch + 1}/{epochs} loss: {train_loss:.2f}")

    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
transform = transforms.ToTensor()
train_mnist = MNIST(root='./mnist', train=True, download=True, transform=transform)
test_mnist = MNIST(root='./mnist', train=False, download=True, transform=transform)
train_loader = DataLoader(train_mnist, shuffle=True, batch_size=128)
test_loader = DataLoader(test_mnist, shuffle=False, batch_size=128)
main(train_loader=train_loader, test_loader=test_loader)
# Out:
# Using device:  cuda (Tesla P100-PCIE-16GB)
# train:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:01<12:05,  1.55s/it]
# Epoch 1 in training:   0%|          | 2/469 [00:02<11:13,  1.44s/it]
# Epoch 1 in training:   1%|          | 3/469 [00:04<10:59,  1.42s/it]
# Epoch 1 in training:   1%|          | 4/469 [00:05<10:52,  1.40s/it]
# Epoch 1 in training:   1%|          | 5/469 [00:07<10:54,  1.41s/it]
# Epoch 1 in training:   1%|▏         | 6/469 [00:08<10:49,  1.40s/it]
# Epoch 1 in training:   1%|▏         | 7/469 [00:10<11:07,  1.44s/it]
# Epoch 1 in training:   2%|▏         | 8/469 [00:11<10:59,  1.43s/it]
# Epoch 1 in training:   2%|▏         | 9/469 [00:12<10:55,  1.43s/it]
# Epoch 1 in training:   2%|▏         | 10/469 [00:14<10:55,  1.43s/it]
# Epoch 1 in training:   2%|▏         | 11/469 [00:15<10:49,  1.42s/it]
# Epoch 1 in training:   3%|▎         | 12/469 [00:17<10:57,  1.44s/it]
# Epoch 1 in training:   3%|▎         | 13/469 [00:18<10:57,  1.44s/it]
# Epoch 1 in training:   3%|▎         | 14/469 [00:20<10:49,  1.43s/it]
# Epoch 1 in training:   3%|▎         | 15/469 [00:21<10:43,  1.42s/it]
# Epoch 1 in training:   3%|▎         | 16/469 [00:22<10:40,  1.41s/it]
# Epoch 1 in training:   4%|▎         | 17/469 [00:24<10:43,  1.42s/it]
# Epoch 1 in training:   4%|▍         | 18/469 [00:25<10:58,  1.46s/it]
# Epoch 1 in training:   4%|▍         | 19/469 [00:27<10:49,  1.44s/it]
# Epoch 1 in training:   4%|▍         | 20/469 [00:28<10:44,  1.44s/it]
# Epoch 1 in training:   4%|▍         | 21/469 [00:30<10:40,  1.43s/it]
# Epoch 1 in training:   5%|▍         | 22/469 [00:31<10:38,  1.43s/it]
# Epoch 1 in training:   5%|▍         | 23/469 [00:32<10:33,  1.42s/it]
# Epoch 1 in training:   5%|▌         | 24/469 [00:34<10:35,  1.43s/it]
# Epoch 1 in training:   5%|▌         | 25/469 [00:35<10:32,  1.42s/it]
# Epoch 1 in training:   6%|▌         | 26/469 [00:37<10:33,  1.43s/it]
# Epoch 1 in training:   6%|▌         | 27/469 [00:38<10:29,  1.42s/it]
# Epoch 1 in training:   6%|▌         | 28/469 [00:40<10:30,  1.43s/it]
# Epoch 1 in training:   6%|▌         | 29/469 [00:41<10:28,  1.43s/it]
# Epoch 1 in training:   6%|▋         | 30/469 [00:42<10:27,  1.43s/it]
# Epoch 1 in training:   7%|▋         | 31/469 [00:44<10:29,  1.44s/it]
# Epoch 1 in training:   7%|▋         | 32/469 [00:45<10:50,  1.49s/it]
# Epoch 1 in training:   7%|▋         | 33/469 [00:47<10:46,  1.48s/it]
# Epoch 1 in training:   7%|▋         | 34/469 [00:48<10:38,  1.47s/it]
# Epoch 1 in training:   7%|▋         | 35/469 [00:50<10:37,  1.47s/it]
# Epoch 1 in training:   8%|▊         | 36/469 [00:51<10:26,  1.45s/it]
# Epoch 1 in training:   8%|▊         | 37/469 [00:53<10:22,  1.44s/it]
# Epoch 1 in training:   8%|▊         | 38/469 [00:54<10:17,  1.43s/it]
# Epoch 1 in training:   8%|▊         | 39/469 [00:56<10:25,  1.46s/it]
# Epoch 1 in training:   9%|▊         | 40/469 [00:57<10:24,  1.46s/it]
# Epoch 1 in training:   9%|▊         | 41/469 [00:58<10:20,  1.45s/it]
# Epoch 1 in training:   9%|▉         | 42/469 [01:00<10:15,  1.44s/it]
# Epoch 1 in training:   9%|▉         | 43/469 [01:01<10:08,  1.43s/it]
# Epoch 1 in training:   9%|▉         | 44/469 [01:03<10:03,  1.42s/it]
# Epoch 1 in training:  10%|▉         | 45/469 [01:04<10:01,  1.42s/it]
# Epoch 1 in training:  10%|▉         | 46/469 [01:06<10:03,  1.43s/it]
# Epoch 1 in training:  10%|█         | 47/469 [01:07<10:00,  1.42s/it]
# Epoch 1 in training:  10%|█         | 48/469 [01:08<09:55,  1.41s/it]
# Epoch 1 in training:  10%|█         | 49/469 [01:10<09:53,  1.41s/it]
# Epoch 1 in training:  11%|█         | 50/469 [01:11<09:48,  1.41s/it]
# Epoch 1 in training:  11%|█         | 51/469 [01:13<09:49,  1.41s/it]
# Epoch 1 in training:  11%|█         | 52/469 [01:14<09:46,  1.41s/it]
# Epoch 1 in training:  11%|█▏        | 53/469 [01:15<09:48,  1.41s/it]
# Epoch 1 in training:  12%|█▏        | 54/469 [01:17<09:45,  1.41s/it]
# Epoch 1 in training:  12%|█▏        | 55/469 [01:18<09:41,  1.40s/it]
# Epoch 1 in training:  12%|█▏        | 56/469 [01:20<09:39,  1.40s/it]
# Epoch 1 in training:  12%|█▏        | 57/469 [01:21<09:38,  1.40s/it]
# Epoch 1 in training:  12%|█▏        | 58/469 [01:22<09:37,  1.41s/it]
# Epoch 1 in training:  13%|█▎        | 59/469 [01:24<09:51,  1.44s/it]
# Epoch 1 in training:  13%|█▎        | 60/469 [01:25<09:49,  1.44s/it]
# Epoch 1 in training:  13%|█▎        | 61/469 [01:27<09:52,  1.45s/it]
# Epoch 1 in training:  13%|█▎        | 62/469 [01:28<09:48,  1.45s/it]
# Epoch 1 in training:  13%|█▎        | 63/469 [01:30<09:42,  1.43s/it]
# Epoch 1 in training:  14%|█▎        | 64/469 [01:31<09:35,  1.42s/it]
# Epoch 1 in training:  14%|█▍        | 65/469 [01:32<09:30,  1.41s/it]
# Epoch 1 in training:  14%|█▍        | 66/469 [01:34<09:27,  1.41s/it]
# Epoch 1 in training:  14%|█▍        | 67/469 [01:35<09:24,  1.40s/it]
# Epoch 1 in training:  14%|█▍        | 68/469 [01:37<09:27,  1.42s/it]
# Epoch 1 in training:  15%|█▍        | 69/469 [01:38<09:26,  1.42s/it]
# Epoch 1 in training:  15%|█▍        | 70/469 [01:40<09:22,  1.41s/it]
# Epoch 1 in training:  15%|█▌        | 71/469 [01:41<09:21,  1.41s/it]
# Epoch 1 in training:  15%|█▌        | 72/469 [01:42<09:20,  1.41s/it]
# Epoch 1 in training:  16%|█▌        | 73/469 [01:44<09:21,  1.42s/it]
# Epoch 1 in training:  16%|█▌        | 74/469 [01:45<09:20,  1.42s/it]
# Epoch 1 in training:  16%|█▌        | 75/469 [01:47<09:27,  1.44s/it]
# Epoch 1 in training:  16%|█▌        | 76/469 [01:48<09:25,  1.44s/it]
# Epoch 1 in training:  16%|█▋        | 77/469 [01:50<09:21,  1.43s/it]
# Epoch 1 in training:  17%|█▋        | 78/469 [01:51<09:15,  1.42s/it]
# Epoch 1 in training:  17%|█▋        | 79/469 [01:52<09:11,  1.41s/it]
# Epoch 1 in training:  17%|█▋        | 80/469 [01:54<09:10,  1.41s/it]
# Epoch 1 in training:  17%|█▋        | 81/469 [01:55<09:06,  1.41s/it]
# Epoch 1 in training:  17%|█▋        | 82/469 [01:57<09:08,  1.42s/it]
# Epoch 1 in training:  18%|█▊        | 83/469 [01:58<09:28,  1.47s/it]
# Epoch 1 in training:  18%|█▊        | 84/469 [02:00<09:23,  1.46s/it]
# Epoch 1 in training:  18%|█▊        | 85/469 [02:01<09:14,  1.45s/it]
# Epoch 1 in training:  18%|█▊        | 86/469 [02:02<09:08,  1.43s/it]
# Epoch 1 in training:  19%|█▊        | 87/469 [02:04<09:03,  1.42s/it]
# Epoch 1 in training:  19%|█▉        | 88/469 [02:05<09:00,  1.42s/it]
# Epoch 1 in training:  19%|█▉        | 89/469 [02:07<09:05,  1.43s/it]
# Epoch 1 in training:  19%|█▉        | 90/469 [02:08<09:00,  1.43s/it]
# Epoch 1 in training:  19%|█▉        | 91/469 [02:10<08:56,  1.42s/it]
# Epoch 1 in training:  20%|█▉        | 92/469 [02:11<08:53,  1.41s/it]
# Epoch 1 in training:  20%|█▉        | 93/469 [02:12<08:51,  1.41s/it]
# Epoch 1 in training:  20%|██        | 94/469 [02:14<08:49,  1.41s/it]
# Epoch 1 in training:  20%|██        | 95/469 [02:15<08:50,  1.42s/it]
# Epoch 1 in training:  20%|██        | 96/469 [02:17<08:52,  1.43s/it]
# Epoch 1 in training:  21%|██        | 97/469 [02:18<08:47,  1.42s/it]
# Epoch 1 in training:  21%|██        | 98/469 [02:19<08:44,  1.41s/it]
# Epoch 1 in training:  21%|██        | 99/469 [02:21<08:41,  1.41s/it]
# Epoch 1 in training:  21%|██▏       | 100/469 [02:22<08:37,  1.40s/it]
# Epoch 1 in training:  22%|██▏       | 101/469 [02:24<08:36,  1.40s/it]
# Epoch 1 in training:  22%|██▏       | 102/469 [02:25<08:33,  1.40s/it]
# Epoch 1 in training:  22%|██▏       | 103/469 [02:26<08:36,  1.41s/it]
# Epoch 1 in training:  22%|██▏       | 104/469 [02:28<08:33,  1.41s/it]
# Epoch 1 in training:  22%|██▏       | 105/469 [02:29<08:39,  1.43s/it]
# Epoch 1 in training:  23%|██▎       | 106/469 [02:31<08:48,  1.45s/it]
# Epoch 1 in training:  23%|██▎       | 107/469 [02:32<08:41,  1.44s/it]
# Epoch 1 in training:  23%|██▎       | 108/469 [02:34<08:33,  1.42s/it]
# Epoch 1 in training:  23%|██▎       | 109/469 [02:35<08:29,  1.42s/it]
# Epoch 1 in training:  23%|██▎       | 110/469 [02:36<08:30,  1.42s/it]
# Epoch 1 in training:  24%|██▎       | 111/469 [02:38<08:25,  1.41s/it]
# Epoch 1 in training:  24%|██▍       | 112/469 [02:39<08:36,  1.45s/it]
# Epoch 1 in training:  24%|██▍       | 113/469 [02:41<08:30,  1.43s/it]
# Epoch 1 in training:  24%|██▍       | 114/469 [02:42<08:23,  1.42s/it]
# Epoch 1 in training:  25%|██▍       | 115/469 [02:44<08:20,  1.41s/it]
# Epoch 1 in training:  25%|██▍       | 116/469 [02:45<08:17,  1.41s/it]
# Epoch 1 in training:  25%|██▍       | 117/469 [02:46<08:21,  1.43s/it]
# Epoch 1 in training:  25%|██▌       | 118/469 [02:48<08:19,  1.42s/it]
# Epoch 1 in training:  25%|██▌       | 119/469 [02:49<08:16,  1.42s/it]
# Epoch 1 in training:  26%|██▌       | 120/469 [02:51<08:12,  1.41s/it]
# Epoch 1 in training:  26%|██▌       | 121/469 [02:52<08:08,  1.40s/it]
# Epoch 1 in training:  26%|██▌       | 122/469 [02:53<08:06,  1.40s/it]
# Epoch 1 in training:  26%|██▌       | 123/469 [02:55<08:03,  1.40s/it]
# Epoch 1 in training:  26%|██▋       | 124/469 [02:56<08:04,  1.41s/it]
# Epoch 1 in training:  27%|██▋       | 125/469 [02:58<08:03,  1.40s/it]
# Epoch 1 in training:  27%|██▋       | 126/469 [02:59<08:00,  1.40s/it]
# Epoch 1 in training:  27%|██▋       | 127/469 [03:00<07:59,  1.40s/it]
# Epoch 1 in training:  27%|██▋       | 128/469 [03:02<08:05,  1.42s/it]
# Epoch 1 in training:  28%|██▊       | 129/469 [03:03<08:02,  1.42s/it]
# Epoch 1 in training:  28%|██▊       | 130/469 [03:05<07:59,  1.41s/it]
# Epoch 1 in training:  28%|██▊       | 131/469 [03:06<07:58,  1.41s/it]
# Epoch 1 in training:  28%|██▊       | 132/469 [03:08<08:01,  1.43s/it]
# Epoch 1 in training:  28%|██▊       | 133/469 [03:09<07:56,  1.42s/it]
# Epoch 1 in training:  29%|██▊       | 134/469 [03:10<07:53,  1.41s/it]
# Epoch 1 in training:  29%|██▉       | 135/469 [03:12<07:51,  1.41s/it]
# Epoch 1 in training:  29%|██▉       | 136/469 [03:13<08:02,  1.45s/it]
# Epoch 1 in training:  29%|██▉       | 137/469 [03:15<07:57,  1.44s/it]
# Epoch 1 in training:  29%|██▉       | 138/469 [03:16<07:58,  1.45s/it]
# Epoch 1 in training:  30%|██▉       | 139/469 [03:18<07:53,  1.44s/it]
# Epoch 1 in training:  30%|██▉       | 140/469 [03:19<07:49,  1.43s/it]
# Epoch 1 in training:  30%|███       | 141/469 [03:20<07:46,  1.42s/it]
# Epoch 1 in training:  30%|███       | 142/469 [03:22<07:43,  1.42s/it]
# Epoch 1 in training:  30%|███       | 143/469 [03:23<07:41,  1.41s/it]
# Epoch 1 in training:  31%|███       | 144/469 [03:25<07:38,  1.41s/it]
# Epoch 1 in training:  31%|███       | 145/469 [03:26<07:41,  1.43s/it]
# Epoch 1 in training:  31%|███       | 146/469 [03:28<07:42,  1.43s/it]
# Epoch 1 in training:  31%|███▏      | 147/469 [03:29<07:42,  1.44s/it]
# Epoch 1 in training:  32%|███▏      | 148/469 [03:30<07:38,  1.43s/it]
# Epoch 1 in training:  32%|███▏      | 149/469 [03:32<07:34,  1.42s/it]
# Epoch 1 in training:  32%|███▏      | 150/469 [03:33<07:41,  1.45s/it]
# Epoch 1 in training:  32%|███▏      | 151/469 [03:35<07:35,  1.43s/it]
# Epoch 1 in training:  32%|███▏      | 152/469 [03:36<07:35,  1.44s/it]
# Epoch 1 in training:  33%|███▎      | 153/469 [03:38<07:30,  1.43s/it]
# Epoch 1 in training:  33%|███▎      | 154/469 [03:39<07:31,  1.43s/it]
# Epoch 1 in training:  33%|███▎      | 155/469 [03:40<07:26,  1.42s/it]
# Epoch 1 in training:  33%|███▎      | 156/469 [03:42<07:22,  1.42s/it]
# Epoch 1 in training:  33%|███▎      | 157/469 [03:43<07:20,  1.41s/it]
# Epoch 1 in training:  34%|███▎      | 158/469 [03:45<07:19,  1.41s/it]
# Epoch 1 in training:  34%|███▍      | 159/469 [03:46<07:20,  1.42s/it]
# Epoch 1 in training:  34%|███▍      | 160/469 [03:48<07:20,  1.43s/it]
# Epoch 1 in training:  34%|███▍      | 161/469 [03:49<07:20,  1.43s/it]
# Epoch 1 in training:  35%|███▍      | 162/469 [03:50<07:15,  1.42s/it]
# Epoch 1 in training:  35%|███▍      | 163/469 [03:52<07:11,  1.41s/it]
# Epoch 1 in training:  35%|███▍      | 164/469 [03:53<07:11,  1.41s/it]
# Epoch 1 in training:  35%|███▌      | 165/469 [03:55<07:20,  1.45s/it]
# Epoch 1 in training:  35%|███▌      | 166/469 [03:56<07:16,  1.44s/it]
# Epoch 1 in training:  36%|███▌      | 167/469 [03:58<07:12,  1.43s/it]
# Epoch 1 in training:  36%|███▌      | 168/469 [03:59<07:10,  1.43s/it]
# Epoch 1 in training:  36%|███▌      | 169/469 [04:00<07:06,  1.42s/it]
# Epoch 1 in training:  36%|███▌      | 170/469 [04:02<07:04,  1.42s/it]
# Epoch 1 in training:  36%|███▋      | 171/469 [04:03<07:00,  1.41s/it]
# Epoch 1 in training:  37%|███▋      | 172/469 [04:05<07:06,  1.44s/it]
# Epoch 1 in training:  37%|███▋      | 173/469 [04:06<07:05,  1.44s/it]
# Epoch 1 in training:  37%|███▋      | 174/469 [04:07<07:00,  1.42s/it]
# Epoch 1 in training:  37%|███▋      | 175/469 [04:09<06:59,  1.43s/it]
# Epoch 1 in training:  38%|███▊      | 176/469 [04:10<06:55,  1.42s/it]
# Epoch 1 in training:  38%|███▊      | 177/469 [04:12<06:52,  1.41s/it]
# Epoch 1 in training:  38%|███▊      | 178/469 [04:13<06:50,  1.41s/it]
# Epoch 1 in training:  38%|███▊      | 179/469 [04:15<06:47,  1.41s/it]
# Epoch 1 in training:  38%|███▊      | 180/469 [04:16<06:47,  1.41s/it]
# Epoch 1 in training:  39%|███▊      | 181/469 [04:17<06:44,  1.41s/it]
# Epoch 1 in training:  39%|███▉      | 182/469 [04:19<06:42,  1.40s/it]
# Epoch 1 in training:  39%|███▉      | 183/469 [04:20<06:40,  1.40s/it]
# Epoch 1 in training:  39%|███▉      | 184/469 [04:22<06:38,  1.40s/it]
# Epoch 1 in training:  39%|███▉      | 185/469 [04:23<06:39,  1.41s/it]
# Epoch 1 in training:  40%|███▉      | 186/469 [04:24<06:37,  1.40s/it]
# Epoch 1 in training:  40%|███▉      | 187/469 [04:26<06:43,  1.43s/it]
# Epoch 1 in training:  40%|████      | 188/469 [04:27<06:39,  1.42s/it]
# Epoch 1 in training:  40%|████      | 189/469 [04:29<06:53,  1.48s/it]
# Epoch 1 in training:  41%|████      | 190/469 [04:30<06:44,  1.45s/it]
# Epoch 1 in training:  41%|████      | 191/469 [04:32<06:38,  1.43s/it]
# Epoch 1 in training:  41%|████      | 192/469 [04:33<06:34,  1.42s/it]
# Epoch 1 in training:  41%|████      | 193/469 [04:34<06:29,  1.41s/it]
# Epoch 1 in training:  41%|████▏     | 194/469 [04:36<06:36,  1.44s/it]
# Epoch 1 in training:  42%|████▏     | 195/469 [04:37<06:33,  1.44s/it]
# Epoch 1 in training:  42%|████▏     | 196/469 [04:39<06:31,  1.44s/it]
# Epoch 1 in training:  42%|████▏     | 197/469 [04:40<06:29,  1.43s/it]
# Epoch 1 in training:  42%|████▏     | 198/469 [04:42<06:25,  1.42s/it]
# Epoch 1 in training:  42%|████▏     | 199/469 [04:43<06:22,  1.42s/it]
# Epoch 1 in training:  43%|████▎     | 200/469 [04:44<06:19,  1.41s/it]
# Epoch 1 in training:  43%|████▎     | 201/469 [04:46<06:23,  1.43s/it]
# Epoch 1 in training:  43%|████▎     | 202/469 [04:47<06:18,  1.42s/it]
# Epoch 1 in training:  43%|████▎     | 203/469 [04:49<06:19,  1.43s/it]
# Epoch 1 in training:  43%|████▎     | 204/469 [04:50<06:16,  1.42s/it]
# Epoch 1 in training:  44%|████▎     | 205/469 [04:52<06:12,  1.41s/it]
# Epoch 1 in training:  44%|████▍     | 206/469 [04:53<06:10,  1.41s/it]
# Epoch 1 in training:  44%|████▍     | 207/469 [04:54<06:07,  1.40s/it]
# Epoch 1 in training:  44%|████▍     | 208/469 [04:56<06:07,  1.41s/it]
# Epoch 1 in training:  45%|████▍     | 209/469 [04:57<06:04,  1.40s/it]
# Epoch 1 in training:  45%|████▍     | 210/469 [04:59<06:03,  1.40s/it]
# Epoch 1 in training:  45%|████▍     | 211/469 [05:00<06:02,  1.41s/it]
# Epoch 1 in training:  45%|████▌     | 212/469 [05:01<06:00,  1.40s/it]
# Epoch 1 in training:  45%|████▌     | 213/469 [05:03<05:58,  1.40s/it]
# Epoch 1 in training:  46%|████▌     | 214/469 [05:04<05:57,  1.40s/it]
# Epoch 1 in training:  46%|████▌     | 215/469 [05:06<05:58,  1.41s/it]
# Epoch 1 in training:  46%|████▌     | 216/469 [05:07<06:01,  1.43s/it]
# Epoch 1 in training:  46%|████▋     | 217/469 [05:08<06:03,  1.44s/it]
# Epoch 1 in training:  46%|████▋     | 218/469 [05:10<06:08,  1.47s/it]
# Epoch 1 in training:  47%|████▋     | 219/469 [05:11<06:01,  1.45s/it]
# Epoch 1 in training:  47%|████▋     | 220/469 [05:13<05:56,  1.43s/it]
# Epoch 1 in training:  47%|████▋     | 221/469 [05:14<05:52,  1.42s/it]
# Epoch 1 in training:  47%|████▋     | 222/469 [05:16<05:52,  1.43s/it]
# Epoch 1 in training:  48%|████▊     | 223/469 [05:17<05:50,  1.42s/it]
# Epoch 1 in training:  48%|████▊     | 224/469 [05:18<05:47,  1.42s/it]
# Epoch 1 in training:  48%|████▊     | 225/469 [05:20<05:43,  1.41s/it]
# Epoch 1 in training:  48%|████▊     | 226/469 [05:21<05:42,  1.41s/it]
# Epoch 1 in training:  48%|████▊     | 227/469 [05:23<05:41,  1.41s/it]
# Epoch 1 in training:  49%|████▊     | 228/469 [05:24<05:41,  1.41s/it]
# Epoch 1 in training:  49%|████▉     | 229/469 [05:26<05:41,  1.42s/it]
# Epoch 1 in training:  49%|████▉     | 230/469 [05:27<05:38,  1.42s/it]
# Epoch 1 in training:  49%|████▉     | 231/469 [05:28<05:37,  1.42s/it]
# Epoch 1 in training:  49%|████▉     | 232/469 [05:30<05:35,  1.42s/it]
# Epoch 1 in training:  50%|████▉     | 233/469 [05:31<05:33,  1.41s/it]
# Epoch 1 in training:  50%|████▉     | 234/469 [05:33<05:29,  1.40s/it]
# Epoch 1 in training:  50%|█████     | 235/469 [05:34<05:27,  1.40s/it]
# Epoch 1 in training:  50%|█████     | 236/469 [05:35<05:29,  1.41s/it]
# Epoch 1 in training:  51%|█████     | 237/469 [05:37<05:27,  1.41s/it]
# Epoch 1 in training:  51%|█████     | 238/469 [05:38<05:29,  1.43s/it]
# Epoch 1 in training:  51%|█████     | 239/469 [05:40<05:30,  1.44s/it]
# Epoch 1 in training:  51%|█████     | 240/469 [05:41<05:26,  1.43s/it]
# Epoch 1 in training:  51%|█████▏    | 241/469 [05:43<05:23,  1.42s/it]
# Epoch 1 in training:  52%|█████▏    | 242/469 [05:44<05:29,  1.45s/it]
# Epoch 1 in training:  52%|█████▏    | 243/469 [05:46<05:27,  1.45s/it]
# Epoch 1 in training:  52%|█████▏    | 244/469 [05:47<05:25,  1.45s/it]
# Epoch 1 in training:  52%|█████▏    | 245/469 [05:48<05:22,  1.44s/it]
# Epoch 1 in training:  52%|█████▏    | 246/469 [05:50<05:24,  1.46s/it]
# Epoch 1 in training:  53%|█████▎    | 247/469 [05:51<05:19,  1.44s/it]
# Epoch 1 in training:  53%|█████▎    | 248/469 [05:53<05:15,  1.43s/it]
# Epoch 1 in training:  53%|█████▎    | 249/469 [05:54<05:12,  1.42s/it]
# Epoch 1 in training:  53%|█████▎    | 250/469 [05:56<05:13,  1.43s/it]
# Epoch 1 in training:  54%|█████▎    | 251/469 [05:57<05:10,  1.42s/it]
# Epoch 1 in training:  54%|█████▎    | 252/469 [05:58<05:08,  1.42s/it]
# Epoch 1 in training:  54%|█████▍    | 253/469 [06:00<05:09,  1.43s/it]
# Epoch 1 in training:  54%|█████▍    | 254/469 [06:01<05:07,  1.43s/it]
# Epoch 1 in training:  54%|█████▍    | 255/469 [06:03<05:04,  1.42s/it]
# Epoch 1 in training:  55%|█████▍    | 256/469 [06:04<05:03,  1.43s/it]
# Epoch 1 in training:  55%|█████▍    | 257/469 [06:06<05:03,  1.43s/it]
# Epoch 1 in training:  55%|█████▌    | 258/469 [06:07<05:01,  1.43s/it]
# Epoch 1 in training:  55%|█████▌    | 259/469 [06:08<04:58,  1.42s/it]
# Epoch 1 in training:  55%|█████▌    | 260/469 [06:10<05:00,  1.44s/it]
# Epoch 1 in training:  56%|█████▌    | 261/469 [06:11<05:00,  1.44s/it]
# Epoch 1 in training:  56%|█████▌    | 262/469 [06:13<04:55,  1.43s/it]
# Epoch 1 in training:  56%|█████▌    | 263/469 [06:14<04:54,  1.43s/it]
# Epoch 1 in training:  56%|█████▋    | 264/469 [06:16<04:52,  1.43s/it]
# Epoch 1 in training:  57%|█████▋    | 265/469 [06:17<04:49,  1.42s/it]
# Epoch 1 in training:  57%|█████▋    | 266/469 [06:18<04:47,  1.41s/it]
# Epoch 1 in training:  57%|█████▋    | 267/469 [06:20<04:45,  1.41s/it]
# Epoch 1 in training:  57%|█████▋    | 268/469 [06:21<04:43,  1.41s/it]
# Epoch 1 in training:  57%|█████▋    | 269/469 [06:23<04:41,  1.41s/it]
# Epoch 1 in training:  58%|█████▊    | 270/469 [06:24<04:40,  1.41s/it]
# Epoch 1 in training:  58%|█████▊    | 271/469 [06:26<04:48,  1.46s/it]
# Epoch 1 in training:  58%|█████▊    | 272/469 [06:27<04:43,  1.44s/it]
# Epoch 1 in training:  58%|█████▊    | 273/469 [06:28<04:40,  1.43s/it]
# Epoch 1 in training:  58%|█████▊    | 274/469 [06:30<04:37,  1.43s/it]
# Epoch 1 in training:  59%|█████▊    | 275/469 [06:31<04:34,  1.42s/it]
# Epoch 1 in training:  59%|█████▉    | 276/469 [06:33<04:32,  1.41s/it]
# Epoch 1 in training:  59%|█████▉    | 277/469 [06:34<04:30,  1.41s/it]
# Epoch 1 in training:  59%|█████▉    | 278/469 [06:35<04:30,  1.42s/it]
# Epoch 1 in training:  59%|█████▉    | 279/469 [06:37<04:28,  1.42s/it]
# Epoch 1 in training:  60%|█████▉    | 280/469 [06:38<04:27,  1.41s/it]
# Epoch 1 in training:  60%|█████▉    | 281/469 [06:40<04:25,  1.41s/it]
# Epoch 1 in training:  60%|██████    | 282/469 [06:41<04:28,  1.43s/it]
# Epoch 1 in training:  60%|██████    | 283/469 [06:43<04:26,  1.43s/it]
# Epoch 1 in training:  61%|██████    | 284/469 [06:44<04:23,  1.42s/it]
# Epoch 1 in training:  61%|██████    | 285/469 [06:45<04:22,  1.42s/it]
# Epoch 1 in training:  61%|██████    | 286/469 [06:47<04:20,  1.43s/it]
# Epoch 1 in training:  61%|██████    | 287/469 [06:48<04:18,  1.42s/it]
# Epoch 1 in training:  61%|██████▏   | 288/469 [06:50<04:17,  1.42s/it]
# Epoch 1 in training:  62%|██████▏   | 289/469 [06:51<04:15,  1.42s/it]
# Epoch 1 in training:  62%|██████▏   | 290/469 [06:52<04:13,  1.42s/it]
# Epoch 1 in training:  62%|██████▏   | 291/469 [06:54<04:10,  1.41s/it]
# Epoch 1 in training:  62%|██████▏   | 292/469 [06:55<04:09,  1.41s/it]
# Epoch 1 in training:  62%|██████▏   | 293/469 [06:57<04:09,  1.42s/it]
# Epoch 1 in training:  63%|██████▎   | 294/469 [06:58<04:07,  1.41s/it]
# Epoch 1 in training:  63%|██████▎   | 295/469 [07:00<04:12,  1.45s/it]
# Epoch 1 in training:  63%|██████▎   | 296/469 [07:01<04:08,  1.43s/it]
# Epoch 1 in training:  63%|██████▎   | 297/469 [07:02<04:04,  1.42s/it]
# Epoch 1 in training:  64%|██████▎   | 298/469 [07:04<04:01,  1.41s/it]
# Epoch 1 in training:  64%|██████▍   | 299/469 [07:05<03:58,  1.40s/it]
# Epoch 1 in training:  64%|██████▍   | 300/469 [07:07<03:57,  1.41s/it]
# Epoch 1 in training:  64%|██████▍   | 301/469 [07:08<03:54,  1.40s/it]
# Epoch 1 in training:  64%|██████▍   | 302/469 [07:09<03:51,  1.39s/it]
# Epoch 1 in training:  65%|██████▍   | 303/469 [07:11<03:53,  1.40s/it]
# Epoch 1 in training:  65%|██████▍   | 304/469 [07:12<03:52,  1.41s/it]
# Epoch 1 in training:  65%|██████▌   | 305/469 [07:14<03:50,  1.40s/it]
# Epoch 1 in training:  65%|██████▌   | 306/469 [07:15<03:47,  1.40s/it]
# Epoch 1 in training:  65%|██████▌   | 307/469 [07:16<03:47,  1.40s/it]
# Epoch 1 in training:  66%|██████▌   | 308/469 [07:18<03:44,  1.40s/it]
# Epoch 1 in training:  66%|██████▌   | 309/469 [07:19<03:42,  1.39s/it]
# Epoch 1 in training:  66%|██████▌   | 310/469 [07:21<03:40,  1.39s/it]
# Epoch 1 in training:  66%|██████▋   | 311/469 [07:22<03:38,  1.38s/it]
# Epoch 1 in training:  67%|██████▋   | 312/469 [07:23<03:36,  1.38s/it]
# Epoch 1 in training:  67%|██████▋   | 313/469 [07:25<03:34,  1.38s/it]
# Epoch 1 in training:  67%|██████▋   | 314/469 [07:26<03:35,  1.39s/it]
# Epoch 1 in training:  67%|██████▋   | 315/469 [07:27<03:33,  1.38s/it]
# Epoch 1 in training:  67%|██████▋   | 316/469 [07:29<03:31,  1.38s/it]
# Epoch 1 in training:  68%|██████▊   | 317/469 [07:30<03:28,  1.37s/it]
# Epoch 1 in training:  68%|██████▊   | 318/469 [07:32<03:28,  1.38s/it]
# Epoch 1 in training:  68%|██████▊   | 319/469 [07:33<03:26,  1.37s/it]
# Epoch 1 in training:  68%|██████▊   | 320/469 [07:34<03:24,  1.37s/it]
# Epoch 1 in training:  68%|██████▊   | 321/469 [07:36<03:24,  1.38s/it]
# Epoch 1 in training:  69%|██████▊   | 322/469 [07:37<03:22,  1.38s/it]
# Epoch 1 in training:  69%|██████▉   | 323/469 [07:38<03:20,  1.37s/it]
# Epoch 1 in training:  69%|██████▉   | 324/469 [07:40<03:24,  1.41s/it]
# Epoch 1 in training:  69%|██████▉   | 325/469 [07:41<03:22,  1.40s/it]
# Epoch 1 in training:  70%|██████▉   | 326/469 [07:43<03:19,  1.39s/it]
# Epoch 1 in training:  70%|██████▉   | 327/469 [07:44<03:21,  1.42s/it]
# Epoch 1 in training:  70%|██████▉   | 328/469 [07:46<03:19,  1.41s/it]
# Epoch 1 in training:  70%|███████   | 329/469 [07:47<03:17,  1.41s/it]
# Epoch 1 in training:  70%|███████   | 330/469 [07:48<03:16,  1.41s/it]
# Epoch 1 in training:  71%|███████   | 331/469 [07:50<03:14,  1.41s/it]
# Epoch 1 in training:  71%|███████   | 332/469 [07:51<03:11,  1.40s/it]
# Epoch 1 in training:  71%|███████   | 333/469 [07:53<03:09,  1.39s/it]
# Epoch 1 in training:  71%|███████   | 334/469 [07:54<03:07,  1.39s/it]
# Epoch 1 in training:  71%|███████▏  | 335/469 [07:55<03:07,  1.40s/it]
# Epoch 1 in training:  72%|███████▏  | 336/469 [07:57<03:05,  1.39s/it]
# Epoch 1 in training:  72%|███████▏  | 337/469 [07:58<03:04,  1.40s/it]
# Epoch 1 in training:  72%|███████▏  | 338/469 [08:00<03:02,  1.39s/it]
# Epoch 1 in training:  72%|███████▏  | 339/469 [08:01<03:01,  1.40s/it]
# Epoch 1 in training:  72%|███████▏  | 340/469 [08:02<02:59,  1.39s/it]
# Epoch 1 in training:  73%|███████▎  | 341/469 [08:04<02:58,  1.39s/it]
# Epoch 1 in training:  73%|███████▎  | 342/469 [08:05<02:56,  1.39s/it]
# Epoch 1 in training:  73%|███████▎  | 343/469 [08:06<02:56,  1.40s/it]
# Epoch 1 in training:  73%|███████▎  | 344/469 [08:08<02:53,  1.39s/it]
# Epoch 1 in training:  74%|███████▎  | 345/469 [08:09<02:51,  1.39s/it]
# Epoch 1 in training:  74%|███████▍  | 346/469 [08:11<02:50,  1.38s/it]
# Epoch 1 in training:  74%|███████▍  | 347/469 [08:12<02:48,  1.38s/it]
# Epoch 1 in training:  74%|███████▍  | 348/469 [08:14<02:52,  1.42s/it]
# Epoch 1 in training:  74%|███████▍  | 349/469 [08:15<02:52,  1.44s/it]
# Epoch 1 in training:  75%|███████▍  | 350/469 [08:16<02:53,  1.45s/it]
# Epoch 1 in training:  75%|███████▍  | 351/469 [08:18<02:50,  1.44s/it]
# Epoch 1 in training:  75%|███████▌  | 352/469 [08:19<02:46,  1.42s/it]
# Epoch 1 in training:  75%|███████▌  | 353/469 [08:21<02:44,  1.41s/it]
# Epoch 1 in training:  75%|███████▌  | 354/469 [08:22<02:41,  1.40s/it]
# Epoch 1 in training:  76%|███████▌  | 355/469 [08:23<02:39,  1.40s/it]
# Epoch 1 in training:  76%|███████▌  | 356/469 [08:25<02:37,  1.39s/it]
# Epoch 1 in training:  76%|███████▌  | 357/469 [08:26<02:36,  1.40s/it]
# Epoch 1 in training:  76%|███████▋  | 358/469 [08:28<02:35,  1.40s/it]
# Epoch 1 in training:  77%|███████▋  | 359/469 [08:29<02:34,  1.41s/it]
# Epoch 1 in training:  77%|███████▋  | 360/469 [08:30<02:32,  1.40s/it]
# Epoch 1 in training:  77%|███████▋  | 361/469 [08:32<02:31,  1.40s/it]
# Epoch 1 in training:  77%|███████▋  | 362/469 [08:33<02:28,  1.39s/it]
# Epoch 1 in training:  77%|███████▋  | 363/469 [08:35<02:27,  1.39s/it]
# Epoch 1 in training:  78%|███████▊  | 364/469 [08:36<02:25,  1.39s/it]
# Epoch 1 in training:  78%|███████▊  | 365/469 [08:37<02:23,  1.38s/it]
# Epoch 1 in training:  78%|███████▊  | 366/469 [08:39<02:22,  1.38s/it]
# Epoch 1 in training:  78%|███████▊  | 367/469 [08:40<02:21,  1.38s/it]
# Epoch 1 in training:  78%|███████▊  | 368/469 [08:41<02:19,  1.38s/it]
# Epoch 1 in training:  79%|███████▊  | 369/469 [08:43<02:18,  1.38s/it]
# Epoch 1 in training:  79%|███████▉  | 370/469 [08:44<02:17,  1.39s/it]
# Epoch 1 in training:  79%|███████▉  | 371/469 [08:46<02:17,  1.40s/it]
# Epoch 1 in training:  79%|███████▉  | 372/469 [08:47<02:17,  1.42s/it]
# Epoch 1 in training:  80%|███████▉  | 373/469 [08:49<02:15,  1.42s/it]
# Epoch 1 in training:  80%|███████▉  | 374/469 [08:50<02:13,  1.41s/it]
# Epoch 1 in training:  80%|███████▉  | 375/469 [08:51<02:11,  1.40s/it]
# Epoch 1 in training:  80%|████████  | 376/469 [08:53<02:10,  1.40s/it]
# Epoch 1 in training:  80%|████████  | 377/469 [08:54<02:11,  1.43s/it]
# Epoch 1 in training:  81%|████████  | 378/469 [08:56<02:09,  1.43s/it]
# Epoch 1 in training:  81%|████████  | 379/469 [08:57<02:07,  1.42s/it]
# Epoch 1 in training:  81%|████████  | 380/469 [08:58<02:05,  1.41s/it]
# Epoch 1 in training:  81%|████████  | 381/469 [09:00<02:03,  1.41s/it]
# Epoch 1 in training:  81%|████████▏ | 382/469 [09:01<02:01,  1.40s/it]
# Epoch 1 in training:  82%|████████▏ | 383/469 [09:03<01:59,  1.39s/it]
# Epoch 1 in training:  82%|████████▏ | 384/469 [09:04<01:58,  1.39s/it]
# Epoch 1 in training:  82%|████████▏ | 385/469 [09:05<01:57,  1.39s/it]
# Epoch 1 in training:  82%|████████▏ | 386/469 [09:07<01:55,  1.39s/it]
# Epoch 1 in training:  83%|████████▎ | 387/469 [09:08<01:53,  1.39s/it]
# Epoch 1 in training:  83%|████████▎ | 388/469 [09:10<01:52,  1.38s/it]
# Epoch 1 in training:  83%|████████▎ | 389/469 [09:11<01:50,  1.38s/it]
# Epoch 1 in training:  83%|████████▎ | 390/469 [09:12<01:49,  1.38s/it]
# Epoch 1 in training:  83%|████████▎ | 391/469 [09:14<01:47,  1.38s/it]
# Epoch 1 in training:  84%|████████▎ | 392/469 [09:15<01:45,  1.38s/it]
# Epoch 1 in training:  84%|████████▍ | 393/469 [09:16<01:45,  1.39s/it]
# Epoch 1 in training:  84%|████████▍ | 394/469 [09:18<01:45,  1.40s/it]
# Epoch 1 in training:  84%|████████▍ | 395/469 [09:19<01:43,  1.40s/it]
# Epoch 1 in training:  84%|████████▍ | 396/469 [09:21<01:41,  1.39s/it]
# Epoch 1 in training:  85%|████████▍ | 397/469 [09:22<01:39,  1.39s/it]
# Epoch 1 in training:  85%|████████▍ | 398/469 [09:23<01:37,  1.38s/it]
# Epoch 1 in training:  85%|████████▌ | 399/469 [09:25<01:36,  1.38s/it]
# Epoch 1 in training:  85%|████████▌ | 400/469 [09:26<01:35,  1.39s/it]
# Epoch 1 in training:  86%|████████▌ | 401/469 [09:28<01:36,  1.42s/it]
# Epoch 1 in training:  86%|████████▌ | 402/469 [09:29<01:34,  1.41s/it]
# Epoch 1 in training:  86%|████████▌ | 403/469 [09:30<01:32,  1.39s/it]
# Epoch 1 in training:  86%|████████▌ | 404/469 [09:32<01:30,  1.39s/it]
# Epoch 1 in training:  86%|████████▋ | 405/469 [09:33<01:28,  1.38s/it]
# Epoch 1 in training:  87%|████████▋ | 406/469 [09:35<01:26,  1.37s/it]
# Epoch 1 in training:  87%|████████▋ | 407/469 [09:36<01:25,  1.38s/it]
# Epoch 1 in training:  87%|████████▋ | 408/469 [09:37<01:23,  1.38s/it]
# Epoch 1 in training:  87%|████████▋ | 409/469 [09:39<01:22,  1.37s/it]
# Epoch 1 in training:  87%|████████▋ | 410/469 [09:40<01:20,  1.37s/it]
# Epoch 1 in training:  88%|████████▊ | 411/469 [09:41<01:19,  1.37s/it]
# Epoch 1 in training:  88%|████████▊ | 412/469 [09:43<01:17,  1.37s/it]
# Epoch 1 in training:  88%|████████▊ | 413/469 [09:44<01:16,  1.36s/it]
# Epoch 1 in training:  88%|████████▊ | 414/469 [09:45<01:15,  1.37s/it]
# Epoch 1 in training:  88%|████████▊ | 415/469 [09:47<01:14,  1.37s/it]
# Epoch 1 in training:  89%|████████▊ | 416/469 [09:48<01:12,  1.37s/it]
# Epoch 1 in training:  89%|████████▉ | 417/469 [09:50<01:12,  1.39s/it]
# Epoch 1 in training:  89%|████████▉ | 418/469 [09:51<01:10,  1.39s/it]
# Epoch 1 in training:  89%|████████▉ | 419/469 [09:52<01:09,  1.39s/it]
# Epoch 1 in training:  90%|████████▉ | 420/469 [09:54<01:08,  1.39s/it]
# Epoch 1 in training:  90%|████████▉ | 421/469 [09:55<01:06,  1.39s/it]
# Epoch 1 in training:  90%|████████▉ | 422/469 [09:57<01:05,  1.39s/it]
# Epoch 1 in training:  90%|█████████ | 423/469 [09:58<01:03,  1.39s/it]
# Epoch 1 in training:  90%|█████████ | 424/469 [09:59<01:02,  1.39s/it]
# Epoch 1 in training:  91%|█████████ | 425/469 [10:01<01:00,  1.38s/it]
# Epoch 1 in training:  91%|█████████ | 426/469 [10:02<00:59,  1.38s/it]
# Epoch 1 in training:  91%|█████████ | 427/469 [10:03<00:57,  1.37s/it]
# Epoch 1 in training:  91%|█████████▏| 428/469 [10:05<00:56,  1.37s/it]
# Epoch 1 in training:  91%|█████████▏| 429/469 [10:06<00:55,  1.38s/it]
# Epoch 1 in training:  92%|█████████▏| 430/469 [10:08<00:55,  1.42s/it]
# Epoch 1 in training:  92%|█████████▏| 431/469 [10:09<00:53,  1.40s/it]
# Epoch 1 in training:  92%|█████████▏| 432/469 [10:10<00:51,  1.39s/it]
# Epoch 1 in training:  92%|█████████▏| 433/469 [10:12<00:49,  1.38s/it]
# Epoch 1 in training:  93%|█████████▎| 434/469 [10:13<00:48,  1.38s/it]
# Epoch 1 in training:  93%|█████████▎| 435/469 [10:15<00:47,  1.38s/it]
# Epoch 1 in training:  93%|█████████▎| 436/469 [10:16<00:45,  1.39s/it]
# Epoch 1 in training:  93%|█████████▎| 437/469 [10:17<00:44,  1.39s/it]
# Epoch 1 in training:  93%|█████████▎| 438/469 [10:19<00:42,  1.38s/it]
# Epoch 1 in training:  94%|█████████▎| 439/469 [10:20<00:41,  1.40s/it]
# Epoch 1 in training:  94%|█████████▍| 440/469 [10:22<00:40,  1.39s/it]
# Epoch 1 in training:  94%|█████████▍| 441/469 [10:23<00:38,  1.39s/it]
# Epoch 1 in training:  94%|█████████▍| 442/469 [10:24<00:37,  1.39s/it]
# Epoch 1 in training:  94%|█████████▍| 443/469 [10:26<00:36,  1.39s/it]
# Epoch 1 in training:  95%|█████████▍| 444/469 [10:27<00:34,  1.39s/it]
# Epoch 1 in training:  95%|█████████▍| 445/469 [10:29<00:33,  1.39s/it]
# Epoch 1 in training:  95%|█████████▌| 446/469 [10:30<00:31,  1.39s/it]
# Epoch 1 in training:  95%|█████████▌| 447/469 [10:31<00:30,  1.39s/it]
# Epoch 1 in training:  96%|█████████▌| 448/469 [10:33<00:29,  1.38s/it]
# Epoch 1 in training:  96%|█████████▌| 449/469 [10:34<00:27,  1.38s/it]
# Epoch 1 in training:  96%|█████████▌| 450/469 [10:35<00:26,  1.39s/it]
# Epoch 1 in training:  96%|█████████▌| 451/469 [10:37<00:24,  1.39s/it]
# Epoch 1 in training:  96%|█████████▋| 452/469 [10:38<00:23,  1.39s/it]
# Epoch 1 in training:  97%|█████████▋| 453/469 [10:40<00:22,  1.39s/it]
# Epoch 1 in training:  97%|█████████▋| 454/469 [10:41<00:21,  1.42s/it]
# Epoch 1 in training:  97%|█████████▋| 455/469 [10:42<00:19,  1.41s/it]
# Epoch 1 in training:  97%|█████████▋| 456/469 [10:44<00:18,  1.40s/it]
# Epoch 1 in training:  97%|█████████▋| 457/469 [10:45<00:16,  1.39s/it]
# Epoch 1 in training:  98%|█████████▊| 458/469 [10:47<00:15,  1.42s/it]
# Epoch 1 in training:  98%|█████████▊| 459/469 [10:48<00:14,  1.41s/it]
# Epoch 1 in training:  98%|█████████▊| 460/469 [10:50<00:12,  1.41s/it]
# Epoch 1 in training:  98%|█████████▊| 461/469 [10:51<00:11,  1.40s/it]
# Epoch 1 in training:  99%|█████████▊| 462/469 [10:52<00:09,  1.43s/it]
# Epoch 1 in training:  99%|█████████▊| 463/469 [10:54<00:08,  1.41s/it]
# Epoch 1 in training:  99%|█████████▉| 464/469 [10:55<00:06,  1.40s/it]
# Epoch 1 in training:  99%|█████████▉| 465/469 [10:57<00:05,  1.41s/it]
# Epoch 1 in training:  99%|█████████▉| 466/469 [10:58<00:04,  1.40s/it]
# Epoch 1 in training: 100%|█████████▉| 467/469 [10:59<00:02,  1.40s/it]
# Epoch 1 in training: 100%|█████████▉| 468/469 [11:01<00:01,  1.39s/it]
# Epoch 1 in training: 100%|██████████| 469/469 [11:02<00:00,  1.29s/it]
# train:  10%|█         | 1/10 [11:02<1:39:20, 662.26s/it]
# Epoch 1/10 loss: 2.06
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:01<10:36,  1.36s/it]
# Epoch 2 in training:   0%|          | 2/469 [00:02<10:40,  1.37s/it]
# Epoch 2 in training:   1%|          | 3/469 [00:04<10:45,  1.39s/it]
# Epoch 2 in training:   1%|          | 4/469 [00:05<10:44,  1.39s/it]
# Epoch 2 in training:   1%|          | 5/469 [00:06<10:42,  1.38s/it]
# Epoch 2 in training:   1%|▏         | 6/469 [00:08<10:46,  1.40s/it]
# Epoch 2 in training:   1%|▏         | 7/469 [00:09<10:43,  1.39s/it]
# Epoch 2 in training:   2%|▏         | 8/469 [00:11<10:43,  1.40s/it]
# Epoch 2 in training:   2%|▏         | 9/469 [00:12<10:49,  1.41s/it]
# Epoch 2 in training:   2%|▏         | 10/469 [00:14<10:52,  1.42s/it]
# Epoch 2 in training:   2%|▏         | 11/469 [00:15<10:46,  1.41s/it]
# Epoch 2 in training:   3%|▎         | 12/469 [00:16<10:39,  1.40s/it]
# Epoch 2 in training:   3%|▎         | 13/469 [00:18<10:53,  1.43s/it]
# Epoch 2 in training:   3%|▎         | 14/469 [00:19<10:46,  1.42s/it]
# Epoch 2 in training:   3%|▎         | 15/469 [00:21<10:50,  1.43s/it]
# Epoch 2 in training:   3%|▎         | 16/469 [00:22<10:44,  1.42s/it]
# Epoch 2 in training:   4%|▎         | 17/469 [00:23<10:44,  1.42s/it]
# Epoch 2 in training:   4%|▍         | 18/469 [00:25<10:38,  1.42s/it]
# Epoch 2 in training:   4%|▍         | 19/469 [00:26<10:34,  1.41s/it]
# Epoch 2 in training:   4%|▍         | 20/469 [00:28<10:30,  1.40s/it]
# Epoch 2 in training:   4%|▍         | 21/469 [00:29<10:25,  1.40s/it]
# Epoch 2 in training:   5%|▍         | 22/469 [00:30<10:23,  1.39s/it]
# Epoch 2 in training:   5%|▍         | 23/469 [00:32<10:24,  1.40s/it]
# Epoch 2 in training:   5%|▌         | 24/469 [00:33<10:28,  1.41s/it]
# Epoch 2 in training:   5%|▌         | 25/469 [00:35<10:23,  1.41s/it]
# Epoch 2 in training:   6%|▌         | 26/469 [00:36<10:20,  1.40s/it]
# Epoch 2 in training:   6%|▌         | 27/469 [00:37<10:17,  1.40s/it]
# Epoch 2 in training:   6%|▌         | 28/469 [00:39<10:13,  1.39s/it]
# Epoch 2 in training:   6%|▌         | 29/469 [00:40<10:10,  1.39s/it]
# Epoch 2 in training:   6%|▋         | 30/469 [00:42<10:07,  1.38s/it]
# Epoch 2 in training:   7%|▋         | 31/469 [00:43<10:05,  1.38s/it]
# Epoch 2 in training:   7%|▋         | 32/469 [00:44<10:08,  1.39s/it]
# Epoch 2 in training:   7%|▋         | 33/469 [00:46<10:04,  1.39s/it]
# Epoch 2 in training:   7%|▋         | 34/469 [00:47<10:03,  1.39s/it]
# Epoch 2 in training:   7%|▋         | 35/469 [00:48<10:00,  1.38s/it]
# Epoch 2 in training:   8%|▊         | 36/469 [00:50<09:57,  1.38s/it]
# Epoch 2 in training:   8%|▊         | 37/469 [00:51<09:55,  1.38s/it]
# Epoch 2 in training:   8%|▊         | 38/469 [00:53<10:04,  1.40s/it]
# Epoch 2 in training:   8%|▊         | 39/469 [00:54<10:06,  1.41s/it]
# Epoch 2 in training:   9%|▊         | 40/469 [00:56<10:03,  1.41s/it]
# Epoch 2 in training:   9%|▊         | 41/469 [00:57<09:59,  1.40s/it]
# Epoch 2 in training:   9%|▉         | 42/469 [00:58<10:11,  1.43s/it]
# Epoch 2 in training:   9%|▉         | 43/469 [01:00<10:03,  1.42s/it]
# Epoch 2 in training:   9%|▉         | 44/469 [01:01<09:58,  1.41s/it]
# Epoch 2 in training:  10%|▉         | 45/469 [01:03<09:53,  1.40s/it]
# Epoch 2 in training:  10%|▉         | 46/469 [01:04<09:55,  1.41s/it]
# Epoch 2 in training:  10%|█         | 47/469 [01:05<09:51,  1.40s/it]
# Epoch 2 in training:  10%|█         | 48/469 [01:07<09:48,  1.40s/it]
# Epoch 2 in training:  10%|█         | 49/469 [01:08<09:45,  1.39s/it]
# Epoch 2 in training:  11%|█         | 50/469 [01:10<09:42,  1.39s/it]
# Epoch 2 in training:  11%|█         | 51/469 [01:11<09:40,  1.39s/it]
# Epoch 2 in training:  11%|█         | 52/469 [01:12<09:37,  1.38s/it]
# Epoch 2 in training:  11%|█▏        | 53/469 [01:14<09:38,  1.39s/it]
# Epoch 2 in training:  12%|█▏        | 54/469 [01:15<09:36,  1.39s/it]
# Epoch 2 in training:  12%|█▏        | 55/469 [01:16<09:33,  1.39s/it]
# Epoch 2 in training:  12%|█▏        | 56/469 [01:18<09:32,  1.39s/it]
# Epoch 2 in training:  12%|█▏        | 57/469 [01:19<09:30,  1.38s/it]
# Epoch 2 in training:  12%|█▏        | 58/469 [01:21<09:28,  1.38s/it]
# Epoch 2 in training:  13%|█▎        | 59/469 [01:22<09:25,  1.38s/it]
# Epoch 2 in training:  13%|█▎        | 60/469 [01:23<09:39,  1.42s/it]
# Epoch 2 in training:  13%|█▎        | 61/469 [01:25<09:37,  1.42s/it]
# Epoch 2 in training:  13%|█▎        | 62/469 [01:26<09:34,  1.41s/it]
# Epoch 2 in training:  13%|█▎        | 63/469 [01:28<09:30,  1.41s/it]
# Epoch 2 in training:  14%|█▎        | 64/469 [01:29<09:26,  1.40s/it]
# Epoch 2 in training:  14%|█▍        | 65/469 [01:30<09:22,  1.39s/it]
# Epoch 2 in training:  14%|█▍        | 66/469 [01:32<09:37,  1.43s/it]
# Epoch 2 in training:  14%|█▍        | 67/469 [01:33<09:36,  1.44s/it]
# Epoch 2 in training:  14%|█▍        | 68/469 [01:35<09:28,  1.42s/it]
# Epoch 2 in training:  15%|█▍        | 69/469 [01:36<09:22,  1.41s/it]
# Epoch 2 in training:  15%|█▍        | 70/469 [01:38<09:18,  1.40s/it]
# Epoch 2 in training:  15%|█▌        | 71/469 [01:39<09:16,  1.40s/it]
# Epoch 2 in training:  15%|█▌        | 72/469 [01:40<09:12,  1.39s/it]
# Epoch 2 in training:  16%|█▌        | 73/469 [01:42<09:11,  1.39s/it]
# Epoch 2 in training:  16%|█▌        | 74/469 [01:43<09:12,  1.40s/it]
# Epoch 2 in training:  16%|█▌        | 75/469 [01:45<09:13,  1.40s/it]
# Epoch 2 in training:  16%|█▌        | 76/469 [01:46<09:09,  1.40s/it]
# Epoch 2 in training:  16%|█▋        | 77/469 [01:47<09:07,  1.40s/it]
# Epoch 2 in training:  17%|█▋        | 78/469 [01:49<09:04,  1.39s/it]
# Epoch 2 in training:  17%|█▋        | 79/469 [01:50<09:01,  1.39s/it]
# Epoch 2 in training:  17%|█▋        | 80/469 [01:51<08:59,  1.39s/it]
# Epoch 2 in training:  17%|█▋        | 81/469 [01:53<09:00,  1.39s/it]
# Epoch 2 in training:  17%|█▋        | 82/469 [01:54<09:06,  1.41s/it]
# Epoch 2 in training:  18%|█▊        | 83/469 [01:56<09:12,  1.43s/it]
# Epoch 2 in training:  18%|█▊        | 84/469 [01:57<09:07,  1.42s/it]
# Epoch 2 in training:  18%|█▊        | 85/469 [01:59<09:01,  1.41s/it]
# Epoch 2 in training:  18%|█▊        | 86/469 [02:00<08:55,  1.40s/it]
# Epoch 2 in training:  19%|█▊        | 87/469 [02:01<08:50,  1.39s/it]
# Epoch 2 in training:  19%|█▉        | 88/469 [02:03<08:48,  1.39s/it]
# Epoch 2 in training:  19%|█▉        | 89/469 [02:04<08:50,  1.40s/it]
# Epoch 2 in training:  19%|█▉        | 90/469 [02:06<08:46,  1.39s/it]
# Epoch 2 in training:  19%|█▉        | 91/469 [02:07<08:44,  1.39s/it]
# Epoch 2 in training:  20%|█▉        | 92/469 [02:08<08:43,  1.39s/it]
# Epoch 2 in training:  20%|█▉        | 93/469 [02:10<08:39,  1.38s/it]
# Epoch 2 in training:  20%|██        | 94/469 [02:11<08:38,  1.38s/it]
# Epoch 2 in training:  20%|██        | 95/469 [02:13<08:50,  1.42s/it]
# Epoch 2 in training:  20%|██        | 96/469 [02:14<08:49,  1.42s/it]
# Epoch 2 in training:  21%|██        | 97/469 [02:15<08:44,  1.41s/it]
# Epoch 2 in training:  21%|██        | 98/469 [02:17<08:38,  1.40s/it]
# Epoch 2 in training:  21%|██        | 99/469 [02:18<08:36,  1.40s/it]
# Epoch 2 in training:  21%|██▏       | 100/469 [02:20<08:36,  1.40s/it]
# Epoch 2 in training:  22%|██▏       | 101/469 [02:21<08:33,  1.40s/it]
# Epoch 2 in training:  22%|██▏       | 102/469 [02:22<08:30,  1.39s/it]
# Epoch 2 in training:  22%|██▏       | 103/469 [02:24<08:31,  1.40s/it]
# Epoch 2 in training:  22%|██▏       | 104/469 [02:25<08:28,  1.39s/it]
# Epoch 2 in training:  22%|██▏       | 105/469 [02:27<08:47,  1.45s/it]
# Epoch 2 in training:  23%|██▎       | 106/469 [02:28<08:38,  1.43s/it]
# Epoch 2 in training:  23%|██▎       | 107/469 [02:29<08:34,  1.42s/it]
# Epoch 2 in training:  23%|██▎       | 108/469 [02:31<08:42,  1.45s/it]
# Epoch 2 in training:  23%|██▎       | 109/469 [02:32<08:40,  1.45s/it]
# Epoch 2 in training:  23%|██▎       | 110/469 [02:34<08:37,  1.44s/it]
# Epoch 2 in training:  24%|██▎       | 111/469 [02:35<08:29,  1.42s/it]
# Epoch 2 in training:  24%|██▍       | 112/469 [02:37<08:24,  1.41s/it]
# Epoch 2 in training:  24%|██▍       | 113/469 [02:38<08:18,  1.40s/it]
# Epoch 2 in training:  24%|██▍       | 114/469 [02:39<08:15,  1.40s/it]
# Epoch 2 in training:  25%|██▍       | 115/469 [02:41<08:12,  1.39s/it]
# Epoch 2 in training:  25%|██▍       | 116/469 [02:42<08:11,  1.39s/it]
# Epoch 2 in training:  25%|██▍       | 117/469 [02:44<08:13,  1.40s/it]
# Epoch 2 in training:  25%|██▌       | 118/469 [02:45<08:11,  1.40s/it]
# Epoch 2 in training:  25%|██▌       | 119/469 [02:46<08:23,  1.44s/it]
# Epoch 2 in training:  26%|██▌       | 120/469 [02:48<08:15,  1.42s/it]
# Epoch 2 in training:  26%|██▌       | 121/469 [02:49<08:10,  1.41s/it]
# Epoch 2 in training:  26%|██▌       | 122/469 [02:51<08:06,  1.40s/it]
# Epoch 2 in training:  26%|██▌       | 123/469 [02:52<08:01,  1.39s/it]
# Epoch 2 in training:  26%|██▋       | 124/469 [02:53<08:07,  1.41s/it]
# Epoch 2 in training:  27%|██▋       | 125/469 [02:55<08:04,  1.41s/it]
# Epoch 2 in training:  27%|██▋       | 126/469 [02:56<08:01,  1.40s/it]
# Epoch 2 in training:  27%|██▋       | 127/469 [02:58<08:05,  1.42s/it]
# Epoch 2 in training:  27%|██▋       | 128/469 [02:59<08:01,  1.41s/it]
# Epoch 2 in training:  28%|██▊       | 129/469 [03:00<07:56,  1.40s/it]
# Epoch 2 in training:  28%|██▊       | 130/469 [03:02<07:51,  1.39s/it]
# Epoch 2 in training:  28%|██▊       | 131/469 [03:03<07:52,  1.40s/it]
# Epoch 2 in training:  28%|██▊       | 132/469 [03:05<07:51,  1.40s/it]
# Epoch 2 in training:  28%|██▊       | 133/469 [03:06<07:49,  1.40s/it]
# Epoch 2 in training:  29%|██▊       | 134/469 [03:07<07:46,  1.39s/it]
# Epoch 2 in training:  29%|██▉       | 135/469 [03:09<07:44,  1.39s/it]
# Epoch 2 in training:  29%|██▉       | 136/469 [03:10<07:41,  1.39s/it]
# Epoch 2 in training:  29%|██▉       | 137/469 [03:12<07:40,  1.39s/it]
# Epoch 2 in training:  29%|██▉       | 138/469 [03:13<07:42,  1.40s/it]
# Epoch 2 in training:  30%|██▉       | 139/469 [03:14<07:45,  1.41s/it]
# Epoch 2 in training:  30%|██▉       | 140/469 [03:16<07:41,  1.40s/it]
# Epoch 2 in training:  30%|███       | 141/469 [03:17<07:38,  1.40s/it]
# Epoch 2 in training:  30%|███       | 142/469 [03:19<07:34,  1.39s/it]
# Epoch 2 in training:  30%|███       | 143/469 [03:20<07:32,  1.39s/it]
# Epoch 2 in training:  31%|███       | 144/469 [03:21<07:29,  1.38s/it]
# Epoch 2 in training:  31%|███       | 145/469 [03:23<07:28,  1.38s/it]
# Epoch 2 in training:  31%|███       | 146/469 [03:24<07:32,  1.40s/it]
# Epoch 2 in training:  31%|███▏      | 147/469 [03:26<07:30,  1.40s/it]
# Epoch 2 in training:  32%|███▏      | 148/469 [03:27<07:40,  1.43s/it]
# Epoch 2 in training:  32%|███▏      | 149/469 [03:28<07:36,  1.43s/it]
# Epoch 2 in training:  32%|███▏      | 150/469 [03:30<07:44,  1.46s/it]
# Epoch 2 in training:  32%|███▏      | 151/469 [03:31<07:35,  1.43s/it]
# Epoch 2 in training:  32%|███▏      | 152/469 [03:33<07:29,  1.42s/it]
# Epoch 2 in training:  33%|███▎      | 153/469 [03:34<07:27,  1.42s/it]
# Epoch 2 in training:  33%|███▎      | 154/469 [03:36<07:24,  1.41s/it]
# Epoch 2 in training:  33%|███▎      | 155/469 [03:37<07:20,  1.40s/it]
# Epoch 2 in training:  33%|███▎      | 156/469 [03:38<07:17,  1.40s/it]
# Epoch 2 in training:  33%|███▎      | 157/469 [03:40<07:14,  1.39s/it]
# Epoch 2 in training:  34%|███▎      | 158/469 [03:41<07:11,  1.39s/it]
# Epoch 2 in training:  34%|███▍      | 159/469 [03:42<07:08,  1.38s/it]
# Epoch 2 in training:  34%|███▍      | 160/469 [03:44<07:12,  1.40s/it]
# Epoch 2 in training:  34%|███▍      | 161/469 [03:45<07:09,  1.40s/it]
# Epoch 2 in training:  35%|███▍      | 162/469 [03:47<07:11,  1.41s/it]
# Epoch 2 in training:  35%|███▍      | 163/469 [03:48<07:11,  1.41s/it]
# Epoch 2 in training:  35%|███▍      | 164/469 [03:50<07:07,  1.40s/it]
# Epoch 2 in training:  35%|███▌      | 165/469 [03:51<07:03,  1.39s/it]
# Epoch 2 in training:  35%|███▌      | 166/469 [03:52<07:01,  1.39s/it]
# Epoch 2 in training:  36%|███▌      | 167/469 [03:54<07:02,  1.40s/it]
# Epoch 2 in training:  36%|███▌      | 168/469 [03:55<06:59,  1.39s/it]
# Epoch 2 in training:  36%|███▌      | 169/469 [03:57<07:01,  1.40s/it]
# Epoch 2 in training:  36%|███▌      | 170/469 [03:58<06:57,  1.40s/it]
# Epoch 2 in training:  36%|███▋      | 171/469 [03:59<06:57,  1.40s/it]
# Epoch 2 in training:  37%|███▋      | 172/469 [04:01<07:11,  1.45s/it]
# Epoch 2 in training:  37%|███▋      | 173/469 [04:02<07:07,  1.44s/it]
# Epoch 2 in training:  37%|███▋      | 174/469 [04:04<07:03,  1.44s/it]
# Epoch 2 in training:  37%|███▋      | 175/469 [04:05<06:58,  1.42s/it]
# Epoch 2 in training:  38%|███▊      | 176/469 [04:06<06:53,  1.41s/it]
# Epoch 2 in training:  38%|███▊      | 177/469 [04:08<06:50,  1.41s/it]
# Epoch 2 in training:  38%|███▊      | 178/469 [04:09<06:47,  1.40s/it]
# Epoch 2 in training:  38%|███▊      | 179/469 [04:11<06:43,  1.39s/it]
# Epoch 2 in training:  38%|███▊      | 180/469 [04:12<06:40,  1.39s/it]
# Epoch 2 in training:  39%|███▊      | 181/469 [04:13<06:42,  1.40s/it]
# Epoch 2 in training:  39%|███▉      | 182/469 [04:15<06:43,  1.40s/it]
# Epoch 2 in training:  39%|███▉      | 183/469 [04:16<06:39,  1.40s/it]
# Epoch 2 in training:  39%|███▉      | 184/469 [04:18<06:37,  1.40s/it]
# Epoch 2 in training:  39%|███▉      | 185/469 [04:19<06:37,  1.40s/it]
# Epoch 2 in training:  40%|███▉      | 186/469 [04:20<06:34,  1.39s/it]
# Epoch 2 in training:  40%|███▉      | 187/469 [04:22<06:33,  1.40s/it]
# Epoch 2 in training:  40%|████      | 188/469 [04:23<06:34,  1.40s/it]
# Epoch 2 in training:  40%|████      | 189/469 [04:25<06:31,  1.40s/it]
# Epoch 2 in training:  41%|████      | 190/469 [04:26<06:32,  1.41s/it]
# Epoch 2 in training:  41%|████      | 191/469 [04:27<06:28,  1.40s/it]
# Epoch 2 in training:  41%|████      | 192/469 [04:29<06:26,  1.39s/it]
# Epoch 2 in training:  41%|████      | 193/469 [04:30<06:23,  1.39s/it]
# Epoch 2 in training:  41%|████▏     | 194/469 [04:32<06:25,  1.40s/it]
# Epoch 2 in training:  42%|████▏     | 195/469 [04:33<06:26,  1.41s/it]
# Epoch 2 in training:  42%|████▏     | 196/469 [04:34<06:22,  1.40s/it]
# Epoch 2 in training:  42%|████▏     | 197/469 [04:36<06:20,  1.40s/it]
# Epoch 2 in training:  42%|████▏     | 198/469 [04:37<06:17,  1.39s/it]
# Epoch 2 in training:  42%|████▏     | 199/469 [04:39<06:15,  1.39s/it]
# Epoch 2 in training:  43%|████▎     | 200/469 [04:40<06:12,  1.38s/it]
# Epoch 2 in training:  43%|████▎     | 201/469 [04:41<06:19,  1.42s/it]
# Epoch 2 in training:  43%|████▎     | 202/469 [04:43<06:15,  1.40s/it]
# Epoch 2 in training:  43%|████▎     | 203/469 [04:44<06:17,  1.42s/it]
# Epoch 2 in training:  43%|████▎     | 204/469 [04:46<06:14,  1.41s/it]
# Epoch 2 in training:  44%|████▎     | 205/469 [04:47<06:11,  1.41s/it]
# Epoch 2 in training:  44%|████▍     | 206/469 [04:48<06:10,  1.41s/it]
# ...
# Epoch 10 in training:  54%|█████▎    | 251/469 [05:53<05:05,  1.40s/it]
# Epoch 10 in training:  54%|█████▎    | 252/469 [05:54<05:04,  1.40s/it]
# Epoch 10 in training:  54%|█████▍    | 253/469 [05:56<05:12,  1.45s/it]
# Epoch 10 in training:  54%|█████▍    | 254/469 [05:57<05:07,  1.43s/it]
# Epoch 10 in training:  54%|█████▍    | 255/469 [05:58<05:03,  1.42s/it]
# Epoch 10 in training:  55%|█████▍    | 256/469 [06:00<04:59,  1.41s/it]
# Epoch 10 in training:  55%|█████▍    | 257/469 [06:01<04:58,  1.41s/it]
# Epoch 10 in training:  55%|█████▌    | 258/469 [06:03<04:56,  1.40s/it]
# Epoch 10 in training:  55%|█████▌    | 259/469 [06:04<04:52,  1.39s/it]
# Epoch 10 in training:  55%|█████▌    | 260/469 [06:05<04:52,  1.40s/it]
# Epoch 10 in training:  56%|█████▌    | 261/469 [06:07<04:55,  1.42s/it]
# Epoch 10 in training:  56%|█████▌    | 262/469 [06:08<04:51,  1.41s/it]
# Epoch 10 in training:  56%|█████▌    | 263/469 [06:10<04:48,  1.40s/it]
# Epoch 10 in training:  56%|█████▋    | 264/469 [06:11<04:47,  1.40s/it]
# Epoch 10 in training:  57%|█████▋    | 265/469 [06:12<04:44,  1.39s/it]
# Epoch 10 in training:  57%|█████▋    | 266/469 [06:14<04:42,  1.39s/it]
# Epoch 10 in training:  57%|█████▋    | 267/469 [06:15<04:40,  1.39s/it]
# Epoch 10 in training:  57%|█████▋    | 268/469 [06:16<04:38,  1.38s/it]
# Epoch 10 in training:  57%|█████▋    | 269/469 [06:18<04:36,  1.38s/it]
# Epoch 10 in training:  58%|█████▊    | 270/469 [06:19<04:35,  1.39s/it]
# Epoch 10 in training:  58%|█████▊    | 271/469 [06:21<04:34,  1.39s/it]
# Epoch 10 in training:  58%|█████▊    | 272/469 [06:22<04:35,  1.40s/it]
# Epoch 10 in training:  58%|█████▊    | 273/469 [06:23<04:33,  1.39s/it]
# Epoch 10 in training:  58%|█████▊    | 274/469 [06:25<04:31,  1.39s/it]
# Epoch 10 in training:  59%|█████▊    | 275/469 [06:26<04:30,  1.40s/it]
# Epoch 10 in training:  59%|█████▉    | 276/469 [06:28<04:29,  1.40s/it]
# Epoch 10 in training:  59%|█████▉    | 277/469 [06:29<04:35,  1.44s/it]
# Epoch 10 in training:  59%|█████▉    | 278/469 [06:31<04:31,  1.42s/it]
# Epoch 10 in training:  59%|█████▉    | 279/469 [06:32<04:30,  1.42s/it]
# Epoch 10 in training:  60%|█████▉    | 280/469 [06:33<04:27,  1.42s/it]
# Epoch 10 in training:  60%|█████▉    | 281/469 [06:35<04:23,  1.40s/it]
# Epoch 10 in training:  60%|██████    | 282/469 [06:36<04:20,  1.39s/it]
# Epoch 10 in training:  60%|██████    | 283/469 [06:38<04:22,  1.41s/it]
# Epoch 10 in training:  61%|██████    | 284/469 [06:39<04:20,  1.41s/it]
# Epoch 10 in training:  61%|██████    | 285/469 [06:40<04:17,  1.40s/it]
# Epoch 10 in training:  61%|██████    | 286/469 [06:42<04:16,  1.40s/it]
# Epoch 10 in training:  61%|██████    | 287/469 [06:43<04:14,  1.40s/it]
# Epoch 10 in training:  61%|██████▏   | 288/469 [06:45<04:12,  1.40s/it]
# Epoch 10 in training:  62%|██████▏   | 289/469 [06:46<04:10,  1.39s/it]
# Epoch 10 in training:  62%|██████▏   | 290/469 [06:47<04:08,  1.39s/it]
# Epoch 10 in training:  62%|██████▏   | 291/469 [06:49<04:06,  1.39s/it]
# Epoch 10 in training:  62%|██████▏   | 292/469 [06:50<04:04,  1.38s/it]
# Epoch 10 in training:  62%|██████▏   | 293/469 [06:52<04:07,  1.41s/it]
# Epoch 10 in training:  63%|██████▎   | 294/469 [06:53<04:05,  1.40s/it]
# Epoch 10 in training:  63%|██████▎   | 295/469 [06:54<04:03,  1.40s/it]
# Epoch 10 in training:  63%|██████▎   | 296/469 [06:56<04:01,  1.39s/it]
# Epoch 10 in training:  63%|██████▎   | 297/469 [06:57<04:01,  1.41s/it]
# Epoch 10 in training:  64%|██████▎   | 298/469 [06:59<03:59,  1.40s/it]
# Epoch 10 in training:  64%|██████▍   | 299/469 [07:00<03:57,  1.39s/it]
# Epoch 10 in training:  64%|██████▍   | 300/469 [07:01<03:57,  1.40s/it]
# Epoch 10 in training:  64%|██████▍   | 301/469 [07:03<03:55,  1.40s/it]
# Epoch 10 in training:  64%|██████▍   | 302/469 [07:04<03:52,  1.39s/it]
# Epoch 10 in training:  65%|██████▍   | 303/469 [07:05<03:50,  1.39s/it]
# Epoch 10 in training:  65%|██████▍   | 304/469 [07:07<03:50,  1.40s/it]
# Epoch 10 in training:  65%|██████▌   | 305/469 [07:08<03:50,  1.40s/it]
# Epoch 10 in training:  65%|██████▌   | 306/469 [07:10<03:57,  1.46s/it]
# Epoch 10 in training:  65%|██████▌   | 307/469 [07:11<03:54,  1.45s/it]
# Epoch 10 in training:  66%|██████▌   | 308/469 [07:13<03:49,  1.43s/it]
# Epoch 10 in training:  66%|██████▌   | 309/469 [07:14<03:47,  1.42s/it]
# Epoch 10 in training:  66%|██████▌   | 310/469 [07:15<03:44,  1.41s/it]
# Epoch 10 in training:  66%|██████▋   | 311/469 [07:17<03:42,  1.41s/it]
# Epoch 10 in training:  67%|██████▋   | 312/469 [07:18<03:40,  1.41s/it]
# Epoch 10 in training:  67%|██████▋   | 313/469 [07:20<03:37,  1.40s/it]
# Epoch 10 in training:  67%|██████▋   | 314/469 [07:21<03:37,  1.40s/it]
# Epoch 10 in training:  67%|██████▋   | 315/469 [07:22<03:34,  1.39s/it]
# Epoch 10 in training:  67%|██████▋   | 316/469 [07:24<03:32,  1.39s/it]
# Epoch 10 in training:  68%|██████▊   | 317/469 [07:25<03:30,  1.39s/it]
# Epoch 10 in training:  68%|██████▊   | 318/469 [07:27<03:29,  1.38s/it]
# Epoch 10 in training:  68%|██████▊   | 319/469 [07:28<03:27,  1.38s/it]
# Epoch 10 in training:  68%|██████▊   | 320/469 [07:29<03:25,  1.38s/it]
# Epoch 10 in training:  68%|██████▊   | 321/469 [07:31<03:25,  1.39s/it]
# Epoch 10 in training:  69%|██████▊   | 322/469 [07:32<03:25,  1.40s/it]
# Epoch 10 in training:  69%|██████▉   | 323/469 [07:34<03:24,  1.40s/it]
# Epoch 10 in training:  69%|██████▉   | 324/469 [07:35<03:21,  1.39s/it]
# Epoch 10 in training:  69%|██████▉   | 325/469 [07:36<03:19,  1.39s/it]
# Epoch 10 in training:  70%|██████▉   | 326/469 [07:38<03:17,  1.38s/it]
# Epoch 10 in training:  70%|██████▉   | 327/469 [07:39<03:16,  1.38s/it]
# Epoch 10 in training:  70%|██████▉   | 328/469 [07:41<03:17,  1.40s/it]
# Epoch 10 in training:  70%|███████   | 329/469 [07:42<03:17,  1.41s/it]
# Epoch 10 in training:  70%|███████   | 330/469 [07:43<03:19,  1.43s/it]
# Epoch 10 in training:  71%|███████   | 331/469 [07:45<03:15,  1.42s/it]
# Epoch 10 in training:  71%|███████   | 332/469 [07:46<03:12,  1.41s/it]
# Epoch 10 in training:  71%|███████   | 333/469 [07:48<03:10,  1.40s/it]
# Epoch 10 in training:  71%|███████   | 334/469 [07:49<03:08,  1.40s/it]
# Epoch 10 in training:  71%|███████▏  | 335/469 [07:50<03:06,  1.39s/it]
# Epoch 10 in training:  72%|███████▏  | 336/469 [07:52<03:05,  1.40s/it]
# Epoch 10 in training:  72%|███████▏  | 337/469 [07:53<03:03,  1.39s/it]
# Epoch 10 in training:  72%|███████▏  | 338/469 [07:55<03:01,  1.39s/it]
# Epoch 10 in training:  72%|███████▏  | 339/469 [07:56<03:00,  1.39s/it]
# Epoch 10 in training:  72%|███████▏  | 340/469 [07:57<02:59,  1.39s/it]
# Epoch 10 in training:  73%|███████▎  | 341/469 [07:59<02:56,  1.38s/it]
# Epoch 10 in training:  73%|███████▎  | 342/469 [08:00<02:54,  1.38s/it]
# Epoch 10 in training:  73%|███████▎  | 343/469 [08:01<02:54,  1.38s/it]
# Epoch 10 in training:  73%|███████▎  | 344/469 [08:03<02:53,  1.39s/it]
# Epoch 10 in training:  74%|███████▎  | 345/469 [08:04<02:51,  1.39s/it]
# Epoch 10 in training:  74%|███████▍  | 346/469 [08:06<02:50,  1.39s/it]
# Epoch 10 in training:  74%|███████▍  | 347/469 [08:07<02:49,  1.39s/it]
# Epoch 10 in training:  74%|███████▍  | 348/469 [08:08<02:48,  1.39s/it]
# Epoch 10 in training:  74%|███████▍  | 349/469 [08:10<02:46,  1.39s/it]
# Epoch 10 in training:  75%|███████▍  | 350/469 [08:11<02:48,  1.42s/it]
# Epoch 10 in training:  75%|███████▍  | 351/469 [08:13<02:47,  1.42s/it]
# Epoch 10 in training:  75%|███████▌  | 352/469 [08:14<02:44,  1.41s/it]
# Epoch 10 in training:  75%|███████▌  | 353/469 [08:15<02:42,  1.40s/it]
# Epoch 10 in training:  75%|███████▌  | 354/469 [08:17<02:40,  1.39s/it]
# Epoch 10 in training:  76%|███████▌  | 355/469 [08:18<02:40,  1.41s/it]
# Epoch 10 in training:  76%|███████▌  | 356/469 [08:20<02:39,  1.41s/it]
# Epoch 10 in training:  76%|███████▌  | 357/469 [08:21<02:38,  1.41s/it]
# Epoch 10 in training:  76%|███████▋  | 358/469 [08:23<02:36,  1.41s/it]
# Epoch 10 in training:  77%|███████▋  | 359/469 [08:24<02:37,  1.43s/it]
# Epoch 10 in training:  77%|███████▋  | 360/469 [08:25<02:34,  1.42s/it]
# Epoch 10 in training:  77%|███████▋  | 361/469 [08:27<02:32,  1.41s/it]
# Epoch 10 in training:  77%|███████▋  | 362/469 [08:28<02:30,  1.41s/it]
# Epoch 10 in training:  77%|███████▋  | 363/469 [08:30<02:28,  1.40s/it]
# Epoch 10 in training:  78%|███████▊  | 364/469 [08:31<02:28,  1.41s/it]
# Epoch 10 in training:  78%|███████▊  | 365/469 [08:32<02:26,  1.41s/it]
# Epoch 10 in training:  78%|███████▊  | 366/469 [08:34<02:23,  1.40s/it]
# Epoch 10 in training:  78%|███████▊  | 367/469 [08:35<02:21,  1.39s/it]
# Epoch 10 in training:  78%|███████▊  | 368/469 [08:37<02:20,  1.39s/it]
# Epoch 10 in training:  79%|███████▊  | 369/469 [08:38<02:18,  1.39s/it]
# Epoch 10 in training:  79%|███████▉  | 370/469 [08:39<02:18,  1.40s/it]
# Epoch 10 in training:  79%|███████▉  | 371/469 [08:41<02:16,  1.39s/it]
# Epoch 10 in training:  79%|███████▉  | 372/469 [08:42<02:15,  1.40s/it]
# Epoch 10 in training:  80%|███████▉  | 373/469 [08:44<02:16,  1.42s/it]
# Epoch 10 in training:  80%|███████▉  | 374/469 [08:45<02:13,  1.41s/it]
# Epoch 10 in training:  80%|███████▉  | 375/469 [08:46<02:12,  1.40s/it]
# Epoch 10 in training:  80%|████████  | 376/469 [08:48<02:09,  1.40s/it]
# Epoch 10 in training:  80%|████████  | 377/469 [08:49<02:08,  1.39s/it]
# Epoch 10 in training:  81%|████████  | 378/469 [08:51<02:06,  1.39s/it]
# Epoch 10 in training:  81%|████████  | 379/469 [08:52<02:05,  1.39s/it]
# Epoch 10 in training:  81%|████████  | 380/469 [08:53<02:03,  1.39s/it]
# Epoch 10 in training:  81%|████████  | 381/469 [08:55<02:02,  1.39s/it]
# Epoch 10 in training:  81%|████████▏ | 382/469 [08:56<02:01,  1.39s/it]
# Epoch 10 in training:  82%|████████▏ | 383/469 [08:58<02:02,  1.43s/it]
# Epoch 10 in training:  82%|████████▏ | 384/469 [08:59<02:00,  1.41s/it]
# Epoch 10 in training:  82%|████████▏ | 385/469 [09:00<01:58,  1.41s/it]
# Epoch 10 in training:  82%|████████▏ | 386/469 [09:02<01:56,  1.41s/it]
# Epoch 10 in training:  83%|████████▎ | 387/469 [09:03<01:54,  1.40s/it]
# Epoch 10 in training:  83%|████████▎ | 388/469 [09:05<01:52,  1.39s/it]
# Epoch 10 in training:  83%|████████▎ | 389/469 [09:06<01:51,  1.39s/it]
# Epoch 10 in training:  83%|████████▎ | 390/469 [09:07<01:49,  1.39s/it]
# Epoch 10 in training:  83%|████████▎ | 391/469 [09:09<01:47,  1.38s/it]
# Epoch 10 in training:  84%|████████▎ | 392/469 [09:10<01:46,  1.38s/it]
# Epoch 10 in training:  84%|████████▍ | 393/469 [09:11<01:45,  1.39s/it]
# Epoch 10 in training:  84%|████████▍ | 394/469 [09:13<01:44,  1.39s/it]
# Epoch 10 in training:  84%|████████▍ | 395/469 [09:14<01:43,  1.40s/it]
# Epoch 10 in training:  84%|████████▍ | 396/469 [09:16<01:41,  1.40s/it]
# Epoch 10 in training:  85%|████████▍ | 397/469 [09:17<01:40,  1.39s/it]
# Epoch 10 in training:  85%|████████▍ | 398/469 [09:18<01:38,  1.39s/it]
# Epoch 10 in training:  85%|████████▌ | 399/469 [09:20<01:36,  1.38s/it]
# Epoch 10 in training:  85%|████████▌ | 400/469 [09:21<01:35,  1.39s/it]
# Epoch 10 in training:  86%|████████▌ | 401/469 [09:23<01:34,  1.39s/it]
# Epoch 10 in training:  86%|████████▌ | 402/469 [09:24<01:32,  1.38s/it]
# Epoch 10 in training:  86%|████████▌ | 403/469 [09:25<01:31,  1.39s/it]
# Epoch 10 in training:  86%|████████▌ | 404/469 [09:27<01:29,  1.38s/it]
# Epoch 10 in training:  86%|████████▋ | 405/469 [09:28<01:28,  1.38s/it]
# Epoch 10 in training:  87%|████████▋ | 406/469 [09:29<01:26,  1.38s/it]
# Epoch 10 in training:  87%|████████▋ | 407/469 [09:31<01:26,  1.39s/it]
# Epoch 10 in training:  87%|████████▋ | 408/469 [09:32<01:25,  1.39s/it]
# Epoch 10 in training:  87%|████████▋ | 409/469 [09:34<01:24,  1.41s/it]
# Epoch 10 in training:  87%|████████▋ | 410/469 [09:35<01:22,  1.40s/it]
# Epoch 10 in training:  88%|████████▊ | 411/469 [09:37<01:20,  1.39s/it]
# Epoch 10 in training:  88%|████████▊ | 412/469 [09:38<01:21,  1.42s/it]
# Epoch 10 in training:  88%|████████▊ | 413/469 [09:39<01:20,  1.44s/it]
# Epoch 10 in training:  88%|████████▊ | 414/469 [09:41<01:18,  1.42s/it]
# Epoch 10 in training:  88%|████████▊ | 415/469 [09:42<01:16,  1.41s/it]
# Epoch 10 in training:  89%|████████▊ | 416/469 [09:44<01:14,  1.41s/it]
# Epoch 10 in training:  89%|████████▉ | 417/469 [09:45<01:12,  1.40s/it]
# Epoch 10 in training:  89%|████████▉ | 418/469 [09:47<01:12,  1.43s/it]
# Epoch 10 in training:  89%|████████▉ | 419/469 [09:48<01:10,  1.41s/it]
# Epoch 10 in training:  90%|████████▉ | 420/469 [09:49<01:09,  1.41s/it]
# Epoch 10 in training:  90%|████████▉ | 421/469 [09:51<01:07,  1.41s/it]
# Epoch 10 in training:  90%|████████▉ | 422/469 [09:52<01:06,  1.41s/it]
# Epoch 10 in training:  90%|█████████ | 423/469 [09:54<01:04,  1.41s/it]
# Epoch 10 in training:  90%|█████████ | 424/469 [09:55<01:03,  1.41s/it]
# Epoch 10 in training:  91%|█████████ | 425/469 [09:56<01:01,  1.40s/it]
# Epoch 10 in training:  91%|█████████ | 426/469 [09:58<01:00,  1.40s/it]
# Epoch 10 in training:  91%|█████████ | 427/469 [09:59<00:58,  1.39s/it]
# Epoch 10 in training:  91%|█████████▏| 428/469 [10:00<00:57,  1.39s/it]
# Epoch 10 in training:  91%|█████████▏| 429/469 [10:02<00:56,  1.40s/it]
# Epoch 10 in training:  92%|█████████▏| 430/469 [10:03<00:54,  1.40s/it]
# Epoch 10 in training:  92%|█████████▏| 431/469 [10:05<00:52,  1.39s/it]
# Epoch 10 in training:  92%|█████████▏| 432/469 [10:06<00:51,  1.40s/it]
# Epoch 10 in training:  92%|█████████▏| 433/469 [10:07<00:50,  1.39s/it]
# Epoch 10 in training:  93%|█████████▎| 434/469 [10:09<00:48,  1.39s/it]
# Epoch 10 in training:  93%|█████████▎| 435/469 [10:10<00:47,  1.39s/it]
# Epoch 10 in training:  93%|█████████▎| 436/469 [10:12<00:47,  1.43s/it]
# Epoch 10 in training:  93%|█████████▎| 437/469 [10:13<00:45,  1.42s/it]
# Epoch 10 in training:  93%|█████████▎| 438/469 [10:15<00:43,  1.40s/it]
# Epoch 10 in training:  94%|█████████▎| 439/469 [10:16<00:41,  1.39s/it]
# Epoch 10 in training:  94%|█████████▍| 440/469 [10:17<00:40,  1.41s/it]
# Epoch 10 in training:  94%|█████████▍| 441/469 [10:19<00:39,  1.40s/it]
# Epoch 10 in training:  94%|█████████▍| 442/469 [10:20<00:37,  1.40s/it]
# Epoch 10 in training:  94%|█████████▍| 443/469 [10:22<00:36,  1.40s/it]
# Epoch 10 in training:  95%|█████████▍| 444/469 [10:23<00:35,  1.40s/it]
# Epoch 10 in training:  95%|█████████▍| 445/469 [10:24<00:33,  1.40s/it]
# Epoch 10 in training:  95%|█████████▌| 446/469 [10:26<00:32,  1.39s/it]
# Epoch 10 in training:  95%|█████████▌| 447/469 [10:27<00:30,  1.40s/it]
# Epoch 10 in training:  96%|█████████▌| 448/469 [10:29<00:29,  1.41s/it]
# Epoch 10 in training:  96%|█████████▌| 449/469 [10:30<00:28,  1.41s/it]
# Epoch 10 in training:  96%|█████████▌| 450/469 [10:31<00:27,  1.42s/it]
# Epoch 10 in training:  96%|█████████▌| 451/469 [10:33<00:25,  1.44s/it]
# Epoch 10 in training:  96%|█████████▋| 452/469 [10:34<00:24,  1.42s/it]
# Epoch 10 in training:  97%|█████████▋| 453/469 [10:36<00:22,  1.41s/it]
# Epoch 10 in training:  97%|█████████▋| 454/469 [10:37<00:21,  1.41s/it]
# Epoch 10 in training:  97%|█████████▋| 455/469 [10:38<00:19,  1.40s/it]
# Epoch 10 in training:  97%|█████████▋| 456/469 [10:40<00:18,  1.40s/it]
# Epoch 10 in training:  97%|█████████▋| 457/469 [10:41<00:16,  1.40s/it]
# Epoch 10 in training:  98%|█████████▊| 458/469 [10:43<00:15,  1.40s/it]
# Epoch 10 in training:  98%|█████████▊| 459/469 [10:44<00:13,  1.39s/it]
# Epoch 10 in training:  98%|█████████▊| 460/469 [10:45<00:12,  1.39s/it]
# Epoch 10 in training:  98%|█████████▊| 461/469 [10:47<00:11,  1.39s/it]
# Epoch 10 in training:  99%|█████████▊| 462/469 [10:48<00:09,  1.40s/it]
# Epoch 10 in training:  99%|█████████▊| 463/469 [10:50<00:08,  1.40s/it]
# Epoch 10 in training:  99%|█████████▉| 464/469 [10:51<00:07,  1.41s/it]
# Epoch 10 in training:  99%|█████████▉| 465/469 [10:53<00:05,  1.44s/it]
# Epoch 10 in training:  99%|█████████▉| 466/469 [10:54<00:04,  1.42s/it]
# Epoch 10 in training: 100%|█████████▉| 467/469 [10:55<00:02,  1.41s/it]
# Epoch 10 in training: 100%|█████████▉| 468/469 [10:57<00:01,  1.40s/it]
# Epoch 10 in training: 100%|██████████| 469/469 [10:58<00:00,  1.30s/it]
# train: 100%|██████████| 10/10 [1:49:52<00:00, 659.27s/it]
# Epoch 10/10 loss: 1.68
# Testing: 100%|██████████| 79/79 [00:49<00:00,  1.60it/s]
# Test loss: 1.70
# Test accuracy: 76.14%

# %%
path: str = "chebykan_vit_10epochs.pth"

torch.save(mnist_model.state_dict(), path)
