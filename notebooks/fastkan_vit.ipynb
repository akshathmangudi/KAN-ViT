# %%
import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import Adam
import torch.nn as nn
import numpy as np
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy

# %%
class SplineLinear(nn.Linear):
    def __init__(self, in_features: int, out_features: int, init_scale: float = 0.1, **kw) -> None:
        self.init_scale = init_scale
        super().__init__(in_features, out_features, bias=False, **kw)

    def reset_parameters(self) -> None:
        nn.init.trunc_normal_(self.weight, mean=0, std=self.init_scale)

class RadialBasisFunction(nn.Module):
    def __init__(
        self,
        grid_min: float = -2.,
        grid_max: float = 2.,
        num_grids: int = 8,
        denominator: float = None,  # larger denominators lead to smoother basis
    ):
        super().__init__()
        grid = torch.linspace(grid_min, grid_max, num_grids)
        self.grid = torch.nn.Parameter(grid, requires_grad=False)
        self.denominator = denominator or (grid_max - grid_min) / (num_grids - 1)

    def forward(self, x):
        return torch.exp(-((x[..., None] - self.grid) / self.denominator) ** 2)

class FastKANLayer(nn.Module):
    def __init__(
        self,
        input_dim: int,
        output_dim: int,
        grid_min: float = -2.,
        grid_max: float = 2.,
        num_grids: int = 8,
        use_base_update: bool = True,
        base_activation = F.silu,
        spline_weight_init_scale: float = 0.1,
    ) -> None:
        super().__init__()
        self.layernorm = nn.LayerNorm(input_dim)
        self.rbf = RadialBasisFunction(grid_min, grid_max, num_grids)
        self.spline_linear = SplineLinear(input_dim * num_grids, output_dim, spline_weight_init_scale)
        self.use_base_update = use_base_update
        if use_base_update:
            self.base_activation = base_activation
            self.base_linear = nn.Linear(input_dim, output_dim)

    def forward(self, x, time_benchmark=False):
        if not time_benchmark:
            spline_basis = self.rbf(self.layernorm(x))
        else:
            spline_basis = self.rbf(x)
        ret = self.spline_linear(spline_basis.view(*spline_basis.shape[:-2], -1))
        if self.use_base_update:
            base = self.base_linear(self.base_activation(x))
            ret = ret + base
        return ret

# %%
torch.manual_seed(42)
numpy.random.seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
def positional_embeddings(seq_length, d):
    """
    the purpose of this function is to find high and low interaction of a word with surrounding words.
    We can do so by the following equation below:

    Args:
        seq_length (int): The length of the sequence/sentence
        d (int): The dimension of the embedding
    """

    result = torch.ones(seq_length, d)
    for i in range(seq_length):
        for j in range(d):
            result[i][j] = numpy.sin(i / 10000 ** (j / d)) if j % 2 == 0 else numpy.cos(i / 10000 ** (j/ d))
    return result

# %%
def patchify(images, n_patches):
    """
    The purpose of this function is to break down the main image into multiple sub-images and map them.

    Args:
        images (_type_): The image passeed into this function.
        n_patches (_type_): The number of sub-images that will be created.
    """

    n, c, h, w = images.shape
    assert h == w, "Only for square images"

    patches = torch.zeros(n, n_patches**2, h * w * c // n_patches ** 2) # The equation to calculate the patches
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches

# %%
class MSA(torch.nn.Module):
    """
        Initializes the Multi-Head Self-Attention (MSA) module with the given dimensions.

        Args:
            d (int): The total dimension of the input.
            n_heads (int): The number of attention heads.

        Returns:
            None
    """
    def __init__(self, d, n_heads):
        super(MSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0
        d_head = int(d / n_heads)

        self.q_mappings = torch.nn.ModuleList([FastKANLayer(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = torch.nn.ModuleList([FastKANLayer(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = torch.nn.ModuleList([FastKANLayer(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = torch.nn.Softmax(dim=-1)

    def forward(self, sequence):
        result = []
        for sequence in sequence:
            seq_res = []
            for head in range(self.n_heads):
                q_map = self.q_mappings[head]
                k_map = self.k_mappings[head]
                v_map = self.v_mappings[head]

                seq = sequence[:, head*self.d_head: (head+1)*self.d_head]
                q, k, v = q_map(seq), k_map(seq), v_map(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_res.append(attention @ v)
            result.append(torch.hstack(seq_res))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class FastKAN_ViT(torch.nn.Module):
    """
        Initializes a Vision Transformer (ViT) module.

        Args:
            chw (list/tuple of 3 ints): The input image shape.
            n_patches (int, optional): The number of patches to split the image into. Defaults to 10.
            n_blocks (int, optional): The number of blocks in the transformer encoder. Defaults to 2.
            d_hidden (int, optional): The number of hidden dimensions in the transformer encoder. Defaults to 8.
            n_heads (int, optional): The number of attention heads in each block. Defaults to 2.
            out_d (int, optional): The number of output dimensions. Defaults to 10.

        Returns:
            None
    """
    def __init__(self, chw, n_patches=10, n_blocks=2, d_hidden=8, n_heads=2, out_d=10):
        super(FastKAN_ViT, self).__init__()

        self.chw = chw
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.d_hidden = d_hidden

        assert chw[1] % n_patches == 0
        assert chw[2] % n_patches == 0

        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # Linear mapping
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = FastKANLayer(self.input_d, self.d_hidden)

        # Classification token
        self.v_class = torch.nn.Parameter(torch.rand(1, self.d_hidden))

        # Positional embedding
        self.register_buffer('positional_embeddings', positional_embeddings(n_patches ** 2 + 1, d_hidden),
                             persistent=False)

        # Encoder blocks
        self.blocks = torch.nn.ModuleList([MSA(d_hidden, n_heads) for _ in range(n_blocks)])

        self.mlp = torch.nn.Sequential(
            FastKANLayer(self.d_hidden, out_d),
            torch.nn.Softmax(dim=-1)
        )

    def forward(self, images):
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)

        # running tokenization
        tokens = self.linear_mapper(patches)
        tokens = torch.cat((self.v_class.expand(n, 1, -1), tokens), dim=1)
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        for block in self.blocks:
            out = block(out)

        out = out[:, 0]
        return self.mlp(out)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mnist_model = FastKAN_ViT((1, 28, 28), n_patches=7, n_blocks=2, d_hidden=8, n_heads=2, out_d=10).to(device)
optimizer = Adam(mnist_model.parameters(), lr=0.005)

# %%
from torch.optim import Adam
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST
from tqdm import tqdm, trange

def main(train_loader, test_loader):
    """
    This code contains the training and testing loop for training the vision transformers model. It requires two
    parameters

    :param train_loader: The dataloader for the training set for training the model.
    :param test_loader: The dataloader for the testing set during evaluation phase.
    """
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    epochs = 10
    criterion = torch.nn.CrossEntropyLoss()
    for epoch in trange(epochs, desc="train"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch + 1}/{epochs} loss: {train_loss:.2f}")

    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
transform = transforms.ToTensor()
train_mnist = MNIST(root='./mnist', train=True, download=True, transform=transform)
test_mnist = MNIST(root='./mnist', train=False, download=True, transform=transform)
train_loader = DataLoader(train_mnist, shuffle=True, batch_size=128)
test_loader = DataLoader(test_mnist, shuffle=False, batch_size=128)
main(train_loader=train_loader, test_loader=test_loader)
# Out:
# Using device:  cuda (Tesla P100-PCIE-16GB)
# train:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:01<12:17,  1.58s/it]
# Epoch 1 in training:   0%|          | 2/469 [00:03<12:01,  1.54s/it]
# Epoch 1 in training:   1%|          | 3/469 [00:04<11:53,  1.53s/it]
# Epoch 1 in training:   1%|          | 4/469 [00:06<11:48,  1.52s/it]
# Epoch 1 in training:   1%|          | 5/469 [00:07<11:47,  1.53s/it]
# Epoch 1 in training:   1%|▏         | 6/469 [00:09<11:56,  1.55s/it]
# Epoch 1 in training:   1%|▏         | 7/469 [00:10<11:55,  1.55s/it]
# Epoch 1 in training:   2%|▏         | 8/469 [00:12<11:50,  1.54s/it]
# Epoch 1 in training:   2%|▏         | 9/469 [00:13<11:45,  1.53s/it]
# Epoch 1 in training:   2%|▏         | 10/469 [00:15<11:44,  1.54s/it]
# Epoch 1 in training:   2%|▏         | 11/469 [00:16<11:43,  1.54s/it]
# Epoch 1 in training:   3%|▎         | 12/469 [00:18<11:41,  1.54s/it]
# Epoch 1 in training:   3%|▎         | 13/469 [00:20<12:03,  1.59s/it]
# Epoch 1 in training:   3%|▎         | 14/469 [00:21<11:52,  1.57s/it]
# Epoch 1 in training:   3%|▎         | 15/469 [00:23<11:45,  1.55s/it]
# Epoch 1 in training:   3%|▎         | 16/469 [00:24<11:41,  1.55s/it]
# Epoch 1 in training:   4%|▎         | 17/469 [00:26<11:38,  1.55s/it]
# Epoch 1 in training:   4%|▍         | 18/469 [00:27<11:38,  1.55s/it]
# Epoch 1 in training:   4%|▍         | 19/469 [00:29<11:37,  1.55s/it]
# Epoch 1 in training:   4%|▍         | 20/469 [00:30<11:36,  1.55s/it]
# Epoch 1 in training:   4%|▍         | 21/469 [00:32<11:33,  1.55s/it]
# Epoch 1 in training:   5%|▍         | 22/469 [00:34<11:31,  1.55s/it]
# Epoch 1 in training:   5%|▍         | 23/469 [00:35<11:29,  1.55s/it]
# Epoch 1 in training:   5%|▌         | 24/469 [00:37<11:27,  1.55s/it]
# Epoch 1 in training:   5%|▌         | 25/469 [00:38<11:24,  1.54s/it]
# Epoch 1 in training:   6%|▌         | 26/469 [00:40<11:34,  1.57s/it]
# Epoch 1 in training:   6%|▌         | 27/469 [00:41<11:28,  1.56s/it]
# Epoch 1 in training:   6%|▌         | 28/469 [00:43<11:23,  1.55s/it]
# Epoch 1 in training:   6%|▌         | 29/469 [00:44<11:20,  1.55s/it]
# Epoch 1 in training:   6%|▋         | 30/469 [00:46<11:22,  1.55s/it]
# Epoch 1 in training:   7%|▋         | 31/469 [00:48<11:38,  1.60s/it]
# Epoch 1 in training:   7%|▋         | 32/469 [00:49<11:36,  1.59s/it]
# Epoch 1 in training:   7%|▋         | 33/469 [00:51<11:28,  1.58s/it]
# Epoch 1 in training:   7%|▋         | 34/469 [00:52<11:21,  1.57s/it]
# Epoch 1 in training:   7%|▋         | 35/469 [00:54<11:16,  1.56s/it]
# Epoch 1 in training:   8%|▊         | 36/469 [00:55<11:13,  1.56s/it]
# Epoch 1 in training:   8%|▊         | 37/469 [00:57<11:16,  1.57s/it]
# Epoch 1 in training:   8%|▊         | 38/469 [00:59<11:10,  1.56s/it]
# Epoch 1 in training:   8%|▊         | 39/469 [01:00<11:12,  1.56s/it]
# Epoch 1 in training:   9%|▊         | 40/469 [01:02<11:11,  1.57s/it]
# Epoch 1 in training:   9%|▊         | 41/469 [01:03<11:06,  1.56s/it]
# Epoch 1 in training:   9%|▉         | 42/469 [01:05<11:01,  1.55s/it]
# Epoch 1 in training:   9%|▉         | 43/469 [01:06<10:57,  1.54s/it]
# Epoch 1 in training:   9%|▉         | 44/469 [01:08<10:53,  1.54s/it]
# Epoch 1 in training:  10%|▉         | 45/469 [01:09<10:56,  1.55s/it]
# Epoch 1 in training:  10%|▉         | 46/469 [01:11<11:03,  1.57s/it]
# Epoch 1 in training:  10%|█         | 47/469 [01:13<10:57,  1.56s/it]
# Epoch 1 in training:  10%|█         | 48/469 [01:14<11:10,  1.59s/it]
# Epoch 1 in training:  10%|█         | 49/469 [01:16<11:03,  1.58s/it]
# Epoch 1 in training:  11%|█         | 50/469 [01:17<10:58,  1.57s/it]
# Epoch 1 in training:  11%|█         | 51/469 [01:19<10:52,  1.56s/it]
# Epoch 1 in training:  11%|█         | 52/469 [01:20<10:51,  1.56s/it]
# Epoch 1 in training:  11%|█▏        | 53/469 [01:22<10:46,  1.55s/it]
# Epoch 1 in training:  12%|█▏        | 54/469 [01:23<10:42,  1.55s/it]
# Epoch 1 in training:  12%|█▏        | 55/469 [01:25<10:39,  1.55s/it]
# Epoch 1 in training:  12%|█▏        | 56/469 [01:27<10:37,  1.54s/it]
# Epoch 1 in training:  12%|█▏        | 57/469 [01:28<10:34,  1.54s/it]
# Epoch 1 in training:  12%|█▏        | 58/469 [01:30<10:35,  1.55s/it]
# Epoch 1 in training:  13%|█▎        | 59/469 [01:31<10:34,  1.55s/it]
# Epoch 1 in training:  13%|█▎        | 60/469 [01:33<10:34,  1.55s/it]
# Epoch 1 in training:  13%|█▎        | 61/469 [01:34<10:31,  1.55s/it]
# Epoch 1 in training:  13%|█▎        | 62/469 [01:36<10:30,  1.55s/it]
# Epoch 1 in training:  13%|█▎        | 63/469 [01:37<10:26,  1.54s/it]
# Epoch 1 in training:  14%|█▎        | 64/469 [01:39<10:24,  1.54s/it]
# Epoch 1 in training:  14%|█▍        | 65/469 [01:40<10:25,  1.55s/it]
# Epoch 1 in training:  14%|█▍        | 66/469 [01:42<10:31,  1.57s/it]
# Epoch 1 in training:  14%|█▍        | 67/469 [01:44<10:24,  1.55s/it]
# Epoch 1 in training:  14%|█▍        | 68/469 [01:45<10:36,  1.59s/it]
# Epoch 1 in training:  15%|█▍        | 69/469 [01:47<10:28,  1.57s/it]
# Epoch 1 in training:  15%|█▍        | 70/469 [01:48<10:22,  1.56s/it]
# Epoch 1 in training:  15%|█▌        | 71/469 [01:50<10:22,  1.56s/it]
# Epoch 1 in training:  15%|█▌        | 72/469 [01:51<10:18,  1.56s/it]
# Epoch 1 in training:  16%|█▌        | 73/469 [01:53<10:13,  1.55s/it]
# Epoch 1 in training:  16%|█▌        | 74/469 [01:55<10:11,  1.55s/it]
# Epoch 1 in training:  16%|█▌        | 75/469 [01:56<10:08,  1.54s/it]
# Epoch 1 in training:  16%|█▌        | 76/469 [01:58<10:05,  1.54s/it]
# Epoch 1 in training:  16%|█▋        | 77/469 [01:59<10:06,  1.55s/it]
# Epoch 1 in training:  17%|█▋        | 78/469 [02:01<10:03,  1.54s/it]
# Epoch 1 in training:  17%|█▋        | 79/469 [02:02<10:02,  1.54s/it]
# Epoch 1 in training:  17%|█▋        | 80/469 [02:04<09:59,  1.54s/it]
# Epoch 1 in training:  17%|█▋        | 81/469 [02:05<09:58,  1.54s/it]
# Epoch 1 in training:  17%|█▋        | 82/469 [02:07<09:55,  1.54s/it]
# Epoch 1 in training:  18%|█▊        | 83/469 [02:09<10:09,  1.58s/it]
# Epoch 1 in training:  18%|█▊        | 84/469 [02:10<10:09,  1.58s/it]
# Epoch 1 in training:  18%|█▊        | 85/469 [02:12<10:01,  1.57s/it]
# Epoch 1 in training:  18%|█▊        | 86/469 [02:13<10:07,  1.59s/it]
# Epoch 1 in training:  19%|█▊        | 87/469 [02:15<10:01,  1.57s/it]
# Epoch 1 in training:  19%|█▉        | 88/469 [02:16<09:55,  1.56s/it]
# Epoch 1 in training:  19%|█▉        | 89/469 [02:18<09:51,  1.56s/it]
# Epoch 1 in training:  19%|█▉        | 90/469 [02:19<09:50,  1.56s/it]
# Epoch 1 in training:  19%|█▉        | 91/469 [02:21<09:46,  1.55s/it]
# Epoch 1 in training:  20%|█▉        | 92/469 [02:23<09:44,  1.55s/it]
# Epoch 1 in training:  20%|█▉        | 93/469 [02:24<09:40,  1.54s/it]
# Epoch 1 in training:  20%|██        | 94/469 [02:26<09:37,  1.54s/it]
# Epoch 1 in training:  20%|██        | 95/469 [02:27<09:35,  1.54s/it]
# Epoch 1 in training:  20%|██        | 96/469 [02:29<09:32,  1.53s/it]
# Epoch 1 in training:  21%|██        | 97/469 [02:30<09:34,  1.55s/it]
# Epoch 1 in training:  21%|██        | 98/469 [02:32<09:31,  1.54s/it]
# Epoch 1 in training:  21%|██        | 99/469 [02:33<09:30,  1.54s/it]
# Epoch 1 in training:  21%|██▏       | 100/469 [02:35<09:43,  1.58s/it]
# Epoch 1 in training:  22%|██▏       | 101/469 [02:37<09:38,  1.57s/it]
# Epoch 1 in training:  22%|██▏       | 102/469 [02:38<09:34,  1.57s/it]
# Epoch 1 in training:  22%|██▏       | 103/469 [02:40<09:32,  1.57s/it]
# Epoch 1 in training:  22%|██▏       | 104/469 [02:41<09:29,  1.56s/it]
# Epoch 1 in training:  22%|██▏       | 105/469 [02:43<09:24,  1.55s/it]
# Epoch 1 in training:  23%|██▎       | 106/469 [02:44<09:29,  1.57s/it]
# Epoch 1 in training:  23%|██▎       | 107/469 [02:46<09:26,  1.56s/it]
# Epoch 1 in training:  23%|██▎       | 108/469 [02:47<09:22,  1.56s/it]
# Epoch 1 in training:  23%|██▎       | 109/469 [02:49<09:18,  1.55s/it]
# Epoch 1 in training:  23%|██▎       | 110/469 [02:51<09:18,  1.55s/it]
# Epoch 1 in training:  24%|██▎       | 111/469 [02:52<09:14,  1.55s/it]
# Epoch 1 in training:  24%|██▍       | 112/469 [02:54<09:12,  1.55s/it]
# Epoch 1 in training:  24%|██▍       | 113/469 [02:55<09:15,  1.56s/it]
# Epoch 1 in training:  24%|██▍       | 114/469 [02:57<09:11,  1.55s/it]
# Epoch 1 in training:  25%|██▍       | 115/469 [02:58<09:07,  1.55s/it]
# Epoch 1 in training:  25%|██▍       | 116/469 [03:00<09:08,  1.55s/it]
# Epoch 1 in training:  25%|██▍       | 117/469 [03:01<09:04,  1.55s/it]
# Epoch 1 in training:  25%|██▌       | 118/469 [03:03<09:02,  1.55s/it]
# Epoch 1 in training:  25%|██▌       | 119/469 [03:05<09:14,  1.58s/it]
# Epoch 1 in training:  26%|██▌       | 120/469 [03:06<09:07,  1.57s/it]
# Epoch 1 in training:  26%|██▌       | 121/469 [03:08<09:01,  1.56s/it]
# Epoch 1 in training:  26%|██▌       | 122/469 [03:09<09:01,  1.56s/it]
# Epoch 1 in training:  26%|██▌       | 123/469 [03:11<08:59,  1.56s/it]
# Epoch 1 in training:  26%|██▋       | 124/469 [03:12<08:56,  1.56s/it]
# Epoch 1 in training:  27%|██▋       | 125/469 [03:14<08:55,  1.56s/it]
# Epoch 1 in training:  27%|██▋       | 126/469 [03:15<08:59,  1.57s/it]
# Epoch 1 in training:  27%|██▋       | 127/469 [03:17<08:54,  1.56s/it]
# Epoch 1 in training:  27%|██▋       | 128/469 [03:19<08:50,  1.56s/it]
# Epoch 1 in training:  28%|██▊       | 129/469 [03:20<08:49,  1.56s/it]
# Epoch 1 in training:  28%|██▊       | 130/469 [03:22<08:46,  1.55s/it]
# Epoch 1 in training:  28%|██▊       | 131/469 [03:23<08:43,  1.55s/it]
# Epoch 1 in training:  28%|██▊       | 132/469 [03:25<08:40,  1.54s/it]
# Epoch 1 in training:  28%|██▊       | 133/469 [03:26<08:38,  1.54s/it]
# Epoch 1 in training:  29%|██▊       | 134/469 [03:28<08:36,  1.54s/it]
# Epoch 1 in training:  29%|██▉       | 135/469 [03:29<08:37,  1.55s/it]
# Epoch 1 in training:  29%|██▉       | 136/469 [03:31<08:48,  1.59s/it]
# Epoch 1 in training:  29%|██▉       | 137/469 [03:33<08:42,  1.57s/it]
# Epoch 1 in training:  29%|██▉       | 138/469 [03:34<08:38,  1.57s/it]
# Epoch 1 in training:  30%|██▉       | 139/469 [03:36<08:34,  1.56s/it]
# Epoch 1 in training:  30%|██▉       | 140/469 [03:37<08:30,  1.55s/it]
# Epoch 1 in training:  30%|███       | 141/469 [03:39<08:28,  1.55s/it]
# Epoch 1 in training:  30%|███       | 142/469 [03:40<08:27,  1.55s/it]
# Epoch 1 in training:  30%|███       | 143/469 [03:42<08:25,  1.55s/it]
# Epoch 1 in training:  31%|███       | 144/469 [03:43<08:22,  1.54s/it]
# Epoch 1 in training:  31%|███       | 145/469 [03:45<08:19,  1.54s/it]
# Epoch 1 in training:  31%|███       | 146/469 [03:47<08:24,  1.56s/it]
# Epoch 1 in training:  31%|███▏      | 147/469 [03:48<08:20,  1.56s/it]
# Epoch 1 in training:  32%|███▏      | 148/469 [03:50<08:19,  1.56s/it]
# Epoch 1 in training:  32%|███▏      | 149/469 [03:51<08:15,  1.55s/it]
# Epoch 1 in training:  32%|███▏      | 150/469 [03:53<08:13,  1.55s/it]
# Epoch 1 in training:  32%|███▏      | 151/469 [03:54<08:11,  1.55s/it]
# Epoch 1 in training:  32%|███▏      | 152/469 [03:56<08:10,  1.55s/it]
# Epoch 1 in training:  33%|███▎      | 153/469 [03:57<08:07,  1.54s/it]
# Epoch 1 in training:  33%|███▎      | 154/469 [03:59<08:04,  1.54s/it]
# Epoch 1 in training:  33%|███▎      | 155/469 [04:00<08:03,  1.54s/it]
# Epoch 1 in training:  33%|███▎      | 156/469 [04:02<08:13,  1.58s/it]
# Epoch 1 in training:  33%|███▎      | 157/469 [04:04<08:11,  1.57s/it]
# Epoch 1 in training:  34%|███▎      | 158/469 [04:05<08:06,  1.56s/it]
# Epoch 1 in training:  34%|███▍      | 159/469 [04:07<08:01,  1.55s/it]
# Epoch 1 in training:  34%|███▍      | 160/469 [04:08<07:58,  1.55s/it]
# Epoch 1 in training:  34%|███▍      | 161/469 [04:10<07:58,  1.55s/it]
# Epoch 1 in training:  35%|███▍      | 162/469 [04:11<07:55,  1.55s/it]
# Epoch 1 in training:  35%|███▍      | 163/469 [04:13<07:51,  1.54s/it]
# Epoch 1 in training:  35%|███▍      | 164/469 [04:14<07:49,  1.54s/it]
# Epoch 1 in training:  35%|███▌      | 165/469 [04:16<07:49,  1.55s/it]
# Epoch 1 in training:  35%|███▌      | 166/469 [04:18<07:54,  1.56s/it]
# Epoch 1 in training:  36%|███▌      | 167/469 [04:19<07:53,  1.57s/it]
# Epoch 1 in training:  36%|███▌      | 168/469 [04:21<07:49,  1.56s/it]
# Epoch 1 in training:  36%|███▌      | 169/469 [04:22<07:45,  1.55s/it]
# Epoch 1 in training:  36%|███▌      | 170/469 [04:24<07:42,  1.55s/it]
# Epoch 1 in training:  36%|███▋      | 171/469 [04:25<07:51,  1.58s/it]
# Epoch 1 in training:  37%|███▋      | 172/469 [04:27<07:45,  1.57s/it]
# Epoch 1 in training:  37%|███▋      | 173/469 [04:29<07:41,  1.56s/it]
# Epoch 1 in training:  37%|███▋      | 174/469 [04:30<07:39,  1.56s/it]
# Epoch 1 in training:  37%|███▋      | 175/469 [04:32<07:38,  1.56s/it]
# Epoch 1 in training:  38%|███▊      | 176/469 [04:33<07:40,  1.57s/it]
# Epoch 1 in training:  38%|███▊      | 177/469 [04:35<07:34,  1.56s/it]
# Epoch 1 in training:  38%|███▊      | 178/469 [04:36<07:31,  1.55s/it]
# Epoch 1 in training:  38%|███▊      | 179/469 [04:38<07:28,  1.55s/it]
# Epoch 1 in training:  38%|███▊      | 180/469 [04:39<07:28,  1.55s/it]
# Epoch 1 in training:  39%|███▊      | 181/469 [04:41<07:26,  1.55s/it]
# Epoch 1 in training:  39%|███▉      | 182/469 [04:42<07:23,  1.55s/it]
# Epoch 1 in training:  39%|███▉      | 183/469 [04:44<07:21,  1.54s/it]
# Epoch 1 in training:  39%|███▉      | 184/469 [04:46<07:20,  1.54s/it]
# Epoch 1 in training:  39%|███▉      | 185/469 [04:47<07:17,  1.54s/it]
# Epoch 1 in training:  40%|███▉      | 186/469 [04:49<07:18,  1.55s/it]
# Epoch 1 in training:  40%|███▉      | 187/469 [04:50<07:21,  1.57s/it]
# Epoch 1 in training:  40%|████      | 188/469 [04:52<07:29,  1.60s/it]
# Epoch 1 in training:  40%|████      | 189/469 [04:53<07:23,  1.58s/it]
# Epoch 1 in training:  41%|████      | 190/469 [04:55<07:20,  1.58s/it]
# Epoch 1 in training:  41%|████      | 191/469 [04:57<07:14,  1.56s/it]
# Epoch 1 in training:  41%|████      | 192/469 [04:58<07:10,  1.56s/it]
# Epoch 1 in training:  41%|████      | 193/469 [05:00<07:09,  1.56s/it]
# Epoch 1 in training:  41%|████▏     | 194/469 [05:01<07:06,  1.55s/it]
# Epoch 1 in training:  42%|████▏     | 195/469 [05:03<07:02,  1.54s/it]
# Epoch 1 in training:  42%|████▏     | 196/469 [05:04<06:59,  1.54s/it]
# Epoch 1 in training:  42%|████▏     | 197/469 [05:06<06:57,  1.54s/it]
# Epoch 1 in training:  42%|████▏     | 198/469 [05:07<06:55,  1.53s/it]
# Epoch 1 in training:  42%|████▏     | 199/469 [05:09<06:54,  1.54s/it]
# Epoch 1 in training:  43%|████▎     | 200/469 [05:10<06:54,  1.54s/it]
# Epoch 1 in training:  43%|████▎     | 201/469 [05:12<06:50,  1.53s/it]
# Epoch 1 in training:  43%|████▎     | 202/469 [05:13<06:48,  1.53s/it]
# Epoch 1 in training:  43%|████▎     | 203/469 [05:15<06:48,  1.54s/it]
# Epoch 1 in training:  43%|████▎     | 204/469 [05:17<06:46,  1.53s/it]
# Epoch 1 in training:  44%|████▎     | 205/469 [05:18<06:44,  1.53s/it]
# Epoch 1 in training:  44%|████▍     | 206/469 [05:20<06:45,  1.54s/it]
# Epoch 1 in training:  44%|████▍     | 207/469 [05:21<06:59,  1.60s/it]
# Epoch 1 in training:  44%|████▍     | 208/469 [05:23<06:51,  1.58s/it]
# Epoch 1 in training:  45%|████▍     | 209/469 [05:24<06:46,  1.56s/it]
# Epoch 1 in training:  45%|████▍     | 210/469 [05:26<06:42,  1.55s/it]
# Epoch 1 in training:  45%|████▍     | 211/469 [05:27<06:39,  1.55s/it]
# Epoch 1 in training:  45%|████▌     | 212/469 [05:29<06:40,  1.56s/it]
# Epoch 1 in training:  45%|████▌     | 213/469 [05:31<06:37,  1.55s/it]
# Epoch 1 in training:  46%|████▌     | 214/469 [05:32<06:34,  1.55s/it]
# Epoch 1 in training:  46%|████▌     | 215/469 [05:34<06:33,  1.55s/it]
# Epoch 1 in training:  46%|████▌     | 216/469 [05:35<06:31,  1.55s/it]
# Epoch 1 in training:  46%|████▋     | 217/469 [05:37<06:29,  1.54s/it]
# Epoch 1 in training:  46%|████▋     | 218/469 [05:38<06:27,  1.54s/it]
# Epoch 1 in training:  47%|████▋     | 219/469 [05:40<06:27,  1.55s/it]
# Epoch 1 in training:  47%|████▋     | 220/469 [05:41<06:24,  1.54s/it]
# Epoch 1 in training:  47%|████▋     | 221/469 [05:43<06:22,  1.54s/it]
# Epoch 1 in training:  47%|████▋     | 222/469 [05:44<06:20,  1.54s/it]
# Epoch 1 in training:  48%|████▊     | 223/469 [05:46<06:18,  1.54s/it]
# Epoch 1 in training:  48%|████▊     | 224/469 [05:48<06:25,  1.57s/it]
# Epoch 1 in training:  48%|████▊     | 225/469 [05:49<06:23,  1.57s/it]
# Epoch 1 in training:  48%|████▊     | 226/469 [05:51<06:18,  1.56s/it]
# Epoch 1 in training:  48%|████▊     | 227/469 [05:52<06:20,  1.57s/it]
# Epoch 1 in training:  49%|████▊     | 228/469 [05:54<06:17,  1.57s/it]
# Epoch 1 in training:  49%|████▉     | 229/469 [05:55<06:13,  1.56s/it]
# Epoch 1 in training:  49%|████▉     | 230/469 [05:57<06:12,  1.56s/it]
# Epoch 1 in training:  49%|████▉     | 231/469 [05:59<06:09,  1.55s/it]
# Epoch 1 in training:  49%|████▉     | 232/469 [06:00<06:09,  1.56s/it]
# Epoch 1 in training:  50%|████▉     | 233/469 [06:02<06:05,  1.55s/it]
# Epoch 1 in training:  50%|████▉     | 234/469 [06:03<06:03,  1.54s/it]
# Epoch 1 in training:  50%|█████     | 235/469 [06:05<06:02,  1.55s/it]
# Epoch 1 in training:  50%|█████     | 236/469 [06:06<06:03,  1.56s/it]
# Epoch 1 in training:  51%|█████     | 237/469 [06:08<05:59,  1.55s/it]
# Epoch 1 in training:  51%|█████     | 238/469 [06:09<06:00,  1.56s/it]
# Epoch 1 in training:  51%|█████     | 239/469 [06:11<05:57,  1.55s/it]
# Epoch 1 in training:  51%|█████     | 240/469 [06:13<05:56,  1.56s/it]
# Epoch 1 in training:  51%|█████▏    | 241/469 [06:14<05:53,  1.55s/it]
# Epoch 1 in training:  52%|█████▏    | 242/469 [06:16<05:50,  1.55s/it]
# Epoch 1 in training:  52%|█████▏    | 243/469 [06:17<05:48,  1.54s/it]
# Epoch 1 in training:  52%|█████▏    | 244/469 [06:19<05:55,  1.58s/it]
# Epoch 1 in training:  52%|█████▏    | 245/469 [06:20<05:52,  1.57s/it]
# Epoch 1 in training:  52%|█████▏    | 246/469 [06:22<05:48,  1.56s/it]
# Epoch 1 in training:  53%|█████▎    | 247/469 [06:24<05:48,  1.57s/it]
# Epoch 1 in training:  53%|█████▎    | 248/469 [06:25<05:44,  1.56s/it]
# Epoch 1 in training:  53%|█████▎    | 249/469 [06:27<05:41,  1.55s/it]
# Epoch 1 in training:  53%|█████▎    | 250/469 [06:28<05:38,  1.54s/it]
# Epoch 1 in training:  54%|█████▎    | 251/469 [06:30<05:38,  1.55s/it]
# Epoch 1 in training:  54%|█████▎    | 252/469 [06:31<05:35,  1.55s/it]
# Epoch 1 in training:  54%|█████▍    | 253/469 [06:33<05:34,  1.55s/it]
# Epoch 1 in training:  54%|█████▍    | 254/469 [06:34<05:31,  1.54s/it]
# Epoch 1 in training:  54%|█████▍    | 255/469 [06:36<05:29,  1.54s/it]
# Epoch 1 in training:  55%|█████▍    | 256/469 [06:37<05:26,  1.54s/it]
# Epoch 1 in training:  55%|█████▍    | 257/469 [06:39<05:25,  1.54s/it]
# Epoch 1 in training:  55%|█████▌    | 258/469 [06:40<05:25,  1.54s/it]
# Epoch 1 in training:  55%|█████▌    | 259/469 [06:42<05:31,  1.58s/it]
# Epoch 1 in training:  55%|█████▌    | 260/469 [06:44<05:26,  1.56s/it]
# Epoch 1 in training:  56%|█████▌    | 261/469 [06:45<05:22,  1.55s/it]
# Epoch 1 in training:  56%|█████▌    | 262/469 [06:47<05:19,  1.54s/it]
# Epoch 1 in training:  56%|█████▌    | 263/469 [06:48<05:17,  1.54s/it]
# Epoch 1 in training:  56%|█████▋    | 264/469 [06:50<05:16,  1.55s/it]
# Epoch 1 in training:  57%|█████▋    | 265/469 [06:51<05:14,  1.54s/it]
# Epoch 1 in training:  57%|█████▋    | 266/469 [06:53<05:11,  1.54s/it]
# Epoch 1 in training:  57%|█████▋    | 267/469 [06:54<05:14,  1.56s/it]
# Epoch 1 in training:  57%|█████▋    | 268/469 [06:56<05:11,  1.55s/it]
# Epoch 1 in training:  57%|█████▋    | 269/469 [06:57<05:09,  1.55s/it]
# Epoch 1 in training:  58%|█████▊    | 270/469 [06:59<05:08,  1.55s/it]
# Epoch 1 in training:  58%|█████▊    | 271/469 [07:01<05:05,  1.54s/it]
# Epoch 1 in training:  58%|█████▊    | 272/469 [07:02<05:04,  1.54s/it]
# Epoch 1 in training:  58%|█████▊    | 273/469 [07:04<05:01,  1.54s/it]
# Epoch 1 in training:  58%|█████▊    | 274/469 [07:05<04:59,  1.54s/it]
# Epoch 1 in training:  59%|█████▊    | 275/469 [07:07<04:57,  1.53s/it]
# Epoch 1 in training:  59%|█████▉    | 276/469 [07:08<05:04,  1.58s/it]
# Epoch 1 in training:  59%|█████▉    | 277/469 [07:10<05:03,  1.58s/it]
# Epoch 1 in training:  59%|█████▉    | 278/469 [07:12<04:59,  1.57s/it]
# Epoch 1 in training:  59%|█████▉    | 279/469 [07:13<04:56,  1.56s/it]
# Epoch 1 in training:  60%|█████▉    | 280/469 [07:15<04:54,  1.56s/it]
# Epoch 1 in training:  60%|█████▉    | 281/469 [07:16<04:52,  1.55s/it]
# Epoch 1 in training:  60%|██████    | 282/469 [07:18<04:49,  1.55s/it]
# Epoch 1 in training:  60%|██████    | 283/469 [07:19<04:49,  1.55s/it]
# Epoch 1 in training:  61%|██████    | 284/469 [07:21<04:46,  1.55s/it]
# Epoch 1 in training:  61%|██████    | 285/469 [07:22<04:44,  1.54s/it]
# Epoch 1 in training:  61%|██████    | 286/469 [07:24<04:41,  1.54s/it]
# Epoch 1 in training:  61%|██████    | 287/469 [07:25<04:43,  1.56s/it]
# Epoch 1 in training:  61%|██████▏   | 288/469 [07:27<04:40,  1.55s/it]
# Epoch 1 in training:  62%|██████▏   | 289/469 [07:29<04:38,  1.55s/it]
# Epoch 1 in training:  62%|██████▏   | 290/469 [07:30<04:36,  1.55s/it]
# Epoch 1 in training:  62%|██████▏   | 291/469 [07:32<04:34,  1.54s/it]
# Epoch 1 in training:  62%|██████▏   | 292/469 [07:33<04:32,  1.54s/it]
# Epoch 1 in training:  62%|██████▏   | 293/469 [07:35<04:31,  1.54s/it]
# Epoch 1 in training:  63%|██████▎   | 294/469 [07:36<04:30,  1.54s/it]
# Epoch 1 in training:  63%|██████▎   | 295/469 [07:38<04:35,  1.58s/it]
# Epoch 1 in training:  63%|██████▎   | 296/469 [07:39<04:33,  1.58s/it]
# Epoch 1 in training:  63%|██████▎   | 297/469 [07:41<04:29,  1.57s/it]
# Epoch 1 in training:  64%|██████▎   | 298/469 [07:43<04:26,  1.56s/it]
# Epoch 1 in training:  64%|██████▍   | 299/469 [07:44<04:23,  1.55s/it]
# Epoch 1 in training:  64%|██████▍   | 300/469 [07:46<04:20,  1.54s/it]
# Epoch 1 in training:  64%|██████▍   | 301/469 [07:47<04:19,  1.54s/it]
# Epoch 1 in training:  64%|██████▍   | 302/469 [07:49<04:16,  1.54s/it]
# Epoch 1 in training:  65%|██████▍   | 303/469 [07:50<04:16,  1.54s/it]
# Epoch 1 in training:  65%|██████▍   | 304/469 [07:52<04:13,  1.54s/it]
# Epoch 1 in training:  65%|██████▌   | 305/469 [07:53<04:12,  1.54s/it]
# Epoch 1 in training:  65%|██████▌   | 306/469 [07:55<04:11,  1.54s/it]
# Epoch 1 in training:  65%|██████▌   | 307/469 [07:56<04:11,  1.56s/it]
# Epoch 1 in training:  66%|██████▌   | 308/469 [07:58<04:10,  1.55s/it]
# Epoch 1 in training:  66%|██████▌   | 309/469 [08:00<04:08,  1.55s/it]
# Epoch 1 in training:  66%|██████▌   | 310/469 [08:01<04:06,  1.55s/it]
# Epoch 1 in training:  66%|██████▋   | 311/469 [08:03<04:03,  1.54s/it]
# Epoch 1 in training:  67%|██████▋   | 312/469 [08:04<04:08,  1.58s/it]
# Epoch 1 in training:  67%|██████▋   | 313/469 [08:06<04:04,  1.56s/it]
# Epoch 1 in training:  67%|██████▋   | 314/469 [08:07<04:01,  1.56s/it]
# Epoch 1 in training:  67%|██████▋   | 315/469 [08:09<03:59,  1.56s/it]
# Epoch 1 in training:  67%|██████▋   | 316/469 [08:10<03:58,  1.56s/it]
# Epoch 1 in training:  68%|██████▊   | 317/469 [08:12<03:56,  1.55s/it]
# Epoch 1 in training:  68%|██████▊   | 318/469 [08:14<03:53,  1.55s/it]
# Epoch 1 in training:  68%|██████▊   | 319/469 [08:15<03:51,  1.55s/it]
# Epoch 1 in training:  68%|██████▊   | 320/469 [08:17<03:50,  1.55s/it]
# Epoch 1 in training:  68%|██████▊   | 321/469 [08:18<03:48,  1.54s/it]
# Epoch 1 in training:  69%|██████▊   | 322/469 [08:20<03:47,  1.55s/it]
# Epoch 1 in training:  69%|██████▉   | 323/469 [08:21<03:46,  1.55s/it]
# Epoch 1 in training:  69%|██████▉   | 324/469 [08:23<03:43,  1.54s/it]
# Epoch 1 in training:  69%|██████▉   | 325/469 [08:24<03:41,  1.54s/it]
# Epoch 1 in training:  70%|██████▉   | 326/469 [08:26<03:40,  1.54s/it]
# Epoch 1 in training:  70%|██████▉   | 327/469 [08:27<03:41,  1.56s/it]
# Epoch 1 in training:  70%|██████▉   | 328/469 [08:29<03:41,  1.57s/it]
# Epoch 1 in training:  70%|███████   | 329/469 [08:31<03:38,  1.56s/it]
# Epoch 1 in training:  70%|███████   | 330/469 [08:32<03:35,  1.55s/it]
# Epoch 1 in training:  71%|███████   | 331/469 [08:34<03:33,  1.54s/it]
# Epoch 1 in training:  71%|███████   | 332/469 [08:35<03:36,  1.58s/it]
# Epoch 1 in training:  71%|███████   | 333/469 [08:37<03:33,  1.57s/it]
# Epoch 1 in training:  71%|███████   | 334/469 [08:38<03:30,  1.56s/it]
# Epoch 1 in training:  71%|███████▏  | 335/469 [08:40<03:29,  1.56s/it]
# Epoch 1 in training:  72%|███████▏  | 336/469 [08:42<03:26,  1.55s/it]
# Epoch 1 in training:  72%|███████▏  | 337/469 [08:43<03:24,  1.55s/it]
# Epoch 1 in training:  72%|███████▏  | 338/469 [08:45<03:22,  1.55s/it]
# Epoch 1 in training:  72%|███████▏  | 339/469 [08:46<03:22,  1.56s/it]
# Epoch 1 in training:  72%|███████▏  | 340/469 [08:48<03:19,  1.55s/it]
# Epoch 1 in training:  73%|███████▎  | 341/469 [08:49<03:18,  1.55s/it]
# Epoch 1 in training:  73%|███████▎  | 342/469 [08:51<03:16,  1.55s/it]
# Epoch 1 in training:  73%|███████▎  | 343/469 [08:52<03:14,  1.54s/it]
# Epoch 1 in training:  73%|███████▎  | 344/469 [08:54<03:12,  1.54s/it]
# Epoch 1 in training:  74%|███████▎  | 345/469 [08:55<03:11,  1.54s/it]
# Epoch 1 in training:  74%|███████▍  | 346/469 [08:57<03:09,  1.54s/it]
# Epoch 1 in training:  74%|███████▍  | 347/469 [08:59<03:13,  1.58s/it]
# Epoch 1 in training:  74%|███████▍  | 348/469 [09:00<03:12,  1.59s/it]
# Epoch 1 in training:  74%|███████▍  | 349/469 [09:02<03:09,  1.58s/it]
# Epoch 1 in training:  75%|███████▍  | 350/469 [09:03<03:07,  1.58s/it]
# Epoch 1 in training:  75%|███████▍  | 351/469 [09:05<03:04,  1.56s/it]
# Epoch 1 in training:  75%|███████▌  | 352/469 [09:06<03:01,  1.55s/it]
# Epoch 1 in training:  75%|███████▌  | 353/469 [09:08<02:58,  1.54s/it]
# Epoch 1 in training:  75%|███████▌  | 354/469 [09:10<02:58,  1.55s/it]
# Epoch 1 in training:  76%|███████▌  | 355/469 [09:11<02:56,  1.55s/it]
# Epoch 1 in training:  76%|███████▌  | 356/469 [09:13<02:54,  1.54s/it]
# Epoch 1 in training:  76%|███████▌  | 357/469 [09:14<02:52,  1.54s/it]
# Epoch 1 in training:  76%|███████▋  | 358/469 [09:16<02:51,  1.54s/it]
# Epoch 1 in training:  77%|███████▋  | 359/469 [09:17<02:49,  1.54s/it]
# Epoch 1 in training:  77%|███████▋  | 360/469 [09:19<02:47,  1.54s/it]
# Epoch 1 in training:  77%|███████▋  | 361/469 [09:20<02:46,  1.55s/it]
# Epoch 1 in training:  77%|███████▋  | 362/469 [09:22<02:45,  1.54s/it]
# Epoch 1 in training:  77%|███████▋  | 363/469 [09:23<02:43,  1.54s/it]
# Epoch 1 in training:  78%|███████▊  | 364/469 [09:25<02:46,  1.58s/it]
# Epoch 1 in training:  78%|███████▊  | 365/469 [09:27<02:42,  1.57s/it]
# Epoch 1 in training:  78%|███████▊  | 366/469 [09:28<02:40,  1.56s/it]
# Epoch 1 in training:  78%|███████▊  | 367/469 [09:30<02:38,  1.56s/it]
# Epoch 1 in training:  78%|███████▊  | 368/469 [09:31<02:38,  1.57s/it]
# Epoch 1 in training:  79%|███████▊  | 369/469 [09:33<02:35,  1.56s/it]
# Epoch 1 in training:  79%|███████▉  | 370/469 [09:34<02:33,  1.55s/it]
# Epoch 1 in training:  79%|███████▉  | 371/469 [09:36<02:31,  1.55s/it]
# Epoch 1 in training:  79%|███████▉  | 372/469 [09:37<02:29,  1.54s/it]
# Epoch 1 in training:  80%|███████▉  | 373/469 [09:39<02:26,  1.53s/it]
# Epoch 1 in training:  80%|███████▉  | 374/469 [09:40<02:25,  1.53s/it]
# Epoch 1 in training:  80%|███████▉  | 375/469 [09:42<02:22,  1.52s/it]
# Epoch 1 in training:  80%|████████  | 376/469 [09:43<02:20,  1.51s/it]
# Epoch 1 in training:  80%|████████  | 377/469 [09:45<02:19,  1.51s/it]
# Epoch 1 in training:  81%|████████  | 378/469 [09:46<02:17,  1.51s/it]
# Epoch 1 in training:  81%|████████  | 379/469 [09:48<02:15,  1.51s/it]
# Epoch 1 in training:  81%|████████  | 380/469 [09:49<02:14,  1.51s/it]
# Epoch 1 in training:  81%|████████  | 381/469 [09:51<02:12,  1.51s/it]
# Epoch 1 in training:  81%|████████▏ | 382/469 [09:52<02:10,  1.50s/it]
# Epoch 1 in training:  82%|████████▏ | 383/469 [09:54<02:12,  1.54s/it]
# Epoch 1 in training:  82%|████████▏ | 384/469 [09:56<02:10,  1.53s/it]
# Epoch 1 in training:  82%|████████▏ | 385/469 [09:57<02:07,  1.52s/it]
# Epoch 1 in training:  82%|████████▏ | 386/469 [09:59<02:05,  1.52s/it]
# Epoch 1 in training:  83%|████████▎ | 387/469 [10:00<02:04,  1.52s/it]
# Epoch 1 in training:  83%|████████▎ | 388/469 [10:02<02:04,  1.54s/it]
# Epoch 1 in training:  83%|████████▎ | 389/469 [10:03<02:02,  1.53s/it]
# Epoch 1 in training:  83%|████████▎ | 390/469 [10:05<02:00,  1.53s/it]
# Epoch 1 in training:  83%|████████▎ | 391/469 [10:06<01:58,  1.52s/it]
# Epoch 1 in training:  84%|████████▎ | 392/469 [10:08<01:56,  1.52s/it]
# Epoch 1 in training:  84%|████████▍ | 393/469 [10:09<01:55,  1.52s/it]
# Epoch 1 in training:  84%|████████▍ | 394/469 [10:11<01:53,  1.51s/it]
# Epoch 1 in training:  84%|████████▍ | 395/469 [10:12<01:52,  1.51s/it]
# Epoch 1 in training:  84%|████████▍ | 396/469 [10:14<01:50,  1.52s/it]
# Epoch 1 in training:  85%|████████▍ | 397/469 [10:15<01:49,  1.52s/it]
# Epoch 1 in training:  85%|████████▍ | 398/469 [10:17<01:47,  1.52s/it]
# Epoch 1 in training:  85%|████████▌ | 399/469 [10:18<01:46,  1.52s/it]
# Epoch 1 in training:  85%|████████▌ | 400/469 [10:20<01:47,  1.56s/it]
# Epoch 1 in training:  86%|████████▌ | 401/469 [10:22<01:44,  1.54s/it]
# Epoch 1 in training:  86%|████████▌ | 402/469 [10:23<01:42,  1.53s/it]
# Epoch 1 in training:  86%|████████▌ | 403/469 [10:25<01:40,  1.52s/it]
# Epoch 1 in training:  86%|████████▌ | 404/469 [10:26<01:38,  1.51s/it]
# Epoch 1 in training:  86%|████████▋ | 405/469 [10:28<01:36,  1.51s/it]
# Epoch 1 in training:  87%|████████▋ | 406/469 [10:29<01:35,  1.52s/it]
# Epoch 1 in training:  87%|████████▋ | 407/469 [10:31<01:34,  1.52s/it]
# Epoch 1 in training:  87%|████████▋ | 408/469 [10:32<01:32,  1.52s/it]
# Epoch 1 in training:  87%|████████▋ | 409/469 [10:34<01:32,  1.54s/it]
# Epoch 1 in training:  87%|████████▋ | 410/469 [10:35<01:30,  1.53s/it]
# Epoch 1 in training:  88%|████████▊ | 411/469 [10:37<01:28,  1.52s/it]
# Epoch 1 in training:  88%|████████▊ | 412/469 [10:38<01:26,  1.51s/it]
# Epoch 1 in training:  88%|████████▊ | 413/469 [10:40<01:25,  1.53s/it]
# Epoch 1 in training:  88%|████████▊ | 414/469 [10:41<01:23,  1.52s/it]
# Epoch 1 in training:  88%|████████▊ | 415/469 [10:43<01:21,  1.52s/it]
# Epoch 1 in training:  89%|████████▊ | 416/469 [10:44<01:20,  1.51s/it]
# Epoch 1 in training:  89%|████████▉ | 417/469 [10:46<01:18,  1.51s/it]
# Epoch 1 in training:  89%|████████▉ | 418/469 [10:47<01:16,  1.51s/it]
# Epoch 1 in training:  89%|████████▉ | 419/469 [10:49<01:15,  1.50s/it]
# Epoch 1 in training:  90%|████████▉ | 420/469 [10:50<01:15,  1.55s/it]
# Epoch 1 in training:  90%|████████▉ | 421/469 [10:52<01:13,  1.53s/it]
# Epoch 1 in training:  90%|████████▉ | 422/469 [10:53<01:11,  1.52s/it]
# Epoch 1 in training:  90%|█████████ | 423/469 [10:55<01:09,  1.51s/it]
# Epoch 1 in training:  90%|█████████ | 424/469 [10:56<01:07,  1.51s/it]
# Epoch 1 in training:  91%|█████████ | 425/469 [10:58<01:06,  1.51s/it]
# Epoch 1 in training:  91%|█████████ | 426/469 [10:59<01:05,  1.51s/it]
# Epoch 1 in training:  91%|█████████ | 427/469 [11:01<01:03,  1.51s/it]
# Epoch 1 in training:  91%|█████████▏| 428/469 [11:02<01:01,  1.50s/it]
# Epoch 1 in training:  91%|█████████▏| 429/469 [11:04<01:00,  1.52s/it]
# Epoch 1 in training:  92%|█████████▏| 430/469 [11:06<00:59,  1.52s/it]
# Epoch 1 in training:  92%|█████████▏| 431/469 [11:07<00:57,  1.51s/it]
# Epoch 1 in training:  92%|█████████▏| 432/469 [11:09<00:55,  1.51s/it]
# Epoch 1 in training:  92%|█████████▏| 433/469 [11:10<00:54,  1.51s/it]
# Epoch 1 in training:  93%|█████████▎| 434/469 [11:12<00:52,  1.51s/it]
# Epoch 1 in training:  93%|█████████▎| 435/469 [11:13<00:52,  1.55s/it]
# Epoch 1 in training:  93%|█████████▎| 436/469 [11:15<00:50,  1.53s/it]
# Epoch 1 in training:  93%|█████████▎| 437/469 [11:16<00:48,  1.53s/it]
# Epoch 1 in training:  93%|█████████▎| 438/469 [11:18<00:47,  1.54s/it]
# Epoch 1 in training:  94%|█████████▎| 439/469 [11:19<00:46,  1.54s/it]
# Epoch 1 in training:  94%|█████████▍| 440/469 [11:21<00:44,  1.53s/it]
# Epoch 1 in training:  94%|█████████▍| 441/469 [11:22<00:42,  1.53s/it]
# Epoch 1 in training:  94%|█████████▍| 442/469 [11:24<00:41,  1.52s/it]
# Epoch 1 in training:  94%|█████████▍| 443/469 [11:25<00:39,  1.53s/it]
# Epoch 1 in training:  95%|█████████▍| 444/469 [11:27<00:38,  1.52s/it]
# Epoch 1 in training:  95%|█████████▍| 445/469 [11:28<00:36,  1.52s/it]
# Epoch 1 in training:  95%|█████████▌| 446/469 [11:30<00:35,  1.53s/it]
# Epoch 1 in training:  95%|█████████▌| 447/469 [11:32<00:33,  1.52s/it]
# Epoch 1 in training:  96%|█████████▌| 448/469 [11:33<00:31,  1.52s/it]
# Epoch 1 in training:  96%|█████████▌| 449/469 [11:35<00:30,  1.52s/it]
# Epoch 1 in training:  96%|█████████▌| 450/469 [11:36<00:29,  1.54s/it]
# Epoch 1 in training:  96%|█████████▌| 451/469 [11:38<00:27,  1.53s/it]
# Epoch 1 in training:  96%|█████████▋| 452/469 [11:39<00:26,  1.58s/it]
# Epoch 1 in training:  97%|█████████▋| 453/469 [11:41<00:24,  1.56s/it]
# Epoch 1 in training:  97%|█████████▋| 454/469 [11:42<00:23,  1.55s/it]
# Epoch 1 in training:  97%|█████████▋| 455/469 [11:44<00:21,  1.54s/it]
# Epoch 1 in training:  97%|█████████▋| 456/469 [11:45<00:19,  1.53s/it]
# Epoch 1 in training:  97%|█████████▋| 457/469 [11:47<00:18,  1.53s/it]
# Epoch 1 in training:  98%|█████████▊| 458/469 [11:48<00:16,  1.52s/it]
# Epoch 1 in training:  98%|█████████▊| 459/469 [11:50<00:15,  1.53s/it]
# Epoch 1 in training:  98%|█████████▊| 460/469 [11:51<00:13,  1.53s/it]
# Epoch 1 in training:  98%|█████████▊| 461/469 [11:53<00:12,  1.52s/it]
# Epoch 1 in training:  99%|█████████▊| 462/469 [11:55<00:10,  1.52s/it]
# Epoch 1 in training:  99%|█████████▊| 463/469 [11:56<00:09,  1.52s/it]
# Epoch 1 in training:  99%|█████████▉| 464/469 [11:58<00:07,  1.52s/it]
# Epoch 1 in training:  99%|█████████▉| 465/469 [11:59<00:06,  1.53s/it]
# Epoch 1 in training:  99%|█████████▉| 466/469 [12:01<00:04,  1.53s/it]
# Epoch 1 in training: 100%|█████████▉| 467/469 [12:02<00:03,  1.52s/it]
# Epoch 1 in training: 100%|█████████▉| 468/469 [12:04<00:01,  1.52s/it]
# Epoch 1 in training: 100%|██████████| 469/469 [12:05<00:00,  1.41s/it]
# train:  10%|█         | 1/10 [12:05<1:48:47, 725.31s/it]
# Epoch 1/10 loss: 1.90
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:01<12:05,  1.55s/it]
# Epoch 2 in training:   0%|          | 2/469 [00:03<11:55,  1.53s/it]
# Epoch 2 in training:   1%|          | 3/469 [00:04<11:59,  1.54s/it]
# Epoch 2 in training:   1%|          | 4/469 [00:06<11:53,  1.53s/it]
# Epoch 2 in training:   1%|          | 5/469 [00:07<12:09,  1.57s/it]
# Epoch 2 in training:   1%|▏         | 6/469 [00:09<11:58,  1.55s/it]
# Epoch 2 in training:   1%|▏         | 7/469 [00:10<11:52,  1.54s/it]
# Epoch 2 in training:   2%|▏         | 8/469 [00:12<11:47,  1.53s/it]
# Epoch 2 in training:   2%|▏         | 9/469 [00:13<11:43,  1.53s/it]
# Epoch 2 in training:   2%|▏         | 10/469 [00:15<11:44,  1.53s/it]
# Epoch 2 in training:   2%|▏         | 11/469 [00:16<11:42,  1.53s/it]
# Epoch 2 in training:   3%|▎         | 12/469 [00:18<11:38,  1.53s/it]
# Epoch 2 in training:   3%|▎         | 13/469 [00:19<11:36,  1.53s/it]
# Epoch 2 in training:   3%|▎         | 14/469 [00:21<11:32,  1.52s/it]
# Epoch 2 in training:   3%|▎         | 15/469 [00:23<11:30,  1.52s/it]
# Epoch 2 in training:   3%|▎         | 16/469 [00:24<11:30,  1.52s/it]
# Epoch 2 in training:   4%|▎         | 17/469 [00:26<11:29,  1.53s/it]
# Epoch 2 in training:   4%|▍         | 18/469 [00:27<11:26,  1.52s/it]
# Epoch 2 in training:   4%|▍         | 19/469 [00:29<11:26,  1.52s/it]
# Epoch 2 in training:   4%|▍         | 20/469 [00:30<11:41,  1.56s/it]
# Epoch 2 in training:   4%|▍         | 21/469 [00:32<11:35,  1.55s/it]
# Epoch 2 in training:   5%|▍         | 22/469 [00:33<11:37,  1.56s/it]
# Epoch 2 in training:   5%|▍         | 23/469 [00:35<11:36,  1.56s/it]
# Epoch 2 in training:   5%|▌         | 24/469 [00:36<11:29,  1.55s/it]
# Epoch 2 in training:   5%|▌         | 25/469 [00:38<11:25,  1.54s/it]
# Epoch 2 in training:   6%|▌         | 26/469 [00:40<11:20,  1.54s/it]
# Epoch 2 in training:   6%|▌         | 27/469 [00:41<11:17,  1.53s/it]
# Epoch 2 in training:   6%|▌         | 28/469 [00:43<11:14,  1.53s/it]
# Epoch 2 in training:   6%|▌         | 29/469 [00:44<11:14,  1.53s/it]
# Epoch 2 in training:   6%|▋         | 30/469 [00:46<11:11,  1.53s/it]
# Epoch 2 in training:   7%|▋         | 31/469 [00:47<11:07,  1.52s/it]
# Epoch 2 in training:   7%|▋         | 32/469 [00:49<11:07,  1.53s/it]
# Epoch 2 in training:   7%|▋         | 33/469 [00:50<11:01,  1.52s/it]
# Epoch 2 in training:   7%|▋         | 34/469 [00:52<10:57,  1.51s/it]
# Epoch 2 in training:   7%|▋         | 35/469 [00:53<10:55,  1.51s/it]
# Epoch 2 in training:   8%|▊         | 36/469 [00:55<10:58,  1.52s/it]
# Epoch 2 in training:   8%|▊         | 37/469 [00:56<11:07,  1.55s/it]
# Epoch 2 in training:   8%|▊         | 38/469 [00:58<10:59,  1.53s/it]
# Epoch 2 in training:   8%|▊         | 39/469 [00:59<10:56,  1.53s/it]
# Epoch 2 in training:   9%|▊         | 40/469 [01:01<10:49,  1.51s/it]
# Epoch 2 in training:   9%|▊         | 41/469 [01:02<10:45,  1.51s/it]
# Epoch 2 in training:   9%|▉         | 42/469 [01:04<10:58,  1.54s/it]
# Epoch 2 in training:   9%|▉         | 43/469 [01:05<10:51,  1.53s/it]
# Epoch 2 in training:   9%|▉         | 44/469 [01:07<10:46,  1.52s/it]
# Epoch 2 in training:  10%|▉         | 45/469 [01:08<10:40,  1.51s/it]
# Epoch 2 in training:  10%|▉         | 46/469 [01:10<10:37,  1.51s/it]
# Epoch 2 in training:  10%|█         | 47/469 [01:11<10:34,  1.50s/it]
# Epoch 2 in training:  10%|█         | 48/469 [01:13<10:30,  1.50s/it]
# Epoch 2 in training:  10%|█         | 49/469 [01:14<10:32,  1.51s/it]
# Epoch 2 in training:  11%|█         | 50/469 [01:16<10:29,  1.50s/it]
# Epoch 2 in training:  11%|█         | 51/469 [01:17<10:28,  1.50s/it]
# Epoch 2 in training:  11%|█         | 52/469 [01:19<10:27,  1.50s/it]
# Epoch 2 in training:  11%|█▏        | 53/469 [01:20<10:27,  1.51s/it]
# Epoch 2 in training:  12%|█▏        | 54/469 [01:22<10:25,  1.51s/it]
# Epoch 2 in training:  12%|█▏        | 55/469 [01:23<10:22,  1.50s/it]
# Epoch 2 in training:  12%|█▏        | 56/469 [01:25<10:39,  1.55s/it]
# Epoch 2 in training:  12%|█▏        | 57/469 [01:27<10:31,  1.53s/it]
# Epoch 2 in training:  12%|█▏        | 58/469 [01:28<10:24,  1.52s/it]
# Epoch 2 in training:  13%|█▎        | 59/469 [01:30<10:19,  1.51s/it]
# Epoch 2 in training:  13%|█▎        | 60/469 [01:31<10:16,  1.51s/it]
# Epoch 2 in training:  13%|█▎        | 61/469 [01:33<10:13,  1.50s/it]
# Epoch 2 in training:  13%|█▎        | 62/469 [01:34<10:16,  1.52s/it]
# Epoch 2 in training:  13%|█▎        | 63/469 [01:36<10:22,  1.53s/it]
# Epoch 2 in training:  14%|█▎        | 64/469 [01:37<10:16,  1.52s/it]
# Epoch 2 in training:  14%|█▍        | 65/469 [01:39<10:12,  1.52s/it]
# Epoch 2 in training:  14%|█▍        | 66/469 [01:40<10:08,  1.51s/it]
# Epoch 2 in training:  14%|█▍        | 67/469 [01:42<10:06,  1.51s/it]
# Epoch 2 in training:  14%|█▍        | 68/469 [01:43<10:02,  1.50s/it]
# Epoch 2 in training:  15%|█▍        | 69/469 [01:45<10:04,  1.51s/it]
# Epoch 2 in training:  15%|█▍        | 70/469 [01:46<10:00,  1.51s/it]
# Epoch 2 in training:  15%|█▌        | 71/469 [01:48<09:57,  1.50s/it]
# Epoch 2 in training:  15%|█▌        | 72/469 [01:49<09:56,  1.50s/it]
# Epoch 2 in training:  16%|█▌        | 73/469 [01:51<10:08,  1.54s/it]
# Epoch 2 in training:  16%|█▌        | 74/469 [01:52<10:01,  1.52s/it]
# Epoch 2 in training:  16%|█▌        | 75/469 [01:54<09:58,  1.52s/it]
# Epoch 2 in training:  16%|█▌        | 76/469 [01:55<09:53,  1.51s/it]
# Epoch 2 in training:  16%|█▋        | 77/469 [01:57<09:50,  1.51s/it]
# Epoch 2 in training:  17%|█▋        | 78/469 [01:58<09:52,  1.51s/it]
# Epoch 2 in training:  17%|█▋        | 79/469 [02:00<09:48,  1.51s/it]
# Epoch 2 in training:  17%|█▋        | 80/469 [02:01<09:45,  1.51s/it]
# Epoch 2 in training:  17%|█▋        | 81/469 [02:03<09:42,  1.50s/it]
# Epoch 2 in training:  17%|█▋        | 82/469 [02:04<09:48,  1.52s/it]
# Epoch 2 in training:  18%|█▊        | 83/469 [02:06<09:55,  1.54s/it]
# Epoch 2 in training:  18%|█▊        | 84/469 [02:07<09:50,  1.53s/it]
# Epoch 2 in training:  18%|█▊        | 85/469 [02:09<09:43,  1.52s/it]
# Epoch 2 in training:  18%|█▊        | 86/469 [02:10<09:37,  1.51s/it]
# Epoch 2 in training:  19%|█▊        | 87/469 [02:12<09:36,  1.51s/it]
# Epoch 2 in training:  19%|█▉        | 88/469 [02:13<09:35,  1.51s/it]
# Epoch 2 in training:  19%|█▉        | 89/469 [02:15<09:36,  1.52s/it]
# Epoch 2 in training:  19%|█▉        | 90/469 [02:17<09:35,  1.52s/it]
# Epoch 2 in training:  19%|█▉        | 91/469 [02:18<09:49,  1.56s/it]
# Epoch 2 in training:  20%|█▉        | 92/469 [02:20<09:52,  1.57s/it]
# Epoch 2 in training:  20%|█▉        | 93/469 [02:22<10:07,  1.62s/it]
# Epoch 2 in training:  20%|██        | 94/469 [02:23<09:53,  1.58s/it]
# Epoch 2 in training:  20%|██        | 95/469 [02:25<09:44,  1.56s/it]
# Epoch 2 in training:  20%|██        | 96/469 [02:26<09:38,  1.55s/it]
# Epoch 2 in training:  21%|██        | 97/469 [02:28<09:33,  1.54s/it]
# Epoch 2 in training:  21%|██        | 98/469 [02:29<09:31,  1.54s/it]
# Epoch 2 in training:  21%|██        | 99/469 [02:31<09:26,  1.53s/it]
# Epoch 2 in training:  21%|██▏       | 100/469 [02:32<09:22,  1.52s/it]
# Epoch 2 in training:  22%|██▏       | 101/469 [02:34<09:19,  1.52s/it]
# Epoch 2 in training:  22%|██▏       | 102/469 [02:35<09:19,  1.53s/it]
# Epoch 2 in training:  22%|██▏       | 103/469 [02:37<09:17,  1.52s/it]
# Epoch 2 in training:  22%|██▏       | 104/469 [02:38<09:26,  1.55s/it]
# Epoch 2 in training:  22%|██▏       | 105/469 [02:40<09:22,  1.55s/it]
# Epoch 2 in training:  23%|██▎       | 106/469 [02:41<09:21,  1.55s/it]
# Epoch 2 in training:  23%|██▎       | 107/469 [02:43<09:14,  1.53s/it]
# Epoch 2 in training:  23%|██▎       | 108/469 [02:45<09:25,  1.57s/it]
# Epoch 2 in training:  23%|██▎       | 109/469 [02:46<09:15,  1.54s/it]
# Epoch 2 in training:  23%|██▎       | 110/469 [02:47<09:05,  1.52s/it]
# Epoch 2 in training:  24%|██▎       | 111/469 [02:49<09:00,  1.51s/it]
# Epoch 2 in training:  24%|██▍       | 112/469 [02:50<08:55,  1.50s/it]
# Epoch 2 in training:  24%|██▍       | 113/469 [02:52<08:52,  1.50s/it]
# Epoch 2 in training:  24%|██▍       | 114/469 [02:53<08:49,  1.49s/it]
# Epoch 2 in training:  25%|██▍       | 115/469 [02:55<08:51,  1.50s/it]
# Epoch 2 in training:  25%|██▍       | 116/469 [02:56<08:50,  1.50s/it]
# Epoch 2 in training:  25%|██▍       | 117/469 [02:58<08:49,  1.50s/it]
# Epoch 2 in training:  25%|██▌       | 118/469 [02:59<08:48,  1.51s/it]
# Epoch 2 in training:  25%|██▌       | 119/469 [03:01<08:46,  1.50s/it]
# Epoch 2 in training:  26%|██▌       | 120/469 [03:02<08:44,  1.50s/it]
# Epoch 2 in training:  26%|██▌       | 121/469 [03:04<08:48,  1.52s/it]
# Epoch 2 in training:  26%|██▌       | 122/469 [03:06<08:45,  1.51s/it]
# Epoch 2 in training:  26%|██▌       | 123/469 [03:07<08:43,  1.51s/it]
# Epoch 2 in training:  26%|██▋       | 124/469 [03:09<08:48,  1.53s/it]
# Epoch 2 in training:  27%|██▋       | 125/469 [03:10<08:58,  1.57s/it]
# Epoch 2 in training:  27%|██▋       | 126/469 [03:12<08:53,  1.55s/it]
# Epoch 2 in training:  27%|██▋       | 127/469 [03:13<08:45,  1.54s/it]
# Epoch 2 in training:  27%|██▋       | 128/469 [03:15<08:43,  1.54s/it]
# Epoch 2 in training:  28%|██▊       | 129/469 [03:16<08:39,  1.53s/it]
# Epoch 2 in training:  28%|██▊       | 130/469 [03:18<08:35,  1.52s/it]
# Epoch 2 in training:  28%|██▊       | 131/469 [03:19<08:32,  1.52s/it]
# Epoch 2 in training:  28%|██▊       | 132/469 [03:21<08:29,  1.51s/it]
# Epoch 2 in training:  28%|██▊       | 133/469 [03:22<08:26,  1.51s/it]
# Epoch 2 in training:  29%|██▊       | 134/469 [03:24<08:26,  1.51s/it]
# Epoch 2 in training:  29%|██▉       | 135/469 [03:25<08:23,  1.51s/it]
# Epoch 2 in training:  29%|██▉       | 136/469 [03:27<08:20,  1.50s/it]
# Epoch 2 in training:  29%|██▉       | 137/469 [03:28<08:18,  1.50s/it]
# Epoch 2 in training:  29%|██▉       | 138/469 [03:30<08:14,  1.50s/it]
# Epoch 2 in training:  30%|██▉       | 139/469 [03:31<08:13,  1.50s/it]
# Epoch 2 in training:  30%|██▉       | 140/469 [03:33<08:12,  1.50s/it]
# Epoch 2 in training:  30%|███       | 141/469 [03:34<08:15,  1.51s/it]
# Epoch 2 in training:  30%|███       | 142/469 [03:36<08:14,  1.51s/it]
# Epoch 2 in training:  30%|███       | 143/469 [03:37<08:11,  1.51s/it]
# Epoch 2 in training:  31%|███       | 144/469 [03:39<08:21,  1.54s/it]
# Epoch 2 in training:  31%|███       | 145/469 [03:41<08:24,  1.56s/it]
# Epoch 2 in training:  31%|███       | 146/469 [03:42<08:18,  1.54s/it]
# Epoch 2 in training:  31%|███▏      | 147/469 [03:44<08:16,  1.54s/it]
# Epoch 2 in training:  32%|███▏      | 148/469 [03:45<08:12,  1.53s/it]
# Epoch 2 in training:  32%|███▏      | 149/469 [03:47<08:08,  1.53s/it]
# Epoch 2 in training:  32%|███▏      | 150/469 [03:48<08:04,  1.52s/it]
# Epoch 2 in training:  32%|███▏      | 151/469 [03:50<08:02,  1.52s/it]
# Epoch 2 in training:  32%|███▏      | 152/469 [03:51<08:00,  1.52s/it]
# Epoch 2 in training:  33%|███▎      | 153/469 [03:53<07:57,  1.51s/it]
# Epoch 2 in training:  33%|███▎      | 154/469 [03:54<07:58,  1.52s/it]
# Epoch 2 in training:  33%|███▎      | 155/469 [03:56<07:55,  1.52s/it]
# Epoch 2 in training:  33%|███▎      | 156/469 [03:57<07:55,  1.52s/it]
# Epoch 2 in training:  33%|███▎      | 157/469 [03:59<07:52,  1.51s/it]
# Epoch 2 in training:  34%|███▎      | 158/469 [04:00<07:52,  1.52s/it]
# Epoch 2 in training:  34%|███▍      | 159/469 [04:02<07:49,  1.52s/it]
# Epoch 2 in training:  34%|███▍      | 160/469 [04:03<07:47,  1.51s/it]
# Epoch 2 in training:  34%|███▍      | 161/469 [04:05<07:59,  1.56s/it]
# Epoch 2 in training:  35%|███▍      | 162/469 [04:06<07:50,  1.53s/it]
# Epoch 2 in training:  35%|███▍      | 163/469 [04:08<07:45,  1.52s/it]
# Epoch 2 in training:  35%|███▍      | 164/469 [04:09<07:42,  1.52s/it]
# Epoch 2 in training:  35%|███▌      | 165/469 [04:11<07:44,  1.53s/it]
# Epoch 2 in training:  35%|███▌      | 166/469 [04:13<07:41,  1.52s/it]
# Epoch 2 in training:  36%|███▌      | 167/469 [04:14<07:41,  1.53s/it]
# Epoch 2 in training:  36%|███▌      | 168/469 [04:16<07:35,  1.51s/it]
# Epoch 2 in training:  36%|███▌      | 169/469 [04:17<07:31,  1.51s/it]
# Epoch 2 in training:  36%|███▌      | 170/469 [04:19<07:27,  1.50s/it]
# Epoch 2 in training:  36%|███▋      | 171/469 [04:20<07:25,  1.50s/it]
# Epoch 2 in training:  37%|███▋      | 172/469 [04:22<07:27,  1.51s/it]
# Epoch 2 in training:  37%|███▋      | 173/469 [04:23<07:24,  1.50s/it]
# Epoch 2 in training:  37%|███▋      | 174/469 [04:25<07:24,  1.51s/it]
# Epoch 2 in training:  37%|███▋      | 175/469 [04:26<07:21,  1.50s/it]
# Epoch 2 in training:  38%|███▊      | 176/469 [04:28<07:18,  1.50s/it]
# Epoch 2 in training:  38%|███▊      | 177/469 [04:29<07:15,  1.49s/it]
# Epoch 2 in training:  38%|███▊      | 178/469 [04:30<07:12,  1.49s/it]
# Epoch 2 in training:  38%|███▊      | 179/469 [04:32<07:10,  1.48s/it]
# Epoch 2 in training:  38%|███▊      | 180/469 [04:33<07:10,  1.49s/it]
# Epoch 2 in training:  39%|███▊      | 181/469 [04:35<07:21,  1.53s/it]
# Epoch 2 in training:  39%|███▉      | 182/469 [04:37<07:15,  1.52s/it]
# Epoch 2 in training:  39%|███▉      | 183/469 [04:38<07:10,  1.50s/it]
# Epoch 2 in training:  39%|███▉      | 184/469 [04:40<07:06,  1.50s/it]
# Epoch 2 in training:  39%|███▉      | 185/469 [04:41<07:04,  1.49s/it]
# Epoch 2 in training:  40%|███▉      | 186/469 [04:43<07:07,  1.51s/it]
# Epoch 2 in training:  40%|███▉      | 187/469 [04:44<07:06,  1.51s/it]
# Epoch 2 in training:  40%|████      | 188/469 [04:46<07:02,  1.50s/it]
# Epoch 2 in training:  40%|████      | 189/469 [04:47<07:05,  1.52s/it]
# Epoch 2 in training:  41%|████      | 190/469 [04:49<07:21,  1.58s/it]
# Epoch 2 in training:  41%|████      | 191/469 [04:50<07:25,  1.60s/it]
# Epoch 2 in training:  41%|████      | 192/469 [04:52<07:16,  1.57s/it]
# Epoch 2 in training:  41%|████      | 193/469 [04:53<07:07,  1.55s/it]
# Epoch 2 in training:  41%|████▏     | 194/469 [04:55<07:08,  1.56s/it]
# Epoch 2 in training:  42%|████▏     | 195/469 [04:57<07:04,  1.55s/it]
# Epoch 2 in training:  42%|████▏     | 196/469 [04:58<07:10,  1.58s/it]
# Epoch 2 in training:  42%|████▏     | 197/469 [05:00<07:03,  1.56s/it]
# Epoch 2 in training:  42%|████▏     | 198/469 [05:01<06:57,  1.54s/it]
# Epoch 2 in training:  42%|████▏     | 199/469 [05:03<06:53,  1.53s/it]
# Epoch 2 in training:  43%|████▎     | 200/469 [05:04<06:53,  1.54s/it]
# Epoch 2 in training:  43%|████▎     | 201/469 [05:06<06:52,  1.54s/it]
# Epoch 2 in training:  43%|████▎     | 202/469 [05:07<06:51,  1.54s/it]
# Epoch 2 in training:  43%|████▎     | 203/469 [05:09<06:50,  1.54s/it]
# Epoch 2 in training:  43%|████▎     | 204/469 [05:11<06:51,  1.55s/it]
# Epoch 2 in training:  44%|████▎     | 205/469 [05:12<06:45,  1.54s/it]
# Epoch 2 in training:  44%|████▍     | 206/469 [05:14<06:45,  1.54s/it]
# ...
# Epoch 10 in training:  54%|█████▎    | 251/469 [06:22<05:30,  1.52s/it]
# Epoch 10 in training:  54%|█████▎    | 252/469 [06:23<05:27,  1.51s/it]
# Epoch 10 in training:  54%|█████▍    | 253/469 [06:25<05:30,  1.53s/it]
# Epoch 10 in training:  54%|█████▍    | 254/469 [06:27<05:27,  1.53s/it]
# Epoch 10 in training:  54%|█████▍    | 255/469 [06:28<05:24,  1.52s/it]
# Epoch 10 in training:  55%|█████▍    | 256/469 [06:30<05:22,  1.51s/it]
# Epoch 10 in training:  55%|█████▍    | 257/469 [06:31<05:19,  1.51s/it]
# Epoch 10 in training:  55%|█████▌    | 258/469 [06:33<05:17,  1.50s/it]
# Epoch 10 in training:  55%|█████▌    | 259/469 [06:34<05:14,  1.50s/it]
# Epoch 10 in training:  55%|█████▌    | 260/469 [06:36<05:13,  1.50s/it]
# Epoch 10 in training:  56%|█████▌    | 261/469 [06:37<05:13,  1.51s/it]
# Epoch 10 in training:  56%|█████▌    | 262/469 [06:39<05:11,  1.50s/it]
# Epoch 10 in training:  56%|█████▌    | 263/469 [06:40<05:09,  1.50s/it]
# Epoch 10 in training:  56%|█████▋    | 264/469 [06:42<05:07,  1.50s/it]
# Epoch 10 in training:  57%|█████▋    | 265/469 [06:43<05:05,  1.50s/it]
# Epoch 10 in training:  57%|█████▋    | 266/469 [06:45<05:11,  1.53s/it]
# Epoch 10 in training:  57%|█████▋    | 267/469 [06:46<05:10,  1.54s/it]
# Epoch 10 in training:  57%|█████▋    | 268/469 [06:48<05:06,  1.52s/it]
# Epoch 10 in training:  57%|█████▋    | 269/469 [06:49<05:03,  1.52s/it]
# Epoch 10 in training:  58%|█████▊    | 270/469 [06:51<05:04,  1.53s/it]
# Epoch 10 in training:  58%|█████▊    | 271/469 [06:52<05:00,  1.52s/it]
# Epoch 10 in training:  58%|█████▊    | 272/469 [06:54<04:58,  1.51s/it]
# Epoch 10 in training:  58%|█████▊    | 273/469 [06:55<04:58,  1.52s/it]
# Epoch 10 in training:  58%|█████▊    | 274/469 [06:57<05:00,  1.54s/it]
# Epoch 10 in training:  59%|█████▊    | 275/469 [06:58<04:56,  1.53s/it]
# Epoch 10 in training:  59%|█████▉    | 276/469 [07:00<04:53,  1.52s/it]
# Epoch 10 in training:  59%|█████▉    | 277/469 [07:01<04:50,  1.51s/it]
# Epoch 10 in training:  59%|█████▉    | 278/469 [07:03<04:48,  1.51s/it]
# Epoch 10 in training:  59%|█████▉    | 279/469 [07:04<04:45,  1.50s/it]
# Epoch 10 in training:  60%|█████▉    | 280/469 [07:06<04:45,  1.51s/it]
# Epoch 10 in training:  60%|█████▉    | 281/469 [07:07<04:42,  1.50s/it]
# Epoch 10 in training:  60%|██████    | 282/469 [07:09<04:40,  1.50s/it]
# Epoch 10 in training:  60%|██████    | 283/469 [07:10<04:38,  1.50s/it]
# Epoch 10 in training:  61%|██████    | 284/469 [07:12<04:37,  1.50s/it]
# Epoch 10 in training:  61%|██████    | 285/469 [07:13<04:35,  1.50s/it]
# Epoch 10 in training:  61%|██████    | 286/469 [07:15<04:41,  1.54s/it]
# Epoch 10 in training:  61%|██████    | 287/469 [07:17<04:38,  1.53s/it]
# Epoch 10 in training:  61%|██████▏   | 288/469 [07:18<04:35,  1.52s/it]
# Epoch 10 in training:  62%|██████▏   | 289/469 [07:20<04:33,  1.52s/it]
# Epoch 10 in training:  62%|██████▏   | 290/469 [07:21<04:32,  1.52s/it]
# Epoch 10 in training:  62%|██████▏   | 291/469 [07:23<04:29,  1.51s/it]
# Epoch 10 in training:  62%|██████▏   | 292/469 [07:24<04:26,  1.51s/it]
# Epoch 10 in training:  62%|██████▏   | 293/469 [07:26<04:24,  1.50s/it]
# Epoch 10 in training:  63%|██████▎   | 294/469 [07:27<04:27,  1.53s/it]
# Epoch 10 in training:  63%|██████▎   | 295/469 [07:29<04:24,  1.52s/it]
# Epoch 10 in training:  63%|██████▎   | 296/469 [07:30<04:22,  1.52s/it]
# Epoch 10 in training:  63%|██████▎   | 297/469 [07:32<04:21,  1.52s/it]
# Epoch 10 in training:  64%|██████▎   | 298/469 [07:33<04:19,  1.52s/it]
# Epoch 10 in training:  64%|██████▍   | 299/469 [07:35<04:16,  1.51s/it]
# Epoch 10 in training:  64%|██████▍   | 300/469 [07:36<04:16,  1.52s/it]
# Epoch 10 in training:  64%|██████▍   | 301/469 [07:38<04:19,  1.55s/it]
# Epoch 10 in training:  64%|██████▍   | 302/469 [07:39<04:15,  1.53s/it]
# Epoch 10 in training:  65%|██████▍   | 303/469 [07:41<04:12,  1.52s/it]
# Epoch 10 in training:  65%|██████▍   | 304/469 [07:42<04:10,  1.52s/it]
# Epoch 10 in training:  65%|██████▌   | 305/469 [07:44<04:08,  1.52s/it]
# Epoch 10 in training:  65%|██████▌   | 306/469 [07:45<04:05,  1.51s/it]
# Epoch 10 in training:  65%|██████▌   | 307/469 [07:47<04:05,  1.52s/it]
# Epoch 10 in training:  66%|██████▌   | 308/469 [07:48<04:03,  1.51s/it]
# Epoch 10 in training:  66%|██████▌   | 309/469 [07:50<04:01,  1.51s/it]
# Epoch 10 in training:  66%|██████▌   | 310/469 [07:51<03:59,  1.50s/it]
# Epoch 10 in training:  66%|██████▋   | 311/469 [07:53<03:58,  1.51s/it]
# Epoch 10 in training:  67%|██████▋   | 312/469 [07:54<03:55,  1.50s/it]
# Epoch 10 in training:  67%|██████▋   | 313/469 [07:56<03:56,  1.52s/it]
# Epoch 10 in training:  67%|██████▋   | 314/469 [07:57<03:54,  1.51s/it]
# Epoch 10 in training:  67%|██████▋   | 315/469 [07:59<03:54,  1.52s/it]
# Epoch 10 in training:  67%|██████▋   | 316/469 [08:00<03:51,  1.52s/it]
# Epoch 10 in training:  68%|██████▊   | 317/469 [08:02<03:49,  1.51s/it]
# Epoch 10 in training:  68%|██████▊   | 318/469 [08:04<03:52,  1.54s/it]
# Epoch 10 in training:  68%|██████▊   | 319/469 [08:05<03:48,  1.53s/it]
# Epoch 10 in training:  68%|██████▊   | 320/469 [08:07<03:46,  1.52s/it]
# Epoch 10 in training:  68%|██████▊   | 321/469 [08:08<03:44,  1.51s/it]
# Epoch 10 in training:  69%|██████▊   | 322/469 [08:10<03:41,  1.51s/it]
# Epoch 10 in training:  69%|██████▉   | 323/469 [08:11<03:39,  1.51s/it]
# Epoch 10 in training:  69%|██████▉   | 324/469 [08:13<03:37,  1.50s/it]
# Epoch 10 in training:  69%|██████▉   | 325/469 [08:14<03:35,  1.50s/it]
# Epoch 10 in training:  70%|██████▉   | 326/469 [08:16<03:34,  1.50s/it]
# Epoch 10 in training:  70%|██████▉   | 327/469 [08:17<03:34,  1.51s/it]
# Epoch 10 in training:  70%|██████▉   | 328/469 [08:19<03:31,  1.50s/it]
# Epoch 10 in training:  70%|███████   | 329/469 [08:20<03:29,  1.50s/it]
# Epoch 10 in training:  70%|███████   | 330/469 [08:22<03:28,  1.50s/it]
# Epoch 10 in training:  71%|███████   | 331/469 [08:23<03:26,  1.50s/it]
# Epoch 10 in training:  71%|███████   | 332/469 [08:25<03:24,  1.49s/it]
# Epoch 10 in training:  71%|███████   | 333/469 [08:26<03:24,  1.50s/it]
# Epoch 10 in training:  71%|███████   | 334/469 [08:28<03:22,  1.50s/it]
# Epoch 10 in training:  71%|███████▏  | 335/469 [08:29<03:21,  1.51s/it]
# Epoch 10 in training:  72%|███████▏  | 336/469 [08:31<03:21,  1.52s/it]
# Epoch 10 in training:  72%|███████▏  | 337/469 [08:32<03:23,  1.54s/it]
# Epoch 10 in training:  72%|███████▏  | 338/469 [08:34<03:20,  1.53s/it]
# Epoch 10 in training:  72%|███████▏  | 339/469 [08:35<03:16,  1.51s/it]
# Epoch 10 in training:  72%|███████▏  | 340/469 [08:37<03:15,  1.51s/it]
# Epoch 10 in training:  73%|███████▎  | 341/469 [08:38<03:12,  1.51s/it]
# Epoch 10 in training:  73%|███████▎  | 342/469 [08:40<03:11,  1.51s/it]
# Epoch 10 in training:  73%|███████▎  | 343/469 [08:41<03:09,  1.50s/it]
# Epoch 10 in training:  73%|███████▎  | 344/469 [08:43<03:07,  1.50s/it]
# Epoch 10 in training:  74%|███████▎  | 345/469 [08:44<03:05,  1.50s/it]
# Epoch 10 in training:  74%|███████▍  | 346/469 [08:46<03:04,  1.50s/it]
# Epoch 10 in training:  74%|███████▍  | 347/469 [08:47<03:02,  1.50s/it]
# Epoch 10 in training:  74%|███████▍  | 348/469 [08:49<03:01,  1.50s/it]
# Epoch 10 in training:  74%|███████▍  | 349/469 [08:50<03:00,  1.50s/it]
# Epoch 10 in training:  75%|███████▍  | 350/469 [08:52<02:58,  1.50s/it]
# Epoch 10 in training:  75%|███████▍  | 351/469 [08:53<02:57,  1.50s/it]
# Epoch 10 in training:  75%|███████▌  | 352/469 [08:55<02:55,  1.50s/it]
# Epoch 10 in training:  75%|███████▌  | 353/469 [08:56<02:55,  1.51s/it]
# Epoch 10 in training:  75%|███████▌  | 354/469 [08:58<02:57,  1.54s/it]
# Epoch 10 in training:  76%|███████▌  | 355/469 [08:59<02:54,  1.53s/it]
# Epoch 10 in training:  76%|███████▌  | 356/469 [09:01<02:54,  1.54s/it]
# Epoch 10 in training:  76%|███████▌  | 357/469 [09:02<02:53,  1.55s/it]
# Epoch 10 in training:  76%|███████▋  | 358/469 [09:04<02:59,  1.62s/it]
# Epoch 10 in training:  77%|███████▋  | 359/469 [09:06<02:55,  1.59s/it]
# Epoch 10 in training:  77%|███████▋  | 360/469 [09:07<02:50,  1.57s/it]
# Epoch 10 in training:  77%|███████▋  | 361/469 [09:09<02:46,  1.54s/it]
# Epoch 10 in training:  77%|███████▋  | 362/469 [09:10<02:43,  1.53s/it]
# Epoch 10 in training:  77%|███████▋  | 363/469 [09:12<02:41,  1.52s/it]
# Epoch 10 in training:  78%|███████▊  | 364/469 [09:13<02:39,  1.52s/it]
# Epoch 10 in training:  78%|███████▊  | 365/469 [09:15<02:37,  1.52s/it]
# Epoch 10 in training:  78%|███████▊  | 366/469 [09:16<02:36,  1.52s/it]
# Epoch 10 in training:  78%|███████▊  | 367/469 [09:18<02:34,  1.52s/it]
# Epoch 10 in training:  78%|███████▊  | 368/469 [09:19<02:33,  1.52s/it]
# Epoch 10 in training:  79%|███████▊  | 369/469 [09:21<02:31,  1.52s/it]
# Epoch 10 in training:  79%|███████▉  | 370/469 [09:22<02:29,  1.51s/it]
# Epoch 10 in training:  79%|███████▉  | 371/469 [09:24<02:28,  1.51s/it]
# Epoch 10 in training:  79%|███████▉  | 372/469 [09:25<02:26,  1.51s/it]
# Epoch 10 in training:  80%|███████▉  | 373/469 [09:27<02:24,  1.51s/it]
# Epoch 10 in training:  80%|███████▉  | 374/469 [09:29<02:28,  1.56s/it]
# Epoch 10 in training:  80%|███████▉  | 375/469 [09:30<02:26,  1.56s/it]
# Epoch 10 in training:  80%|████████  | 376/469 [09:32<02:24,  1.55s/it]
# Epoch 10 in training:  80%|████████  | 377/469 [09:33<02:22,  1.54s/it]
# Epoch 10 in training:  81%|████████  | 378/469 [09:35<02:19,  1.53s/it]
# Epoch 10 in training:  81%|████████  | 379/469 [09:36<02:17,  1.53s/it]
# Epoch 10 in training:  81%|████████  | 380/469 [09:38<02:15,  1.52s/it]
# Epoch 10 in training:  81%|████████  | 381/469 [09:39<02:13,  1.52s/it]
# Epoch 10 in training:  81%|████████▏ | 382/469 [09:41<02:11,  1.51s/it]
# Epoch 10 in training:  82%|████████▏ | 383/469 [09:42<02:10,  1.51s/it]
# Epoch 10 in training:  82%|████████▏ | 384/469 [09:44<02:08,  1.51s/it]
# Epoch 10 in training:  82%|████████▏ | 385/469 [09:45<02:06,  1.51s/it]
# Epoch 10 in training:  82%|████████▏ | 386/469 [09:47<02:06,  1.52s/it]
# Epoch 10 in training:  83%|████████▎ | 387/469 [09:48<02:04,  1.52s/it]
# Epoch 10 in training:  83%|████████▎ | 388/469 [09:50<02:02,  1.51s/it]
# Epoch 10 in training:  83%|████████▎ | 389/469 [09:51<02:04,  1.55s/it]
# Epoch 10 in training:  83%|████████▎ | 390/469 [09:53<02:01,  1.54s/it]
# Epoch 10 in training:  83%|████████▎ | 391/469 [09:54<01:58,  1.52s/it]
# Epoch 10 in training:  84%|████████▎ | 392/469 [09:56<01:57,  1.53s/it]
# Epoch 10 in training:  84%|████████▍ | 393/469 [09:58<01:55,  1.52s/it]
# Epoch 10 in training:  84%|████████▍ | 394/469 [09:59<01:53,  1.52s/it]
# Epoch 10 in training:  84%|████████▍ | 395/469 [10:01<01:51,  1.51s/it]
# Epoch 10 in training:  84%|████████▍ | 396/469 [10:02<01:50,  1.51s/it]
# Epoch 10 in training:  85%|████████▍ | 397/469 [10:04<01:50,  1.53s/it]
# Epoch 10 in training:  85%|████████▍ | 398/469 [10:05<01:48,  1.52s/it]
# Epoch 10 in training:  85%|████████▌ | 399/469 [10:07<01:47,  1.53s/it]
# Epoch 10 in training:  85%|████████▌ | 400/469 [10:08<01:45,  1.52s/it]
# Epoch 10 in training:  86%|████████▌ | 401/469 [10:10<01:43,  1.52s/it]
# Epoch 10 in training:  86%|████████▌ | 402/469 [10:11<01:41,  1.51s/it]
# Epoch 10 in training:  86%|████████▌ | 403/469 [10:13<01:39,  1.51s/it]
# Epoch 10 in training:  86%|████████▌ | 404/469 [10:14<01:37,  1.51s/it]
# Epoch 10 in training:  86%|████████▋ | 405/469 [10:16<01:37,  1.52s/it]
# Epoch 10 in training:  87%|████████▋ | 406/469 [10:17<01:37,  1.55s/it]
# Epoch 10 in training:  87%|████████▋ | 407/469 [10:19<01:35,  1.54s/it]
# Epoch 10 in training:  87%|████████▋ | 408/469 [10:20<01:33,  1.53s/it]
# Epoch 10 in training:  87%|████████▋ | 409/469 [10:22<01:31,  1.52s/it]
# Epoch 10 in training:  87%|████████▋ | 410/469 [10:23<01:29,  1.52s/it]
# Epoch 10 in training:  88%|████████▊ | 411/469 [10:25<01:27,  1.51s/it]
# Epoch 10 in training:  88%|████████▊ | 412/469 [10:26<01:26,  1.52s/it]
# Epoch 10 in training:  88%|████████▊ | 413/469 [10:28<01:24,  1.52s/it]
# Epoch 10 in training:  88%|████████▊ | 414/469 [10:29<01:23,  1.52s/it]
# Epoch 10 in training:  88%|████████▊ | 415/469 [10:31<01:21,  1.51s/it]
# Epoch 10 in training:  89%|████████▊ | 416/469 [10:32<01:20,  1.51s/it]
# Epoch 10 in training:  89%|████████▉ | 417/469 [10:34<01:19,  1.53s/it]
# Epoch 10 in training:  89%|████████▉ | 418/469 [10:36<01:18,  1.53s/it]
# Epoch 10 in training:  89%|████████▉ | 419/469 [10:37<01:16,  1.53s/it]
# Epoch 10 in training:  90%|████████▉ | 420/469 [10:39<01:14,  1.52s/it]
# Epoch 10 in training:  90%|████████▉ | 421/469 [10:40<01:13,  1.52s/it]
# Epoch 10 in training:  90%|████████▉ | 422/469 [10:42<01:12,  1.53s/it]
# Epoch 10 in training:  90%|█████████ | 423/469 [10:43<01:10,  1.53s/it]
# Epoch 10 in training:  90%|█████████ | 424/469 [10:45<01:08,  1.52s/it]
# Epoch 10 in training:  91%|█████████ | 425/469 [10:46<01:08,  1.55s/it]
# Epoch 10 in training:  91%|█████████ | 426/469 [10:48<01:06,  1.54s/it]
# Epoch 10 in training:  91%|█████████ | 427/469 [10:49<01:04,  1.53s/it]
# Epoch 10 in training:  91%|█████████▏| 428/469 [10:51<01:02,  1.53s/it]
# Epoch 10 in training:  91%|█████████▏| 429/469 [10:52<01:00,  1.52s/it]
# Epoch 10 in training:  92%|█████████▏| 430/469 [10:54<00:58,  1.51s/it]
# Epoch 10 in training:  92%|█████████▏| 431/469 [10:55<00:57,  1.50s/it]
# Epoch 10 in training:  92%|█████████▏| 432/469 [10:57<00:56,  1.52s/it]
# Epoch 10 in training:  92%|█████████▏| 433/469 [10:58<00:54,  1.52s/it]
# Epoch 10 in training:  93%|█████████▎| 434/469 [11:00<00:53,  1.52s/it]
# Epoch 10 in training:  93%|█████████▎| 435/469 [11:01<00:51,  1.51s/it]
# Epoch 10 in training:  93%|█████████▎| 436/469 [11:03<00:49,  1.50s/it]
# Epoch 10 in training:  93%|█████████▎| 437/469 [11:04<00:48,  1.50s/it]
# Epoch 10 in training:  93%|█████████▎| 438/469 [11:06<00:47,  1.53s/it]
# Epoch 10 in training:  94%|█████████▎| 439/469 [11:08<00:45,  1.52s/it]
# Epoch 10 in training:  94%|█████████▍| 440/469 [11:09<00:43,  1.52s/it]
# Epoch 10 in training:  94%|█████████▍| 441/469 [11:11<00:42,  1.51s/it]
# Epoch 10 in training:  94%|█████████▍| 442/469 [11:12<00:41,  1.54s/it]
# Epoch 10 in training:  94%|█████████▍| 443/469 [11:14<00:39,  1.53s/it]
# Epoch 10 in training:  95%|█████████▍| 444/469 [11:15<00:38,  1.53s/it]
# Epoch 10 in training:  95%|█████████▍| 445/469 [11:17<00:36,  1.53s/it]
# Epoch 10 in training:  95%|█████████▌| 446/469 [11:18<00:34,  1.52s/it]
# Epoch 10 in training:  95%|█████████▌| 447/469 [11:20<00:33,  1.51s/it]
# Epoch 10 in training:  96%|█████████▌| 448/469 [11:21<00:31,  1.51s/it]
# Epoch 10 in training:  96%|█████████▌| 449/469 [11:23<00:30,  1.51s/it]
# Epoch 10 in training:  96%|█████████▌| 450/469 [11:24<00:28,  1.51s/it]
# Epoch 10 in training:  96%|█████████▌| 451/469 [11:26<00:27,  1.51s/it]
# Epoch 10 in training:  96%|█████████▋| 452/469 [11:27<00:25,  1.51s/it]
# Epoch 10 in training:  97%|█████████▋| 453/469 [11:29<00:24,  1.50s/it]
# Epoch 10 in training:  97%|█████████▋| 454/469 [11:30<00:22,  1.50s/it]
# Epoch 10 in training:  97%|█████████▋| 455/469 [11:32<00:21,  1.51s/it]
# Epoch 10 in training:  97%|█████████▋| 456/469 [11:33<00:19,  1.50s/it]
# Epoch 10 in training:  97%|█████████▋| 457/469 [11:35<00:18,  1.50s/it]
# Epoch 10 in training:  98%|█████████▊| 458/469 [11:36<00:16,  1.51s/it]
# Epoch 10 in training:  98%|█████████▊| 459/469 [11:38<00:15,  1.53s/it]
# Epoch 10 in training:  98%|█████████▊| 460/469 [11:39<00:13,  1.51s/it]
# Epoch 10 in training:  98%|█████████▊| 461/469 [11:41<00:12,  1.51s/it]
# Epoch 10 in training:  99%|█████████▊| 462/469 [11:42<00:10,  1.54s/it]
# Epoch 10 in training:  99%|█████████▊| 463/469 [11:44<00:09,  1.53s/it]
# Epoch 10 in training:  99%|█████████▉| 464/469 [11:45<00:07,  1.52s/it]
# Epoch 10 in training:  99%|█████████▉| 465/469 [11:47<00:06,  1.52s/it]
# Epoch 10 in training:  99%|█████████▉| 466/469 [11:48<00:04,  1.52s/it]
# Epoch 10 in training: 100%|█████████▉| 467/469 [11:50<00:03,  1.53s/it]
# Epoch 10 in training: 100%|█████████▉| 468/469 [11:51<00:01,  1.52s/it]
# Epoch 10 in training: 100%|██████████| 469/469 [11:53<00:00,  1.40s/it]
# train: 100%|██████████| 10/10 [1:59:06<00:00, 714.65s/it]
# Epoch 10/10 loss: 1.68
# Testing: 100%|██████████| 79/79 [00:56<00:00,  1.41it/s]
# Test loss: 1.66
# Test accuracy: 80.14%

# %%
path: str = "fastkan_vit_10epochs.pth"

torch.save(mnist_model.state_dict(), path)
