# %%
import torch as th
import numpy as np

# %%
import math
import numpy
import torch
import torch.nn.functional as F

torch.manual_seed(42)
numpy.random.seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
class NaiveFourierKANLayer(th.nn.Module):
    def __init__( self, inputdim, outdim, gridsize, addbias=True, smooth_initialization=False):
        super(NaiveFourierKANLayer,self).__init__()
        self.gridsize= gridsize
        self.addbias = addbias
        self.inputdim = inputdim
        self.outdim = outdim
        
        # With smooth_initialization, fourier coefficients are attenuated by the square of their frequency.
        # This makes KAN's scalar functions smooth at initialization.
        # Without smooth_initialization, high gridsizes will lead to high-frequency scalar functions,
        # with high derivatives and low correlation between similar inputs.
        grid_norm_factor = (th.arange(gridsize) + 1)**2 if smooth_initialization else np.sqrt(gridsize)
        
        #The normalization has been chosen so that if given inputs where each coordinate is of unit variance,
        #then each coordinates of the output is of unit variance 
        #independently of the various sizes
        self.fouriercoeffs = th.nn.Parameter( th.randn(2,outdim,inputdim,gridsize) / 
                                                (np.sqrt(inputdim) * grid_norm_factor ) )
        if( self.addbias ):
            self.bias  = th.nn.Parameter( th.zeros(1,outdim))

    #x.shape ( ... , indim ) 
    #out.shape ( ..., outdim)
    def forward(self,x):
        xshp = x.shape
        outshape = xshp[0:-1]+(self.outdim,)
        x = th.reshape(x,(-1,self.inputdim))
        #Starting at 1 because constant terms are in the bias
        k = th.reshape( th.arange(1,self.gridsize+1,device=x.device),(1,1,1,self.gridsize))
        xrshp = th.reshape(x,(x.shape[0],1,x.shape[1],1) ) 
        #This should be fused to avoid materializing memory
        c = th.cos( k*xrshp )
        s = th.sin( k*xrshp )
        #We compute the interpolation of the various functions defined by their fourier coefficient for each input coordinates and we sum them 
        y =  th.sum( c*self.fouriercoeffs[0:1],(-2,-1)) 
        y += th.sum( s*self.fouriercoeffs[1:2],(-2,-1))
        if( self.addbias):
            y += self.bias
        #End fuse
        '''
        #You can use einsum instead to reduce memory usage
        #It stills not as good as fully fused but it should help
        #einsum is usually slower though
        c = th.reshape(c,(1,x.shape[0],x.shape[1],self.gridsize))
        s = th.reshape(s,(1,x.shape[0],x.shape[1],self.gridsize))
        y2 = th.einsum( "dbik,djik->bj", th.concat([c,s],axis=0) ,self.fouriercoeffs )
        if( self.addbias):
            y2 += self.bias
        diff = th.sum((y2-y)**2)
        print("diff")
        print(diff) #should be ~0
        '''
        y = th.reshape( y, outshape)
        return y

# %%
class NaiveFourierMSA(torch.nn.Module):
    """
        Initializes the Multi-Head Self-Attention (MSA) module with the given dimensions.

        Args:
            d (int): The total dimension of the input.
            n_heads (int): The number of attention heads.

        Returns:
            None
    """
    def __init__(self, d, n_heads):
        super(NaiveFourierMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0
        d_head = int(d / n_heads)

        self.q_mappings = torch.nn.ModuleList([NaiveFourierKANLayer(d_head, d_head, gridsize=4) for _ in range(self.n_heads)])
        self.k_mappings = torch.nn.ModuleList([NaiveFourierKANLayer(d_head, d_head, gridsize=4) for _ in range(self.n_heads)])
        self.v_mappings = torch.nn.ModuleList([NaiveFourierKANLayer(d_head, d_head, gridsize=4) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = torch.nn.Softmax(dim=-1)

    def forward(self, sequence):
        result = []
        for sequence in sequence:
            seq_res = []
            for head in range(self.n_heads):
                q_map = self.q_mappings[head]
                k_map = self.k_mappings[head]
                v_map = self.v_mappings[head]

                seq = sequence[:, head*self.d_head: (head+1)*self.d_head]
                q, k, v = q_map(seq), k_map(seq), v_map(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_res.append(attention @ v)
            result.append(torch.hstack(seq_res))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class FourierKAN_ViT(torch.nn.Module): 
    """
        Initializes a Vision Transformer (ViT) module.

        Args:
            chw (list/tuple of 3 ints): The input image shape.
            n_patches (int, optional): The number of patches to split the image into. Defaults to 10.
            n_blocks (int, optional): The number of blocks in the transformer encoder. Defaults to 2.
            d_hidden (int, optional): The number of hidden dimensions in the transformer encoder. Defaults to 8.
            n_heads (int, optional): The number of attention heads in each block. Defaults to 2.
            out_d (int, optional): The number of output dimensions. Defaults to 10.

        Returns:
            None
    """    
    def __init__(self, chw, n_patches=10, n_blocks=2, d_hidden=8, n_heads=2, out_d=10): 
        super(FourierKAN_ViT, self).__init__()
        
        self.chw = chw
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.d_hidden = d_hidden
        
        assert chw[1] % n_patches == 0 
        assert chw[2] % n_patches == 0
        
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # Linear mapping
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = NaiveFourierKANLayer(self.input_d, self.d_hidden, gridsize=28)

        # Classification token
        self.v_class = torch.nn.Parameter(torch.rand(1, self.d_hidden))

        # Positional embedding
        self.register_buffer('pos_embeddings', self.positional_embeddings(n_patches ** 2 + 1, d_hidden),
                             persistent=False)

        # Encoder blocks
        self.blocks = torch.nn.ModuleList([NaiveFourierMSA(d_hidden, n_heads) for _ in range(n_blocks)])

        self.mlp = torch.nn.Sequential(
            NaiveFourierKANLayer(self.d_hidden, out_d, gridsize=4),
            torch.nn.Softmax(dim=-1)
        )
        
    def patchify(self, images, n_patches):
        """
        The purpose of this function is to break down the main image into multiple sub-images and map them.

        Args:
            images (_type_): The image passeed into this function.
            n_patches (_type_): The number of sub-images that will be created.
        """

        n, c, h, w = images.shape
        assert h == w, "Only for square images"

        patches = torch.zeros(n, n_patches**2, h * w * c // n_patches ** 2) # The equation to calculate the patches
        patch_size = h // n_patches

        for idx, image in enumerate(images):
            for i in range(n_patches):
                for j in range(n_patches):
                    patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                    patches[idx, i * n_patches + j] = patch.flatten()
        return patches

    def positional_embeddings(self, seq_length, d):
        """
        the purpose of this function is to find high and low interaction of a word with surrounding words.
        We can do so by the following equation below:

        Args:
            seq_length (int): The length of the sequence/sentence
            d (int): The dimension of the embedding
        """

        result = torch.ones(seq_length, d)
        for i in range(seq_length):
            for j in range(d):
                result[i][j] = numpy.sin(i / 10000 ** (j / d)) if j % 2 == 0 else numpy.cos(i / 10000 ** (j/ d))
        return result

    def forward(self, images):
        n, c, h, w = images.shape
        patches = self.patchify(images, self.n_patches).to(self.pos_embeddings.device)

        # running tokenization
        tokens = self.linear_mapper(patches)
        tokens = torch.cat((self.v_class.expand(n, 1, -1), tokens), dim=1)
        out = tokens + self.pos_embeddings.repeat(n, 1, 1)

        for block in self.blocks:
            out = block(out)

        out = out[:, 0]
        return self.mlp(out)

# %%
from torch.optim import Adam
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
mnist_model = FourierKAN_ViT((1, 28, 28), n_patches=7, n_blocks=2, d_hidden=8, n_heads=2, out_d=10).to(device)
optimizer = Adam(mnist_model.parameters(), lr=0.005)

# %%
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST
from tqdm import tqdm, trange

def main(train_loader, test_loader):
    """
    This code contains the training and testing loop for training the vision transformers model. It requires two
    parameters

    :param train_loader: The dataloader for the training set for training the model.
    :param test_loader: The dataloader for the testing set during evaluation phase.
    """
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

    epochs = 10
    criterion = torch.nn.CrossEntropyLoss()
    for epoch in trange(epochs, desc="train"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch + 1}/{epochs} loss: {train_loss:.2f}")

    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = mnist_model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
transform = transforms.ToTensor()
train_mnist = MNIST(root='./mnist', train=True, download=True, transform=transform)
test_mnist = MNIST(root='./mnist', train=False, download=True, transform=transform)
train_loader = DataLoader(train_mnist, shuffle=True, batch_size=128)
test_loader = DataLoader(test_mnist, shuffle=False, batch_size=128)
main(train_loader=train_loader, test_loader=test_loader)
# Out:
# Using device:  cuda (Tesla P100-PCIE-16GB)
# train:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:02<15:44,  2.02s/it]
# Epoch 1 in training:   0%|          | 2/469 [00:03<13:41,  1.76s/it]
# Epoch 1 in training:   1%|          | 3/469 [00:05<12:59,  1.67s/it]
# Epoch 1 in training:   1%|          | 4/469 [00:06<12:13,  1.58s/it]
# Epoch 1 in training:   1%|          | 5/469 [00:08<12:07,  1.57s/it]
# Epoch 1 in training:   1%|▏         | 6/469 [00:09<11:44,  1.52s/it]
# Epoch 1 in training:   1%|▏         | 7/469 [00:11<11:31,  1.50s/it]
# Epoch 1 in training:   2%|▏         | 8/469 [00:12<11:38,  1.51s/it]
# Epoch 1 in training:   2%|▏         | 9/469 [00:14<11:25,  1.49s/it]
# Epoch 1 in training:   2%|▏         | 10/469 [00:15<11:18,  1.48s/it]
# Epoch 1 in training:   2%|▏         | 11/469 [00:16<11:13,  1.47s/it]
# Epoch 1 in training:   3%|▎         | 12/469 [00:18<11:13,  1.47s/it]
# Epoch 1 in training:   3%|▎         | 13/469 [00:19<11:06,  1.46s/it]
# Epoch 1 in training:   3%|▎         | 14/469 [00:21<11:16,  1.49s/it]
# Epoch 1 in training:   3%|▎         | 15/469 [00:22<11:08,  1.47s/it]
# Epoch 1 in training:   3%|▎         | 16/469 [00:24<11:04,  1.47s/it]
# Epoch 1 in training:   4%|▎         | 17/469 [00:25<10:59,  1.46s/it]
# Epoch 1 in training:   4%|▍         | 18/469 [00:27<11:08,  1.48s/it]
# Epoch 1 in training:   4%|▍         | 19/469 [00:28<11:03,  1.47s/it]
# Epoch 1 in training:   4%|▍         | 20/469 [00:30<11:11,  1.50s/it]
# Epoch 1 in training:   4%|▍         | 21/469 [00:31<11:03,  1.48s/it]
# Epoch 1 in training:   5%|▍         | 22/469 [00:33<10:58,  1.47s/it]
# Epoch 1 in training:   5%|▍         | 23/469 [00:34<10:54,  1.47s/it]
# Epoch 1 in training:   5%|▌         | 24/469 [00:36<10:49,  1.46s/it]
# Epoch 1 in training:   5%|▌         | 25/469 [00:37<10:49,  1.46s/it]
# Epoch 1 in training:   6%|▌         | 26/469 [00:38<10:45,  1.46s/it]
# Epoch 1 in training:   6%|▌         | 27/469 [00:40<10:58,  1.49s/it]
# Epoch 1 in training:   6%|▌         | 28/469 [00:41<10:49,  1.47s/it]
# Epoch 1 in training:   6%|▌         | 29/469 [00:43<10:45,  1.47s/it]
# Epoch 1 in training:   6%|▋         | 30/469 [00:44<10:40,  1.46s/it]
# Epoch 1 in training:   7%|▋         | 31/469 [00:46<10:36,  1.45s/it]
# Epoch 1 in training:   7%|▋         | 32/469 [00:47<10:37,  1.46s/it]
# Epoch 1 in training:   7%|▋         | 33/469 [00:49<10:48,  1.49s/it]
# Epoch 1 in training:   7%|▋         | 34/469 [00:50<10:41,  1.48s/it]
# Epoch 1 in training:   7%|▋         | 35/469 [00:52<10:36,  1.47s/it]
# Epoch 1 in training:   8%|▊         | 36/469 [00:53<10:30,  1.46s/it]
# Epoch 1 in training:   8%|▊         | 37/469 [00:55<10:29,  1.46s/it]
# Epoch 1 in training:   8%|▊         | 38/469 [00:56<10:27,  1.46s/it]
# Epoch 1 in training:   8%|▊         | 39/469 [00:58<10:36,  1.48s/it]
# Epoch 1 in training:   9%|▊         | 40/469 [00:59<10:37,  1.49s/it]
# Epoch 1 in training:   9%|▊         | 41/469 [01:01<10:48,  1.52s/it]
# Epoch 1 in training:   9%|▉         | 42/469 [01:02<10:41,  1.50s/it]
# Epoch 1 in training:   9%|▉         | 43/469 [01:04<10:34,  1.49s/it]
# Epoch 1 in training:   9%|▉         | 44/469 [01:05<10:29,  1.48s/it]
# Epoch 1 in training:  10%|▉         | 45/469 [01:07<10:23,  1.47s/it]
# Epoch 1 in training:  10%|▉         | 46/469 [01:08<10:22,  1.47s/it]
# Epoch 1 in training:  10%|█         | 47/469 [01:09<10:16,  1.46s/it]
# Epoch 1 in training:  10%|█         | 48/469 [01:11<10:24,  1.48s/it]
# Epoch 1 in training:  10%|█         | 49/469 [01:12<10:17,  1.47s/it]
# Epoch 1 in training:  11%|█         | 50/469 [01:14<10:11,  1.46s/it]
# Epoch 1 in training:  11%|█         | 51/469 [01:15<10:05,  1.45s/it]
# Epoch 1 in training:  11%|█         | 52/469 [01:17<10:05,  1.45s/it]
# Epoch 1 in training:  11%|█▏        | 53/469 [01:18<10:01,  1.45s/it]
# Epoch 1 in training:  12%|█▏        | 54/469 [01:20<10:13,  1.48s/it]
# Epoch 1 in training:  12%|█▏        | 55/469 [01:21<10:05,  1.46s/it]
# Epoch 1 in training:  12%|█▏        | 56/469 [01:23<09:58,  1.45s/it]
# Epoch 1 in training:  12%|█▏        | 57/469 [01:24<09:57,  1.45s/it]
# Epoch 1 in training:  12%|█▏        | 58/469 [01:25<09:52,  1.44s/it]
# Epoch 1 in training:  13%|█▎        | 59/469 [01:27<09:53,  1.45s/it]
# Epoch 1 in training:  13%|█▎        | 60/469 [01:28<09:51,  1.45s/it]
# Epoch 1 in training:  13%|█▎        | 61/469 [01:30<09:59,  1.47s/it]
# Epoch 1 in training:  13%|█▎        | 62/469 [01:31<10:08,  1.50s/it]
# Epoch 1 in training:  13%|█▎        | 63/469 [01:33<10:02,  1.48s/it]
# Epoch 1 in training:  14%|█▎        | 64/469 [01:34<09:56,  1.47s/it]
# Epoch 1 in training:  14%|█▍        | 65/469 [01:36<09:51,  1.46s/it]
# Epoch 1 in training:  14%|█▍        | 66/469 [01:37<09:52,  1.47s/it]
# Epoch 1 in training:  14%|█▍        | 67/469 [01:39<09:47,  1.46s/it]
# Epoch 1 in training:  14%|█▍        | 68/469 [01:40<09:43,  1.46s/it]
# Epoch 1 in training:  15%|█▍        | 69/469 [01:42<09:55,  1.49s/it]
# Epoch 1 in training:  15%|█▍        | 70/469 [01:43<09:48,  1.47s/it]
# Epoch 1 in training:  15%|█▌        | 71/469 [01:45<09:45,  1.47s/it]
# Epoch 1 in training:  15%|█▌        | 72/469 [01:46<09:42,  1.47s/it]
# Epoch 1 in training:  16%|█▌        | 73/469 [01:48<09:39,  1.46s/it]
# Epoch 1 in training:  16%|█▌        | 74/469 [01:49<09:35,  1.46s/it]
# Epoch 1 in training:  16%|█▌        | 75/469 [01:51<09:47,  1.49s/it]
# Epoch 1 in training:  16%|█▌        | 76/469 [01:52<09:39,  1.47s/it]
# Epoch 1 in training:  16%|█▋        | 77/469 [01:53<09:33,  1.46s/it]
# Epoch 1 in training:  17%|█▋        | 78/469 [01:55<09:31,  1.46s/it]
# Epoch 1 in training:  17%|█▋        | 79/469 [01:56<09:26,  1.45s/it]
# Epoch 1 in training:  17%|█▋        | 80/469 [01:58<09:29,  1.46s/it]
# Epoch 1 in training:  17%|█▋        | 81/469 [01:59<09:26,  1.46s/it]
# Epoch 1 in training:  17%|█▋        | 82/469 [02:01<09:32,  1.48s/it]
# Epoch 1 in training:  18%|█▊        | 83/469 [02:02<09:39,  1.50s/it]
# Epoch 1 in training:  18%|█▊        | 84/469 [02:04<09:30,  1.48s/it]
# Epoch 1 in training:  18%|█▊        | 85/469 [02:05<09:25,  1.47s/it]
# Epoch 1 in training:  18%|█▊        | 86/469 [02:07<09:23,  1.47s/it]
# Epoch 1 in training:  19%|█▊        | 87/469 [02:08<09:19,  1.47s/it]
# Epoch 1 in training:  19%|█▉        | 88/469 [02:10<09:15,  1.46s/it]
# Epoch 1 in training:  19%|█▉        | 89/469 [02:11<09:14,  1.46s/it]
# Epoch 1 in training:  19%|█▉        | 90/469 [02:13<09:25,  1.49s/it]
# Epoch 1 in training:  19%|█▉        | 91/469 [02:14<09:18,  1.48s/it]
# Epoch 1 in training:  20%|█▉        | 92/469 [02:15<09:13,  1.47s/it]
# Epoch 1 in training:  20%|█▉        | 93/469 [02:17<09:12,  1.47s/it]
# Epoch 1 in training:  20%|██        | 94/469 [02:18<09:07,  1.46s/it]
# Epoch 1 in training:  20%|██        | 95/469 [02:20<09:05,  1.46s/it]
# Epoch 1 in training:  20%|██        | 96/469 [02:21<09:15,  1.49s/it]
# Epoch 1 in training:  21%|██        | 97/469 [02:23<09:13,  1.49s/it]
# Epoch 1 in training:  21%|██        | 98/469 [02:24<09:06,  1.47s/it]
# Epoch 1 in training:  21%|██        | 99/469 [02:26<09:01,  1.46s/it]
# Epoch 1 in training:  21%|██▏       | 100/469 [02:27<08:59,  1.46s/it]
# Epoch 1 in training:  22%|██▏       | 101/469 [02:29<08:54,  1.45s/it]
# Epoch 1 in training:  22%|██▏       | 102/469 [02:30<08:51,  1.45s/it]
# Epoch 1 in training:  22%|██▏       | 103/469 [02:32<08:55,  1.46s/it]
# Epoch 1 in training:  22%|██▏       | 104/469 [02:33<09:03,  1.49s/it]
# Epoch 1 in training:  22%|██▏       | 105/469 [02:35<08:57,  1.48s/it]
# Epoch 1 in training:  23%|██▎       | 106/469 [02:36<08:51,  1.46s/it]
# Epoch 1 in training:  23%|██▎       | 107/469 [02:37<08:51,  1.47s/it]
# Epoch 1 in training:  23%|██▎       | 108/469 [02:39<08:47,  1.46s/it]
# Epoch 1 in training:  23%|██▎       | 109/469 [02:40<08:43,  1.45s/it]
# Epoch 1 in training:  23%|██▎       | 110/469 [02:42<08:41,  1.45s/it]
# Epoch 1 in training:  24%|██▎       | 111/469 [02:43<08:49,  1.48s/it]
# Epoch 1 in training:  24%|██▍       | 112/469 [02:45<08:45,  1.47s/it]
# Epoch 1 in training:  24%|██▍       | 113/469 [02:46<08:41,  1.47s/it]
# Epoch 1 in training:  24%|██▍       | 114/469 [02:48<08:40,  1.47s/it]
# Epoch 1 in training:  25%|██▍       | 115/469 [02:49<08:34,  1.45s/it]
# Epoch 1 in training:  25%|██▍       | 116/469 [02:51<08:31,  1.45s/it]
# Epoch 1 in training:  25%|██▍       | 117/469 [02:52<08:37,  1.47s/it]
# Epoch 1 in training:  25%|██▌       | 118/469 [02:54<08:31,  1.46s/it]
# Epoch 1 in training:  25%|██▌       | 119/469 [02:55<08:31,  1.46s/it]
# Epoch 1 in training:  26%|██▌       | 120/469 [02:56<08:28,  1.46s/it]
# Epoch 1 in training:  26%|██▌       | 121/469 [02:58<08:28,  1.46s/it]
# Epoch 1 in training:  26%|██▌       | 122/469 [02:59<08:25,  1.46s/it]
# Epoch 1 in training:  26%|██▌       | 123/469 [03:01<08:22,  1.45s/it]
# Epoch 1 in training:  26%|██▋       | 124/469 [03:02<08:24,  1.46s/it]
# Epoch 1 in training:  27%|██▋       | 125/469 [03:04<08:35,  1.50s/it]
# Epoch 1 in training:  27%|██▋       | 126/469 [03:05<08:27,  1.48s/it]
# Epoch 1 in training:  27%|██▋       | 127/469 [03:07<08:24,  1.47s/it]
# Epoch 1 in training:  27%|██▋       | 128/469 [03:08<08:20,  1.47s/it]
# Epoch 1 in training:  28%|██▊       | 129/469 [03:10<08:14,  1.45s/it]
# Epoch 1 in training:  28%|██▊       | 130/469 [03:11<08:11,  1.45s/it]
# Epoch 1 in training:  28%|██▊       | 131/469 [03:13<08:09,  1.45s/it]
# Epoch 1 in training:  28%|██▊       | 132/469 [03:14<08:17,  1.48s/it]
# Epoch 1 in training:  28%|██▊       | 133/469 [03:16<08:14,  1.47s/it]
# Epoch 1 in training:  29%|██▊       | 134/469 [03:17<08:15,  1.48s/it]
# Epoch 1 in training:  29%|██▉       | 135/469 [03:18<08:08,  1.46s/it]
# Epoch 1 in training:  29%|██▉       | 136/469 [03:20<08:05,  1.46s/it]
# Epoch 1 in training:  29%|██▉       | 137/469 [03:21<08:02,  1.45s/it]
# Epoch 1 in training:  29%|██▉       | 138/469 [03:23<08:09,  1.48s/it]
# Epoch 1 in training:  30%|██▉       | 139/469 [03:24<08:05,  1.47s/it]
# Epoch 1 in training:  30%|██▉       | 140/469 [03:26<07:59,  1.46s/it]
# Epoch 1 in training:  30%|███       | 141/469 [03:27<07:58,  1.46s/it]
# Epoch 1 in training:  30%|███       | 142/469 [03:29<07:55,  1.46s/it]
# Epoch 1 in training:  30%|███       | 143/469 [03:30<07:52,  1.45s/it]
# Epoch 1 in training:  31%|███       | 144/469 [03:32<07:50,  1.45s/it]
# Epoch 1 in training:  31%|███       | 145/469 [03:33<07:48,  1.45s/it]
# Epoch 1 in training:  31%|███       | 146/469 [03:35<08:02,  1.49s/it]
# Epoch 1 in training:  31%|███▏      | 147/469 [03:36<07:55,  1.48s/it]
# Epoch 1 in training:  32%|███▏      | 148/469 [03:38<07:53,  1.48s/it]
# Epoch 1 in training:  32%|███▏      | 149/469 [03:39<07:48,  1.47s/it]
# Epoch 1 in training:  32%|███▏      | 150/469 [03:40<07:43,  1.45s/it]
# Epoch 1 in training:  32%|███▏      | 151/469 [03:42<07:41,  1.45s/it]
# Epoch 1 in training:  32%|███▏      | 152/469 [03:43<07:38,  1.45s/it]
# Epoch 1 in training:  33%|███▎      | 153/469 [03:45<07:45,  1.47s/it]
# Epoch 1 in training:  33%|███▎      | 154/469 [03:46<07:41,  1.46s/it]
# Epoch 1 in training:  33%|███▎      | 155/469 [03:48<07:41,  1.47s/it]
# Epoch 1 in training:  33%|███▎      | 156/469 [03:49<07:36,  1.46s/it]
# Epoch 1 in training:  33%|███▎      | 157/469 [03:51<07:34,  1.46s/it]
# Epoch 1 in training:  34%|███▎      | 158/469 [03:52<07:31,  1.45s/it]
# Epoch 1 in training:  34%|███▍      | 159/469 [03:54<07:39,  1.48s/it]
# Epoch 1 in training:  34%|███▍      | 160/469 [03:55<07:37,  1.48s/it]
# Epoch 1 in training:  34%|███▍      | 161/469 [03:57<07:34,  1.48s/it]
# Epoch 1 in training:  35%|███▍      | 162/469 [03:58<07:32,  1.47s/it]
# Epoch 1 in training:  35%|███▍      | 163/469 [03:59<07:26,  1.46s/it]
# Epoch 1 in training:  35%|███▍      | 164/469 [04:01<07:23,  1.45s/it]
# Epoch 1 in training:  35%|███▌      | 165/469 [04:02<07:20,  1.45s/it]
# Epoch 1 in training:  35%|███▌      | 166/469 [04:04<07:19,  1.45s/it]
# Epoch 1 in training:  36%|███▌      | 167/469 [04:05<07:33,  1.50s/it]
# Epoch 1 in training:  36%|███▌      | 168/469 [04:07<07:29,  1.49s/it]
# Epoch 1 in training:  36%|███▌      | 169/469 [04:08<07:23,  1.48s/it]
# Epoch 1 in training:  36%|███▌      | 170/469 [04:10<07:18,  1.47s/it]
# Epoch 1 in training:  36%|███▋      | 171/469 [04:11<07:15,  1.46s/it]
# Epoch 1 in training:  37%|███▋      | 172/469 [04:13<07:13,  1.46s/it]
# Epoch 1 in training:  37%|███▋      | 173/469 [04:14<07:10,  1.45s/it]
# Epoch 1 in training:  37%|███▋      | 174/469 [04:16<07:22,  1.50s/it]
# Epoch 1 in training:  37%|███▋      | 175/469 [04:17<07:17,  1.49s/it]
# Epoch 1 in training:  38%|███▊      | 176/469 [04:19<07:11,  1.47s/it]
# Epoch 1 in training:  38%|███▊      | 177/469 [04:20<07:07,  1.46s/it]
# Epoch 1 in training:  38%|███▊      | 178/469 [04:21<07:03,  1.45s/it]
# Epoch 1 in training:  38%|███▊      | 179/469 [04:23<07:00,  1.45s/it]
# Epoch 1 in training:  38%|███▊      | 180/469 [04:24<07:08,  1.48s/it]
# Epoch 1 in training:  39%|███▊      | 181/469 [04:26<07:02,  1.47s/it]
# Epoch 1 in training:  39%|███▉      | 182/469 [04:27<06:59,  1.46s/it]
# Epoch 1 in training:  39%|███▉      | 183/469 [04:29<06:56,  1.46s/it]
# Epoch 1 in training:  39%|███▉      | 184/469 [04:30<06:53,  1.45s/it]
# Epoch 1 in training:  39%|███▉      | 185/469 [04:32<06:50,  1.45s/it]
# Epoch 1 in training:  40%|███▉      | 186/469 [04:33<06:49,  1.45s/it]
# Epoch 1 in training:  40%|███▉      | 187/469 [04:35<06:47,  1.45s/it]
# Epoch 1 in training:  40%|████      | 188/469 [04:36<07:01,  1.50s/it]
# Epoch 1 in training:  40%|████      | 189/469 [04:38<06:59,  1.50s/it]
# Epoch 1 in training:  41%|████      | 190/469 [04:39<06:51,  1.48s/it]
# Epoch 1 in training:  41%|████      | 191/469 [04:41<06:46,  1.46s/it]
# Epoch 1 in training:  41%|████      | 192/469 [04:42<06:44,  1.46s/it]
# Epoch 1 in training:  41%|████      | 193/469 [04:43<06:39,  1.45s/it]
# Epoch 1 in training:  41%|████▏     | 194/469 [04:45<06:37,  1.45s/it]
# Epoch 1 in training:  42%|████▏     | 195/469 [04:46<06:45,  1.48s/it]
# Epoch 1 in training:  42%|████▏     | 196/469 [04:48<06:42,  1.47s/it]
# Epoch 1 in training:  42%|████▏     | 197/469 [04:49<06:38,  1.46s/it]
# Epoch 1 in training:  42%|████▏     | 198/469 [04:51<06:34,  1.46s/it]
# Epoch 1 in training:  42%|████▏     | 199/469 [04:52<06:32,  1.45s/it]
# Epoch 1 in training:  43%|████▎     | 200/469 [04:54<06:30,  1.45s/it]
# Epoch 1 in training:  43%|████▎     | 201/469 [04:55<06:37,  1.48s/it]
# Epoch 1 in training:  43%|████▎     | 202/469 [04:57<06:35,  1.48s/it]
# Epoch 1 in training:  43%|████▎     | 203/469 [04:58<06:32,  1.47s/it]
# Epoch 1 in training:  43%|████▎     | 204/469 [05:00<06:27,  1.46s/it]
# Epoch 1 in training:  44%|████▎     | 205/469 [05:01<06:23,  1.45s/it]
# Epoch 1 in training:  44%|████▍     | 206/469 [05:02<06:21,  1.45s/it]
# Epoch 1 in training:  44%|████▍     | 207/469 [05:04<06:18,  1.44s/it]
# Epoch 1 in training:  44%|████▍     | 208/469 [05:05<06:15,  1.44s/it]
# Epoch 1 in training:  45%|████▍     | 209/469 [05:07<06:31,  1.51s/it]
# Epoch 1 in training:  45%|████▍     | 210/469 [05:08<06:25,  1.49s/it]
# Epoch 1 in training:  45%|████▍     | 211/469 [05:10<06:19,  1.47s/it]
# Epoch 1 in training:  45%|████▌     | 212/469 [05:11<06:16,  1.46s/it]
# Epoch 1 in training:  45%|████▌     | 213/469 [05:13<06:12,  1.46s/it]
# Epoch 1 in training:  46%|████▌     | 214/469 [05:14<06:09,  1.45s/it]
# Epoch 1 in training:  46%|████▌     | 215/469 [05:16<06:08,  1.45s/it]
# Epoch 1 in training:  46%|████▌     | 216/469 [05:17<06:16,  1.49s/it]
# Epoch 1 in training:  46%|████▋     | 217/469 [05:19<06:10,  1.47s/it]
# Epoch 1 in training:  46%|████▋     | 218/469 [05:20<06:07,  1.46s/it]
# Epoch 1 in training:  47%|████▋     | 219/469 [05:22<06:03,  1.46s/it]
# Epoch 1 in training:  47%|████▋     | 220/469 [05:23<06:01,  1.45s/it]
# Epoch 1 in training:  47%|████▋     | 221/469 [05:24<05:59,  1.45s/it]
# Epoch 1 in training:  47%|████▋     | 222/469 [05:26<06:05,  1.48s/it]
# Epoch 1 in training:  48%|████▊     | 223/469 [05:27<06:04,  1.48s/it]
# Epoch 1 in training:  48%|████▊     | 224/469 [05:29<06:02,  1.48s/it]
# Epoch 1 in training:  48%|████▊     | 225/469 [05:30<05:58,  1.47s/it]
# Epoch 1 in training:  48%|████▊     | 226/469 [05:32<05:54,  1.46s/it]
# Epoch 1 in training:  48%|████▊     | 227/469 [05:33<05:52,  1.46s/it]
# Epoch 1 in training:  49%|████▊     | 228/469 [05:35<05:49,  1.45s/it]
# Epoch 1 in training:  49%|████▉     | 229/469 [05:36<05:47,  1.45s/it]
# Epoch 1 in training:  49%|████▉     | 230/469 [05:38<05:57,  1.50s/it]
# Epoch 1 in training:  49%|████▉     | 231/469 [05:39<05:54,  1.49s/it]
# Epoch 1 in training:  49%|████▉     | 232/469 [05:41<05:49,  1.47s/it]
# Epoch 1 in training:  50%|████▉     | 233/469 [05:42<05:45,  1.46s/it]
# Epoch 1 in training:  50%|████▉     | 234/469 [05:44<05:41,  1.46s/it]
# Epoch 1 in training:  50%|█████     | 235/469 [05:45<05:39,  1.45s/it]
# Epoch 1 in training:  50%|█████     | 236/469 [05:46<05:36,  1.44s/it]
# Epoch 1 in training:  51%|█████     | 237/469 [05:48<05:45,  1.49s/it]
# Epoch 1 in training:  51%|█████     | 238/469 [05:49<05:41,  1.48s/it]
# Epoch 1 in training:  51%|█████     | 239/469 [05:51<05:37,  1.47s/it]
# Epoch 1 in training:  51%|█████     | 240/469 [05:52<05:33,  1.46s/it]
# Epoch 1 in training:  51%|█████▏    | 241/469 [05:54<05:31,  1.45s/it]
# Epoch 1 in training:  52%|█████▏    | 242/469 [05:55<05:28,  1.45s/it]
# Epoch 1 in training:  52%|█████▏    | 243/469 [05:57<05:37,  1.49s/it]
# Epoch 1 in training:  52%|█████▏    | 244/469 [05:58<05:33,  1.48s/it]
# Epoch 1 in training:  52%|█████▏    | 245/469 [06:00<05:28,  1.47s/it]
# Epoch 1 in training:  52%|█████▏    | 246/469 [06:01<05:25,  1.46s/it]
# Epoch 1 in training:  53%|█████▎    | 247/469 [06:03<05:21,  1.45s/it]
# Epoch 1 in training:  53%|█████▎    | 248/469 [06:04<05:20,  1.45s/it]
# Epoch 1 in training:  53%|█████▎    | 249/469 [06:05<05:17,  1.44s/it]
# Epoch 1 in training:  53%|█████▎    | 250/469 [06:07<05:18,  1.45s/it]
# Epoch 1 in training:  54%|█████▎    | 251/469 [06:08<05:23,  1.48s/it]
# Epoch 1 in training:  54%|█████▎    | 252/469 [06:10<05:23,  1.49s/it]
# Epoch 1 in training:  54%|█████▍    | 253/469 [06:11<05:18,  1.47s/it]
# Epoch 1 in training:  54%|█████▍    | 254/469 [06:13<05:13,  1.46s/it]
# Epoch 1 in training:  54%|█████▍    | 255/469 [06:14<05:10,  1.45s/it]
# Epoch 1 in training:  55%|█████▍    | 256/469 [06:16<05:09,  1.45s/it]
# Epoch 1 in training:  55%|█████▍    | 257/469 [06:17<05:08,  1.46s/it]
# Epoch 1 in training:  55%|█████▌    | 258/469 [06:19<05:13,  1.49s/it]
# Epoch 1 in training:  55%|█████▌    | 259/469 [06:20<05:09,  1.48s/it]
# Epoch 1 in training:  55%|█████▌    | 260/469 [06:22<05:05,  1.46s/it]
# Epoch 1 in training:  56%|█████▌    | 261/469 [06:23<05:03,  1.46s/it]
# Epoch 1 in training:  56%|█████▌    | 262/469 [06:24<05:00,  1.45s/it]
# Epoch 1 in training:  56%|█████▌    | 263/469 [06:26<04:57,  1.44s/it]
# Epoch 1 in training:  56%|█████▋    | 264/469 [06:28<05:08,  1.50s/it]
# Epoch 1 in training:  57%|█████▋    | 265/469 [06:29<05:03,  1.49s/it]
# Epoch 1 in training:  57%|█████▋    | 266/469 [06:30<04:57,  1.47s/it]
# Epoch 1 in training:  57%|█████▋    | 267/469 [06:32<04:55,  1.46s/it]
# Epoch 1 in training:  57%|█████▋    | 268/469 [06:33<04:52,  1.45s/it]
# Epoch 1 in training:  57%|█████▋    | 269/469 [06:35<04:50,  1.45s/it]
# Epoch 1 in training:  58%|█████▊    | 270/469 [06:36<04:48,  1.45s/it]
# Epoch 1 in training:  58%|█████▊    | 271/469 [06:38<04:48,  1.46s/it]
# Epoch 1 in training:  58%|█████▊    | 272/469 [06:39<04:53,  1.49s/it]
# Epoch 1 in training:  58%|█████▊    | 273/469 [06:41<04:53,  1.50s/it]
# Epoch 1 in training:  58%|█████▊    | 274/469 [06:42<04:49,  1.48s/it]
# Epoch 1 in training:  59%|█████▊    | 275/469 [06:44<04:44,  1.47s/it]
# Epoch 1 in training:  59%|█████▉    | 276/469 [06:45<04:41,  1.46s/it]
# Epoch 1 in training:  59%|█████▉    | 277/469 [06:47<04:39,  1.45s/it]
# Epoch 1 in training:  59%|█████▉    | 278/469 [06:48<04:39,  1.46s/it]
# Epoch 1 in training:  59%|█████▉    | 279/469 [06:50<04:43,  1.49s/it]
# Epoch 1 in training:  60%|█████▉    | 280/469 [06:51<04:39,  1.48s/it]
# Epoch 1 in training:  60%|█████▉    | 281/469 [06:52<04:35,  1.47s/it]
# Epoch 1 in training:  60%|██████    | 282/469 [06:54<04:33,  1.46s/it]
# Epoch 1 in training:  60%|██████    | 283/469 [06:55<04:30,  1.46s/it]
# Epoch 1 in training:  61%|██████    | 284/469 [06:57<04:31,  1.47s/it]
# Epoch 1 in training:  61%|██████    | 285/469 [06:58<04:35,  1.50s/it]
# Epoch 1 in training:  61%|██████    | 286/469 [07:00<04:30,  1.48s/it]
# Epoch 1 in training:  61%|██████    | 287/469 [07:01<04:26,  1.47s/it]
# Epoch 1 in training:  61%|██████▏   | 288/469 [07:03<04:24,  1.46s/it]
# Epoch 1 in training:  62%|██████▏   | 289/469 [07:04<04:21,  1.45s/it]
# Epoch 1 in training:  62%|██████▏   | 290/469 [07:06<04:19,  1.45s/it]
# Epoch 1 in training:  62%|██████▏   | 291/469 [07:07<04:19,  1.46s/it]
# Epoch 1 in training:  62%|██████▏   | 292/469 [07:09<04:16,  1.45s/it]
# Epoch 1 in training:  62%|██████▏   | 293/469 [07:10<04:21,  1.48s/it]
# Epoch 1 in training:  63%|██████▎   | 294/469 [07:12<04:21,  1.49s/it]
# Epoch 1 in training:  63%|██████▎   | 295/469 [07:13<04:17,  1.48s/it]
# Epoch 1 in training:  63%|██████▎   | 296/469 [07:14<04:13,  1.47s/it]
# Epoch 1 in training:  63%|██████▎   | 297/469 [07:16<04:11,  1.46s/it]
# Epoch 1 in training:  64%|██████▎   | 298/469 [07:17<04:10,  1.46s/it]
# Epoch 1 in training:  64%|██████▍   | 299/469 [07:19<04:08,  1.46s/it]
# Epoch 1 in training:  64%|██████▍   | 300/469 [07:20<04:11,  1.49s/it]
# Epoch 1 in training:  64%|██████▍   | 301/469 [07:22<04:07,  1.47s/it]
# Epoch 1 in training:  64%|██████▍   | 302/469 [07:23<04:04,  1.47s/it]
# Epoch 1 in training:  65%|██████▍   | 303/469 [07:25<04:02,  1.46s/it]
# Epoch 1 in training:  65%|██████▍   | 304/469 [07:26<03:59,  1.45s/it]
# Epoch 1 in training:  65%|██████▌   | 305/469 [07:28<03:59,  1.46s/it]
# Epoch 1 in training:  65%|██████▌   | 306/469 [07:29<04:02,  1.49s/it]
# Epoch 1 in training:  65%|██████▌   | 307/469 [07:31<03:58,  1.47s/it]
# Epoch 1 in training:  66%|██████▌   | 308/469 [07:32<03:55,  1.46s/it]
# Epoch 1 in training:  66%|██████▌   | 309/469 [07:34<03:54,  1.47s/it]
# Epoch 1 in training:  66%|██████▌   | 310/469 [07:35<03:51,  1.46s/it]
# Epoch 1 in training:  66%|██████▋   | 311/469 [07:36<03:49,  1.45s/it]
# Epoch 1 in training:  67%|██████▋   | 312/469 [07:38<03:49,  1.46s/it]
# Epoch 1 in training:  67%|██████▋   | 313/469 [07:39<03:46,  1.46s/it]
# Epoch 1 in training:  67%|██████▋   | 314/469 [07:41<03:51,  1.49s/it]
# Epoch 1 in training:  67%|██████▋   | 315/469 [07:42<03:50,  1.50s/it]
# Epoch 1 in training:  67%|██████▋   | 316/469 [07:44<03:47,  1.48s/it]
# Epoch 1 in training:  68%|██████▊   | 317/469 [07:45<03:43,  1.47s/it]
# Epoch 1 in training:  68%|██████▊   | 318/469 [07:47<03:41,  1.47s/it]
# Epoch 1 in training:  68%|██████▊   | 319/469 [07:48<03:39,  1.46s/it]
# Epoch 1 in training:  68%|██████▊   | 320/469 [07:50<03:36,  1.46s/it]
# Epoch 1 in training:  68%|██████▊   | 321/469 [07:51<03:39,  1.48s/it]
# Epoch 1 in training:  69%|██████▊   | 322/469 [07:53<03:35,  1.47s/it]
# Epoch 1 in training:  69%|██████▉   | 323/469 [07:54<03:34,  1.47s/it]
# Epoch 1 in training:  69%|██████▉   | 324/469 [07:56<03:32,  1.46s/it]
# Epoch 1 in training:  69%|██████▉   | 325/469 [07:57<03:32,  1.47s/it]
# Epoch 1 in training:  70%|██████▉   | 326/469 [07:59<03:29,  1.47s/it]
# Epoch 1 in training:  70%|██████▉   | 327/469 [08:00<03:31,  1.49s/it]
# Epoch 1 in training:  70%|██████▉   | 328/469 [08:02<03:27,  1.48s/it]
# Epoch 1 in training:  70%|███████   | 329/469 [08:03<03:24,  1.46s/it]
# Epoch 1 in training:  70%|███████   | 330/469 [08:04<03:21,  1.45s/it]
# Epoch 1 in training:  71%|███████   | 331/469 [08:06<03:19,  1.45s/it]
# Epoch 1 in training:  71%|███████   | 332/469 [08:07<03:19,  1.46s/it]
# Epoch 1 in training:  71%|███████   | 333/469 [08:09<03:17,  1.45s/it]
# Epoch 1 in training:  71%|███████   | 334/469 [08:10<03:15,  1.45s/it]
# Epoch 1 in training:  71%|███████▏  | 335/469 [08:12<03:18,  1.48s/it]
# Epoch 1 in training:  72%|███████▏  | 336/469 [08:13<03:15,  1.47s/it]
# Epoch 1 in training:  72%|███████▏  | 337/469 [08:15<03:15,  1.48s/it]
# Epoch 1 in training:  72%|███████▏  | 338/469 [08:16<03:12,  1.47s/it]
# Epoch 1 in training:  72%|███████▏  | 339/469 [08:18<03:10,  1.47s/it]
# Epoch 1 in training:  72%|███████▏  | 340/469 [08:19<03:08,  1.46s/it]
# Epoch 1 in training:  73%|███████▎  | 341/469 [08:20<03:05,  1.45s/it]
# Epoch 1 in training:  73%|███████▎  | 342/469 [08:22<03:08,  1.48s/it]
# Epoch 1 in training:  73%|███████▎  | 343/469 [08:23<03:05,  1.47s/it]
# Epoch 1 in training:  73%|███████▎  | 344/469 [08:25<03:02,  1.46s/it]
# Epoch 1 in training:  74%|███████▎  | 345/469 [08:26<03:00,  1.45s/it]
# Epoch 1 in training:  74%|███████▍  | 346/469 [08:28<02:59,  1.46s/it]
# Epoch 1 in training:  74%|███████▍  | 347/469 [08:29<02:56,  1.45s/it]
# Epoch 1 in training:  74%|███████▍  | 348/469 [08:31<02:58,  1.48s/it]
# Epoch 1 in training:  74%|███████▍  | 349/469 [08:32<02:55,  1.46s/it]
# Epoch 1 in training:  75%|███████▍  | 350/469 [08:34<02:53,  1.46s/it]
# Epoch 1 in training:  75%|███████▍  | 351/469 [08:35<02:50,  1.45s/it]
# Epoch 1 in training:  75%|███████▌  | 352/469 [08:37<02:49,  1.45s/it]
# Epoch 1 in training:  75%|███████▌  | 353/469 [08:38<02:48,  1.45s/it]
# Epoch 1 in training:  75%|███████▌  | 354/469 [08:39<02:46,  1.45s/it]
# Epoch 1 in training:  76%|███████▌  | 355/469 [08:41<02:44,  1.45s/it]
# Epoch 1 in training:  76%|███████▌  | 356/469 [08:42<02:47,  1.48s/it]
# Epoch 1 in training:  76%|███████▌  | 357/469 [08:44<02:44,  1.46s/it]
# Epoch 1 in training:  76%|███████▋  | 358/469 [08:45<02:44,  1.48s/it]
# Epoch 1 in training:  77%|███████▋  | 359/469 [08:47<02:42,  1.48s/it]
# Epoch 1 in training:  77%|███████▋  | 360/469 [08:48<02:39,  1.46s/it]
# Epoch 1 in training:  77%|███████▋  | 361/469 [08:50<02:37,  1.46s/it]
# Epoch 1 in training:  77%|███████▋  | 362/469 [08:51<02:35,  1.45s/it]
# Epoch 1 in training:  77%|███████▋  | 363/469 [08:53<02:36,  1.48s/it]
# Epoch 1 in training:  78%|███████▊  | 364/469 [08:54<02:34,  1.47s/it]
# Epoch 1 in training:  78%|███████▊  | 365/469 [08:56<02:31,  1.46s/it]
# Epoch 1 in training:  78%|███████▊  | 366/469 [08:57<02:31,  1.47s/it]
# Epoch 1 in training:  78%|███████▊  | 367/469 [08:59<02:29,  1.47s/it]
# Epoch 1 in training:  78%|███████▊  | 368/469 [09:00<02:27,  1.46s/it]
# Epoch 1 in training:  79%|███████▊  | 369/469 [09:02<02:28,  1.49s/it]
# Epoch 1 in training:  79%|███████▉  | 370/469 [09:03<02:25,  1.47s/it]
# Epoch 1 in training:  79%|███████▉  | 371/469 [09:04<02:22,  1.46s/it]
# Epoch 1 in training:  79%|███████▉  | 372/469 [09:06<02:21,  1.45s/it]
# Epoch 1 in training:  80%|███████▉  | 373/469 [09:07<02:19,  1.45s/it]
# Epoch 1 in training:  80%|███████▉  | 374/469 [09:09<02:17,  1.45s/it]
# Epoch 1 in training:  80%|███████▉  | 375/469 [09:10<02:16,  1.45s/it]
# Epoch 1 in training:  80%|████████  | 376/469 [09:12<02:13,  1.44s/it]
# Epoch 1 in training:  80%|████████  | 377/469 [09:13<02:15,  1.47s/it]
# Epoch 1 in training:  81%|████████  | 378/469 [09:15<02:13,  1.47s/it]
# Epoch 1 in training:  81%|████████  | 379/469 [09:16<02:13,  1.49s/it]
# Epoch 1 in training:  81%|████████  | 380/469 [09:18<02:12,  1.49s/it]
# Epoch 1 in training:  81%|████████  | 381/469 [09:19<02:09,  1.48s/it]
# Epoch 1 in training:  81%|████████▏ | 382/469 [09:20<02:08,  1.47s/it]
# Epoch 1 in training:  82%|████████▏ | 383/469 [09:22<02:05,  1.46s/it]
# Epoch 1 in training:  82%|████████▏ | 384/469 [09:23<02:06,  1.49s/it]
# Epoch 1 in training:  82%|████████▏ | 385/469 [09:25<02:03,  1.47s/it]
# Epoch 1 in training:  82%|████████▏ | 386/469 [09:26<02:00,  1.46s/it]
# Epoch 1 in training:  83%|████████▎ | 387/469 [09:28<02:00,  1.47s/it]
# Epoch 1 in training:  83%|████████▎ | 388/469 [09:29<01:58,  1.46s/it]
# Epoch 1 in training:  83%|████████▎ | 389/469 [09:31<01:56,  1.45s/it]
# Epoch 1 in training:  83%|████████▎ | 390/469 [09:32<01:56,  1.48s/it]
# Epoch 1 in training:  83%|████████▎ | 391/469 [09:34<01:54,  1.46s/it]
# Epoch 1 in training:  84%|████████▎ | 392/469 [09:35<01:52,  1.46s/it]
# Epoch 1 in training:  84%|████████▍ | 393/469 [09:37<01:50,  1.46s/it]
# Epoch 1 in training:  84%|████████▍ | 394/469 [09:38<01:49,  1.45s/it]
# Epoch 1 in training:  84%|████████▍ | 395/469 [09:39<01:47,  1.45s/it]
# Epoch 1 in training:  84%|████████▍ | 396/469 [09:41<01:45,  1.44s/it]
# Epoch 1 in training:  85%|████████▍ | 397/469 [09:42<01:43,  1.44s/it]
# Epoch 1 in training:  85%|████████▍ | 398/469 [09:44<01:44,  1.47s/it]
# Epoch 1 in training:  85%|████████▌ | 399/469 [09:45<01:42,  1.46s/it]
# Epoch 1 in training:  85%|████████▌ | 400/469 [09:47<01:41,  1.47s/it]
# Epoch 1 in training:  86%|████████▌ | 401/469 [09:48<01:40,  1.48s/it]
# Epoch 1 in training:  86%|████████▌ | 402/469 [09:50<01:38,  1.46s/it]
# Epoch 1 in training:  86%|████████▌ | 403/469 [09:51<01:36,  1.46s/it]
# Epoch 1 in training:  86%|████████▌ | 404/469 [09:53<01:34,  1.46s/it]
# Epoch 1 in training:  86%|████████▋ | 405/469 [09:54<01:34,  1.48s/it]
# Epoch 1 in training:  87%|████████▋ | 406/469 [09:56<01:32,  1.47s/it]
# Epoch 1 in training:  87%|████████▋ | 407/469 [09:57<01:31,  1.47s/it]
# Epoch 1 in training:  87%|████████▋ | 408/469 [09:59<01:29,  1.46s/it]
# Epoch 1 in training:  87%|████████▋ | 409/469 [10:00<01:27,  1.45s/it]
# Epoch 1 in training:  87%|████████▋ | 410/469 [10:01<01:25,  1.45s/it]
# Epoch 1 in training:  88%|████████▊ | 411/469 [10:03<01:25,  1.48s/it]
# Epoch 1 in training:  88%|████████▊ | 412/469 [10:04<01:23,  1.47s/it]
# Epoch 1 in training:  88%|████████▊ | 413/469 [10:06<01:21,  1.46s/it]
# Epoch 1 in training:  88%|████████▊ | 414/469 [10:07<01:20,  1.46s/it]
# Epoch 1 in training:  88%|████████▊ | 415/469 [10:09<01:18,  1.45s/it]
# Epoch 1 in training:  89%|████████▊ | 416/469 [10:10<01:16,  1.45s/it]
# Epoch 1 in training:  89%|████████▉ | 417/469 [10:12<01:15,  1.45s/it]
# Epoch 1 in training:  89%|████████▉ | 418/469 [10:13<01:13,  1.45s/it]
# Epoch 1 in training:  89%|████████▉ | 419/469 [10:15<01:13,  1.48s/it]
# Epoch 1 in training:  90%|████████▉ | 420/469 [10:16<01:11,  1.47s/it]
# Epoch 1 in training:  90%|████████▉ | 421/469 [10:17<01:10,  1.47s/it]
# Epoch 1 in training:  90%|████████▉ | 422/469 [10:19<01:09,  1.48s/it]
# Epoch 1 in training:  90%|█████████ | 423/469 [10:20<01:07,  1.47s/it]
# Epoch 1 in training:  90%|█████████ | 424/469 [10:22<01:05,  1.46s/it]
# Epoch 1 in training:  91%|█████████ | 425/469 [10:23<01:03,  1.45s/it]
# Epoch 1 in training:  91%|█████████ | 426/469 [10:25<01:03,  1.48s/it]
# Epoch 1 in training:  91%|█████████ | 427/469 [10:26<01:01,  1.47s/it]
# Epoch 1 in training:  91%|█████████▏| 428/469 [10:28<01:00,  1.47s/it]
# Epoch 1 in training:  91%|█████████▏| 429/469 [10:29<00:58,  1.46s/it]
# Epoch 1 in training:  92%|█████████▏| 430/469 [10:31<00:56,  1.45s/it]
# Epoch 1 in training:  92%|█████████▏| 431/469 [10:32<00:55,  1.45s/it]
# Epoch 1 in training:  92%|█████████▏| 432/469 [10:34<00:54,  1.48s/it]
# Epoch 1 in training:  92%|█████████▏| 433/469 [10:35<00:52,  1.47s/it]
# Epoch 1 in training:  93%|█████████▎| 434/469 [10:37<00:51,  1.46s/it]
# Epoch 1 in training:  93%|█████████▎| 435/469 [10:38<00:49,  1.46s/it]
# Epoch 1 in training:  93%|█████████▎| 436/469 [10:39<00:48,  1.46s/it]
# Epoch 1 in training:  93%|█████████▎| 437/469 [10:41<00:46,  1.45s/it]
# Epoch 1 in training:  93%|█████████▎| 438/469 [10:42<00:44,  1.45s/it]
# Epoch 1 in training:  94%|█████████▎| 439/469 [10:44<00:43,  1.45s/it]
# Epoch 1 in training:  94%|█████████▍| 440/469 [10:45<00:42,  1.47s/it]
# Epoch 1 in training:  94%|█████████▍| 441/469 [10:47<00:41,  1.47s/it]
# Epoch 1 in training:  94%|█████████▍| 442/469 [10:48<00:39,  1.46s/it]
# Epoch 1 in training:  94%|█████████▍| 443/469 [10:50<00:38,  1.47s/it]
# Epoch 1 in training:  95%|█████████▍| 444/469 [10:51<00:36,  1.47s/it]
# Epoch 1 in training:  95%|█████████▍| 445/469 [10:53<00:35,  1.46s/it]
# Epoch 1 in training:  95%|█████████▌| 446/469 [10:54<00:33,  1.45s/it]
# Epoch 1 in training:  95%|█████████▌| 447/469 [10:56<00:32,  1.48s/it]
# Epoch 1 in training:  96%|█████████▌| 448/469 [10:57<00:31,  1.48s/it]
# Epoch 1 in training:  96%|█████████▌| 449/469 [10:58<00:29,  1.47s/it]
# Epoch 1 in training:  96%|█████████▌| 450/469 [11:00<00:27,  1.46s/it]
# Epoch 1 in training:  96%|█████████▌| 451/469 [11:01<00:26,  1.45s/it]
# Epoch 1 in training:  96%|█████████▋| 452/469 [11:03<00:24,  1.45s/it]
# Epoch 1 in training:  97%|█████████▋| 453/469 [11:04<00:23,  1.48s/it]
# Epoch 1 in training:  97%|█████████▋| 454/469 [11:06<00:21,  1.47s/it]
# Epoch 1 in training:  97%|█████████▋| 455/469 [11:07<00:20,  1.46s/it]
# Epoch 1 in training:  97%|█████████▋| 456/469 [11:09<00:18,  1.46s/it]
# Epoch 1 in training:  97%|█████████▋| 457/469 [11:10<00:17,  1.45s/it]
# Epoch 1 in training:  98%|█████████▊| 458/469 [11:12<00:15,  1.45s/it]
# Epoch 1 in training:  98%|█████████▊| 459/469 [11:13<00:14,  1.45s/it]
# Epoch 1 in training:  98%|█████████▊| 460/469 [11:14<00:12,  1.44s/it]
# Epoch 1 in training:  98%|█████████▊| 461/469 [11:16<00:11,  1.48s/it]
# Epoch 1 in training:  99%|█████████▊| 462/469 [11:17<00:10,  1.48s/it]
# Epoch 1 in training:  99%|█████████▊| 463/469 [11:19<00:08,  1.47s/it]
# Epoch 1 in training:  99%|█████████▉| 464/469 [11:20<00:07,  1.48s/it]
# Epoch 1 in training:  99%|█████████▉| 465/469 [11:22<00:05,  1.47s/it]
# Epoch 1 in training:  99%|█████████▉| 466/469 [11:23<00:04,  1.46s/it]
# Epoch 1 in training: 100%|█████████▉| 467/469 [11:25<00:02,  1.46s/it]
# Epoch 1 in training: 100%|█████████▉| 468/469 [11:26<00:01,  1.49s/it]
# Epoch 1 in training: 100%|██████████| 469/469 [11:27<00:00,  1.38s/it]
# train:  10%|█         | 1/10 [11:27<1:43:11, 687.96s/it]
# Epoch 1/10 loss: 2.28
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:01<11:15,  1.44s/it]
# Epoch 2 in training:   0%|          | 2/469 [00:02<11:13,  1.44s/it]
# Epoch 2 in training:   1%|          | 3/469 [00:04<11:11,  1.44s/it]
# Epoch 2 in training:   1%|          | 4/469 [00:05<11:10,  1.44s/it]
# Epoch 2 in training:   1%|          | 5/469 [00:07<11:07,  1.44s/it]
# Epoch 2 in training:   1%|▏         | 6/469 [00:08<11:05,  1.44s/it]
# Epoch 2 in training:   1%|▏         | 7/469 [00:10<11:27,  1.49s/it]
# Epoch 2 in training:   2%|▏         | 8/469 [00:11<11:17,  1.47s/it]
# Epoch 2 in training:   2%|▏         | 9/469 [00:13<11:11,  1.46s/it]
# Epoch 2 in training:   2%|▏         | 10/469 [00:14<11:07,  1.45s/it]
# Epoch 2 in training:   2%|▏         | 11/469 [00:15<11:03,  1.45s/it]
# Epoch 2 in training:   3%|▎         | 12/469 [00:17<10:57,  1.44s/it]
# Epoch 2 in training:   3%|▎         | 13/469 [00:18<10:56,  1.44s/it]
# Epoch 2 in training:   3%|▎         | 14/469 [00:20<11:12,  1.48s/it]
# Epoch 2 in training:   3%|▎         | 15/469 [00:21<11:05,  1.47s/it]
# Epoch 2 in training:   3%|▎         | 16/469 [00:23<11:12,  1.49s/it]
# Epoch 2 in training:   4%|▎         | 17/469 [00:24<11:14,  1.49s/it]
# Epoch 2 in training:   4%|▍         | 18/469 [00:26<11:05,  1.48s/it]
# Epoch 2 in training:   4%|▍         | 19/469 [00:27<11:00,  1.47s/it]
# Epoch 2 in training:   4%|▍         | 20/469 [00:29<11:16,  1.51s/it]
# Epoch 2 in training:   4%|▍         | 21/469 [00:30<11:07,  1.49s/it]
# Epoch 2 in training:   5%|▍         | 22/469 [00:32<11:00,  1.48s/it]
# Epoch 2 in training:   5%|▍         | 23/469 [00:33<10:54,  1.47s/it]
# Epoch 2 in training:   5%|▌         | 24/469 [00:35<10:48,  1.46s/it]
# Epoch 2 in training:   5%|▌         | 25/469 [00:36<10:46,  1.46s/it]
# Epoch 2 in training:   6%|▌         | 26/469 [00:38<10:42,  1.45s/it]
# Epoch 2 in training:   6%|▌         | 27/469 [00:39<11:00,  1.49s/it]
# Epoch 2 in training:   6%|▌         | 28/469 [00:41<10:53,  1.48s/it]
# Epoch 2 in training:   6%|▌         | 29/469 [00:42<10:46,  1.47s/it]
# Epoch 2 in training:   6%|▋         | 30/469 [00:43<10:46,  1.47s/it]
# Epoch 2 in training:   7%|▋         | 31/469 [00:45<10:40,  1.46s/it]
# Epoch 2 in training:   7%|▋         | 32/469 [00:46<10:36,  1.46s/it]
# Epoch 2 in training:   7%|▋         | 33/469 [00:48<10:48,  1.49s/it]
# Epoch 2 in training:   7%|▋         | 34/469 [00:49<10:44,  1.48s/it]
# Epoch 2 in training:   7%|▋         | 35/469 [00:51<10:34,  1.46s/it]
# Epoch 2 in training:   8%|▊         | 36/469 [00:52<10:31,  1.46s/it]
# Epoch 2 in training:   8%|▊         | 37/469 [00:54<10:26,  1.45s/it]
# Epoch 2 in training:   8%|▊         | 38/469 [00:55<10:33,  1.47s/it]
# Epoch 2 in training:   8%|▊         | 39/469 [00:57<10:44,  1.50s/it]
# Epoch 2 in training:   9%|▊         | 40/469 [00:58<10:35,  1.48s/it]
# Epoch 2 in training:   9%|▊         | 41/469 [01:00<10:33,  1.48s/it]
# Epoch 2 in training:   9%|▉         | 42/469 [01:01<10:27,  1.47s/it]
# Epoch 2 in training:   9%|▉         | 43/469 [01:03<10:21,  1.46s/it]
# Epoch 2 in training:   9%|▉         | 44/469 [01:04<10:16,  1.45s/it]
# Epoch 2 in training:  10%|▉         | 45/469 [01:05<10:14,  1.45s/it]
# Epoch 2 in training:  10%|▉         | 46/469 [01:07<10:26,  1.48s/it]
# Epoch 2 in training:  10%|█         | 47/469 [01:08<10:18,  1.47s/it]
# Epoch 2 in training:  10%|█         | 48/469 [01:10<10:18,  1.47s/it]
# Epoch 2 in training:  10%|█         | 49/469 [01:11<10:12,  1.46s/it]
# Epoch 2 in training:  11%|█         | 50/469 [01:13<10:09,  1.45s/it]
# Epoch 2 in training:  11%|█         | 51/469 [01:14<10:06,  1.45s/it]
# Epoch 2 in training:  11%|█         | 52/469 [01:16<10:19,  1.49s/it]
# Epoch 2 in training:  11%|█▏        | 53/469 [01:17<10:12,  1.47s/it]
# Epoch 2 in training:  12%|█▏        | 54/469 [01:19<10:10,  1.47s/it]
# Epoch 2 in training:  12%|█▏        | 55/469 [01:20<10:03,  1.46s/it]
# Epoch 2 in training:  12%|█▏        | 56/469 [01:22<09:57,  1.45s/it]
# Epoch 2 in training:  12%|█▏        | 57/469 [01:23<09:54,  1.44s/it]
# Epoch 2 in training:  12%|█▏        | 58/469 [01:24<09:52,  1.44s/it]
# Epoch 2 in training:  13%|█▎        | 59/469 [01:26<10:00,  1.47s/it]
# Epoch 2 in training:  13%|█▎        | 60/469 [01:28<10:12,  1.50s/it]
# Epoch 2 in training:  13%|█▎        | 61/469 [01:29<10:11,  1.50s/it]
# Epoch 2 in training:  13%|█▎        | 62/469 [01:30<10:01,  1.48s/it]
# Epoch 2 in training:  13%|█▎        | 63/469 [01:32<09:56,  1.47s/it]
# Epoch 2 in training:  14%|█▎        | 64/469 [01:33<09:50,  1.46s/it]
# Epoch 2 in training:  14%|█▍        | 65/469 [01:35<09:46,  1.45s/it]
# Epoch 2 in training:  14%|█▍        | 66/469 [01:36<09:43,  1.45s/it]
# Epoch 2 in training:  14%|█▍        | 67/469 [01:38<09:51,  1.47s/it]
# Epoch 2 in training:  14%|█▍        | 68/469 [01:39<09:51,  1.47s/it]
# Epoch 2 in training:  15%|█▍        | 69/469 [01:41<09:46,  1.47s/it]
# Epoch 2 in training:  15%|█▍        | 70/469 [01:42<09:42,  1.46s/it]
# Epoch 2 in training:  15%|█▌        | 71/469 [01:44<09:38,  1.45s/it]
# Epoch 2 in training:  15%|█▌        | 72/469 [01:45<09:37,  1.45s/it]
# Epoch 2 in training:  16%|█▌        | 73/469 [01:47<09:47,  1.48s/it]
# Epoch 2 in training:  16%|█▌        | 74/469 [01:48<09:39,  1.47s/it]
# Epoch 2 in training:  16%|█▌        | 75/469 [01:49<09:38,  1.47s/it]
# Epoch 2 in training:  16%|█▌        | 76/469 [01:51<09:31,  1.46s/it]
# Epoch 2 in training:  16%|█▋        | 77/469 [01:52<09:30,  1.45s/it]
# Epoch 2 in training:  17%|█▋        | 78/469 [01:54<09:28,  1.45s/it]
# Epoch 2 in training:  17%|█▋        | 79/469 [01:55<09:25,  1.45s/it]
# Epoch 2 in training:  17%|█▋        | 80/469 [01:57<09:28,  1.46s/it]
# Epoch 2 in training:  17%|█▋        | 81/469 [01:58<09:40,  1.50s/it]
# Epoch 2 in training:  17%|█▋        | 82/469 [02:00<09:35,  1.49s/it]
# Epoch 2 in training:  18%|█▊        | 83/469 [02:01<09:29,  1.47s/it]
# Epoch 2 in training:  18%|█▊        | 84/469 [02:03<09:24,  1.47s/it]
# Epoch 2 in training:  18%|█▊        | 85/469 [02:04<09:18,  1.45s/it]
# Epoch 2 in training:  18%|█▊        | 86/469 [02:06<09:15,  1.45s/it]
# Epoch 2 in training:  19%|█▊        | 87/469 [02:07<09:11,  1.44s/it]
# Epoch 2 in training:  19%|█▉        | 88/469 [02:08<09:21,  1.47s/it]
# Epoch 2 in training:  19%|█▉        | 89/469 [02:10<09:19,  1.47s/it]
# Epoch 2 in training:  19%|█▉        | 90/469 [02:11<09:14,  1.46s/it]
# Epoch 2 in training:  19%|█▉        | 91/469 [02:13<09:09,  1.45s/it]
# Epoch 2 in training:  20%|█▉        | 92/469 [02:14<09:04,  1.45s/it]
# Epoch 2 in training:  20%|█▉        | 93/469 [02:16<09:01,  1.44s/it]
# Epoch 2 in training:  20%|██        | 94/469 [02:17<09:11,  1.47s/it]
# Epoch 2 in training:  20%|██        | 95/469 [02:19<09:10,  1.47s/it]
# Epoch 2 in training:  20%|██        | 96/469 [02:20<09:05,  1.46s/it]
# Epoch 2 in training:  21%|██        | 97/469 [02:22<09:01,  1.46s/it]
# Epoch 2 in training:  21%|██        | 98/469 [02:23<08:59,  1.45s/it]
# Epoch 2 in training:  21%|██        | 99/469 [02:24<08:54,  1.44s/it]
# Epoch 2 in training:  21%|██▏       | 100/469 [02:26<08:52,  1.44s/it]
# Epoch 2 in training:  22%|██▏       | 101/469 [02:27<08:50,  1.44s/it]
# Epoch 2 in training:  22%|██▏       | 102/469 [02:29<09:13,  1.51s/it]
# Epoch 2 in training:  22%|██▏       | 103/469 [02:30<09:04,  1.49s/it]
# Epoch 2 in training:  22%|██▏       | 104/469 [02:32<08:57,  1.47s/it]
# Epoch 2 in training:  22%|██▏       | 105/469 [02:33<08:50,  1.46s/it]
# Epoch 2 in training:  23%|██▎       | 106/469 [02:35<08:47,  1.45s/it]
# Epoch 2 in training:  23%|██▎       | 107/469 [02:36<08:42,  1.44s/it]
# Epoch 2 in training:  23%|██▎       | 108/469 [02:38<08:39,  1.44s/it]
# Epoch 2 in training:  23%|██▎       | 109/469 [02:39<08:52,  1.48s/it]
# Epoch 2 in training:  23%|██▎       | 110/469 [02:41<08:45,  1.46s/it]
# Epoch 2 in training:  24%|██▎       | 111/469 [02:42<08:41,  1.46s/it]
# Epoch 2 in training:  24%|██▍       | 112/469 [02:43<08:38,  1.45s/it]
# Epoch 2 in training:  24%|██▍       | 113/469 [02:45<08:33,  1.44s/it]
# Epoch 2 in training:  24%|██▍       | 114/469 [02:46<08:30,  1.44s/it]
# Epoch 2 in training:  25%|██▍       | 115/469 [02:48<08:41,  1.47s/it]
# Epoch 2 in training:  25%|██▍       | 116/469 [02:49<08:38,  1.47s/it]
# Epoch 2 in training:  25%|██▍       | 117/469 [02:51<08:34,  1.46s/it]
# Epoch 2 in training:  25%|██▌       | 118/469 [02:52<08:32,  1.46s/it]
# Epoch 2 in training:  25%|██▌       | 119/469 [02:54<08:27,  1.45s/it]
# Epoch 2 in training:  26%|██▌       | 120/469 [02:55<08:24,  1.45s/it]
# Epoch 2 in training:  26%|██▌       | 121/469 [02:57<08:22,  1.45s/it]
# Epoch 2 in training:  26%|██▌       | 122/469 [02:58<08:22,  1.45s/it]
# Epoch 2 in training:  26%|██▌       | 123/469 [03:00<08:43,  1.51s/it]
# Epoch 2 in training:  26%|██▋       | 124/469 [03:01<08:35,  1.49s/it]
# Epoch 2 in training:  27%|██▋       | 125/469 [03:03<08:28,  1.48s/it]
# Epoch 2 in training:  27%|██▋       | 126/469 [03:04<08:22,  1.47s/it]
# Epoch 2 in training:  27%|██▋       | 127/469 [03:05<08:18,  1.46s/it]
# Epoch 2 in training:  27%|██▋       | 128/469 [03:07<08:13,  1.45s/it]
# Epoch 2 in training:  28%|██▊       | 129/469 [03:08<08:12,  1.45s/it]
# Epoch 2 in training:  28%|██▊       | 130/469 [03:10<08:22,  1.48s/it]
# Epoch 2 in training:  28%|██▊       | 131/469 [03:11<08:16,  1.47s/it]
# Epoch 2 in training:  28%|██▊       | 132/469 [03:13<08:11,  1.46s/it]
# Epoch 2 in training:  28%|██▊       | 133/469 [03:14<08:08,  1.45s/it]
# Epoch 2 in training:  29%|██▊       | 134/469 [03:16<08:04,  1.45s/it]
# Epoch 2 in training:  29%|██▉       | 135/469 [03:17<08:02,  1.44s/it]
# Epoch 2 in training:  29%|██▉       | 136/469 [03:19<08:09,  1.47s/it]
# Epoch 2 in training:  29%|██▉       | 137/469 [03:20<08:05,  1.46s/it]
# Epoch 2 in training:  29%|██▉       | 138/469 [03:21<08:02,  1.46s/it]
# Epoch 2 in training:  30%|██▉       | 139/469 [03:23<07:58,  1.45s/it]
# Epoch 2 in training:  30%|██▉       | 140/469 [03:24<07:55,  1.44s/it]
# Epoch 2 in training:  30%|███       | 141/469 [03:26<07:54,  1.45s/it]
# Epoch 2 in training:  30%|███       | 142/469 [03:27<07:51,  1.44s/it]
# Epoch 2 in training:  30%|███       | 143/469 [03:29<07:54,  1.46s/it]
# Epoch 2 in training:  31%|███       | 144/469 [03:30<08:08,  1.50s/it]
# Epoch 2 in training:  31%|███       | 145/469 [03:32<08:01,  1.49s/it]
# Epoch 2 in training:  31%|███       | 146/469 [03:33<07:54,  1.47s/it]
# Epoch 2 in training:  31%|███▏      | 147/469 [03:35<07:49,  1.46s/it]
# Epoch 2 in training:  32%|███▏      | 148/469 [03:36<07:46,  1.45s/it]
# Epoch 2 in training:  32%|███▏      | 149/469 [03:37<07:42,  1.45s/it]
# Epoch 2 in training:  32%|███▏      | 150/469 [03:39<07:43,  1.45s/it]
# Epoch 2 in training:  32%|███▏      | 151/469 [03:41<07:50,  1.48s/it]
# Epoch 2 in training:  32%|███▏      | 152/469 [03:42<07:44,  1.47s/it]
# Epoch 2 in training:  33%|███▎      | 153/469 [03:43<07:40,  1.46s/it]
# Epoch 2 in training:  33%|███▎      | 154/469 [03:45<07:36,  1.45s/it]
# Epoch 2 in training:  33%|███▎      | 155/469 [03:46<07:33,  1.45s/it]
# Epoch 2 in training:  33%|███▎      | 156/469 [03:48<07:32,  1.44s/it]
# Epoch 2 in training:  33%|███▎      | 157/469 [03:49<07:42,  1.48s/it]
# Epoch 2 in training:  34%|███▎      | 158/469 [03:51<07:36,  1.47s/it]
# Epoch 2 in training:  34%|███▍      | 159/469 [03:52<07:32,  1.46s/it]
# Epoch 2 in training:  34%|███▍      | 160/469 [03:54<07:28,  1.45s/it]
# Epoch 2 in training:  34%|███▍      | 161/469 [03:55<07:27,  1.45s/it]
# Epoch 2 in training:  35%|███▍      | 162/469 [03:56<07:24,  1.45s/it]
# Epoch 2 in training:  35%|███▍      | 163/469 [03:58<07:22,  1.44s/it]
# Epoch 2 in training:  35%|███▍      | 164/469 [03:59<07:23,  1.45s/it]
# Epoch 2 in training:  35%|███▌      | 165/469 [04:01<07:33,  1.49s/it]
# Epoch 2 in training:  35%|███▌      | 166/469 [04:02<07:31,  1.49s/it]
# Epoch 2 in training:  36%|███▌      | 167/469 [04:04<07:26,  1.48s/it]
# Epoch 2 in training:  36%|███▌      | 168/469 [04:05<07:20,  1.46s/it]
# Epoch 2 in training:  36%|███▌      | 169/469 [04:07<07:15,  1.45s/it]
# Epoch 2 in training:  36%|███▌      | 170/469 [04:08<07:12,  1.45s/it]
# Epoch 2 in training:  36%|███▋      | 171/469 [04:10<07:12,  1.45s/it]
# Epoch 2 in training:  37%|███▋      | 172/469 [04:11<07:18,  1.47s/it]
# Epoch 2 in training:  37%|███▋      | 173/469 [04:13<07:12,  1.46s/it]
# Epoch 2 in training:  37%|███▋      | 174/469 [04:14<07:08,  1.45s/it]
# Epoch 2 in training:  37%|███▋      | 175/469 [04:15<07:04,  1.44s/it]
# Epoch 2 in training:  38%|███▊      | 176/469 [04:17<07:03,  1.44s/it]
# Epoch 2 in training:  38%|███▊      | 177/469 [04:18<07:00,  1.44s/it]
# Epoch 2 in training:  38%|███▊      | 178/469 [04:20<07:09,  1.48s/it]
# Epoch 2 in training:  38%|███▊      | 179/469 [04:21<07:05,  1.47s/it]
# Epoch 2 in training:  38%|███▊      | 180/469 [04:23<07:00,  1.46s/it]
# Epoch 2 in training:  39%|███▊      | 181/469 [04:24<06:58,  1.45s/it]
# Epoch 2 in training:  39%|███▉      | 182/469 [04:26<06:55,  1.45s/it]
# Epoch 2 in training:  39%|███▉      | 183/469 [04:27<06:53,  1.44s/it]
# Epoch 2 in training:  39%|███▉      | 184/469 [04:29<06:53,  1.45s/it]
# Epoch 2 in training:  39%|███▉      | 185/469 [04:30<06:53,  1.46s/it]
# Epoch 2 in training:  40%|███▉      | 186/469 [04:32<06:58,  1.48s/it]
# Epoch 2 in training:  40%|███▉      | 187/469 [04:33<07:00,  1.49s/it]
# Epoch 2 in training:  40%|████      | 188/469 [04:35<06:54,  1.47s/it]
# Epoch 2 in training:  40%|████      | 189/469 [04:36<06:49,  1.46s/it]
# Epoch 2 in training:  41%|████      | 190/469 [04:37<06:46,  1.46s/it]
# Epoch 2 in training:  41%|████      | 191/469 [04:39<06:46,  1.46s/it]
# Epoch 2 in training:  41%|████      | 192/469 [04:40<06:42,  1.45s/it]
# Epoch 2 in training:  41%|████      | 193/469 [04:42<06:50,  1.49s/it]
# Epoch 2 in training:  41%|████▏     | 194/469 [04:43<06:45,  1.47s/it]
# Epoch 2 in training:  42%|████▏     | 195/469 [04:45<06:40,  1.46s/it]
# Epoch 2 in training:  42%|████▏     | 196/469 [04:46<06:40,  1.47s/it]
# Epoch 2 in training:  42%|████▏     | 197/469 [04:48<06:36,  1.46s/it]
# Epoch 2 in training:  42%|████▏     | 198/469 [04:49<06:35,  1.46s/it]
# Epoch 2 in training:  42%|████▏     | 199/469 [04:51<06:42,  1.49s/it]
# Epoch 2 in training:  43%|████▎     | 200/469 [04:52<06:36,  1.47s/it]
# Epoch 2 in training:  43%|████▎     | 201/469 [04:54<06:31,  1.46s/it]
# Epoch 2 in training:  43%|████▎     | 202/469 [04:55<06:29,  1.46s/it]
# Epoch 2 in training:  43%|████▎     | 203/469 [04:56<06:25,  1.45s/it]
# Epoch 2 in training:  43%|████▎     | 204/469 [04:58<06:23,  1.45s/it]
# Epoch 2 in training:  44%|████▎     | 205/469 [04:59<06:23,  1.45s/it]
# Epoch 2 in training:  44%|████▍     | 206/469 [05:01<06:20,  1.44s/it]
# ...
# Epoch 10 in training:  54%|█████▎    | 251/469 [06:06<05:17,  1.45s/it]
# Epoch 10 in training:  54%|█████▎    | 252/469 [06:08<05:13,  1.45s/it]
# Epoch 10 in training:  54%|█████▍    | 253/469 [06:09<05:11,  1.44s/it]
# Epoch 10 in training:  54%|█████▍    | 254/469 [06:11<05:19,  1.48s/it]
# Epoch 10 in training:  54%|█████▍    | 255/469 [06:12<05:14,  1.47s/it]
# Epoch 10 in training:  55%|█████▍    | 256/469 [06:13<05:11,  1.46s/it]
# Epoch 10 in training:  55%|█████▍    | 257/469 [06:15<05:08,  1.45s/it]
# Epoch 10 in training:  55%|█████▌    | 258/469 [06:16<05:05,  1.45s/it]
# Epoch 10 in training:  55%|█████▌    | 259/469 [06:18<05:03,  1.44s/it]
# Epoch 10 in training:  55%|█████▌    | 260/469 [06:19<05:02,  1.45s/it]
# Epoch 10 in training:  56%|█████▌    | 261/469 [06:21<05:09,  1.49s/it]
# Epoch 10 in training:  56%|█████▌    | 262/469 [06:22<05:05,  1.47s/it]
# Epoch 10 in training:  56%|█████▌    | 263/469 [06:24<05:01,  1.46s/it]
# Epoch 10 in training:  56%|█████▋    | 264/469 [06:25<04:58,  1.45s/it]
# Epoch 10 in training:  57%|█████▋    | 265/469 [06:27<04:55,  1.45s/it]
# Epoch 10 in training:  57%|█████▋    | 266/469 [06:28<04:58,  1.47s/it]
# Epoch 10 in training:  57%|█████▋    | 267/469 [06:30<05:01,  1.49s/it]
# Epoch 10 in training:  57%|█████▋    | 268/469 [06:31<04:58,  1.49s/it]
# Epoch 10 in training:  57%|█████▋    | 269/469 [06:33<04:53,  1.47s/it]
# Epoch 10 in training:  58%|█████▊    | 270/469 [06:34<04:49,  1.46s/it]
# Epoch 10 in training:  58%|█████▊    | 271/469 [06:35<04:47,  1.45s/it]
# Epoch 10 in training:  58%|█████▊    | 272/469 [06:37<04:45,  1.45s/it]
# Epoch 10 in training:  58%|█████▊    | 273/469 [06:38<04:43,  1.45s/it]
# Epoch 10 in training:  58%|█████▊    | 274/469 [06:40<04:40,  1.44s/it]
# Epoch 10 in training:  59%|█████▊    | 275/469 [06:41<04:47,  1.48s/it]
# Epoch 10 in training:  59%|█████▉    | 276/469 [06:43<04:43,  1.47s/it]
# Epoch 10 in training:  59%|█████▉    | 277/469 [06:44<04:40,  1.46s/it]
# Epoch 10 in training:  59%|█████▉    | 278/469 [06:46<04:37,  1.45s/it]
# Epoch 10 in training:  59%|█████▉    | 279/469 [06:47<04:34,  1.45s/it]
# Epoch 10 in training:  60%|█████▉    | 280/469 [06:48<04:33,  1.45s/it]
# Epoch 10 in training:  60%|█████▉    | 281/469 [06:50<04:31,  1.44s/it]
# Epoch 10 in training:  60%|██████    | 282/469 [06:51<04:37,  1.48s/it]
# Epoch 10 in training:  60%|██████    | 283/469 [06:53<04:33,  1.47s/it]
# Epoch 10 in training:  61%|██████    | 284/469 [06:54<04:30,  1.46s/it]
# Epoch 10 in training:  61%|██████    | 285/469 [06:56<04:27,  1.45s/it]
# Epoch 10 in training:  61%|██████    | 286/469 [06:57<04:25,  1.45s/it]
# Epoch 10 in training:  61%|██████    | 287/469 [06:59<04:22,  1.44s/it]
# Epoch 10 in training:  61%|██████▏   | 288/469 [07:00<04:31,  1.50s/it]
# Epoch 10 in training:  62%|██████▏   | 289/469 [07:02<04:25,  1.48s/it]
# Epoch 10 in training:  62%|██████▏   | 290/469 [07:03<04:21,  1.46s/it]
# Epoch 10 in training:  62%|██████▏   | 291/469 [07:05<04:18,  1.45s/it]
# Epoch 10 in training:  62%|██████▏   | 292/469 [07:06<04:16,  1.45s/it]
# Epoch 10 in training:  62%|██████▏   | 293/469 [07:07<04:14,  1.44s/it]
# Epoch 10 in training:  63%|██████▎   | 294/469 [07:09<04:12,  1.44s/it]
# Epoch 10 in training:  63%|██████▎   | 295/469 [07:10<04:11,  1.45s/it]
# Epoch 10 in training:  63%|██████▎   | 296/469 [07:12<04:15,  1.48s/it]
# Epoch 10 in training:  63%|██████▎   | 297/469 [07:13<04:11,  1.46s/it]
# Epoch 10 in training:  64%|██████▎   | 298/469 [07:15<04:08,  1.45s/it]
# Epoch 10 in training:  64%|██████▍   | 299/469 [07:16<04:05,  1.44s/it]
# Epoch 10 in training:  64%|██████▍   | 300/469 [07:18<04:03,  1.44s/it]
# Epoch 10 in training:  64%|██████▍   | 301/469 [07:19<04:01,  1.44s/it]
# Epoch 10 in training:  64%|██████▍   | 302/469 [07:20<04:01,  1.45s/it]
# Epoch 10 in training:  65%|██████▍   | 303/469 [07:22<04:04,  1.47s/it]
# Epoch 10 in training:  65%|██████▍   | 304/469 [07:23<04:00,  1.46s/it]
# Epoch 10 in training:  65%|██████▌   | 305/469 [07:25<03:58,  1.45s/it]
# Epoch 10 in training:  65%|██████▌   | 306/469 [07:26<03:55,  1.44s/it]
# Epoch 10 in training:  65%|██████▌   | 307/469 [07:28<03:54,  1.45s/it]
# Epoch 10 in training:  66%|██████▌   | 308/469 [07:29<03:52,  1.44s/it]
# Epoch 10 in training:  66%|██████▌   | 309/469 [07:31<04:00,  1.50s/it]
# Epoch 10 in training:  66%|██████▌   | 310/469 [07:32<03:56,  1.49s/it]
# Epoch 10 in training:  66%|██████▋   | 311/469 [07:34<03:52,  1.47s/it]
# Epoch 10 in training:  67%|██████▋   | 312/469 [07:35<03:49,  1.46s/it]
# Epoch 10 in training:  67%|██████▋   | 313/469 [07:37<03:46,  1.45s/it]
# Epoch 10 in training:  67%|██████▋   | 314/469 [07:38<03:44,  1.45s/it]
# Epoch 10 in training:  67%|██████▋   | 315/469 [07:39<03:42,  1.45s/it]
# Epoch 10 in training:  67%|██████▋   | 316/469 [07:41<03:42,  1.46s/it]
# Epoch 10 in training:  68%|██████▊   | 317/469 [07:43<03:45,  1.48s/it]
# Epoch 10 in training:  68%|██████▊   | 318/469 [07:44<03:41,  1.47s/it]
# Epoch 10 in training:  68%|██████▊   | 319/469 [07:45<03:39,  1.46s/it]
# Epoch 10 in training:  68%|██████▊   | 320/469 [07:47<03:36,  1.45s/it]
# Epoch 10 in training:  68%|██████▊   | 321/469 [07:48<03:33,  1.44s/it]
# Epoch 10 in training:  69%|██████▊   | 322/469 [07:50<03:32,  1.44s/it]
# Epoch 10 in training:  69%|██████▉   | 323/469 [07:51<03:31,  1.45s/it]
# Epoch 10 in training:  69%|██████▉   | 324/469 [07:53<03:34,  1.48s/it]
# Epoch 10 in training:  69%|██████▉   | 325/469 [07:54<03:30,  1.46s/it]
# Epoch 10 in training:  70%|██████▉   | 326/469 [07:56<03:27,  1.45s/it]
# Epoch 10 in training:  70%|██████▉   | 327/469 [07:57<03:25,  1.45s/it]
# Epoch 10 in training:  70%|██████▉   | 328/469 [07:58<03:23,  1.44s/it]
# Epoch 10 in training:  70%|███████   | 329/469 [08:00<03:21,  1.44s/it]
# Epoch 10 in training:  70%|███████   | 330/469 [08:01<03:28,  1.50s/it]
# Epoch 10 in training:  71%|███████   | 331/469 [08:03<03:24,  1.48s/it]
# Epoch 10 in training:  71%|███████   | 332/469 [08:04<03:20,  1.47s/it]
# Epoch 10 in training:  71%|███████   | 333/469 [08:06<03:17,  1.46s/it]
# Epoch 10 in training:  71%|███████   | 334/469 [08:07<03:15,  1.45s/it]
# Epoch 10 in training:  71%|███████▏  | 335/469 [08:09<03:12,  1.44s/it]
# Epoch 10 in training:  72%|███████▏  | 336/469 [08:10<03:12,  1.45s/it]
# Epoch 10 in training:  72%|███████▏  | 337/469 [08:12<03:10,  1.44s/it]
# Epoch 10 in training:  72%|███████▏  | 338/469 [08:13<03:12,  1.47s/it]
# Epoch 10 in training:  72%|███████▏  | 339/469 [08:15<03:09,  1.46s/it]
# Epoch 10 in training:  72%|███████▏  | 340/469 [08:16<03:07,  1.45s/it]
# Epoch 10 in training:  73%|███████▎  | 341/469 [08:17<03:04,  1.44s/it]
# Epoch 10 in training:  73%|███████▎  | 342/469 [08:19<03:02,  1.44s/it]
# Epoch 10 in training:  73%|███████▎  | 343/469 [08:20<03:01,  1.44s/it]
# Epoch 10 in training:  73%|███████▎  | 344/469 [08:22<03:00,  1.44s/it]
# Epoch 10 in training:  74%|███████▎  | 345/469 [08:23<03:02,  1.47s/it]
# Epoch 10 in training:  74%|███████▍  | 346/469 [08:25<02:59,  1.46s/it]
# Epoch 10 in training:  74%|███████▍  | 347/469 [08:26<02:57,  1.45s/it]
# Epoch 10 in training:  74%|███████▍  | 348/469 [08:28<02:55,  1.45s/it]
# Epoch 10 in training:  74%|███████▍  | 349/469 [08:29<02:53,  1.44s/it]
# Epoch 10 in training:  75%|███████▍  | 350/469 [08:30<02:52,  1.45s/it]
# Epoch 10 in training:  75%|███████▍  | 351/469 [08:32<02:54,  1.48s/it]
# Epoch 10 in training:  75%|███████▌  | 352/469 [08:33<02:54,  1.49s/it]
# Epoch 10 in training:  75%|███████▌  | 353/469 [08:35<02:50,  1.47s/it]
# Epoch 10 in training:  75%|███████▌  | 354/469 [08:36<02:47,  1.46s/it]
# Epoch 10 in training:  76%|███████▌  | 355/469 [08:38<02:45,  1.45s/it]
# Epoch 10 in training:  76%|███████▌  | 356/469 [08:39<02:42,  1.44s/it]
# Epoch 10 in training:  76%|███████▌  | 357/469 [08:41<02:42,  1.45s/it]
# Epoch 10 in training:  76%|███████▋  | 358/469 [08:42<02:41,  1.45s/it]
# Epoch 10 in training:  77%|███████▋  | 359/469 [08:44<02:42,  1.48s/it]
# Epoch 10 in training:  77%|███████▋  | 360/469 [08:45<02:39,  1.46s/it]
# Epoch 10 in training:  77%|███████▋  | 361/469 [08:47<02:36,  1.45s/it]
# Epoch 10 in training:  77%|███████▋  | 362/469 [08:48<02:34,  1.45s/it]
# Epoch 10 in training:  77%|███████▋  | 363/469 [08:49<02:32,  1.44s/it]
# Epoch 10 in training:  78%|███████▊  | 364/469 [08:51<02:31,  1.45s/it]
# Epoch 10 in training:  78%|███████▊  | 365/469 [08:52<02:30,  1.44s/it]
# Epoch 10 in training:  78%|███████▊  | 366/469 [08:54<02:31,  1.47s/it]
# Epoch 10 in training:  78%|███████▊  | 367/469 [08:55<02:29,  1.46s/it]
# Epoch 10 in training:  78%|███████▊  | 368/469 [08:57<02:26,  1.45s/it]
# Epoch 10 in training:  79%|███████▊  | 369/469 [08:58<02:24,  1.45s/it]
# Epoch 10 in training:  79%|███████▉  | 370/469 [09:00<02:22,  1.44s/it]
# Epoch 10 in training:  79%|███████▉  | 371/469 [09:01<02:22,  1.45s/it]
# Epoch 10 in training:  79%|███████▉  | 372/469 [09:03<02:23,  1.48s/it]
# Epoch 10 in training:  80%|███████▉  | 373/469 [09:04<02:22,  1.49s/it]
# Epoch 10 in training:  80%|███████▉  | 374/469 [09:05<02:19,  1.47s/it]
# Epoch 10 in training:  80%|███████▉  | 375/469 [09:07<02:16,  1.46s/it]
# Epoch 10 in training:  80%|████████  | 376/469 [09:08<02:14,  1.45s/it]
# Epoch 10 in training:  80%|████████  | 377/469 [09:10<02:13,  1.45s/it]
# Epoch 10 in training:  81%|████████  | 378/469 [09:11<02:11,  1.45s/it]
# Epoch 10 in training:  81%|████████  | 379/469 [09:13<02:09,  1.44s/it]
# Epoch 10 in training:  81%|████████  | 380/469 [09:14<02:11,  1.48s/it]
# Epoch 10 in training:  81%|████████  | 381/469 [09:16<02:08,  1.46s/it]
# Epoch 10 in training:  81%|████████▏ | 382/469 [09:17<02:06,  1.45s/it]
# Epoch 10 in training:  82%|████████▏ | 383/469 [09:19<02:04,  1.45s/it]
# Epoch 10 in training:  82%|████████▏ | 384/469 [09:20<02:02,  1.44s/it]
# Epoch 10 in training:  82%|████████▏ | 385/469 [09:21<02:01,  1.45s/it]
# Epoch 10 in training:  82%|████████▏ | 386/469 [09:23<01:59,  1.44s/it]
# Epoch 10 in training:  83%|████████▎ | 387/469 [09:24<02:00,  1.47s/it]
# Epoch 10 in training:  83%|████████▎ | 388/469 [09:26<01:58,  1.46s/it]
# Epoch 10 in training:  83%|████████▎ | 389/469 [09:27<01:56,  1.45s/it]
# Epoch 10 in training:  83%|████████▎ | 390/469 [09:29<01:54,  1.44s/it]
# Epoch 10 in training:  83%|████████▎ | 391/469 [09:30<01:53,  1.45s/it]
# Epoch 10 in training:  84%|████████▎ | 392/469 [09:32<01:51,  1.44s/it]
# Epoch 10 in training:  84%|████████▍ | 393/469 [09:33<01:51,  1.47s/it]
# Epoch 10 in training:  84%|████████▍ | 394/469 [09:35<01:50,  1.47s/it]
# Epoch 10 in training:  84%|████████▍ | 395/469 [09:36<01:48,  1.47s/it]
# Epoch 10 in training:  84%|████████▍ | 396/469 [09:37<01:46,  1.46s/it]
# Epoch 10 in training:  85%|████████▍ | 397/469 [09:39<01:44,  1.45s/it]
# Epoch 10 in training:  85%|████████▍ | 398/469 [09:40<01:43,  1.45s/it]
# Epoch 10 in training:  85%|████████▌ | 399/469 [09:42<01:41,  1.45s/it]
# Epoch 10 in training:  85%|████████▌ | 400/469 [09:43<01:39,  1.45s/it]
# Epoch 10 in training:  86%|████████▌ | 401/469 [09:45<01:40,  1.47s/it]
# Epoch 10 in training:  86%|████████▌ | 402/469 [09:46<01:37,  1.46s/it]
# Epoch 10 in training:  86%|████████▌ | 403/469 [09:48<01:35,  1.45s/it]
# Epoch 10 in training:  86%|████████▌ | 404/469 [09:49<01:33,  1.44s/it]
# Epoch 10 in training:  86%|████████▋ | 405/469 [09:51<01:32,  1.45s/it]
# Epoch 10 in training:  87%|████████▋ | 406/469 [09:52<01:31,  1.45s/it]
# Epoch 10 in training:  87%|████████▋ | 407/469 [09:53<01:29,  1.44s/it]
# Epoch 10 in training:  87%|████████▋ | 408/469 [09:55<01:29,  1.47s/it]
# Epoch 10 in training:  87%|████████▋ | 409/469 [09:56<01:28,  1.47s/it]
# Epoch 10 in training:  87%|████████▋ | 410/469 [09:58<01:26,  1.46s/it]
# Epoch 10 in training:  88%|████████▊ | 411/469 [09:59<01:24,  1.45s/it]
# Epoch 10 in training:  88%|████████▊ | 412/469 [10:01<01:23,  1.46s/it]
# Epoch 10 in training:  88%|████████▊ | 413/469 [10:02<01:21,  1.45s/it]
# Epoch 10 in training:  88%|████████▊ | 414/469 [10:04<01:21,  1.48s/it]
# Epoch 10 in training:  88%|████████▊ | 415/469 [10:05<01:19,  1.47s/it]
# Epoch 10 in training:  89%|████████▊ | 416/469 [10:07<01:18,  1.48s/it]
# Epoch 10 in training:  89%|████████▉ | 417/469 [10:08<01:16,  1.47s/it]
# Epoch 10 in training:  89%|████████▉ | 418/469 [10:10<01:14,  1.47s/it]
# Epoch 10 in training:  89%|████████▉ | 419/469 [10:11<01:13,  1.46s/it]
# Epoch 10 in training:  90%|████████▉ | 420/469 [10:12<01:11,  1.46s/it]
# Epoch 10 in training:  90%|████████▉ | 421/469 [10:14<01:09,  1.45s/it]
# Epoch 10 in training:  90%|████████▉ | 422/469 [10:15<01:09,  1.48s/it]
# Epoch 10 in training:  90%|█████████ | 423/469 [10:17<01:07,  1.47s/it]
# Epoch 10 in training:  90%|█████████ | 424/469 [10:18<01:05,  1.46s/it]
# Epoch 10 in training:  91%|█████████ | 425/469 [10:20<01:03,  1.45s/it]
# Epoch 10 in training:  91%|█████████ | 426/469 [10:21<01:02,  1.46s/it]
# Epoch 10 in training:  91%|█████████ | 427/469 [10:23<01:00,  1.45s/it]
# Epoch 10 in training:  91%|█████████▏| 428/469 [10:24<00:59,  1.45s/it]
# Epoch 10 in training:  91%|█████████▏| 429/469 [10:26<00:58,  1.47s/it]
# Epoch 10 in training:  92%|█████████▏| 430/469 [10:27<00:57,  1.46s/it]
# Epoch 10 in training:  92%|█████████▏| 431/469 [10:29<00:55,  1.45s/it]
# Epoch 10 in training:  92%|█████████▏| 432/469 [10:30<00:53,  1.45s/it]
# Epoch 10 in training:  92%|█████████▏| 433/469 [10:31<00:52,  1.46s/it]
# Epoch 10 in training:  93%|█████████▎| 434/469 [10:33<00:50,  1.45s/it]
# Epoch 10 in training:  93%|█████████▎| 435/469 [10:34<00:50,  1.48s/it]
# Epoch 10 in training:  93%|█████████▎| 436/469 [10:36<00:48,  1.46s/it]
# Epoch 10 in training:  93%|█████████▎| 437/469 [10:37<00:47,  1.48s/it]
# Epoch 10 in training:  93%|█████████▎| 438/469 [10:39<00:45,  1.47s/it]
# Epoch 10 in training:  94%|█████████▎| 439/469 [10:40<00:44,  1.47s/it]
# Epoch 10 in training:  94%|█████████▍| 440/469 [10:42<00:42,  1.46s/it]
# Epoch 10 in training:  94%|█████████▍| 441/469 [10:43<00:40,  1.46s/it]
# Epoch 10 in training:  94%|█████████▍| 442/469 [10:45<00:39,  1.45s/it]
# Epoch 10 in training:  94%|█████████▍| 443/469 [10:46<00:38,  1.48s/it]
# Epoch 10 in training:  95%|█████████▍| 444/469 [10:48<00:36,  1.47s/it]
# Epoch 10 in training:  95%|█████████▍| 445/469 [10:49<00:34,  1.46s/it]
# Epoch 10 in training:  95%|█████████▌| 446/469 [10:50<00:33,  1.46s/it]
# Epoch 10 in training:  95%|█████████▌| 447/469 [10:52<00:31,  1.45s/it]
# Epoch 10 in training:  96%|█████████▌| 448/469 [10:53<00:30,  1.44s/it]
# Epoch 10 in training:  96%|█████████▌| 449/469 [10:55<00:28,  1.44s/it]
# Epoch 10 in training:  96%|█████████▌| 450/469 [10:56<00:27,  1.47s/it]
# Epoch 10 in training:  96%|█████████▌| 451/469 [10:58<00:26,  1.46s/it]
# Epoch 10 in training:  96%|█████████▋| 452/469 [10:59<00:24,  1.45s/it]
# Epoch 10 in training:  97%|█████████▋| 453/469 [11:01<00:23,  1.46s/it]
# Epoch 10 in training:  97%|█████████▋| 454/469 [11:02<00:21,  1.45s/it]
# Epoch 10 in training:  97%|█████████▋| 455/469 [11:04<00:20,  1.45s/it]
# Epoch 10 in training:  97%|█████████▋| 456/469 [11:05<00:19,  1.48s/it]
# Epoch 10 in training:  97%|█████████▋| 457/469 [11:07<00:17,  1.47s/it]
# Epoch 10 in training:  98%|█████████▊| 458/469 [11:08<00:16,  1.47s/it]
# Epoch 10 in training:  98%|█████████▊| 459/469 [11:09<00:14,  1.47s/it]
# Epoch 10 in training:  98%|█████████▊| 460/469 [11:11<00:13,  1.47s/it]
# Epoch 10 in training:  98%|█████████▊| 461/469 [11:12<00:11,  1.46s/it]
# Epoch 10 in training:  99%|█████████▊| 462/469 [11:14<00:10,  1.45s/it]
# Epoch 10 in training:  99%|█████████▊| 463/469 [11:15<00:08,  1.45s/it]
# Epoch 10 in training:  99%|█████████▉| 464/469 [11:17<00:07,  1.48s/it]
# Epoch 10 in training:  99%|█████████▉| 465/469 [11:18<00:05,  1.47s/it]
# Epoch 10 in training:  99%|█████████▉| 466/469 [11:20<00:04,  1.46s/it]
# Epoch 10 in training: 100%|█████████▉| 467/469 [11:21<00:02,  1.46s/it]
# Epoch 10 in training: 100%|█████████▉| 468/469 [11:23<00:01,  1.45s/it]
# Epoch 10 in training: 100%|██████████| 469/469 [11:24<00:00,  1.34s/it]
# train: 100%|██████████| 10/10 [1:54:50<00:00, 689.08s/it]
# Epoch 10/10 loss: 2.23
# Testing: 100%|██████████| 79/79 [00:49<00:00,  1.59it/s]
# Test loss: 2.23
# Test accuracy: 20.33%

# %%
path: str = "fourierkan_vit_10epochs.pth"

torch.save(mnist_model.state_dict(), path)
