# %%
import numpy 
from generate_bsplines import generate_bspline, visualize_spline

# %%
X = numpy.random.uniform(-10, 10, 10)
y = numpy.random.uniform(-10, 10, 10)

# %%
line, spline = generate_bspline(X, y, s=0, k=4, N=100)
line, spline
# Out:
# (array([-8.03617445, -7.87936161, -7.72254877, -7.56573593, -7.40892309,
#         -7.25211025, -7.09529741, -6.93848457, -6.78167173, -6.62485889,
#         -6.46804605, -6.31123321, -6.15442037, -5.99760753, -5.84079469,
#         -5.68398185, -5.52716901, -5.37035617, -5.21354333, -5.05673049,
#         -4.89991765, -4.74310481, -4.58629197, -4.42947913, -4.27266628,
#         -4.11585344, -3.9590406 , -3.80222776, -3.64541492, -3.48860208,
#         -3.33178924, -3.1749764 , -3.01816356, -2.86135072, -2.70453788,
#         -2.54772504, -2.3909122 , -2.23409936, -2.07728652, -1.92047368,
#         -1.76366084, -1.606848  , -1.45003516, -1.29322232, -1.13640948,
#         -0.97959664, -0.8227838 , -0.66597096, -0.50915812, -0.35234528,
#         -0.19553244, -0.0387196 ,  0.11809324,  0.27490608,  0.43171892,
#          0.58853176,  0.7453446 ,  0.90215744,  1.05897028,  1.21578312,
#          1.37259596,  1.5294088 ,  1.68622164,  1.84303448,  1.99984732,
# ...

# %%
visualize_spline(X, y, line, spline)
